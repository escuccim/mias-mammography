# %%
import numpy as np
import PIL
import os
import matplotlib.pyplot as plt

# %%
A = np.array([0.53, 0.34, 0.13])
B = np.array([.46, .43, .11])
C = np.array([.62, .29, .9])

# %%
A_ = np.linalg.norm(A)
B_ = np.linalg.norm(B)
C_ = np.linalg.norm(C)

# %%
foo = 0.53 ** 2 + 0.34 ** 2 + 0.13 ** 2
np.sqrt(foo)
# Out:
# 0.6429618962271404

# %%
A_
# Out:
# 0.6429618962271404

# %%
def cosine_sim(X, Y):
    top = np.dot(X, Y)
    bottom = np.linalg.norm(X) * np.linalg.norm(Y)
    
    return top / bottom

# %%
print("A + B", cosine_sim(A, B))
print("A + C", cosine_sim(A, C))
# Out:
# A + B 0.9837150687217671
# A + C 0.7485536547638625

# %%
image_dir = "C:\\Users\\eric\\Documents\\Courses\\Applied ML 2\\mammography\\data\\train_images2"
file = "P_00266_LEFT_CC_289_cropped.png"

image = np.array(PIL.Image.open(os.path.join(image_dir, file)))

plt.imshow(image[:,:,0])
plt.show()

plt.imshow(image[:,:,1])
plt.show()
