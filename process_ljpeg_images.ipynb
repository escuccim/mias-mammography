# %%
import os
from mammo_utils import copy_subdirectories_to_directory, convert_png_to_jpg
import shutil
from PIL import Image, ImageMath

# %%
# copy the files from the subdirectories to another directory so they are all in the same place
copy_subdirectories_to_directory("C:\\Users\\eric\\Documents\\Courses\\DDSM\\normal_06\\", "C:\\Users\\eric\\Documents\\Courses\\DDSM\\AllFiles_06\\")

# %%
# to convert the ljpegs to pngs we need to run a python script from a CygWin prompt
# I used this package to do this: https://github.com/zizo202/Decompressing-For-LJPEG-image
# this process takes rather a long time

# %%
# now convert the pngs to jpegs and resize them. I wrote a function to convert them, but ended up doing the process in Photoshop
# as it was easier to do the conversion and resizing while maintaining the quality there

# %%
## load an image
img = Image.open("C:\\Users\\eric\\Documents\\Courses\\Applied ML 2\\mammography\\data\\new\\DDSM\\DBA pngs\\A_0366_1.LEFT_CC.LJPEG.png")
img2 = ImageMath.eval('im/256', {'im':img}).convert('L')

# %%
plt.imshow(img2)

# %%
im_array = np.array(img2)
im_array[im_array == 255] = 0

# %%
plt.imshow(im_array)
