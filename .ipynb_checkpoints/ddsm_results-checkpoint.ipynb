# %% [markdown]
# The results for selected model training runs are included below. The full logs are in "model notes.xlsx".
#
# Model 1.0.0.35b.96 had the best performance in scoring high accuracy and recall and generalizing well to the MIAS data. We would guess that this is because it was trained on Dataset 9 which did not resize the raw images depending on the size of the ROI.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ddsm_results = pd.read_csv("ddsm_results.csv")

# %%
# Results sorted by best accuracy
ddsm_results.sort_values("Test Accuracy", inplace=True, ascending=False)
ddsm_results
# Out:
#                  Model Classification  Dataset  XE Weight  Initialization  \
# 0          1.0.0.29b.8              B        8          2         Scratch
# 14       1.0.0.46b.8.4              B        8          2     1.0.0.46b.6
# 17        1.0.0.35b.98              B        9          6         Scratch
# 3         1.0.0.29l.14              L        6          2         Scratch
# 1          1.0.0.29l.8              L        8          2         Scratch
# 4       vgg_16.3.04b.9              B        9          2         Scratch
# 6     vgg_16.3.04b.8.1              B        8          2  vgg_16.3.04l.6
# 10       1.0.0.46b.8.2              B        8          2     1.0.0.46l.8
# 15       1.0.0.28.2b.9              B        9          2         Scratch
# 16        1.0.0.35b.94              B        9          4         Scratch
# 5       vgg_16.3.04l.6              L        6          2         Scratch
# 2          1.0.0.29g.6              B        6          2         Scratch
# 7          1.0.0.46b.9              B        9          2         Scratch
# 18      vgg_16.3.06b.9              B        9          6         Scratch
# 8          1.0.0.46b.8              B        8          2         Scratch
# 13  inception_v4.05b.9              B        9          2         Scratch
# 12         1.0.0.46l.6              L        6          2         Scratch
# 11         1.0.0.46b.6              B        6          2         Scratch
# 9          1.0.0.46l.8              L        8          2         Scratch
#
#    Layers  Epochs  Baseline  Test Accuracy  Test Recall  MIAS Acc  \
# 0     All      30    0.8333         0.9930       1.0000    0.2189
# 14    All      10    0.8333         0.9896       0.9776    0.2746
# 17    All      35    0.8333         0.9571       0.9012    0.8802
# 3     All      40    0.8376         0.9142       0.9353    0.1665
# 1     All      35    0.8333         0.8890       0.9092    0.1462
# 4     All      30    0.8333         0.8881       0.3589    0.9314
# 6      FC       5    0.8333         0.8747       0.2951    0.3986
# 10     FC       5    0.8333         0.8711       0.9434    0.2535
# 15    All      20    0.8333         0.8675       0.2756    0.9165
# 16    All      30    0.8333         0.8502       0.7438    0.7328
# 5     All      20    0.8376         0.8333       0.0288    0.4783
# 2     All      35    0.8376         0.8299       0.0477    0.8224
# 7     All      35    0.8333         0.8242       0.0000    0.8811
# 18    All      30    0.8333         0.8138       0.9884    0.4357
# 8     All      30    0.8333         0.5434       0.7549    0.0911
# 13    All      20    0.8333         0.1828       1.0000    0.1066
# 12    All      20    0.8376         0.1800       1.0000    0.1690
# 11    All      20    0.8376         0.1800       1.0000    0.1690
# 9     All      20    0.8333         0.1139       1.0000    0.0325
#
#     MIAS Recall                                      Notes
# 0        0.9831                                        NaN
# 14       0.9811                                        NaN
# 17       0.8173                     Tuning hyperparameters
# 3        0.9663                                        NaN
# 1        0.9781                           Unstable results
# 4        0.6517                                        NaN
# 6        0.6553                                        NaN
# 10       0.9749  Retrained only fc layers from 1.0.0.46l.8
# 15       0.5342                                        NaN
# 16       0.8870                                        NaN
# 5        0.1759                                        NaN
# 2        0.0144                                        NaN
# 7        0.0157                                        NaN
# 18       0.9797                                        NaN
# 8        0.8136                                        NaN
# 13       1.0000                                        NaN
# 12       1.0000                                        NaN
# 11       1.0000                                        NaN
# 9        0.9741                                        NaN

# %% [markdown]
# I am skeptical of the results for models 1.0.0.29 as we were not able to replicate the results in future training runs. Models 1.0.0.29 and 1.0.0.46 also did not score well in both accuracy and recall on the MIAS data.

# %%
# remove any rows where the accuracy is below the baseline
ddsm_results_filtered = ddsm_results[ddsm_results["Test Accuracy"] > ddsm_results["Baseline"]]
ddsm_results_filtered
# Out:
#                Model Classification  Dataset  XE Weight  Initialization  \
# 0        1.0.0.29b.8              B        8          2         Scratch
# 14     1.0.0.46b.8.4              B        8          2     1.0.0.46b.6
# 17      1.0.0.35b.98              B        9          6         Scratch
# 3       1.0.0.29l.14              L        6          2         Scratch
# 1        1.0.0.29l.8              L        8          2         Scratch
# 4     vgg_16.3.04b.9              B        9          2         Scratch
# 6   vgg_16.3.04b.8.1              B        8          2  vgg_16.3.04l.6
# 10     1.0.0.46b.8.2              B        8          2     1.0.0.46l.8
# 15     1.0.0.28.2b.9              B        9          2         Scratch
# 16      1.0.0.35b.94              B        9          4         Scratch
#
#    Layers  Epochs  Baseline  Test Accuracy  Test Recall  MIAS Acc  \
# 0     All      30    0.8333         0.9930       1.0000    0.2189
# 14    All      10    0.8333         0.9896       0.9776    0.2746
# 17    All      35    0.8333         0.9571       0.9012    0.8802
# 3     All      40    0.8376         0.9142       0.9353    0.1665
# 1     All      35    0.8333         0.8890       0.9092    0.1462
# 4     All      30    0.8333         0.8881       0.3589    0.9314
# 6      FC       5    0.8333         0.8747       0.2951    0.3986
# 10     FC       5    0.8333         0.8711       0.9434    0.2535
# 15    All      20    0.8333         0.8675       0.2756    0.9165
# 16    All      30    0.8333         0.8502       0.7438    0.7328
#
#     MIAS Recall                                      Notes
# 0        0.9831                                        NaN
# 14       0.9811                                        NaN
# 17       0.8173                     Tuning hyperparameters
# 3        0.9663                                        NaN
# 1        0.9781                           Unstable results
# 4        0.6517                                        NaN
# 6        0.6553                                        NaN
# 10       0.9749  Retrained only fc layers from 1.0.0.46l.8
# 15       0.5342                                        NaN
# 16       0.8870                                        NaN

# %%
# Results sorted by best recall
ddsm_results_filtered.sort_values("Test Recall", ascending=False)
# Out:
#                Model Classification  Dataset  XE Weight  Initialization  \
# 0        1.0.0.29b.8              B        8          2         Scratch
# 14     1.0.0.46b.8.4              B        8          2     1.0.0.46b.6
# 10     1.0.0.46b.8.2              B        8          2     1.0.0.46l.8
# 3       1.0.0.29l.14              L        6          2         Scratch
# 1        1.0.0.29l.8              L        8          2         Scratch
# 17      1.0.0.35b.98              B        9          6         Scratch
# 16      1.0.0.35b.94              B        9          4         Scratch
# 4     vgg_16.3.04b.9              B        9          2         Scratch
# 6   vgg_16.3.04b.8.1              B        8          2  vgg_16.3.04l.6
# 15     1.0.0.28.2b.9              B        9          2         Scratch
#
#    Layers  Epochs  Baseline  Test Accuracy  Test Recall  MIAS Acc  \
# 0     All      30    0.8333         0.9930       1.0000    0.2189
# 14    All      10    0.8333         0.9896       0.9776    0.2746
# 10     FC       5    0.8333         0.8711       0.9434    0.2535
# 3     All      40    0.8376         0.9142       0.9353    0.1665
# 1     All      35    0.8333         0.8890       0.9092    0.1462
# 17    All      35    0.8333         0.9571       0.9012    0.8802
# 16    All      30    0.8333         0.8502       0.7438    0.7328
# 4     All      30    0.8333         0.8881       0.3589    0.9314
# 6      FC       5    0.8333         0.8747       0.2951    0.3986
# 15    All      20    0.8333         0.8675       0.2756    0.9165
#
#     MIAS Recall                                      Notes
# 0        0.9831                                        NaN
# 14       0.9811                                        NaN
# 10       0.9749  Retrained only fc layers from 1.0.0.46l.8
# 3        0.9663                                        NaN
# 1        0.9781                           Unstable results
# 17       0.8173                     Tuning hyperparameters
# 16       0.8870                                        NaN
# 4        0.6517                                        NaN
# 6        0.6553                                        NaN
# 15       0.5342                                        NaN

# %%
# Sort by best accuracy on MIAS data
ddsm_results_filtered.sort_values("MIAS Acc", ascending=False)
# Out:
#                Model Classification  Dataset  XE Weight  Initialization  \
# 4     vgg_16.3.04b.9              B        9          2         Scratch
# 15     1.0.0.28.2b.9              B        9          2         Scratch
# 17      1.0.0.35b.98              B        9          6         Scratch
# 16      1.0.0.35b.94              B        9          4         Scratch
# 6   vgg_16.3.04b.8.1              B        8          2  vgg_16.3.04l.6
# 14     1.0.0.46b.8.4              B        8          2     1.0.0.46b.6
# 10     1.0.0.46b.8.2              B        8          2     1.0.0.46l.8
# 0        1.0.0.29b.8              B        8          2         Scratch
# 3       1.0.0.29l.14              L        6          2         Scratch
# 1        1.0.0.29l.8              L        8          2         Scratch
#
#    Layers  Epochs  Baseline  Test Accuracy  Test Recall  MIAS Acc  \
# 4     All      30    0.8333         0.8881       0.3589    0.9314
# 15    All      20    0.8333         0.8675       0.2756    0.9165
# 17    All      35    0.8333         0.9571       0.9012    0.8802
# 16    All      30    0.8333         0.8502       0.7438    0.7328
# 6      FC       5    0.8333         0.8747       0.2951    0.3986
# 14    All      10    0.8333         0.9896       0.9776    0.2746
# 10     FC       5    0.8333         0.8711       0.9434    0.2535
# 0     All      30    0.8333         0.9930       1.0000    0.2189
# 3     All      40    0.8376         0.9142       0.9353    0.1665
# 1     All      35    0.8333         0.8890       0.9092    0.1462
#
#     MIAS Recall                                      Notes
# 4        0.6517                                        NaN
# 15       0.5342                                        NaN
# 17       0.8173                     Tuning hyperparameters
# 16       0.8870                                        NaN
# 6        0.6553                                        NaN
# 14       0.9811                                        NaN
# 10       0.9749  Retrained only fc layers from 1.0.0.46l.8
# 0        0.9831                                        NaN
# 3        0.9663                                        NaN
# 1        0.9781                           Unstable results

# %%
# sorted by highest MIAS recall
ddsm_results_filtered.sort_values("MIAS Recall", ascending=False)
# Out:
#                Model Classification  Dataset  XE Weight  Initialization  \
# 0        1.0.0.29b.8              B        8          2         Scratch
# 14     1.0.0.46b.8.4              B        8          2     1.0.0.46b.6
# 1        1.0.0.29l.8              L        8          2         Scratch
# 10     1.0.0.46b.8.2              B        8          2     1.0.0.46l.8
# 3       1.0.0.29l.14              L        6          2         Scratch
# 16      1.0.0.35b.94              B        9          4         Scratch
# 17      1.0.0.35b.98              B        9          6         Scratch
# 6   vgg_16.3.04b.8.1              B        8          2  vgg_16.3.04l.6
# 4     vgg_16.3.04b.9              B        9          2         Scratch
# 15     1.0.0.28.2b.9              B        9          2         Scratch
#
#    Layers  Epochs  Baseline  Test Accuracy  Test Recall  MIAS Acc  \
# 0     All      30    0.8333         0.9930       1.0000    0.2189
# 14    All      10    0.8333         0.9896       0.9776    0.2746
# 1     All      35    0.8333         0.8890       0.9092    0.1462
# 10     FC       5    0.8333         0.8711       0.9434    0.2535
# 3     All      40    0.8376         0.9142       0.9353    0.1665
# 16    All      30    0.8333         0.8502       0.7438    0.7328
# 17    All      35    0.8333         0.9571       0.9012    0.8802
# 6      FC       5    0.8333         0.8747       0.2951    0.3986
# 4     All      30    0.8333         0.8881       0.3589    0.9314
# 15    All      20    0.8333         0.8675       0.2756    0.9165
#
#     MIAS Recall                                      Notes
# 0        0.9831                                        NaN
# 14       0.9811                                        NaN
# 1        0.9781                           Unstable results
# 10       0.9749  Retrained only fc layers from 1.0.0.46l.8
# 3        0.9663                                        NaN
# 16       0.8870                                        NaN
# 17       0.8173                     Tuning hyperparameters
# 6        0.6553                                        NaN
# 4        0.6517                                        NaN
# 15       0.5342                                        NaN

# %% [markdown]
# # Results by Dataset

# %% [markdown]
# ## Dataset 9
#
# We focused on this dataset as the others resized the images based on the size of the ROI. This dataset did not, making models trained on it generalize the best to the MIAS data.

# %%
ddsm_results.loc[ddsm_results.Dataset == 9]
# Out:
#                  Model Classification  Dataset  XE Weight Initialization  \
# 17        1.0.0.35b.98              B        9          6        Scratch
# 4       vgg_16.3.04b.9              B        9          2        Scratch
# 15       1.0.0.28.2b.9              B        9          2        Scratch
# 16        1.0.0.35b.94              B        9          4        Scratch
# 7          1.0.0.46b.9              B        9          2        Scratch
# 18      vgg_16.3.06b.9              B        9          6        Scratch
# 13  inception_v4.05b.9              B        9          2        Scratch
#
#    Layers  Epochs  Baseline  Test Accuracy  Test Recall  MIAS Acc  \
# 17    All      35    0.8333         0.9571       0.9012    0.8802
# 4     All      30    0.8333         0.8881       0.3589    0.9314
# 15    All      20    0.8333         0.8675       0.2756    0.9165
# 16    All      30    0.8333         0.8502       0.7438    0.7328
# 7     All      35    0.8333         0.8242       0.0000    0.8811
# 18    All      30    0.8333         0.8138       0.9884    0.4357
# 13    All      20    0.8333         0.1828       1.0000    0.1066
#
#     MIAS Recall                   Notes
# 17       0.8173  Tuning hyperparameters
# 4        0.6517                     NaN
# 15       0.5342                     NaN
# 16       0.8870                     NaN
# 7        0.0157                     NaN
# 18       0.9797                     NaN
# 13       1.0000                     NaN

# %% [markdown]
# Model 1.0.0.35b.96 is the model which we feel has the best performance on the test dataset while generalizing well to the MIAS dataset.

# %% [markdown]
# ## Dataset 8
#
# While some models performed very well on Dataset 8, those models did not perform well on the MIAS dataset. They all traded off accuracy and recall.

# %%
ddsm_results.loc[ddsm_results.Dataset == 8]
# Out:
#                Model Classification  Dataset  XE Weight  Initialization  \
# 0        1.0.0.29b.8              B        8          2         Scratch
# 14     1.0.0.46b.8.4              B        8          2     1.0.0.46b.6
# 1        1.0.0.29l.8              L        8          2         Scratch
# 6   vgg_16.3.04b.8.1              B        8          2  vgg_16.3.04l.6
# 10     1.0.0.46b.8.2              B        8          2     1.0.0.46l.8
# 8        1.0.0.46b.8              B        8          2         Scratch
# 9        1.0.0.46l.8              L        8          2         Scratch
#
#    Layers  Epochs  Baseline  Test Accuracy  Test Recall  MIAS Acc  \
# 0     All      30    0.8333         0.9930       1.0000    0.2189
# 14    All      10    0.8333         0.9896       0.9776    0.2746
# 1     All      35    0.8333         0.8890       0.9092    0.1462
# 6      FC       5    0.8333         0.8747       0.2951    0.3986
# 10     FC       5    0.8333         0.8711       0.9434    0.2535
# 8     All      30    0.8333         0.5434       0.7549    0.0911
# 9     All      20    0.8333         0.1139       1.0000    0.0325
#
#     MIAS Recall                                      Notes
# 0        0.9831                                        NaN
# 14       0.9811                                        NaN
# 1        0.9781                           Unstable results
# 6        0.6553                                        NaN
# 10       0.9749  Retrained only fc layers from 1.0.0.46l.8
# 8        0.8136                                        NaN
# 9        0.9741                                        NaN

# %% [markdown]
# ## Dataset 6
#
# We stopped training on Dataset 6 after Dataset 9 was created. These results are just included as a reference.

# %%
ddsm_results.loc[ddsm_results.Dataset == 6]
# Out:
#              Model Classification  Dataset  XE Weight Initialization Layers  \
# 3     1.0.0.29l.14              L        6          2        Scratch    All
# 5   vgg_16.3.04l.6              L        6          2        Scratch    All
# 2      1.0.0.29g.6              B        6          2        Scratch    All
# 12     1.0.0.46l.6              L        6          2        Scratch    All
# 11     1.0.0.46b.6              B        6          2        Scratch    All
#
#     Epochs  Baseline  Test Accuracy  Test Recall  MIAS Acc  MIAS Recall Notes
# 3       40    0.8376         0.9142       0.9353    0.1665       0.9663   NaN
# 5       20    0.8376         0.8333       0.0288    0.4783       0.1759   NaN
# 2       35    0.8376         0.8299       0.0477    0.8224       0.0144   NaN
# 12      20    0.8376         0.1800       1.0000    0.1690       1.0000   NaN
# 11      20    0.8376         0.1800       1.0000    0.1690       1.0000   NaN

# %% [markdown]
# ## Effect of Contrast and Threshold on Accuracy and Recall

# %%
# results of trained model 2.0.0.35b evaluated with different contrast and threshold levels
aug_results = pd.read_csv("eval_results.csv")

# %%
# contrast
contrast_1 = aug_results[aug_results.Contrast == 1]
contrast_15  = aug_results[aug_results.Contrast == 1.5]
contrast_2  = aug_results[aug_results.Contrast == 2]

# %%
plt.plot(contrast_1.Threshold, contrast_1["Test Acc"], color="blue", label="Contrast 1.0")
plt.plot(contrast_15.Threshold, contrast_15["Test Acc"], color="red", label="Contrast 1.5")
plt.plot(contrast_2.Threshold, contrast_2["Test Acc"], color="green", label="Contrast 2.0")
plt.ylabel("Accuracy")
plt.xlabel("Threshold")
plt.legend()
plt.title("Threshold vs Accuracy")
plt.show()

# %%
plt.plot(contrast_1.Threshold, contrast_1["Test Re"], color="blue", label="Contrast 1.0")
plt.plot(contrast_15.Threshold, contrast_15["Test Re"], color="red", label="Contrast 1.5")
plt.plot(contrast_2.Threshold, contrast_2["Test Re"], color="green", label="Contrast 2.0")
plt.ylabel("Recall")
plt.xlabel("Threshold")
plt.legend()
plt.title("Threshold vs Recall")
plt.show()
