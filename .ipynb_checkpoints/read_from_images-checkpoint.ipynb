# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
# Out:
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def _parse_function(filename, size=640):
    image_string = tf.read_file(filename)
    image_decoded = tf.image.decode_image(image_string)

    cropped_image = tf.random_crop(image_decoded, size=[size, size, 3])

    image = cropped_image[:, :, 0]
    label = cropped_image[:, :, 1]

    return image, label


def _read_images(image_dir, crop_size, scale_by=0.66):
    filenames = tf.train.match_filenames_once(image_dir + "*.png")
    filename_queue = tf.train.string_input_producer(filenames)

    # create the reader
    image_reader = tf.WholeFileReader()

    # Read a whole file from the queue
    filename, image_file = image_reader.read(filename_queue)

    # decode the image
    raw_image = tf.image.decode_png(image_file)
    
    # figure out size of raw crop by dividing size by scale
    image_size = int(crop_size // scale_by)

    # crop the image
    raw_image = tf.random_crop(raw_image, size=[image_size, image_size, 3])

    # resize the image
    resized_image = tf.image.resize_images(raw_image, size=[crop_size, crop_size])

    # extract the image and label from the channels and resize them for convnet
    image = tf.reshape(resized_image[:, :, 0], [crop_size, crop_size, 1])
    label = tf.reshape(resized_image[:, :, 1], [crop_size, crop_size, 1])
    
    label = tf.cast(label, dtype=tf.int32)
    
    return image, label

def _scale_input_data(X, contrast=None, mu=104.1353, scale=255.0):
    # if we are adjusting contrast do that
    if contrast and contrast != 1.0:
        X_adj = tf.image.adjust_contrast(X, contrast)
    else:
        X_adj = X

    # cast to float
    if X_adj.dtype != tf.float32:
        X_adj = tf.cast(X_adj, dtype=tf.float32)

    # center the pixel data
    X_adj = tf.subtract(X_adj, mu, name="centered_input")

    # scale the data
    X_adj = tf.divide(X_adj, scale)

    return X_adj

# %%
batch_size = 16
size = 320
distort = False
image_size = 640
contrast = 0
graph = tf.Graph()

with graph.as_default():
    with tf.name_scope('inputs') as scope:
        with tf.device('/cpu:0'):
            image, label = _read_images("./data/train_images/", size, scale_by=0.66)
            X_def, y_def = tf.train.batch([image, label], batch_size=batch_size)

            # image, label = read_and_decode_single_example(train_files, label_type=how, normalize=False, distort=False, size=640)
            # X_def, y_def = tf.train.shuffle_batch([image, label], batch_size=batch_size, capacity=2000, seed=None, min_after_dequeue=1000)

            # Placeholders
            X = tf.placeholder_with_default(X_def, shape=[None, size, size, 1])
            y = tf.placeholder_with_default(y_def, shape=[None, size, size, 1])

            X_fl = tf.cast(X, tf.float32)

            # optional online data augmentation
            if distort:
                X_dis, y_adj = augment(X_fl, y, horizontal_flip=True, augment_labels=True, vertical_flip=True, mixup=0)
            else:
                y_adj = y
                X_dis = X_fl

            # cast to float and scale input data
            X_adj = _scale_input_data(X_dis, contrast=contrast, mu=127.0, scale=255.0)
        
print("Graph created...")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-02f34408bdf6> in <module>()
#      28
#      29             # cast to float and scale input data
# ---> 30             X_adj = _scale_input_data(X_dis, contrast=contrast, mu=127.0, scale=255.0)
#      31
#      32 print("Graph created...")
#
# NameError: name 'contrast' is not defined

# %%
with tf.Session(graph=graph) as sess:
    
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())
    
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    
    for epoch in range(5):
        
        X_, y_ = sess.run([X_adj, y_def])
        
        for j in range(len(X_)):
            plt.imshow(np.squeeze(X_[j]))
            plt.title("Image - " + str(np.max(X_[j])))
            plt.show()
            
            plt.imshow(np.squeeze(y_[j]))
            plt.title("label")
            plt.show()
            
    # Finish off the filename queue coordinator.
    coord.request_stop()
    coord.join(threads)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in __init__(self, fetches, contraction_fn)
#     281         self._unique_fetches.append(ops.get_default_graph().as_graph_element(
# --> 282             fetch, allow_tensor=True, allow_operation=True))
#     283       except TypeError as e:
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\ops.py in as_graph_element(self, obj, allow_tensor, allow_operation)
#    3477     with self._lock:
# -> 3478       return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    3479
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\ops.py in _as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    3556       if obj.graph is not self:
# -> 3557         raise ValueError("Tensor %s is not an element of this graph." % obj)
#    3558       return obj
#
# ValueError: Tensor Tensor("inputs/truediv:0", shape=(?, 640, 640, 1), dtype=float32) is not an element of this graph.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-bb00bc979f38> in <module>()
#       9     for epoch in range(5):
#      10
# ---> 11         X_, y_ = sess.run([X_adj, y_def])
#      12
#      13         for j in range(len(X_)):
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1123     # Create a fetch handler to take care of the structure of fetches.
#    1124     fetch_handler = _FetchHandler(
# -> 1125         self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1126
#    1127     # Run request and get response.
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in __init__(self, graph, fetches, feeds, feed_handles)
#     425     """
#     426     with graph.as_default():
# --> 427       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     428     self._fetches = []
#     429     self._targets = []
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in for_fetch(fetch)
#     243     elif isinstance(fetch, (list, tuple)):
#     244       # NOTE(touts): This is also the code path for namedtuples.
# --> 245       return _ListFetchMapper(fetch)
#     246     elif isinstance(fetch, dict):
#     247       return _DictFetchMapper(fetch)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in __init__(self, fetches)
#     350     """
#     351     self._fetch_type = type(fetches)
# --> 352     self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     353     self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#     354
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in <listcomp>(.0)
#     350     """
#     351     self._fetch_type = type(fetches)
# --> 352     self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     353     self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#     354
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in for_fetch(fetch)
#     251         if isinstance(fetch, tensor_type):
#     252           fetches, contraction_fn = fetch_fn(fetch)
# --> 253           return _ElementFetchMapper(fetches, contraction_fn)
#     254     # Did not find anything.
#     255     raise TypeError('Fetch argument %r has invalid type %r' % (fetch,
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in __init__(self, fetches, contraction_fn)
#     287       except ValueError as e:
#     288         raise ValueError('Fetch argument %r cannot be interpreted as a '
# --> 289                          'Tensor. (%s)' % (fetch, str(e)))
#     290       except KeyError as e:
#     291         raise ValueError('Fetch argument %r cannot be interpreted as a '
#
# ValueError: Fetch argument <tf.Tensor 'inputs/truediv:0' shape=(?, 640, 640, 1) dtype=float32> cannot be interpreted as a Tensor. (Tensor Tensor("inputs/truediv:0", shape=(?, 640, 640, 1), dtype=float32) is not an element of this graph.)

# %%
def logloss(true_label, predicted, eps=1e-15):
    p = np.clip(predicted, eps, 1 - eps)
    if true_label == 1:
        return -np.log(p)
    else:
        return -np.log(1 - p)

# %%
one = logloss(0, 0.4)
two = logloss(0, 0.5)
three = logloss(0, 0.5)
four = logloss(0, 0.6)

np.mean([one,two,three,four])
# Out:
# 0.7033526791900091

# %%
foo = [18, 3, 15, 24]
foo / np.sum(foo)
# Out:
# array([0.3 , 0.05, 0.25, 0.4 ])

# %% [markdown]
# ## Backup

# %%
def _create_image_list(image_dir):
    files = tf.convert_to_tensor(os.listdir(image_dir))
    return files

def read_my_file_format(filename):
    file_contents = tf.read_file(filename)
    image = tf.image.decode_png(file_contents)
    
    cropped_image = tf.random_crop(image, size=[size, size, 3])

    image = cropped_image[:, :, 0]
    label = cropped_image[:, :, 1]
    
    return image, label

image_list = _create_image_list("./data/train_images/")

input_queue = tf.train.slice_input_producer(image_list, num_epochs=None, shuffle=True)

image, label = read_my_file_format(input_queue.dequeue())

image_batch, label_batch = tf.train.batch([image, label], batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-63faa17e52f4> in <module>()
#      18 input_queue = tf.train.slice_input_producer([image_list], num_epochs=None, shuffle=True)
#      19
# ---> 20 image, label = read_my_file_format(input_queue.dequeue())
#      21
#      22 image_batch, label_batch = tf.train.batch([image, label], batch_size=16)
#
# AttributeError: 'list' object has no attribute 'dequeue'

# %%
def _read_images_from_disk(input_queue, image_dir, size=640):
    image_string = tf.read_file(os.path.join(image_dir, input_queue))
    image_decoded = tf.image.decode_image(image_string)

    cropped_image = tf.random_crop(image_decoded, size=[size, size, 3])

    image = cropped_image[:, :, 0]
    label = cropped_image[:, :, 1]

    return image, label

def _create_image_queue(files):
    input_queue = tf.train.slice_input_producer(files,
                                            num_epochs=None,
                                            shuffle=True)
    
    image, label = _read_images_from_disk(input_queue.dequeue(), size=320)
    
    image_batch, label_batch = tf.train.batch([image, label], batch_size=batch_size)
    
    return image_batch, label_batch

# %%
os.listdir("./data/train_images/")
# Out:
# ['P_00001_LEFT_CC_1.png',
#  'P_00001_LEFT_MLO_2.png',
#  'P_00004_LEFT_CC_3.png',
#  'P_00004_LEFT_MLO_4.png',
#  'P_00004_RIGHT_MLO_5.png',
#  'P_00005_RIGHT_CC_6.png',
#  'P_00005_RIGHT_MLO_7.png',
#  'P_00007_LEFT_CC_8.png',
#  'P_00007_LEFT_MLO_9.png',
#  'P_00008_LEFT_CC_10.png',
#  'P_00008_LEFT_MLO_11.png',
#  'P_00008_RIGHT_CC_12.png',
#  'P_00008_RIGHT_MLO_13.png',
#  'P_00009_RIGHT_CC_14.png',
#  'P_00009_RIGHT_MLO_15.png',
#  'P_00010_LEFT_CC_16.png',
#  'P_00010_LEFT_MLO_17.png',
#  'P_00011_LEFT_CC_18.png',
#  'P_00011_LEFT_MLO_19.png',
#  'P_00012_LEFT_CC_20.png',
#  'P_00012_LEFT_MLO_21.png',
#  'P_00013_RIGHT_MLO_22.png',
#  'P_00014_LEFT_CC_23.png',
#  'P_00014_LEFT_MLO_24.png',
#  'P_00015_LEFT_MLO_25.png',
#  'P_00018_RIGHT_CC_30.png',
#  'P_00018_RIGHT_MLO_31.png',
#  'P_00019_RIGHT_CC_32.png',
#  'P_00019_RIGHT_MLO_33.png',
#  'P_00020_LEFT_CC_34.png',
#  'P_00020_LEFT_MLO_35.png',
#  'P_00021_LEFT_CC_36.png',
#  'P_00021_LEFT_MLO_37.png',
#  'P_00021_RIGHT_CC_38.png',
#  'P_00021_RIGHT_MLO_39.png',
#  'P_00022_LEFT_CC_40.png',
#  'P_00022_LEFT_MLO_41.png',
#  'P_00023_RIGHT_CC_42.png',
#  'P_00023_RIGHT_MLO_43.png',
#  'P_00024_LEFT_CC_44.png',
#  'P_00024_LEFT_MLO_45.png',
#  'P_00026_LEFT_CC_46.png',
#  'P_00026_LEFT_MLO_47.png',
#  'P_00027_RIGHT_CC_48.png',
#  'P_00027_RIGHT_MLO_49.png',
#  'P_00028_LEFT_MLO_50.png',
#  'P_00029_LEFT_CC_51.png',
#  'P_00029_LEFT_MLO_52.png',
#  'P_00030_LEFT_CC_53.png',
#  'P_00030_LEFT_MLO_54.png',
#  'P_00030_RIGHT_CC_55.png',
#  'P_00030_RIGHT_MLO_56.png',
#  'P_00031_LEFT_CC_57.png',
#  'P_00034_RIGHT_CC_60.png',
#  'P_00034_RIGHT_MLO_61.png',
#  'P_00039_RIGHT_CC_68.png',
#  'P_00039_RIGHT_MLO_69.png',
#  'P_00043_LEFT_MLO_74.png',
#  'P_00044_RIGHT_CC_75.png',
#  'P_00044_RIGHT_MLO_76.png',
#  'P_00045_LEFT_CC_77.png',
#  'P_00045_LEFT_MLO_78.png',
#  'P_00046_RIGHT_MLO_79.png',
#  'P_00047_LEFT_CC_80.png',
#  'P_00047_LEFT_MLO_81.png',
#  'P_00048_RIGHT_CC_82.png',
#  'P_00048_RIGHT_MLO_83.png',
#  'P_00049_RIGHT_CC_84.png',
#  'P_00049_RIGHT_MLO_85.png',
#  'P_00051_LEFT_CC_86.png',
#  'P_00051_LEFT_MLO_87.png',
#  'P_00054_RIGHT_MLO_88.png',
#  'P_00055_LEFT_CC_89.png',
#  'P_00057_RIGHT_CC_91.png',
#  'P_00057_RIGHT_MLO_92.png',
#  'P_00058_RIGHT_CC_93.png',
#  'P_00059_LEFT_MLO_96.png',
#  'P_00060_RIGHT_CC_97.png',
#  'P_00060_RIGHT_MLO_98.png',
#  'P_00061_RIGHT_CC_99.png',
#  'P_00061_RIGHT_MLO_100.png',
#  'P_00062_LEFT_CC_101.png',
#  'P_00062_LEFT_MLO_102.png',
#  'P_00063_RIGHT_CC_103.png',
#  'P_00063_RIGHT_MLO_104.png',
#  'P_00064_RIGHT_MLO_105.png',
#  'P_00065_LEFT_CC_106.png',
#  'P_00065_LEFT_MLO_107.png',
#  'P_00068_RIGHT_CC_110.png',
#  'P_00068_RIGHT_MLO_111.png',
#  'P_00071_RIGHT_CC_112.png',
#  'P_00071_RIGHT_MLO_113.png',
#  'P_00074_LEFT_MLO_114.png',
#  'P_00074_RIGHT_CC_115.png',
#  'P_00074_RIGHT_MLO_116.png',
#  'P_00076_LEFT_CC_117.png',
#  'P_00076_LEFT_MLO_118.png',
#  'P_00078_LEFT_CC_123.png',
#  'P_00078_LEFT_MLO_124.png',
#  'P_00079_RIGHT_CC_125.png',
#  'P_00079_RIGHT_MLO_126.png',
#  'P_00080_RIGHT_CC_127.png',
#  'P_00080_RIGHT_MLO_128.png',
#  'P_00081_RIGHT_CC_129.png',
#  'P_00081_RIGHT_MLO_130.png',
#  'P_00083_RIGHT_CC_131.png',
#  'P_00084_LEFT_CC_132.png',
#  'P_00084_LEFT_MLO_133.png',
#  'P_00085_RIGHT_CC_134.png',
#  'P_00085_RIGHT_MLO_135.png',
#  'P_00086_RIGHT_CC_136.png',
#  'P_00086_RIGHT_MLO_137.png',
#  'P_00088_LEFT_CC_138.png',
#  'P_00088_LEFT_MLO_139.png',
#  'P_00090_LEFT_CC_140.png',
#  'P_00090_LEFT_MLO_141.png',
#  'P_00091_LEFT_CC_142.png',
#  'P_00091_LEFT_MLO_143.png',
#  'P_00092_LEFT_CC_144.png',
#  'P_00092_LEFT_MLO_145.png',
#  'P_00092_RIGHT_CC_146.png',
#  'P_00092_RIGHT_MLO_147.png',
#  'P_00094_RIGHT_CC_148.png',
#  'P_00094_RIGHT_MLO_149.png',
#  'P_00095_LEFT_CC_150.png',
#  'P_00095_LEFT_MLO_151.png',
#  'P_00096_RIGHT_CC_152.png',
#  'P_00096_RIGHT_MLO_153.png',
#  'P_00098_LEFT_CC_154.png',
#  'P_00098_LEFT_MLO_155.png',
#  'P_00098_RIGHT_CC_156.png',
#  'P_00098_RIGHT_MLO_157.png',
#  'P_00101_RIGHT_CC_161.png',
#  'P_00101_RIGHT_MLO_162.png',
#  'P_00105_LEFT_CC_163.png',
#  'P_00105_LEFT_MLO_164.png',
#  'P_00106_LEFT_CC_165.png',
#  'P_00106_LEFT_MLO_166.png',
#  'P_00106_RIGHT_CC_167.png',
#  'P_00106_RIGHT_MLO_168.png',
#  'P_00107_RIGHT_MLO_169.png',
#  'P_00108_LEFT_CC_170.png',
#  'P_00108_LEFT_MLO_171.png',
#  'P_00109_LEFT_CC_172.png',
#  'P_00110_LEFT_CC_173.png',
#  'P_00110_LEFT_MLO_174.png',
#  'P_00110_RIGHT_CC_175.png',
#  'P_00112_LEFT_CC_176.png',
#  'P_00112_LEFT_MLO_177.png',
#  'P_00112_RIGHT_CC_178.png',
#  'P_00112_RIGHT_MLO_179.png',
#  'P_00117_LEFT_MLO_183.png',
#  'P_00119_LEFT_CC_186.png',
#  'P_00119_LEFT_MLO_187.png',
#  'P_00120_LEFT_CC_188.png',
#  'P_00120_LEFT_MLO_189.png',
#  'P_00121_LEFT_CC_190.png',
#  'P_00121_LEFT_MLO_191.png',
#  'P_00122_RIGHT_MLO_192.png',
#  'P_00123_LEFT_CC_193.png',
#  'P_00123_LEFT_MLO_194.png',
#  'P_00128_LEFT_CC_200.png',
#  'P_00129_LEFT_CC_201.png',
#  'P_00129_LEFT_MLO_202.png',
#  'P_00133_LEFT_CC_206.png',
#  'P_00133_LEFT_MLO_207.png',
#  'P_00134_LEFT_CC_208.png',
#  'P_00134_LEFT_MLO_209.png',
#  'P_00136_LEFT_CC_210.png',
#  'P_00136_LEFT_MLO_211.png',
#  'P_00137_LEFT_CC_212.png',
#  'P_00137_LEFT_MLO_213.png',
#  'P_00146_RIGHT_CC_223.png',
#  'P_00146_RIGHT_MLO_224.png',
#  'P_00148_RIGHT_CC_227.png',
#  'P_00148_RIGHT_MLO_228.png',
#  'P_00149_LEFT_CC_229.png',
#  'P_00149_LEFT_MLO_230.png',
#  'P_00151_RIGHT_MLO_232.png',
#  'P_00157_LEFT_CC_234.png',
#  'P_00157_LEFT_MLO_235.png',
#  'P_00159_LEFT_CC_237.png',
#  'P_00159_LEFT_MLO_238.png',
#  'P_00160_LEFT_CC_240.png',
#  'P_00160_LEFT_MLO_241.png',
#  'P_00160_RIGHT_CC_242.png',
#  'P_00160_RIGHT_MLO_243.png',
#  'P_00161_LEFT_MLO_244.png',
#  'P_00162_LEFT_CC_245.png',
#  'P_00162_LEFT_MLO_246.png',
#  'P_00166_RIGHT_CC_250.png',
#  'P_00166_RIGHT_MLO_251.png',
#  'P_00169_RIGHT_MLO_252.png',
#  'P_00172_LEFT_CC_255.png',
#  'P_00172_LEFT_MLO_256.png',
#  'P_00174_RIGHT_CC_261.png',
#  'P_00174_RIGHT_MLO_262.png',
#  'P_00175_RIGHT_CC_263.png',
#  'P_00175_RIGHT_MLO_264.png',
#  'P_00179_LEFT_CC_267.png',
#  'P_00179_LEFT_MLO_268.png',
#  'P_00181_RIGHT_CC_271.png',
#  'P_00181_RIGHT_MLO_272.png',
#  'P_00182_LEFT_CC_273.png',
#  'P_00182_LEFT_MLO_274.png',
#  'P_00183_RIGHT_MLO_275.png',
#  'P_00185_LEFT_CC_276.png',
#  'P_00185_LEFT_MLO_277.png',
#  'P_00187_LEFT_CC_278.png',
#  'P_00187_LEFT_MLO_279.png',
#  'P_00188_RIGHT_MLO_280.png',
#  'P_00189_LEFT_CC_281.png',
#  'P_00189_LEFT_MLO_282.png',
#  'P_00190_LEFT_MLO_283.png',
#  'P_00196_RIGHT_CC_289.png',
#  'P_00196_RIGHT_MLO_290.png',
#  'P_00197_RIGHT_CC_291.png',
#  'P_00197_RIGHT_MLO_292.png',
#  'P_00199_LEFT_CC_295.png',
#  'P_00199_LEFT_MLO_296.png',
#  'P_00201_LEFT_MLO_301.png',
#  'P_00205_RIGHT_CC_308.png',
#  'P_00205_RIGHT_MLO_309.png',
#  'P_00206_RIGHT_MLO_310.png',
#  'P_00207_LEFT_CC_311.png',
#  'P_00207_LEFT_MLO_312.png',
#  'P_00208_RIGHT_CC_313.png',
#  'P_00208_RIGHT_MLO_314.png',
#  'P_00215_RIGHT_CC_321.png',
#  'P_00217_LEFT_CC_322.png',
#  'P_00218_LEFT_CC_323.png',
#  'P_00218_LEFT_MLO_324.png',
#  'P_00219_RIGHT_CC_325.png',
#  'P_00220_LEFT_CC_326.png',
#  'P_00220_LEFT_MLO_327.png',
#  'P_00221_RIGHT_MLO_328.png',
#  'P_00224_LEFT_CC_330.png',
#  'P_00224_LEFT_MLO_331.png',
#  'P_00224_RIGHT_CC_332.png',
#  'P_00224_RIGHT_MLO_333.png',
#  'P_00225_RIGHT_CC_334.png',
#  'P_00225_RIGHT_MLO_335.png',
#  'P_00226_LEFT_CC_336.png',
#  'P_00226_LEFT_MLO_337.png',
#  'P_00229_LEFT_CC_338.png',
#  'P_00229_LEFT_MLO_339.png',
#  'P_00231_LEFT_CC_342.png',
#  'P_00231_LEFT_MLO_343.png',
#  'P_00232_RIGHT_CC_344.png',
#  'P_00232_RIGHT_MLO_345.png',
#  'P_00234_LEFT_CC_346.png',
#  'P_00235_RIGHT_CC_347.png',
#  'P_00235_RIGHT_MLO_348.png',
#  'P_00236_RIGHT_MLO_349.png',
#  'P_00239_RIGHT_CC_352.png',
#  'P_00239_RIGHT_MLO_353.png',
#  'P_00240_RIGHT_CC_354.png',
#  'P_00240_RIGHT_MLO_355.png',
#  'P_00241_RIGHT_CC_356.png',
#  'P_00241_RIGHT_MLO_357.png',
#  'P_00242_RIGHT_CC_358.png',
#  'P_00242_RIGHT_MLO_359.png',
#  'P_00243_LEFT_CC_360.png',
#  'P_00243_LEFT_MLO_361.png',
#  'P_00245_RIGHT_MLO_363.png',
#  'P_00247_RIGHT_CC_365.png',
#  'P_00247_RIGHT_MLO_366.png',
#  'P_00248_LEFT_MLO_367.png',
#  'P_00250_LEFT_MLO_368.png',
#  'P_00251_RIGHT_CC_369.png',
#  'P_00251_RIGHT_MLO_370.png',
#  'P_00254_LEFT_CC_371.png',
#  'P_00254_LEFT_MLO_372.png',
#  'P_00255_RIGHT_CC_373.png',
#  'P_00255_RIGHT_MLO_374.png',
#  'P_00256_LEFT_CC_375.png',
#  'P_00256_LEFT_MLO_376.png',
#  'P_00259_RIGHT_CC_379.png',
#  'P_00259_RIGHT_MLO_380.png',
#  'P_00260_RIGHT_CC_381.png',
#  'P_00260_RIGHT_MLO_382.png',
#  'P_00263_LEFT_MLO_383.png',
#  'P_00264_LEFT_CC_384.png',
#  'P_00264_LEFT_MLO_385.png',
#  'P_00265_RIGHT_CC_386.png',
#  'P_00265_RIGHT_MLO_387.png',
#  'P_00266_LEFT_CC_388.png',
#  'P_00266_LEFT_MLO_389.png',
#  'P_00268_LEFT_CC_390.png',
#  'P_00268_LEFT_MLO_391.png',
#  'P_00269_LEFT_CC_392.png',
#  'P_00269_LEFT_MLO_393.png',
#  'P_00270_LEFT_CC_394.png',
#  'P_00270_LEFT_MLO_395.png',
#  'P_00271_LEFT_CC_396.png',
#  'P_00271_LEFT_MLO_397.png',
#  'P_00273_LEFT_CC_398.png',
#  'P_00274_RIGHT_MLO_399.png',
#  'P_00275_LEFT_CC_400.png',
#  'P_00275_LEFT_MLO_401.png',
#  'P_00276_RIGHT_CC_402.png',
#  'P_00276_RIGHT_MLO_403.png',
#  'P_00279_LEFT_CC_406.png',
#  'P_00280_LEFT_CC_407.png',
#  'P_00280_LEFT_MLO_408.png',
#  'P_00281_LEFT_MLO_409.png',
#  'P_00282_LEFT_CC_410.png',
#  'P_00282_LEFT_MLO_411.png',
#  'P_00283_RIGHT_CC_412.png',
#  'P_00283_RIGHT_MLO_413.png',
#  'P_00284_LEFT_CC_414.png',
#  'P_00284_LEFT_MLO_415.png',
#  'P_00287_RIGHT_CC_416.png',
#  'P_00287_RIGHT_MLO_417.png',
#  'P_00288_RIGHT_CC_418.png',
#  'P_00288_RIGHT_MLO_419.png',
#  'P_00289_LEFT_CC_420.png',
#  'P_00289_LEFT_MLO_421.png',
#  'P_00291_LEFT_CC_422.png',
#  'P_00291_LEFT_MLO_423.png',
#  'P_00291_RIGHT_CC_424.png',
#  'P_00291_RIGHT_MLO_425.png',
#  'P_00293_LEFT_CC_426.png',
#  'P_00293_LEFT_MLO_427.png',
#  'P_00294_LEFT_CC_428.png',
#  'P_00294_LEFT_MLO_429.png',
#  'P_00297_RIGHT_CC_432.png',
#  'P_00297_RIGHT_MLO_433.png',
#  'P_00298_LEFT_CC_434.png',
#  'P_00298_LEFT_MLO_435.png',
#  'P_00302_LEFT_CC_439.png',
#  'P_00302_LEFT_MLO_440.png',
#  'P_00302_RIGHT_CC_441.png',
#  'P_00302_RIGHT_MLO_442.png',
#  'P_00303_LEFT_CC_443.png',
#  'P_00303_LEFT_MLO_444.png',
#  'P_00303_RIGHT_CC_445.png',
#  'P_00303_RIGHT_MLO_446.png',
#  'P_00304_LEFT_MLO_447.png',
#  'P_00307_LEFT_CC_448.png',
#  'P_00307_LEFT_MLO_449.png',
#  'P_00308_LEFT_CC_450.png',
#  'P_00308_LEFT_MLO_451.png',
#  'P_00309_LEFT_CC_452.png',
#  'P_00309_LEFT_MLO_453.png',
#  'P_00311_RIGHT_CC_454.png',
#  'P_00312_RIGHT_MLO_455.png',
#  'P_00313_RIGHT_CC_456.png',
#  'P_00313_RIGHT_MLO_457.png',
#  'P_00314_RIGHT_CC_458.png',
#  'P_00314_RIGHT_MLO_459.png',
#  'P_00316_RIGHT_CC_461.png',
#  'P_00316_RIGHT_MLO_462.png',
#  'P_00317_RIGHT_MLO_463.png',
#  'P_00318_LEFT_MLO_464.png',
#  'P_00319_LEFT_CC_465.png',
#  'P_00319_LEFT_MLO_466.png',
#  'P_00320_LEFT_CC_467.png',
#  'P_00320_LEFT_MLO_468.png',
#  'P_00321_LEFT_CC_469.png',
#  'P_00321_LEFT_MLO_470.png',
#  'P_00322_LEFT_CC_471.png',
#  'P_00322_LEFT_MLO_472.png',
#  'P_00326_LEFT_MLO_476.png',
#  'P_00328_LEFT_MLO_477.png',
#  'P_00328_RIGHT_CC_478.png',
#  'P_00328_RIGHT_MLO_479.png',
#  'P_00330_LEFT_CC_480.png',
#  'P_00330_LEFT_MLO_481.png',
#  'P_00332_LEFT_CC_484.png',
#  'P_00332_LEFT_MLO_485.png',
#  'P_00332_RIGHT_CC_486.png',
#  'P_00332_RIGHT_MLO_487.png',
#  'P_00333_RIGHT_CC_488.png',
#  'P_00333_RIGHT_MLO_489.png',
#  'P_00334_LEFT_MLO_490.png',
#  'P_00335_LEFT_MLO_491.png',
#  'P_00336_LEFT_CC_492.png',
#  'P_00336_LEFT_MLO_493.png',
#  'P_00337_LEFT_CC_494.png',
#  'P_00337_LEFT_MLO_495.png',
#  'P_00339_LEFT_CC_496.png',
#  'P_00339_LEFT_MLO_497.png',
#  'P_00342_RIGHT_CC_499.png',
#  'P_00342_RIGHT_MLO_500.png',
#  'P_00346_RIGHT_CC_507.png',
#  'P_00346_RIGHT_MLO_508.png',
#  'P_00348_LEFT_CC_511.png',
#  'P_00348_LEFT_MLO_512.png',
#  'P_00349_RIGHT_CC_513.png',
#  'P_00349_RIGHT_MLO_514.png',
#  'P_00351_LEFT_CC_515.png',
#  'P_00351_LEFT_MLO_516.png',
#  'P_00354_LEFT_CC_521.png',
#  'P_00354_LEFT_MLO_522.png',
#  'P_00355_LEFT_CC_523.png',
#  'P_00355_LEFT_MLO_524.png',
#  'P_00356_LEFT_CC_525.png',
#  'P_00357_LEFT_CC_526.png',
#  'P_00360_RIGHT_CC_530.png',
#  'P_00360_RIGHT_MLO_531.png',
#  'P_00361_RIGHT_MLO_532.png',
#  'P_00363_LEFT_CC_533.png',
#  'P_00363_LEFT_MLO_534.png',
#  'P_00364_RIGHT_CC_535.png',
#  'P_00364_RIGHT_MLO_536.png',
#  'P_00366_RIGHT_CC_537.png',
#  'P_00366_RIGHT_MLO_538.png',
#  'P_00370_RIGHT_CC_543.png',
#  'P_00370_RIGHT_MLO_544.png',
#  'P_00373_LEFT_CC_547.png',
#  'P_00373_LEFT_MLO_548.png',
#  'P_00376_RIGHT_CC_551.png',
#  'P_00376_RIGHT_MLO_552.png',
#  'P_00377_LEFT_CC_553.png',
#  'P_00377_LEFT_MLO_554.png',
#  'P_00378_LEFT_CC_555.png',
#  'P_00378_LEFT_MLO_556.png',
#  'P_00380_RIGHT_CC_559.png',
#  'P_00380_RIGHT_MLO_560.png',
#  'P_00383_LEFT_MLO_563.png',
#  'P_00384_RIGHT_CC_564.png',
#  'P_00384_RIGHT_MLO_565.png',
#  'P_00385_LEFT_CC_566.png',
#  'P_00385_LEFT_MLO_567.png',
#  'P_00385_RIGHT_CC_568.png',
#  'P_00385_RIGHT_MLO_569.png',
#  'P_00386_LEFT_CC_570.png',
#  'P_00386_LEFT_MLO_571.png',
#  'P_00389_LEFT_MLO_574.png',
#  'P_00392_LEFT_CC_581.png',
#  'P_00392_LEFT_MLO_582.png',
#  'P_00393_LEFT_MLO_583.png',
#  'P_00394_LEFT_MLO_584.png',
#  'P_00395_RIGHT_CC_586.png',
#  'P_00395_RIGHT_MLO_587.png',
#  'P_00396_LEFT_CC_588.png',
#  'P_00396_LEFT_MLO_589.png',
#  'P_00398_LEFT_CC_591.png',
#  'P_00398_LEFT_MLO_592.png',
#  'P_00399_RIGHT_CC_593.png',
#  'P_00399_RIGHT_MLO_594.png',
#  'P_00400_RIGHT_CC_595.png',
#  'P_00400_RIGHT_MLO_596.png',
#  'P_00401_LEFT_CC_597.png',
#  'P_00401_LEFT_MLO_598.png',
#  'P_00404_RIGHT_MLO_603.png',
#  'P_00406_RIGHT_CC_606.png',
#  'P_00406_RIGHT_MLO_607.png',
#  'P_00408_RIGHT_CC_608.png',
#  'P_00408_RIGHT_MLO_609.png',
#  'P_00410_RIGHT_CC_612.png',
#  'P_00410_RIGHT_MLO_613.png',
#  'P_00411_RIGHT_CC_614.png',
#  'P_00411_RIGHT_MLO_615.png',
#  'P_00412_RIGHT_CC_616.png',
#  'P_00412_RIGHT_MLO_617.png',
#  'P_00413_LEFT_CC_618.png',
#  'P_00413_LEFT_MLO_619.png',
#  'P_00414_LEFT_CC_620.png',
#  'P_00414_LEFT_MLO_621.png',
#  'P_00415_RIGHT_CC_622.png',
#  'P_00415_RIGHT_MLO_623.png',
#  'P_00417_RIGHT_CC_624.png',
#  'P_00417_RIGHT_MLO_625.png',
#  'P_00418_LEFT_CC_626.png',
#  'P_00418_LEFT_MLO_627.png',
#  'P_00418_RIGHT_CC_628.png',
#  'P_00418_RIGHT_MLO_629.png',
#  'P_00419_LEFT_CC_630.png',
#  'P_00419_LEFT_MLO_631.png',
#  'P_00419_RIGHT_CC_632.png',
#  'P_00419_RIGHT_MLO_633.png',
#  'P_00420_RIGHT_CC_634.png',
#  'P_00420_RIGHT_MLO_635.png',
#  'P_00421_LEFT_CC_636.png',
#  'P_00421_LEFT_MLO_637.png',
#  'P_00422_LEFT_CC_638.png',
#  'P_00422_LEFT_MLO_639.png',
#  'P_00423_RIGHT_CC_640.png',
#  'P_00425_RIGHT_CC_641.png',
#  'P_00425_RIGHT_MLO_642.png',
#  'P_00426_RIGHT_CC_643.png',
#  'P_00426_RIGHT_MLO_644.png',
#  'P_00427_RIGHT_MLO_645.png',
#  'P_00428_LEFT_CC_646.png',
#  'P_00430_LEFT_CC_649.png',
#  'P_00430_LEFT_MLO_650.png',
#  'P_00431_RIGHT_CC_651.png',
#  'P_00431_RIGHT_MLO_652.png',
#  'P_00432_LEFT_CC_653.png',
#  'P_00432_LEFT_MLO_654.png',
#  'P_00432_RIGHT_CC_655.png',
#  'P_00432_RIGHT_MLO_656.png',
#  'P_00435_RIGHT_MLO_659.png',
#  'P_00436_LEFT_CC_660.png',
#  'P_00436_LEFT_MLO_661.png',
#  'P_00437_LEFT_CC_662.png',
#  'P_00437_LEFT_MLO_663.png',
#  'P_00438_LEFT_CC_664.png',
#  'P_00438_LEFT_MLO_665.png',
#  'P_00439_RIGHT_CC_666.png',
#  'P_00439_RIGHT_MLO_667.png',
#  'P_00440_RIGHT_MLO_668.png',
#  'P_00441_RIGHT_MLO_669.png',
#  'P_00442_RIGHT_CC_670.png',
#  'P_00442_RIGHT_MLO_671.png',
#  'P_00443_RIGHT_MLO_672.png',
#  'P_00444_LEFT_CC_673.png',
#  'P_00444_LEFT_MLO_674.png',
#  'P_00445_LEFT_MLO_675.png',
#  'P_00447_RIGHT_CC_676.png',
#  'P_00447_RIGHT_MLO_677.png',
#  'P_00448_LEFT_CC_678.png',
#  'P_00448_LEFT_MLO_679.png',
#  'P_00450_LEFT_CC_680.png',
#  'P_00450_LEFT_MLO_681.png',
#  'P_00451_LEFT_CC_682.png',
#  'P_00451_LEFT_MLO_683.png',
#  'P_00452_LEFT_CC_684.png',
#  'P_00452_LEFT_MLO_685.png',
#  'P_00452_RIGHT_CC_686.png',
#  'P_00452_RIGHT_MLO_687.png',
#  'P_00453_LEFT_CC_688.png',
#  'P_00453_LEFT_MLO_689.png',
#  'P_00454_RIGHT_CC_690.png',
#  'P_00454_RIGHT_MLO_691.png',
#  'P_00455_LEFT_CC_692.png',
#  'P_00455_LEFT_MLO_693.png',
#  'P_00456_RIGHT_CC_694.png',
#  'P_00456_RIGHT_MLO_695.png',
#  'P_00458_LEFT_CC_698.png',
#  'P_00462_LEFT_CC_701.png',
#  'P_00462_LEFT_MLO_702.png',
#  'P_00465_LEFT_CC_705.png',
#  'P_00465_LEFT_MLO_706.png',
#  'P_00467_LEFT_CC_708.png',
#  'P_00467_LEFT_MLO_709.png',
#  'P_00467_RIGHT_CC_710.png',
#  'P_00467_RIGHT_MLO_711.png',
#  'P_00468_LEFT_CC_712.png',
#  'P_00468_LEFT_MLO_713.png',
#  'P_00469_LEFT_CC_714.png',
#  'P_00469_LEFT_MLO_715.png',
#  'P_00471_LEFT_CC_718.png',
#  'P_00471_LEFT_MLO_719.png',
#  'P_00471_RIGHT_CC_720.png',
#  'P_00471_RIGHT_MLO_721.png',
#  'P_00473_LEFT_CC_722.png',
#  'P_00473_LEFT_MLO_723.png',
#  'P_00474_LEFT_CC_724.png',
#  'P_00474_LEFT_MLO_725.png',
#  'P_00475_LEFT_MLO_726.png',
#  'P_00475_RIGHT_MLO_727.png',
#  'P_00476_LEFT_CC_728.png',
#  'P_00476_LEFT_MLO_729.png',
#  'P_00476_RIGHT_CC_730.png',
#  'P_00476_RIGHT_MLO_731.png',
#  'P_00479_LEFT_CC_732.png',
#  'P_00479_LEFT_MLO_733.png',
#  'P_00480_LEFT_CC_734.png',
#  'P_00480_LEFT_MLO_735.png',
#  'P_00480_RIGHT_CC_736.png',
#  'P_00480_RIGHT_MLO_737.png',
#  'P_00484_LEFT_CC_742.png',
#  'P_00484_LEFT_MLO_743.png',
#  'P_00484_RIGHT_CC_744.png',
#  'P_00486_RIGHT_CC_747.png',
#  'P_00486_RIGHT_MLO_748.png',
#  'P_00487_RIGHT_CC_749.png',
#  'P_00487_RIGHT_MLO_750.png',
#  'P_00488_LEFT_CC_751.png',
#  'P_00488_LEFT_MLO_752.png',
#  'P_00491_LEFT_MLO_755.png',
#  'P_00492_RIGHT_MLO_756.png',
#  'P_00496_LEFT_CC_764.png',
#  'P_00496_LEFT_MLO_765.png',
#  'P_00499_RIGHT_CC_770.png',
#  'P_00499_RIGHT_MLO_771.png',
#  'P_00502_LEFT_CC_773.png',
#  'P_00502_LEFT_MLO_774.png',
#  'P_00503_RIGHT_CC_775.png',
#  'P_00503_RIGHT_MLO_776.png',
#  'P_00504_RIGHT_MLO_777.png',
#  'P_00505_LEFT_CC_778.png',
#  'P_00505_LEFT_MLO_779.png',
#  'P_00505_RIGHT_CC_780.png',
#  'P_00505_RIGHT_MLO_781.png',
#  'P_00506_LEFT_MLO_782.png',
#  'P_00506_RIGHT_CC_783.png',
#  'P_00506_RIGHT_MLO_784.png',
#  'P_00508_LEFT_CC_785.png',
#  'P_00508_LEFT_MLO_786.png',
#  'P_00509_RIGHT_CC_787.png',
#  'P_00509_RIGHT_MLO_788.png',
#  'P_00510_RIGHT_CC_791.png',
#  'P_00510_RIGHT_MLO_792.png',
#  'P_00512_RIGHT_CC_793.png',
#  'P_00512_RIGHT_MLO_794.png',
#  'P_00515_LEFT_CC_796.png',
#  'P_00515_LEFT_MLO_797.png',
#  'P_00515_RIGHT_CC_798.png',
#  'P_00517_LEFT_CC_801.png',
#  'P_00517_LEFT_MLO_802.png',
#  'P_00518_LEFT_CC_803.png',
#  'P_00518_LEFT_MLO_804.png',
#  'P_00519_LEFT_CC_805.png',
#  'P_00519_LEFT_MLO_806.png',
#  'P_00519_RIGHT_CC_807.png',
#  'P_00519_RIGHT_MLO_808.png',
#  'P_00520_LEFT_CC_809.png',
#  'P_00520_LEFT_MLO_810.png',
#  'P_00522_RIGHT_CC_811.png',
#  'P_00522_RIGHT_MLO_812.png',
#  'P_00523_RIGHT_CC_813.png',
#  'P_00523_RIGHT_MLO_814.png',
#  'P_00526_RIGHT_CC_817.png',
#  'P_00526_RIGHT_MLO_818.png',
#  'P_00527_RIGHT_MLO_819.png',
#  'P_00528_LEFT_MLO_820.png',
#  'P_00528_RIGHT_CC_821.png',
#  'P_00528_RIGHT_MLO_822.png',
#  'P_00529_LEFT_MLO_823.png',
#  'P_00529_RIGHT_CC_824.png',
#  'P_00529_RIGHT_MLO_825.png',
#  'P_00530_LEFT_CC_826.png',
#  'P_00530_LEFT_MLO_827.png',
#  'P_00531_RIGHT_CC_828.png',
#  'P_00531_RIGHT_MLO_829.png',
#  'P_00532_LEFT_CC_830.png',
#  'P_00534_LEFT_CC_833.png',
#  'P_00534_LEFT_MLO_834.png',
#  'P_00534_RIGHT_CC_835.png',
#  'P_00534_RIGHT_MLO_836.png',
#  'P_00535_LEFT_CC_837.png',
#  'P_00538_RIGHT_CC_839.png',
#  'P_00538_RIGHT_MLO_840.png',
#  'P_00539_RIGHT_CC_841.png',
#  'P_00539_RIGHT_MLO_842.png',
#  'P_00540_LEFT_CC_843.png',
#  'P_00540_LEFT_MLO_844.png',
#  'P_00543_RIGHT_CC_845.png',
#  'P_00543_RIGHT_MLO_846.png',
#  'P_00545_LEFT_MLO_849.png',
#  'P_00546_RIGHT_MLO_850.png',
#  'P_00548_LEFT_CC_851.png',
#  'P_00548_LEFT_MLO_852.png',
#  'P_00549_LEFT_CC_853.png',
#  'P_00549_LEFT_MLO_854.png',
#  'P_00550_RIGHT_MLO_855.png',
#  'P_00551_RIGHT_CC_856.png',
#  'P_00551_RIGHT_MLO_857.png',
#  'P_00552_RIGHT_MLO_858.png',
#  'P_00553_LEFT_CC_859.png',
#  'P_00553_LEFT_MLO_860.png',
#  'P_00554_LEFT_CC_861.png',
#  'P_00554_LEFT_MLO_862.png',
#  'P_00555_RIGHT_CC_863.png',
#  'P_00555_RIGHT_MLO_864.png',
#  'P_00556_LEFT_CC_865.png',
#  'P_00556_LEFT_MLO_866.png',
#  'P_00557_LEFT_CC_867.png',
#  'P_00557_LEFT_MLO_868.png',
#  'P_00557_RIGHT_CC_869.png',
#  'P_00557_RIGHT_MLO_870.png',
#  'P_00558_RIGHT_CC_871.png',
#  'P_00558_RIGHT_MLO_872.png',
#  'P_00559_LEFT_CC_873.png',
#  'P_00559_LEFT_MLO_874.png',
#  'P_00559_RIGHT_CC_875.png',
#  'P_00559_RIGHT_MLO_876.png',
#  'P_00560_RIGHT_MLO_877.png',
#  'P_00563_RIGHT_MLO_882.png',
#  'P_00564_RIGHT_CC_883.png',
#  'P_00566_RIGHT_CC_884.png',
#  'P_00566_RIGHT_MLO_885.png',
#  'P_00568_LEFT_CC_886.png',
#  'P_00568_LEFT_MLO_887.png',
#  'P_00569_RIGHT_CC_888.png',
#  'P_00569_RIGHT_MLO_889.png',
#  'P_00571_RIGHT_CC_891.png',
#  'P_00571_RIGHT_MLO_892.png',
#  'P_00572_RIGHT_CC_893.png',
#  'P_00572_RIGHT_MLO_894.png',
#  'P_00573_RIGHT_CC_895.png',
#  'P_00573_RIGHT_MLO_896.png',
#  'P_00574_RIGHT_CC_897.png',
#  'P_00574_RIGHT_MLO_898.png',
#  'P_00575_RIGHT_MLO_899.png',
#  'P_00577_RIGHT_CC_902.png',
#  'P_00577_RIGHT_MLO_903.png',
#  'P_00578_LEFT_CC_904.png',
#  'P_00578_LEFT_MLO_905.png',
#  'P_00581_LEFT_MLO_907.png',
#  'P_00582_RIGHT_MLO_908.png',
#  'P_00583_LEFT_CC_909.png',
#  'P_00583_LEFT_MLO_910.png',
#  'P_00584_LEFT_CC_911.png',
#  'P_00584_LEFT_MLO_912.png',
#  'P_00585_LEFT_CC_913.png',
#  'P_00585_LEFT_MLO_914.png',
#  'P_00586_LEFT_CC_915.png',
#  'P_00586_LEFT_MLO_916.png',
#  'P_00591_RIGHT_CC_921.png',
#  'P_00592_LEFT_CC_923.png',
#  'P_00592_LEFT_MLO_924.png',
#  'P_00593_RIGHT_CC_925.png',
#  'P_00593_RIGHT_MLO_926.png',
#  'P_00594_LEFT_CC_927.png',
#  'P_00594_LEFT_MLO_928.png',
#  'P_00595_LEFT_CC_929.png',
#  'P_00595_LEFT_MLO_930.png',
#  'P_00596_LEFT_CC_931.png',
#  'P_00596_LEFT_MLO_932.png',
#  'P_00596_RIGHT_CC_933.png',
#  'P_00596_RIGHT_MLO_934.png',
#  'P_00597_LEFT_CC_935.png',
#  'P_00597_LEFT_MLO_936.png',
#  'P_00597_RIGHT_MLO_937.png',
#  'P_00600_LEFT_CC_940.png',
#  'P_00600_LEFT_MLO_941.png',
#  'P_00604_LEFT_CC_944.png',
#  'P_00604_LEFT_MLO_945.png',
#  'P_00605_RIGHT_MLO_946.png',
#  'P_00606_LEFT_CC_947.png',
#  'P_00606_LEFT_MLO_948.png',
#  'P_00607_RIGHT_CC_949.png',
#  'P_00607_RIGHT_MLO_950.png',
#  'P_00609_RIGHT_CC_953.png',
#  'P_00609_RIGHT_MLO_954.png',
#  'P_00611_RIGHT_CC_955.png',
#  'P_00611_RIGHT_MLO_956.png',
#  'P_00613_RIGHT_CC_958.png',
#  'P_00613_RIGHT_MLO_959.png',
#  'P_00616_LEFT_MLO_962.png',
#  'P_00617_RIGHT_MLO_963.png',
#  'P_00621_LEFT_CC_965.png',
#  'P_00621_LEFT_MLO_966.png',
#  'P_00622_LEFT_CC_967.png',
#  'P_00624_LEFT_CC_970.png',
#  'P_00624_LEFT_MLO_971.png',
#  'P_00624_RIGHT_CC_972.png',
#  'P_00624_RIGHT_MLO_973.png',
#  'P_00625_RIGHT_MLO_974.png',
#  'P_00626_LEFT_CC_975.png',
#  'P_00626_LEFT_MLO_976.png',
#  'P_00627_LEFT_CC_977.png',
#  'P_00630_LEFT_CC_980.png',
#  'P_00630_LEFT_MLO_981.png',
#  'P_00631_RIGHT_CC_982.png',
#  'P_00631_RIGHT_MLO_983.png',
#  'P_00633_RIGHT_MLO_984.png',
#  'P_00634_LEFT_CC_985.png',
#  'P_00634_LEFT_MLO_986.png',
#  'P_00634_RIGHT_MLO_987.png',
#  'P_00635_LEFT_CC_988.png',
#  'P_00635_LEFT_MLO_989.png',
#  'P_00635_RIGHT_CC_990.png',
#  'P_00635_RIGHT_MLO_991.png',
#  'P_00637_RIGHT_CC_994.png',
#  'P_00638_LEFT_CC_995.png',
#  'P_00638_LEFT_MLO_996.png',
#  'P_00639_RIGHT_CC_998.png',
#  'P_00639_RIGHT_MLO_999.png',
#  'P_00640_RIGHT_CC_1000.png',
#  'P_00640_RIGHT_MLO_1001.png',
#  'P_00642_LEFT_CC_1004.png',
#  'P_00642_LEFT_MLO_1005.png',
#  'P_00642_RIGHT_CC_1006.png',
#  'P_00642_RIGHT_MLO_1007.png',
#  'P_00644_LEFT_CC_1010.png',
#  'P_00644_LEFT_MLO_1011.png',
#  'P_00645_RIGHT_MLO_1012.png',
#  'P_00647_RIGHT_CC_1015.png',
#  'P_00647_RIGHT_MLO_1016.png',
#  'P_00648_LEFT_CC_1017.png',
#  'P_00648_LEFT_MLO_1018.png',
#  'P_00651_RIGHT_MLO_1021.png',
#  'P_00652_LEFT_MLO_1023.png',
#  'P_00653_LEFT_CC_1024.png',
#  'P_00653_LEFT_MLO_1025.png',
#  'P_00654_RIGHT_CC_1026.png',
#  'P_00654_RIGHT_MLO_1027.png',
#  'P_00655_RIGHT_CC_1028.png',
#  'P_00655_RIGHT_MLO_1029.png',
#  'P_00658_LEFT_CC_1031.png',
#  'P_00658_LEFT_MLO_1032.png',
#  'P_00659_RIGHT_MLO_1033.png',
#  'P_00660_LEFT_CC_1034.png',
#  'P_00660_LEFT_MLO_1035.png',
#  'P_00661_LEFT_CC_1036.png',
#  'P_00661_LEFT_MLO_1037.png',
#  'P_00664_RIGHT_CC_1042.png',
#  'P_00664_RIGHT_MLO_1043.png',
#  'P_00665_LEFT_MLO_1044.png',
#  'P_00666_LEFT_CC_1045.png',
#  'P_00666_LEFT_MLO_1046.png',
#  'P_00666_RIGHT_CC_1047.png',
#  'P_00666_RIGHT_MLO_1048.png',
#  'P_00667_RIGHT_CC_1049.png',
#  'P_00667_RIGHT_MLO_1050.png',
#  'P_00669_RIGHT_CC_1051.png',
#  'P_00669_RIGHT_MLO_1052.png',
#  'P_00670_RIGHT_CC_1053.png',
#  'P_00670_RIGHT_MLO_1054.png',
#  'P_00673_LEFT_MLO_1057.png',
#  'P_00673_RIGHT_MLO_1058.png',
#  'P_00674_RIGHT_CC_1059.png',
#  'P_00674_RIGHT_MLO_1060.png',
#  'P_00675_LEFT_CC_1061.png',
#  'P_00675_LEFT_MLO_1062.png',
#  'P_00678_LEFT_MLO_1067.png',
#  'P_00680_LEFT_CC_1070.png',
#  'P_00680_LEFT_MLO_1071.png',
#  'P_00680_RIGHT_CC_1072.png',
#  'P_00680_RIGHT_MLO_1073.png',
#  'P_00682_RIGHT_CC_1076.png',
#  'P_00682_RIGHT_MLO_1077.png',
#  'P_00683_RIGHT_CC_1078.png',
#  'P_00683_RIGHT_MLO_1079.png',
#  'P_00684_RIGHT_CC_1080.png',
#  'P_00684_RIGHT_MLO_1081.png',
#  'P_00685_RIGHT_CC_1082.png',
#  'P_00685_RIGHT_MLO_1083.png',
#  'P_00687_LEFT_CC_1085.png',
#  'P_00687_LEFT_MLO_1086.png',
#  'P_00690_LEFT_MLO_1087.png',
#  'P_00692_LEFT_MLO_1088.png',
#  'P_00693_LEFT_CC_1089.png',
#  'P_00693_LEFT_MLO_1090.png',
#  'P_00694_RIGHT_CC_1091.png',
#  'P_00694_RIGHT_MLO_1092.png',
#  'P_00695_RIGHT_CC_1093.png',
#  'P_00695_RIGHT_MLO_1094.png',
#  'P_00698_RIGHT_CC_1095.png',
#  'P_00698_RIGHT_MLO_1096.png',
#  'P_00700_RIGHT_CC_1099.png',
#  'P_00700_RIGHT_MLO_1100.png',
#  'P_00701_LEFT_CC_1101.png',
#  'P_00701_LEFT_MLO_1102.png',
#  'P_00702_RIGHT_CC_1103.png',
#  'P_00702_RIGHT_MLO_1104.png',
#  'P_00703_LEFT_CC_1105.png',
#  'P_00703_LEFT_MLO_1106.png',
#  'P_00704_LEFT_CC_1107.png',
#  'P_00704_LEFT_MLO_1108.png',
#  'P_00705_LEFT_CC_1109.png',
#  'P_00705_LEFT_MLO_1110.png',
#  'P_00706_RIGHT_CC_1111.png',
#  'P_00706_RIGHT_MLO_1112.png',
#  'P_00708_RIGHT_CC_1115.png',
#  'P_00708_RIGHT_MLO_1116.png',
#  'P_00709_RIGHT_CC_1117.png',
#  'P_00709_RIGHT_MLO_1118.png',
#  'P_00710_LEFT_CC_1119.png',
#  'P_00710_LEFT_MLO_1120.png',
#  'P_00710_RIGHT_CC_1121.png',
#  'P_00710_RIGHT_MLO_1122.png',
#  'P_00711_LEFT_CC_1123.png',
#  'P_00711_LEFT_MLO_1124.png',
#  'P_00711_RIGHT_CC_1125.png',
#  'P_00711_RIGHT_MLO_1126.png',
#  'P_00712_RIGHT_CC_1127.png',
#  'P_00712_RIGHT_MLO_1128.png',
#  'P_00713_LEFT_CC_1129.png',
#  'P_00715_RIGHT_CC_1130.png',
#  'P_00715_RIGHT_MLO_1131.png',
#  'P_00716_LEFT_MLO_1132.png',
#  'P_00717_RIGHT_CC_1133.png',
#  'P_00717_RIGHT_MLO_1134.png',
#  'P_00719_LEFT_CC_1136.png',
#  'P_00719_LEFT_MLO_1137.png',
#  'P_00720_RIGHT_MLO_1138.png',
#  'P_00725_LEFT_CC_1141.png',
#  'P_00725_LEFT_MLO_1142.png',
#  'P_00726_RIGHT_CC_1143.png',
#  'P_00726_RIGHT_MLO_1144.png',
#  'P_00728_RIGHT_CC_1145.png',
#  'P_00728_RIGHT_MLO_1146.png',
#  'P_00729_LEFT_CC_1147.png',
#  'P_00729_LEFT_MLO_1148.png',
#  'P_00730_RIGHT_CC_1149.png',
#  'P_00731_RIGHT_CC_1150.png',
#  'P_00731_RIGHT_MLO_1151.png',
#  'P_00732_LEFT_CC_1152.png',
#  'P_00732_LEFT_MLO_1153.png',
#  'P_00733_RIGHT_CC_1154.png',
#  'P_00733_RIGHT_MLO_1155.png',
#  'P_00734_RIGHT_CC_1156.png',
#  'P_00734_RIGHT_MLO_1157.png',
#  'P_00735_LEFT_CC_1158.png',
#  'P_00735_LEFT_MLO_1159.png',
#  'P_00736_LEFT_CC_1160.png',
#  'P_00736_LEFT_MLO_1161.png',
#  'P_00737_LEFT_CC_1162.png',
#  'P_00737_LEFT_MLO_1163.png',
#  'P_00739_LEFT_CC_1166.png',
#  'P_00739_LEFT_MLO_1167.png',
#  'P_00742_LEFT_CC_1170.png',
#  'P_00742_LEFT_MLO_1171.png',
#  'P_00743_LEFT_CC_1172.png',
#  'P_00743_LEFT_MLO_1173.png',
#  'P_00744_RIGHT_CC_1174.png',
#  'P_00744_RIGHT_MLO_1175.png',
#  'P_00746_LEFT_CC_1176.png',
#  'P_00746_LEFT_MLO_1177.png',
#  'P_00747_LEFT_CC_1178.png',
#  'P_00747_LEFT_MLO_1179.png',
#  'P_00750_LEFT_CC_1180.png',
#  'P_00750_LEFT_MLO_1181.png',
#  'P_00750_RIGHT_CC_1182.png',
#  'P_00750_RIGHT_MLO_1183.png',
#  'P_00751_LEFT_CC_1184.png',
#  'P_00753_RIGHT_CC_1187.png',
#  'P_00753_RIGHT_MLO_1188.png',
#  'P_00754_LEFT_CC_1189.png',
#  'P_00754_LEFT_MLO_1190.png',
#  'P_00757_LEFT_MLO_1191.png',
#  'P_00759_LEFT_CC_1194.png',
#  'P_00759_LEFT_MLO_1195.png',
#  'P_00761_RIGHT_CC_1196.png',
#  'P_00761_RIGHT_MLO_1197.png',
#  'P_00764_RIGHT_CC_1198.png',
#  'P_00764_RIGHT_MLO_1199.png',
#  'P_00765_RIGHT_CC_1200.png',
#  'P_00765_RIGHT_MLO_1201.png',
#  'P_00767_LEFT_CC_1204.png',
#  'P_00767_LEFT_MLO_1205.png',
#  'P_00767_RIGHT_CC_1206.png',
#  'P_00767_RIGHT_MLO_1207.png',
#  'P_00768_LEFT_CC_1208.png',
#  'P_00768_LEFT_MLO_1209.png',
#  'P_00770_RIGHT_CC_1210.png',
#  'P_00771_RIGHT_CC_1211.png',
#  'P_00771_RIGHT_MLO_1212.png',
#  'P_00772_RIGHT_CC_1213.png',
#  'P_00772_RIGHT_MLO_1214.png',
#  'P_00775_LEFT_CC_1219.png',
#  'P_00775_LEFT_MLO_1220.png',
#  'P_00776_RIGHT_CC_1221.png',
#  'P_00776_RIGHT_MLO_1222.png',
#  'P_00778_LEFT_CC_1223.png',
#  'P_00778_LEFT_MLO_1224.png',
#  'P_00778_RIGHT_CC_1225.png',
#  'P_00778_RIGHT_MLO_1226.png',
#  'P_00779_LEFT_CC_1227.png',
#  'P_00779_LEFT_MLO_1228.png',
#  'P_00780_LEFT_CC_1229.png',
#  'P_00780_LEFT_MLO_1230.png',
#  'P_00780_RIGHT_CC_1231.png',
#  'P_00780_RIGHT_MLO_1232.png',
#  'P_00781_RIGHT_CC_1233.png',
#  'P_00781_RIGHT_MLO_1234.png',
#  'P_00782_RIGHT_CC_1235.png',
#  'P_00784_RIGHT_CC_1236.png',
#  'P_00784_RIGHT_MLO_1237.png',
#  'P_00787_LEFT_CC_1238.png',
#  'P_00787_LEFT_MLO_1239.png',
#  'P_00792_LEFT_CC_1244.png',
#  'P_00792_LEFT_MLO_1245.png',
#  'P_00793_LEFT_CC_1246.png',
#  'P_00793_LEFT_MLO_1247.png',
#  'P_00794_LEFT_CC_1248.png',
#  'P_00794_LEFT_MLO_1249.png',
#  'P_00797_LEFT_CC_1252.png',
#  'P_00797_LEFT_MLO_1253.png',
#  'P_00797_RIGHT_CC_1254.png',
#  'P_00797_RIGHT_MLO_1255.png',
#  'P_00798_RIGHT_CC_1256.png',
#  'P_00798_RIGHT_MLO_1257.png',
#  'P_00799_LEFT_CC_1258.png',
#  'P_00799_LEFT_MLO_1259.png',
#  'P_00799_RIGHT_CC_1260.png',
#  'P_00799_RIGHT_MLO_1261.png',
#  'P_00801_LEFT_CC_1262.png',
#  'P_00801_LEFT_MLO_1263.png',
#  'P_00802_LEFT_CC_1264.png',
#  'P_00802_LEFT_MLO_1265.png',
#  'P_00803_LEFT_CC_1266.png',
#  'P_00806_LEFT_CC_1267.png',
#  'P_00806_LEFT_MLO_1268.png',
#  'P_00808_LEFT_MLO_1269.png',
#  'P_00809_LEFT_CC_1270.png',
#  'P_00809_LEFT_MLO_1271.png',
#  'P_00810_RIGHT_MLO_1272.png',
#  'P_00812_LEFT_CC_1274.png',
#  'P_00812_LEFT_MLO_1275.png',
#  'P_00814_LEFT_CC_1277.png',
#  'P_00814_LEFT_MLO_1278.png',
#  'P_00814_RIGHT_CC_1279.png',
#  'P_00814_RIGHT_MLO_1280.png',
#  'P_00815_LEFT_CC_1281.png',
#  'P_00815_LEFT_MLO_1282.png',
#  'P_00816_RIGHT_CC_1283.png',
#  'P_00816_RIGHT_MLO_1284.png',
#  'P_00818_RIGHT_CC_1285.png',
#  'P_00818_RIGHT_MLO_1286.png',
#  'P_00819_RIGHT_CC_1287.png',
#  'P_00819_RIGHT_MLO_1288.png',
#  'P_00823_RIGHT_CC_1293.png',
#  ...]

# %%
files = _create_image_list("./data/train_images/")
X, y = _create_image_queue(files)

# Start a new session to show example output.
with tf.Session() as sess:
    # Required to get the filename matching to run.
    sess.run(tf.local_variables_initializer())
    sess.run(tf.global_variables_initializer())

    # Coordinate the loading of image files.
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)

    # Get an image tensor and print its value.
    image_tensor, label_tensor = sess.run([X, y])
    
    plt.imshow(image_tensor)
    plt.show()
    
    plt.imshow(label_tensor)
    plt.show()
    
    # Finish off the filename queue coordinator.
    coord.request_stop()
    coord.join(threads)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-35ea7acb2fc8> in <module>()
#       1 files = _create_image_list("./data/train_images/")
# ----> 2 X, y = _create_image_queue(files)
#       3
#       4 # Start a new session to show example output.
#       5 with tf.Session() as sess:
#
# <ipython-input-12-7a535cab8468> in _create_image_queue(files)
#      17     input_queue = tf.train.slice_input_producer(files,
#      18                                             num_epochs=None,
# ---> 19                                             shuffle=True)
#      20
#      21     image, label = _read_images_from_disk(input_queue.dequeue(), size=320)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\training\input.py in slice_input_producer(tensor_list, num_epochs, shuffle, seed, capacity, shared_name, name)
#     335   @end_compatibility
#     336   """
# --> 337   with ops.name_scope(name, "input_producer", tensor_list):
#     338     tensor_list = ops.convert_n_to_tensor_or_indexed_slices(tensor_list)
#     339     if not tensor_list:
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\ops.py in __enter__(self)
#    5768       if self._values is None:
#    5769         self._values = []
# -> 5770       g = _get_graph_from_inputs(self._values)
#    5771       self._g_manager = g.as_default()
#    5772       self._g_manager.__enter__()
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\ops.py in _get_graph_from_inputs(op_input_list, graph)
#    5402     return get_default_graph()
#    5403
# -> 5404   op_input_list = tuple(op_input_list)  # Handle generators correctly
#    5405   if graph and not isinstance(graph, Graph):
#    5406     raise TypeError("Input graph needs to be a Graph: %s" % graph)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\ops.py in __iter__(self)
#     398     if not context.executing_eagerly():
#     399       raise TypeError(
# --> 400           "Tensor objects are not iterable when eager execution is not "
#     401           "enabled. To iterate over this tensor use tf.map_fn.")
#     402     shape = self._shape_tuple()
#
# TypeError: Tensor objects are not iterable when eager execution is not enabled. To iterate over this tensor use tf.map_fn.

# %%
print(_create_image_list("./data/train_images/"))
# Out:
# Tensor("Const_1:0", shape=(2390,), dtype=string)

# %%
def _parse_function(filename, size=640):
    image_string = tf.read_file(filename)
    image_decoded = tf.image.decode_image(image_string)

    cropped_image = tf.random_crop(image_decoded, size=[size, size, 3])

    image = cropped_image[:, :, 0]
    label = cropped_image[:, :, 1]

    return image, label

def _get_dataset(image_dir, batch_size=16):
    filenames = tf.constant(os.listdir(image_dir))

    dataset = tf.data.Dataset.from_tensor_slices((filenames))
    dataset = dataset.map(_parse_function).batch(batch_size)
    iterator = dataset.make_one_shot_iterator()
    image_batch, label_batch  = iterator.get_next()

    return image_batch, label_batch

# %%
X, y = _get_dataset("./data/train_images")

# Start a new session to show example output.
with tf.Session() as sess:
    # Required to get the filename matching to run.
    sess.run(tf.local_variables_initializer())
    sess.run(tf.global_variables_initializer())

    # Coordinate the loading of image files.
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)

    # Get an image tensor and print its value.
    image_tensor, label_tensor = sess.run([X, y])
    
    plt.imshow(image_tensor)
    plt.show()
    
    plt.imshow(label_tensor)
    plt.show()
    
    # Finish off the filename queue coordinator.
    coord.request_stop()
    coord.join(threads)
# Out:
# INFO:tensorflow:Error reported to Coordinator: <class 'tensorflow.python.framework.errors_impl.CancelledError'>, Enqueue operation was cancelled
# 	 [[Node: input_producer_1/input_producer_1_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_STRING], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](input_producer_1, input_producer_1/RandomShuffle)]]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: NewRandomAccessFile failed to Create/Open: P_00001_LEFT_CC_1.png : The system cannot find the file specified.
# ; No such file or directory
# 	 [[Node: ReadFile = ReadFile[](arg0)]]
# 	 [[Node: IteratorGetNext_3 = IteratorGetNext[output_shapes=[[?,640,640], [?,640,640]], output_types=[DT_UINT8, DT_UINT8], _device="/job:localhost/replica:0/task:0/device:CPU:0"](OneShotIterator_3)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-24-29f631e63fc2> in <module>()
#      12
#      13     # Get an image tensor and print its value.
# ---> 14     image_tensor, label_tensor = sess.run([X, y])
#      15
#      16     plt.imshow(image_tensor)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# NotFoundError: NewRandomAccessFile failed to Create/Open: P_00001_LEFT_CC_1.png : The system cannot find the file specified.
# ; No such file or directory
# 	 [[Node: ReadFile = ReadFile[](arg0)]]
# 	 [[Node: IteratorGetNext_3 = IteratorGetNext[output_shapes=[[?,640,640], [?,640,640]], output_types=[DT_UINT8, DT_UINT8], _device="/job:localhost/replica:0/task:0/device:CPU:0"](OneShotIterator_3)]]

# %%
image, label = _read_images("./data/train_images/", crop_size=640)
batch_size = 8
X, y = tf.train.shuffle_batch([image, label], batch_size=batch_size, capacity=2000, seed=None, min_after_dequeue=1000)

# Start a new session to show example output.
with tf.Session() as sess:
    # Required to get the filename matching to run.
    sess.run(tf.local_variables_initializer())
    sess.run(tf.global_variables_initializer())

    # Coordinate the loading of image files.
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    
    for i in range(3):
        # Get an image tensor and print its value.
        image_tensor, label_tensor = sess.run([X, y])

        plt.imshow(image_tensor[0])
        plt.show()

        plt.imshow(label_tensor[0])
        plt.show()
    
    # Finish off the filename queue coordinator.
    coord.request_stop()
    coord.join(threads)

# %%
filenames = tf.train.string_input_producer(tf.train.match_filenames_once("./data/train_images/" + "*.png"), shuffle=True)

dataset = tf.data.Dataset.from_tensor_slices((filenames))
dataset = dataset.map(_parse_function).batch(16)
iterator = dataset.make_one_shot_iterator()
image_batch, label_batch  = iterator.get_next()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     517     try:
# --> 518       str_values = [compat.as_bytes(x) for x in proto_values]
#     519     except TypeError:
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\tensor_util.py in <listcomp>(.0)
#     517     try:
# --> 518       str_values = [compat.as_bytes(x) for x in proto_values]
#     519     except TypeError:
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\util\compat.py in as_bytes(bytes_or_text, encoding)
#      67     raise TypeError('Expected binary or unicode string, got %r' %
# ---> 68                     (bytes_or_text,))
#      69
#
# TypeError: Expected binary or unicode string, got <tensorflow.python.ops.data_flow_ops.FIFOQueue object at 0x000002516B3A1E80>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-d00344669df9> in <module>()
#       1 filenames = tf.train.string_input_producer(tf.train.match_filenames_once("./data/train_images/" + "*.png"))
#       2
# ----> 3 dataset = tf.data.Dataset.from_tensor_slices((filenames))
#       4 dataset = dataset.map(_parse_function).batch(16)
#       5 iterator = dataset.make_one_shot_iterator()
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in from_tensor_slices(tensors)
#     220       Dataset: A `Dataset`.
#     221     """
# --> 222     return TensorSliceDataset(tensors)
#     223
#     224   @staticmethod
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, tensors)
#    1015           if sparse_tensor_lib.is_sparse(t) else ops.convert_to_tensor(
#    1016               t, name="component_%d" % i)
# -> 1017           for i, t in enumerate(nest.flatten(tensors))
#    1018       ])
#    1019       flat_tensors = nest.flatten(tensors)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in <listcomp>(.0)
#    1015           if sparse_tensor_lib.is_sparse(t) else ops.convert_to_tensor(
#    1016               t, name="component_%d" % i)
# -> 1017           for i, t in enumerate(nest.flatten(tensors))
#    1018       ])
#    1019       flat_tensors = nest.flatten(tensors)
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, preferred_dtype)
#     948       name=name,
#     949       preferred_dtype=preferred_dtype,
# --> 950       as_ref=False)
#     951
#     952
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1038
#    1039     if ret is None:
# -> 1040       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1041
#    1042     if ret is NotImplemented:
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     233                                          as_ref=False):
#     234   _ = as_ref
# --> 235   return constant(v, dtype=dtype, name=name)
#     236
#     237
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     212   tensor_value.tensor.CopyFrom(
#     213       tensor_util.make_tensor_proto(
# --> 214           value, dtype=dtype, shape=shape, verify_shape=verify_shape))
#     215   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     216   const_tensor = g.create_op(
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\tensorflow\python\framework\tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     520       raise TypeError("Failed to convert object of type %s to Tensor. "
#     521                       "Contents: %s. Consider casting elements to a "
# --> 522                       "supported type." % (type(values), values))
#     523     tensor_proto.string_val.extend(str_values)
#     524     return tensor_proto
#
# TypeError: Failed to convert object of type <class 'tensorflow.python.ops.data_flow_ops.FIFOQueue'> to Tensor. Contents: <tensorflow.python.ops.data_flow_ops.FIFOQueue object at 0x000002516B3A1E80>. Consider casting elements to a supported type.

# %%
def _parse_function(filename, size=640):
    image_string = tf.read_file(filename)
    image_decoded = tf.image.decode_image(image_string)
    
    cropped_image = tf.random_crop(image_decoded, size=[size, size, 3])
    
    image = cropped_image[:,:,0]
    label = cropped_image[:,:,1]
    
    return image, label

def _read_images(image_dir, crop_size):
    filenames = tf.train.match_filenames_once(image_dir + "*.png")
    filename_queue = tf.train.string_input_producer(filenames)

    # create the reader
    image_reader = tf.WholeFileReader()

    # Read a whole file from the queue
    filename, image_file = image_reader.read(filename_queue)

    # decode the image
    raw_image = tf.image.decode_png(image_file)
    
    # crop the image
    raw_image = tf.random_crop(raw_image, size=[crop_size, crop_size, 3])

    image = raw_image[:, :, 0]
    label = raw_image[:, :, 1]

    return image, label

# %%
# create the queue
image, label = _read_images("./data/train_images/", 640)

X_def, y_def = tf.train.batch([image, label], batch_size=16)

# Start a new session to show example output.
with tf.Session() as sess:
    # Required to get the filename matching to run.
    sess.run(tf.local_variables_initializer())
    sess.run(tf.global_variables_initializer())

    # Coordinate the loading of image files.
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)

    for i in range(3):
        # Get an image tensor and print its value.
        image_tensor, label_tensor = sess.run([X_def, y_def])
        
        for j in range(6):
            plt.imshow(np.squeeze(image_tensor[j]))
            plt.title("Image")
            plt.show()

            plt.imshow(np.squeeze(label_tensor[j]))
            plt.title("Label")
            plt.show()
    
    # Finish off the filename queue coordinator.
    coord.request_stop()
    coord.join(threads)
