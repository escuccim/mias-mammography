# %%
import PIL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import shutil
import re
from scipy.misc import imresize
from mammo_utils import create_mask, half_image
# %matplotlib inline

# %%
## rename the files to include the patient id so we can match the image up with the labels
## also copy the images to a single directory so we have them all in one place
def rename_and_copy_files(path, sourcedir="JPEG512", destdir="AllJPEGS512", scan_type="FULL"):
    directories = os.listdir(path+sourcedir)
    source_path = path + sourcedir + "/"
    destination_path = path + destdir + "/"
    
    # keep a counter so each file has a unique name
    i = 1
    
    # loop through the directories
    for directory in directories:
        # get the patient number and image type from the directory name
        patient_id = re.findall("_(P_[\d]+)_", directory)
        
        if len(patient_id) > 0:
            patient_id = str(patient_id[0])
        else:
            continue
        
        image_side = re.findall("_(LEFT|RIGHT)_", directory)
        
        if len(image_side) > 0:
            image_side = str(image_side[0])
        else:
            continue
        
        image_type = re.findall("(CC|MLO)", directory)
        if len(image_type) > 0:
            image_type = str(image_type[0])
        else:
            continue
        
        if not patient_id:
            continue
            
        # get the subdirectories
        subdir = os.listdir(source_path+directory)
        flag = False
        
        # get the next level of subdirectories
        if scan_type == 'FULL':
            subdir = subdir[0]
        elif (scan_type == "MASK") and (len(subdir) > 1):
            subdir = subdir[1]
        else:
            subdir = subdir[0]
            flag = True
            
        subsubdir = os.listdir(source_path+directory+'/'+subdir)
        if flag == False:
            files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[0])
            path = source_path+directory+'/'+subdir+'/'+subsubdir[0]
        else:
            try:
                if "mask" in str(subsubdir[0]):
                    files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[0])
                    path = source_path+directory+'/'+subdir+'/'+subsubdir[0]
                else:
                    files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[1])
                    path = source_path+directory+'/'+subdir+'/'+subsubdir[1]
            except:
                continue

        for file in files:
            # rename the file so we know where it came from, if image is not properly labeled skip it
            try:
                new_name = path+'/'+patient_id+'_'+image_side+'_'+image_type+'_'+scan_type+'.jpg'
                os.rename(path+'/'+file, new_name)
            except:
                print("Error:", new_name)
                continue
            
            # make sure the destination directory exists
            try:
                os.stat(destination_path)
            except:
                os.mkdir(destination_path)  
            
            # copy the files so they are all in one directory
            shutil.copy(new_name, destination_path)

        i += 1

## for the masks that are too big we are going to attempt to slice it into four slices, one for each corner.
## this function makes sure that the corners don't run off the image
def check_slice_corners(image_slice, full_image_arr, corners):
    h, w = image_slice.shape
    image_h, image_w = full_image_arr.shape
    
    # if the slice is the right shape return it
    if (h == 299) & (w == 299) and (np.mean(image_slice) > 25):
        return image_slice
    
    # else try to reframe it by checking each corner
    else:
        if corners[0] < 0:
            corners[0] = 0
            corners[1] = 299
        elif corners[1] > image_h:
            corners[1] = image_h
            corners[0] = image_h - 299
        
        if corners[2] < 0:
            corners[2] = 0
            corners[3] = 299
        elif corners[3] > image_w:
            corners[3] = image_w
            corners[2] = image_w - 299
            
        image_slice = full_image_arr[corners[0]:corners[1],corners[2]:corners[3]]
        
        # check that the slice contains useable info and doesn't just contain empty space
        if (np.mean(image_slice) > 25):
            return image_slice
    
    # else there is a problem, return an unusable array
    return np.array([0]).reshape((1,1))
        
## function to create ROI slices from masks and full images
## inputs: mask_dir and image_dir - paths to directories containing respective images
##         output - if True will output each file processed, 
##                  if False will only output errors and warnings, 
##                  if None won't ouput anything
## returns: numpy array of images and list of corresponding file names
def create_roi_slices(mask_dir, image_dir, output=True):
    # loop through mask directory
    mask_files = os.listdir(mask_dir)
    slices_list = []
    image_names_list = []

    for mask in mask_files:
        if output:
            print(mask)
        
        # open the full image
        image_file = mask.replace("MASK", "FULL")
        
        # some files have multiple masks, handle that case
        image_file = re.sub("(00\d+).jpg", ".jpg", image_file)
        base_image_file = image_file
        
        # try to open the image, if it doesn't exist continue
        try:
            full_image = PIL.Image.open(image_dir + "/" + image_file)
        except:
            # strip the image_file down to the bare name and then try some variations
            image_file = image_file.replace("_FULL", "")
            image_file = re.sub("_(\d).jpg", ".jpg", image_file)
            image_file = image_file.replace("000000", "")
            base_image_file = image_file.replace("000001", "")
            image_file = base_image_file.replace(".jpg", "000000.jpg")
            try:
                full_image = PIL.Image.open(image_dir + "/" + image_file)
            except:
                image_file = base_image_file.replace(".jpg", "_FULL.jpg")
                try:
                    full_image = PIL.Image.open(image_dir + "/" + image_file)
                except:
                    print("Error:", image_file)
                    continue

        # scale the full image to half size
        full_image = half_image(full_image)
        image_h, image_w = full_image.size
        
        # turn it into an array
        full_image_arr = np.array(full_image)
        
        # get rid of the extra dimensions with unneccessary info
        full_image_arr = full_image_arr[:,:,0]
        image_h, image_w = full_image_arr.shape
        
        # get the mask, if the mask is bigger than the slice we will create multiple slices 
        # using the corners of the mask. 
        center_row, center_col, too_big = create_mask(mask_dir + "/" + mask, full_image_arr)
        
        # if there is a problem then skip this one
        if (center_row == 0) and (center_col == 0):
            continue
        
        # if the mask (with 20 pixel margin) will fit in one slice do that
        if not too_big:
            full_image_slice = full_image_arr[center_row-150:center_row+149,center_col-150:center_col+149]
        
        # otherwise if the mask is too big we are going to cut the ROI into multiple slices so each contains an edge
        else:
            if output is not None:
                print(mask, "Mask too big, reframing...")
                
            # get the height and width of the mask
            mask_height = center_row[1] - center_row[0]
            mask_width = center_col[1] - center_col[0]
            
            mask_too_high = mask_height > 309
            mask_too_wide = mask_width > 309
            
            # first let's size the abnormality down so it fits in one slice and use that as well
            mask_size = np.max([mask_height, mask_width])
            
            use_full_slice = False
            full_image_slice = full_image_arr[center_row[0] - 10:center_row[0] + mask_size,center_col[0] - 10:center_col[0] + mask_size]
            
            # if the slice isn't shaped right just ignore it, this isn't important enough to try to reshape it
            if full_image_slice.shape[0] == full_image_slice.shape[1]:
                try:
                    full_image_slice = imresize(full_image_slice, (299,299))
                    use_full_slice = True
                except:
                    use_full_slice = False
            
            # let's create the set of corners for each slice
            slice_1_corners = [center_row[0], center_row[0] + 299, center_col[0], center_col[0]+299]
            slice_2_corners = [center_row[0], center_row[0] + 299, center_col[1] - 299, center_col[1]]
            slice_3_corners = [center_row[1] - 299, center_row[1], center_col[0], center_col[0] + 299]
            slice_4_corners = [center_row[1] - 299, center_row[1], center_col[1] - 299, center_col[1]]
            
            # now let's cut the ROI into up to four slices so that each contains an edge
            if mask_too_wide:
                full_image_slice_1 = full_image_arr[center_row[0]:center_row[0]+299,center_col[0]:center_col[0]+299]
                full_image_slice_2 = full_image_arr[center_row[0]:center_row[0]+299,center_col[1]-299:center_col[1]]
                
                # check the shape of the slices
                full_image_slice_1 = check_slice_corners(full_image_slice_1, full_image_arr, slice_1_corners)
                full_image_slice_2 = check_slice_corners(full_image_slice_2, full_image_arr, slice_2_corners)
            
            # if the mask is not too wide create slices that will fail the test and not be used
            else:
                full_image_slice_1 = np.array([0]).reshape(1,1)
                full_image_slice_2 = np.array([0]).reshape(1,1)
                
            if mask_too_high:
                full_image_slice_3 = full_image_arr[center_row[1]-299:center_row[1],center_col[0]:center_col[0]+299]
                full_image_slice_4 = full_image_arr[center_row[1]-299:center_row[1],center_col[1]-299:center_col[1]]            
                
                # check the shapes
                full_image_slice_3 = check_slice_corners(full_image_slice_3, full_image_arr, slice_3_corners)
                full_image_slice_4 = check_slice_corners(full_image_slice_4, full_image_arr, slice_4_corners)
            
            # if the mask is not too high create slices that will fail the test and not be used    
            else:
                full_image_slice_3 = np.array([0]).reshape(1,1)
                full_image_slice_4 = np.array([0]).reshape(1,1)
                
        # if the slice is the wrong shape the mask must be too close to the edges of the scan, move it so it fits
        if full_image_slice.shape != (299,299) and not too_big:
            if (center_row - 150 < 0):
                center_row = 150
            elif center_row + 150 > image_h:
                center_row = image_h - 150
            
            if center_col - 150 < 0:
                center_col = 150
            elif center_col + 150 > image_w:
                center_col = image_w - 150
            
            if not too_big:
                full_image_slice = full_image_arr[center_row-150:center_row+149,center_col-150:center_col+149]
            elif output is not None:
                print(mask, "Slice is wrong size:")
        
        # if the main slice is the right shape add it to the list
        if full_image_slice.shape == (299,299):
            slices_list.append(full_image_slice.reshape(299,299,1))
            image_names_list.append(base_image_file.replace("_FULL", ""))
        
        # if we have multiple slices check them
        if too_big:
            if full_image_slice_1.shape == (299,299):
                slices_list.append(full_image_slice_1.reshape(299,299,1))
                image_names_list.append(base_image_file.replace("_FULL", ""))
            elif output is not None:
                print("Slice_1 wrong shape:", full_image_slice_1.shape, "- image", base_image_file)
                
            if full_image_slice_2.shape == (299,299):
                slices_list.append(full_image_slice_2.reshape(299,299,1))
                image_names_list.append(base_image_file.replace("_FULL", ""))
            elif output is not None:
                print("Slice_2 wrong shape:", full_image_slice_2.shape, "- image", base_image_file)
                
            if full_image_slice_3.shape == (299,299):
                slices_list.append(full_image_slice_3.reshape(299,299,1))
                image_names_list.append(base_image_file.replace("_FULL", ""))
            elif output is not None:
                print("Slice_3 wrong shape:", full_image_slice_3.shape, "- image", base_image_file)
                
            if full_image_slice_4.shape == (299,299):
                slices_list.append(full_image_slice_4.reshape(299,299,1))
                image_names_list.append(base_image_file.replace("_FULL", ""))
            elif output is not None:
                print("Slice_4 wrong shape:", full_image_slice_4.shape, "- image", base_image_file)
        
    return np.array(slices_list), image_names_list

# %% [markdown]
# ## Mass Train

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Train ROI JPEGs", "Mass Train All Mask JPEGs Full", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Train JPEGs Full 2", "Mass Train All JPEGs Full", scan_type="FULL")
# Out:
# Error: Patient-Mass-Training_P_00779_LEFT_CC_1/Study_DDSM_MG[20160720]
# Error: Patient-Mass-Training_P_01849_RIGHT_MLO_1/Study_DDSM_MG[20160720]

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Train All Mask JPEGs Full"
image_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Train All JPEGs Full"

mass_train_slices, mass_train_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# P_00044_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00044_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00044_RIGHT_MLO_FULL.jpg
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# P_00051_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00051_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00051_LEFT_CC_FULL.jpg
# P_00051_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00051_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00051_LEFT_MLO_FULL.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00059_LEFT_CC000000.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00059_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00108_LEFT_CC_MASK.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00108_LEFT_MLO_MASK.jpg
# P_00110_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00110_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00120_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00120_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00120_LEFT_CC_FULL.jpg
# P_00120_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00128_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00146_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00146_RIGHT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00146_RIGHT_CC_FULL.jpg
# P_00190_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00190_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00190_LEFT_MLO_FULL.jpg
# P_00206_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00206_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00206_RIGHT_MLO_FULL.jpg
# P_00234_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00236_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00236_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00236_RIGHT_MLO_FULL.jpg
# P_00265_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00279_LEFT_CC_MASK.jpg
# Error: P_00279_LEFT_MLO_FULL.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00304_LEFT_MLO_MASK.jpg
# P_00314_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00314_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00319_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00319_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00319_LEFT_CC_FULL.jpg
# P_00335_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00335_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00335_LEFT_MLO_FULL.jpg
# P_00363_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00363_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00363_LEFT_MLO_FULL.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00384_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00384_RIGHT_MLO_MASK.jpg
# P_00413_LEFT_CC_MASK.jpg Mask too big, reframing...
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00423_RIGHT_CC_MASK.jpg
# P_00423_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00431_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00431_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00431_RIGHT_MLO_FULL.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00436_LEFT_CC_MASK.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00436_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00453_LEFT_CC_MASK.jpg
# Mishaped mask, resizing mask D:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00453_LEFT_MLO_MASK.jpg
# P_00462_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00462_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00462_LEFT_CC_FULL.jpg
# P_00462_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00517_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00517_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00517_LEFT_CC_FULL.jpg
# P_00517_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00517_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00517_LEFT_MLO_FULL.jpg
# P_00539_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00568_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00568_LEFT_MLO_MASK.jpg Mask too big, reframing...

# %%
print("Mass Train Slices shape:",mass_train_slices.shape)
print("Mass Train File Name List:", len(mass_train_image_names))

# %%
# check image to make sure it matches the cropped image
plt.imshow(mass_train_slices[437].reshape(299,299))
plt.title(mass_train_image_names[437])

# %%
# P_00059_LEFT_CC
for i in range(len(mass_train_image_names)):
    if mass_train_image_names[i] == "P_00059_LEFT_CC.jpg":
        plt.imshow(mass_train_slices[i].reshape(299,299))
        plt.title("P_00059_LEFT_CC.jpg - idx: " + str(i))
        plt.show()

# %%
# process labels for slices
train_labels = pd.read_pickle(os.path.join("data", "train_labels.pkl"))
train_labels['IMAGE_NAME2'] = train_labels.index
train_labels = train_labels.drop_duplicates(['IMAGE_NAME2'])

#mass_train_image_names = np.load(os.path.join("data", "mass_train_filenames.npy"))
mass_train_labels = []

for image in mass_train_image_names:
    label = train_labels.loc[image]['CLASS']
    mass_train_labels.append(label)
    
mass_train_labels = np.array(mass_train_labels)
print("Mass Train Labels:", len(mass_train_labels))
# Out:
# Mass Train Labels: 1387

# %%
np.save(os.path.join("data", "mass_train_slices.npy"), mass_train_slices)
np.save(os.path.join("data", "mass_train_filenames.npy"), mass_train_image_names)
np.save(os.path.join("data", "mass_train_labels.npy"), mass_train_labels)

# %% [markdown]
# ## Calc Train

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Train ROI JPEGsl", "Calc Train All Mask JPEGs Full", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Train All JPEGs Full", "Calc Train All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Train All Mask JPEGs Full"
image_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Train All Full JPEGs"

calc_train_slices, calc_train_image_names = create_roi_slices(mask_dir, image_dir, output=True)
# Out:
# P_00005_RIGHT_CC_MASK.jpg
# P_00005_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00005_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00005_RIGHT_CC_FULL.jpg
# P_00005_RIGHT_MLO_MASK.jpg
# P_00005_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Slice_3 wrong shape: (1, 1) - image P_00005_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00005_RIGHT_MLO_FULL.jpg
# P_00007_LEFT_CC_MASK.jpg
# P_00007_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00007_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00007_LEFT_CC_FULL.jpg
# P_00007_LEFT_MLO_MASK.jpg
# P_00007_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00008_LEFT_CC_MASK.jpg
# P_00008_LEFT_MLO_MASK.jpg
# P_00008_RIGHT_CC_MASK.jpg
# P_00008_RIGHT_MLO_MASK.jpg
# P_00010_LEFT_CC_MASK.jpg
# P_00010_LEFT_MLO_MASK.jpg
# P_00011_LEFT_CC_MASK.jpg
# P_00011_LEFT_MLO_MASK.jpg
# P_00012_LEFT_CC_MASK.jpg
# P_00012_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00012_LEFT_MLO_MASK.jpg
# P_00012_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00013_RIGHT_MLO_MASK.jpg
# P_00013_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00013_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00013_RIGHT_MLO_FULL.jpg
# P_00014_LEFT_CC_MASK.jpg
# P_00014_LEFT_MLO_MASK.jpg
# P_00016_LEFT_CC_MASK.jpg
# P_00016_LEFT_MLO_MASK.jpg
# P_00019_RIGHT_CC_MASK.jpg
# P_00019_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00019_RIGHT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00019_RIGHT_CC_FULL.jpg
# P_00019_RIGHT_MLO_MASK.jpg
# P_00019_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00020_LEFT_CC_MASK.jpg
# P_00020_LEFT_MLO_MASK.jpg
# P_00022_LEFT_CC_MASK.jpg
# P_00022_LEFT_MLO_MASK.jpg
# P_00024_LEFT_CC_MASK.jpg
# P_00024_LEFT_MLO_MASK.jpg
# P_00028_LEFT_MLO_MASK.jpg
# P_00029_LEFT_CC_MASK.jpg
# P_00029_LEFT_MLO_MASK.jpg
# P_00030_LEFT_CC_MASK.jpg
# P_00030_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00030_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00030_LEFT_CC_FULL.jpg
# P_00030_LEFT_MLO_MASK.jpg
# P_00030_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00030_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00030_LEFT_MLO_FULL.jpg
# P_00030_RIGHT_CC_MASK.jpg
# P_00030_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00030_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00030_RIGHT_CC_FULL.jpg
# P_00030_RIGHT_MLO_MASK.jpg
# P_00030_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00031_LEFT_CC_MASK.jpg
# P_00034_RIGHT_CC_MASK.jpg
# P_00034_RIGHT_MLO_MASK.jpg
# P_00043_LEFT_MLO_MASK.jpg
# P_00043_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00047_LEFT_CC_MASK.jpg
# P_00047_LEFT_MLO_MASK.jpg
# P_00048_RIGHT_CC_MASK.jpg
# P_00048_RIGHT_MLO_MASK.jpg
# P_00049_RIGHT_CC_MASK.jpg
# P_00049_RIGHT_MLO_MASK.jpg
# P_00060_RIGHT_CC_MASK.jpg
# P_00060_RIGHT_MLO_MASK.jpg
# P_00062_LEFT_CC_MASK.jpg
# P_00062_LEFT_MLO_MASK.jpg
# P_00063_RIGHT_CC_MASK.jpg
# P_00063_RIGHT_MLO_MASK.jpg
# P_00071_RIGHT_CC_MASK.jpg
# P_00071_RIGHT_MLO_MASK.jpg
# P_00078_LEFT_CC_MASK.jpg
# P_00078_LEFT_MLO_MASK.jpg
# P_00083_RIGHT_CC_MASK.jpg
# P_00084_LEFT_CC_MASK.jpg
# P_00084_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00084_LEFT_MLO_MASK.jpg
# P_00084_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00084_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00084_LEFT_MLO_FULL.jpg
# P_00085_RIGHT_CC_MASK.jpg
# P_00085_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00085_RIGHT_MLO_MASK.jpg
# P_00085_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00088_LEFT_CC_MASK.jpg
# P_00088_LEFT_MLO_MASK.jpg
# P_00091_LEFT_CC_MASK.jpg
# P_00091_LEFT_MLO_MASK.jpg
# P_00098_LEFT_CC_MASK.jpg
# P_00098_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00098_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00098_LEFT_CC_FULL.jpg
# P_00098_LEFT_MLO_MASK.jpg
# P_00098_RIGHT_CC_MASK.jpg
# P_00098_RIGHT_MLO_MASK.jpg
# P_00098_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00101_RIGHT_CC_MASK.jpg
# P_00101_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00101_RIGHT_MLO_MASK.jpg
# P_00101_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00105_LEFT_CC_MASK.jpg
# P_00105_LEFT_MLO_MASK.jpg
# P_00106_RIGHT_CC_MASK.jpg
# P_00106_RIGHT_MLO_MASK.jpg
# P_00112_LEFT_CC_MASK.jpg
# P_00112_LEFT_MLO_MASK.jpg
# P_00112_RIGHT_CC_MASK.jpg
# P_00112_RIGHT_MLO_MASK.jpg
# P_00121_LEFT_CC_MASK.jpg
# P_00121_LEFT_MLO_MASK.jpg
# P_00123_LEFT_CC_MASK.jpg
# P_00123_LEFT_MLO_MASK.jpg
# P_00129_LEFT_CC_MASK.jpg
# P_00129_LEFT_MLO_MASK.jpg
# P_00136_LEFT_CC_MASK.jpg
# P_00136_LEFT_MLO_MASK.jpg
# P_00151_RIGHT_MLO_MASK.jpg
# P_00151_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00157_LEFT_CC_MASK.jpg
# P_00157_LEFT_MLO_MASK.jpg
# P_00159_LEFT_CC_MASK.jpg
# P_00159_LEFT_MLO_MASK.jpg
# P_00161_LEFT_MLO_MASK.jpg
# P_00161_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00162_LEFT_CC_MASK.jpg
# P_00162_LEFT_MLO_MASK.jpg
# P_00179_LEFT_CC_MASK.jpg
# P_00179_LEFT_MLO_MASK.jpg
# P_00181_RIGHT_CC_MASK.jpg
# P_00181_RIGHT_MLO_MASK.jpg
# P_00182_LEFT_CC_MASK.jpg
# P_00182_LEFT_MLO_MASK.jpg
# P_00183_RIGHT_MLO_MASK.jpg
# P_00185_LEFT_CC_MASK.jpg
# P_00185_LEFT_MLO_MASK.jpg
# P_00188_RIGHT_MLO_MASK.jpg
# P_00189_LEFT_CC_MASK.jpg
# P_00189_LEFT_MLO_MASK.jpg
# P_00196_RIGHT_CC_MASK.jpg
# P_00196_RIGHT_MLO_MASK.jpg
# P_00197_RIGHT_CC_MASK.jpg
# P_00197_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00197_RIGHT_MLO_MASK.jpg
# P_00197_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00197_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00197_RIGHT_MLO_FULL.jpg
# P_00201_LEFT_MLO_MASK.jpg
# P_00201_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00208_RIGHT_CC_MASK.jpg
# P_00208_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00208_RIGHT_MLO_MASK.jpg
# P_00220_LEFT_CC_MASK.jpg
# P_00220_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00220_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00220_LEFT_CC_FULL.jpg
# P_00220_LEFT_MLO_MASK.jpg
# P_00220_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00224_LEFT_CC_MASK.jpg
# P_00224_LEFT_MLO_MASK.jpg
# P_00232_RIGHT_CC_MASK.jpg
# P_00232_RIGHT_MLO_MASK.jpg
# P_00243_LEFT_CC_MASK.jpg
# P_00243_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00243_LEFT_MLO_MASK.jpg
# P_00243_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00245_RIGHT_MLO_MASK.jpg
# P_00250_LEFT_MLO_MASK.jpg
# P_00251_RIGHT_CC_MASK.jpg
# P_00251_RIGHT_MLO_MASK.jpg
# P_00255_RIGHT_CC_MASK.jpg
# P_00255_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00255_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00255_RIGHT_CC_FULL.jpg
# P_00255_RIGHT_MLO_MASK.jpg
# P_00255_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00256_LEFT_CC_MASK.jpg
# P_00256_LEFT_MLO_MASK.jpg
# P_00260_RIGHT_CC_MASK.jpg
# P_00260_RIGHT_MLO_MASK.jpg
# P_00263_LEFT_MLO_MASK.jpg
# P_00266_LEFT_CC_MASK.jpg
# P_00266_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_00266_LEFT_CC_FULL.jpg
# P_00266_LEFT_MLO_MASK.jpg
# P_00266_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_00266_LEFT_MLO_FULL.jpg
# Slice_3 wrong shape: (1, 1) - image P_00266_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00266_LEFT_MLO_FULL.jpg
# P_00268_LEFT_CC_MASK.jpg
# P_00268_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00268_LEFT_MLO_MASK.jpg
# P_00268_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00269_LEFT_CC_MASK.jpg
# P_00269_LEFT_MLO_MASK.jpg
# P_00270_LEFT_CC_MASK.jpg
# P_00270_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00270_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00270_LEFT_CC_FULL.jpg
# P_00270_LEFT_MLO_MASK.jpg
# P_00270_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00270_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00270_LEFT_MLO_FULL.jpg
# P_00271_LEFT_CC_MASK.jpg
# P_00271_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00271_LEFT_MLO_MASK.jpg
# P_00271_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00274_RIGHT_MLO_MASK.jpg
# P_00275_LEFT_CC_MASK.jpg
# P_00275_LEFT_MLO_MASK.jpg
# P_00276_RIGHT_CC_MASK.jpg
# P_00276_RIGHT_MLO_MASK.jpg
# P_00280_LEFT_CC_MASK.jpg
# P_00280_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00280_LEFT_MLO_MASK.jpg
# P_00280_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00280_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00280_LEFT_MLO_FULL.jpg
# P_00282_LEFT_CC_MASK.jpg
# P_00282_LEFT_MLO_MASK.jpg
# P_00284_LEFT_CC_MASK.jpg
# P_00284_LEFT_MLO_MASK.jpg
# P_00288_RIGHT_CC_MASK.jpg
# P_00288_RIGHT_MLO_MASK.jpg
# P_00291_LEFT_CC_MASK.jpg
# P_00291_LEFT_MLO_MASK.jpg
# P_00291_RIGHT_CC_MASK.jpg
# P_00291_RIGHT_MLO_MASK.jpg
# P_00293_LEFT_CC_MASK.jpg
# P_00293_LEFT_MLO_MASK.jpg
# P_00297_RIGHT_CC_MASK.jpg
# P_00297_RIGHT_MLO_MASK.jpg
# P_00302_LEFT_CC_MASK.jpg
# P_00302_LEFT_MLO_MASK.jpg
# P_00302_RIGHT_CC_MASK.jpg
# P_00302_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00302_RIGHT_MLO_MASK.jpg
# P_00302_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00307_LEFT_CC_MASK.jpg
# P_00307_LEFT_MLO_MASK.jpg
# P_00308_LEFT_CC_MASK.jpg
# P_00308_LEFT_MLO_MASK.jpg
# P_00311_RIGHT_CC_MASK.jpg
# P_00311_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00312_RIGHT_MLO_MASK.jpg
# P_00316_RIGHT_CC_MASK.jpg
# P_00316_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00316_RIGHT_MLO_MASK.jpg
# P_00316_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00318_LEFT_MLO_MASK.jpg
# P_00321_LEFT_CC_MASK.jpg
# P_00321_LEFT_MLO_MASK.jpg
# P_00322_LEFT_CC_MASK.jpg
# P_00322_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00322_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00322_LEFT_CC_FULL.jpg
# P_00322_LEFT_MLO_MASK.jpg
# P_00322_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00326_LEFT_MLO_MASK.jpg
# P_00336_LEFT_CC_MASK.jpg
# P_00336_LEFT_MLO_MASK.jpg
# P_00337_LEFT_CC_MASK.jpg
# P_00337_LEFT_MLO_MASK.jpg
# P_00339_LEFT_CC_MASK.jpg
# P_00339_LEFT_MLO_MASK.jpg
# P_00346_RIGHT_CC_MASK.jpg
# P_00346_RIGHT_MLO_MASK.jpg
# P_00349_RIGHT_CC_MASK.jpg
# P_00349_RIGHT_MLO_MASK.jpg
# P_00355_LEFT_CC_MASK.jpg
# P_00355_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00355_LEFT_MLO_MASK.jpg
# P_00355_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00357_LEFT_CC_MASK.jpg
# P_00357_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00357_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00357_LEFT_CC_FULL.jpg
# P_00360_RIGHT_CC_MASK.jpg
# P_00360_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00360_RIGHT_MLO_MASK.jpg
# P_00360_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00360_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00360_RIGHT_MLO_FULL.jpg
# P_00364_RIGHT_CC_MASK.jpg
# P_00364_RIGHT_MLO_MASK.jpg
# P_00373_LEFT_CC_MASK.jpg
# P_00373_LEFT_MLO_MASK.jpg
# P_00377_LEFT_CC_MASK.jpg
# P_00377_LEFT_MLO_MASK.jpg
# P_00377_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00378_LEFT_CC_MASK.jpg
# P_00378_LEFT_MLO_MASK.jpg
# P_00380_RIGHT_CC_MASK.jpg
# P_00380_RIGHT_MLO_MASK.jpg
# P_00385_LEFT_CC_MASK.jpg
# P_00385_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00385_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00385_LEFT_CC_FULL.jpg
# P_00385_LEFT_MLO_MASK.jpg
# P_00385_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00385_RIGHT_CC_MASK.jpg
# P_00385_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00385_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00385_RIGHT_CC_FULL.jpg
# P_00385_RIGHT_MLO_MASK.jpg
# P_00385_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00392_LEFT_CC_MASK.jpg
# P_00392_LEFT_MLO_MASK.jpg
# P_00393_LEFT_MLO_MASK.jpg
# P_00393_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00394_LEFT_MLO_MASK.jpg
# P_00395_RIGHT_CC_MASK.jpg
# P_00395_RIGHT_MLO_MASK.jpg
# P_00398_LEFT_CC_MASK.jpg
# P_00398_LEFT_MLO_MASK.jpg
# P_00400_RIGHT_CC_MASK.jpg
# P_00400_RIGHT_MLO_MASK.jpg
# P_00404_RIGHT_MLO_MASK.jpg
# P_00410_RIGHT_CC_MASK.jpg
# P_00410_RIGHT_MLO_MASK.jpg
# P_00418_LEFT_CC_MASK.jpg
# P_00418_LEFT_MLO_MASK.jpg
# P_00418_RIGHT_CC_MASK.jpg
# P_00418_RIGHT_MLO_MASK.jpg
# P_00422_LEFT_CC_MASK.jpg
# P_00422_LEFT_MLO_MASK.jpg
# P_00425_RIGHT_CC_MASK.jpg
# P_00425_RIGHT_MLO_MASK.jpg
# P_00432_RIGHT_CC_MASK.jpg
# P_00432_RIGHT_MLO_MASK.jpg
# P_00438_LEFT_CC_MASK.jpg
# P_00438_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00438_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00438_LEFT_CC_FULL.jpg
# P_00438_LEFT_MLO_MASK.jpg
# P_00438_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00438_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00438_LEFT_MLO_FULL.jpg
# P_00443_RIGHT_MLO_MASK.jpg
# P_00443_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00443_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00443_RIGHT_MLO_FULL.jpg
# P_00445_LEFT_MLO_MASK.jpg
# P_00445_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00447_RIGHT_CC_MASK.jpg
# P_00447_RIGHT_MLO_MASK.jpg
# P_00448_LEFT_CC_MASK.jpg
# P_00448_LEFT_MLO_MASK.jpg
# P_00452_LEFT_CC_MASK.jpg
# P_00452_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00452_LEFT_MLO_MASK.jpg
# P_00452_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00452_RIGHT_CC_MASK.jpg
# P_00452_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00452_RIGHT_MLO_MASK.jpg
# P_00452_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00455_LEFT_CC_MASK.jpg
# P_00455_LEFT_MLO_MASK.jpg
# P_00456_RIGHT_CC_MASK.jpg
# P_00456_RIGHT_MLO_MASK.jpg
# P_00458_LEFT_CC_MASK.jpg
# P_00467_LEFT_CC_MASK.jpg
# P_00467_LEFT_MLO_MASK.jpg
# P_00467_RIGHT_CC_MASK.jpg
# P_00467_RIGHT_MLO_MASK.jpg
# P_00469_LEFT_CC_MASK.jpg
# P_00469_LEFT_MLO_MASK.jpg
# P_00471_LEFT_CC_MASK.jpg
# P_00471_LEFT_MLO_MASK.jpg
# P_00473_LEFT_CC_MASK.jpg
# P_00473_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00473_LEFT_MLO_MASK.jpg
# P_00473_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00474_LEFT_CC_MASK.jpg
# P_00474_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00474_LEFT_MLO_MASK.jpg
# P_00474_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00476_LEFT_CC_MASK.jpg
# P_00476_LEFT_MLO_MASK.jpg
# P_00476_RIGHT_CC_MASK.jpg
# P_00476_RIGHT_MLO_MASK.jpg
# P_00479_LEFT_CC_MASK.jpg
# P_00479_LEFT_MLO_MASK.jpg
# P_00480_LEFT_CC_MASK.jpg
# P_00480_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00480_LEFT_MLO_MASK.jpg
# P_00480_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00480_RIGHT_CC_MASK.jpg
# P_00480_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00480_RIGHT_CC_FULL.jpg
# P_00480_RIGHT_MLO_MASK.jpg
# P_00480_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00480_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00480_RIGHT_MLO_FULL.jpg
# P_00484_LEFT_CC_MASK.jpg
# P_00484_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00484_LEFT_MLO_MASK.jpg
# P_00484_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00486_RIGHT_CC_MASK.jpg
# P_00486_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00486_RIGHT_CC_FULL.jpg
# P_00486_RIGHT_MLO_MASK.jpg
# P_00486_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00491_LEFT_MLO_MASK.jpg
# P_00502_LEFT_CC_MASK.jpg
# P_00502_LEFT_MLO_MASK.jpg
# P_00503_RIGHT_CC_MASK.jpg
# P_00503_RIGHT_MLO_MASK.jpg
# P_00505_LEFT_CC_MASK.jpg
# P_00505_LEFT_MLO_MASK.jpg
# P_00505_RIGHT_CC_MASK.jpg
# P_00505_RIGHT_MLO_MASK.jpg
# P_00506_RIGHT_CC_MASK.jpg
# P_00506_RIGHT_MLO_MASK.jpg
# P_00508_LEFT_CC_MASK.jpg
# P_00508_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00508_LEFT_MLO_MASK.jpg
# P_00508_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00510_LEFT_CC_MASK.jpg
# P_00510_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00510_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00510_LEFT_CC_FULL.jpg
# P_00510_LEFT_MLO_MASK.jpg
# P_00510_RIGHT_CC_MASK.jpg
# P_00510_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00510_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00510_RIGHT_CC_FULL.jpg
# P_00510_RIGHT_MLO_MASK.jpg
# P_00510_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00519_LEFT_CC_MASK.jpg
# P_00519_LEFT_MLO_MASK.jpg
# P_00520_LEFT_CC_MASK.jpg
# P_00520_LEFT_MLO_MASK.jpg
# P_00522_RIGHT_CC_MASK.jpg
# P_00522_RIGHT_MLO_MASK.jpg
# P_00523_RIGHT_CC_MASK.jpg
# P_00523_RIGHT_MLO_MASK.jpg
# P_00527_RIGHT_MLO_MASK.jpg
# P_00529_LEFT_MLO_MASK.jpg
# P_00529_RIGHT_CC_MASK.jpg
# P_00529_RIGHT_MLO_MASK.jpg
# P_00530_LEFT_CC_MASK.jpg
# P_00530_LEFT_MLO_MASK.jpg
# P_00531_RIGHT_CC_MASK.jpg
# P_00531_RIGHT_MLO_MASK.jpg
# P_00534_RIGHT_CC_MASK.jpg
# P_00534_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00534_RIGHT_MLO_MASK.jpg
# P_00534_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00538_RIGHT_CC_MASK.jpg
# P_00538_RIGHT_MLO_MASK.jpg
# P_00539_RIGHT_CC_MASK.jpg
# P_00539_RIGHT_MLO_MASK.jpg
# P_00546_RIGHT_MLO_MASK.jpg
# P_00546_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00548_LEFT_CC_MASK.jpg
# P_00548_LEFT_MLO_MASK.jpg
# P_00551_RIGHT_CC_MASK.jpg
# P_00551_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00551_RIGHT_MLO_MASK.jpg
# P_00551_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00551_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00551_RIGHT_MLO_FULL.jpg
# P_00552_RIGHT_MLO_MASK.jpg
# P_00555_RIGHT_CC_MASK.jpg
# P_00555_RIGHT_MLO_MASK.jpg
# P_00556_LEFT_CC_MASK.jpg
# P_00556_LEFT_MLO_MASK.jpg
# P_00557_LEFT_CC_MASK.jpg
# P_00557_LEFT_MLO_MASK.jpg
# P_00557_RIGHT_CC_MASK.jpg
# P_00557_RIGHT_MLO_MASK.jpg
# P_00558_RIGHT_CC_MASK.jpg
# P_00558_RIGHT_MLO_MASK.jpg
# P_00559_RIGHT_CC_MASK.jpg
# P_00559_RIGHT_MLO_MASK.jpg
# P_00563_RIGHT_MLO_MASK.jpg
# P_00571_RIGHT_CC_MASK.jpg
# P_00571_RIGHT_MLO_MASK.jpg
# P_00573_RIGHT_CC_MASK.jpg
# P_00573_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00573_RIGHT_MLO_MASK.jpg
# P_00573_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00574_RIGHT_CC_MASK.jpg
# P_00574_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00574_RIGHT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00574_RIGHT_CC_FULL.jpg
# P_00574_RIGHT_MLO_MASK.jpg
# P_00574_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00574_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00574_RIGHT_MLO_FULL.jpg
# P_00578_LEFT_CC_MASK.jpg
# P_00578_LEFT_MLO_MASK.jpg
# P_00582_RIGHT_MLO_MASK.jpg
# P_00582_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00583_LEFT_CC_MASK.jpg
# P_00583_LEFT_MLO_MASK.jpg
# P_00584_LEFT_CC_MASK.jpg
# P_00584_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00585_LEFT_CC_MASK.jpg
# P_00585_LEFT_MLO_MASK.jpg
# P_00591_RIGHT_CC_MASK.jpg
# P_00591_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00591_RIGHT_CC_FULL.jpg
# P_00591_RIGHT_MLO_MASK.jpg
# P_00591_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00591_RIGHT_MLO_FULL.jpg
# P_00593_RIGHT_CC_MASK.jpg
# P_00593_RIGHT_MLO_MASK.jpg
# P_00594_LEFT_CC_MASK.jpg
# P_00594_LEFT_MLO_MASK.jpg
# P_00595_LEFT_CC_MASK.jpg
# P_00595_LEFT_MLO_MASK.jpg
# P_00597_LEFT_CC_MASK.jpg
# P_00597_LEFT_MLO_MASK.jpg
# P_00600_LEFT_CC_MASK.jpg
# P_00600_LEFT_MLO_MASK.jpg
# P_00601_LEFT_CC_MASK.jpg
# P_00601_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00601_LEFT_MLO_MASK.jpg
# P_00601_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00606_LEFT_CC_MASK.jpg
# P_00606_LEFT_MLO_MASK.jpg
# P_00606_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00606_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00606_LEFT_MLO_FULL.jpg
# P_00609_RIGHT_CC_MASK.jpg
# P_00609_RIGHT_MLO_MASK.jpg
# P_00609_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00609_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00609_RIGHT_MLO_FULL.jpg
# P_00613_RIGHT_CC_MASK.jpg
# P_00613_RIGHT_MLO_MASK.jpg
# P_00621_LEFT_CC_MASK.jpg
# P_00621_LEFT_MLO_MASK.jpg
# P_00624_LEFT_CC_MASK.jpg
# P_00624_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00624_LEFT_MLO_MASK.jpg
# P_00624_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00624_RIGHT_CC_MASK.jpg
# P_00624_RIGHT_MLO_MASK.jpg
# P_00625_RIGHT_MLO_MASK.jpg
# P_00627_LEFT_CC_MASK.jpg
# P_00627_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00631_RIGHT_CC_MASK.jpg
# P_00631_RIGHT_MLO_MASK.jpg
# P_00633_RIGHT_MLO_MASK.jpg
# P_00635_LEFT_CC_MASK.jpg
# P_00635_LEFT_MLO_MASK.jpg
# P_00635_RIGHT_CC_MASK.jpg
# P_00635_RIGHT_MLO_MASK.jpg
# P_00638_LEFT_CC_MASK.jpg
# P_00638_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00638_LEFT_MLO_MASK.jpg
# P_00638_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00639_RIGHT_CC_MASK.jpg
# P_00639_RIGHT_MLO_MASK.jpg
# P_00642_LEFT_CC_MASK.jpg
# P_00642_LEFT_MLO_MASK.jpg
# P_00642_RIGHT_CC_MASK.jpg
# P_00642_RIGHT_MLO_MASK.jpg
# P_00645_RIGHT_MLO_MASK.jpg
# P_00647_RIGHT_CC_MASK.jpg
# P_00647_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00647_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00647_RIGHT_CC_FULL.jpg
# P_00647_RIGHT_MLO_MASK.jpg
# P_00652_LEFT_CC_MASK.jpg
# P_00652_LEFT_MLO_MASK.jpg
# P_00654_RIGHT_CC_MASK.jpg
# P_00654_RIGHT_MLO_MASK.jpg
# P_00655_RIGHT_CC_MASK.jpg
# P_00655_RIGHT_MLO_MASK.jpg
# P_00655_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00655_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00655_RIGHT_MLO_FULL.jpg
# P_00658_LEFT_CC_MASK.jpg
# P_00658_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00658_LEFT_MLO_MASK.jpg
# P_00658_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00658_LEFT_MLO_FULL.jpg
# P_00664_RIGHT_CC_MASK.jpg
# P_00664_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00664_RIGHT_MLO_MASK.jpg
# P_00664_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00666_LEFT_CC_MASK.jpg
# P_00666_LEFT_MLO_MASK.jpg
# P_00666_RIGHT_CC_MASK.jpg
# P_00666_RIGHT_MLO_MASK.jpg
# P_00667_RIGHT_CC_MASK.jpg
# P_00667_RIGHT_MLO_MASK.jpg
# P_00669_RIGHT_CC_MASK.jpg
# P_00669_RIGHT_MLO_MASK.jpg
# P_00673_LEFT_MLO_MASK.jpg
# P_00673_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00673_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00673_LEFT_MLO_FULL.jpg
# P_00673_RIGHT_MLO_MASK.jpg
# P_00674_RIGHT_CC_MASK.jpg
# P_00674_RIGHT_MLO_MASK.jpg
# P_00680_LEFT_CC_MASK.jpg
# P_00680_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00680_LEFT_MLO_MASK.jpg
# P_00680_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00680_RIGHT_CC_MASK.jpg
# P_00680_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00680_RIGHT_MLO_MASK.jpg
# P_00680_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00682_RIGHT_CC_MASK.jpg
# P_00682_RIGHT_MLO_MASK.jpg
# P_00683_RIGHT_CC_MASK.jpg
# P_00683_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00683_RIGHT_MLO_MASK.jpg
# P_00683_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00684_RIGHT_CC_MASK.jpg
# P_00684_RIGHT_MLO_MASK.jpg
# P_00685_RIGHT_CC_MASK.jpg
# P_00685_RIGHT_MLO_MASK.jpg
# P_00685_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00685_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00685_RIGHT_MLO_FULL.jpg
# P_00693_LEFT_CC_MASK.jpg
# P_00693_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_00693_LEFT_CC_FULL.jpg
# P_00693_LEFT_MLO_MASK.jpg
# P_00693_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00693_LEFT_MLO_FULL.jpg
# P_00701_LEFT_CC_MASK.jpg
# P_00701_LEFT_MLO_MASK.jpg
# P_00704_LEFT_CC_MASK.jpg
# P_00704_LEFT_MLO_MASK.jpg
# P_00705_LEFT_CC_MASK.jpg
# P_00705_LEFT_MLO_MASK.jpg
# P_00709_RIGHT_CC_MASK.jpg
# P_00709_RIGHT_MLO_MASK.jpg
# P_00710_RIGHT_CC_MASK.jpg
# P_00710_RIGHT_MLO_MASK.jpg
# P_00710_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00710_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00710_RIGHT_MLO_FULL.jpg
# P_00712_RIGHT_CC_MASK.jpg
# P_00712_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00712_RIGHT_MLO_MASK.jpg
# P_00712_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00713_LEFT_CC_MASK.jpg
# P_00725_LEFT_CC_MASK.jpg
# P_00725_LEFT_MLO_MASK.jpg
# P_00729_LEFT_CC_MASK.jpg
# P_00729_LEFT_MLO_MASK.jpg
# P_00734_RIGHT_CC_MASK.jpg
# P_00734_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00734_RIGHT_MLO_MASK.jpg
# P_00734_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00735_LEFT_CC_MASK.jpg
# P_00735_LEFT_MLO_MASK.jpg
# P_00736_LEFT_CC_MASK.jpg
# P_00736_LEFT_MLO_MASK.jpg
# P_00743_LEFT_CC_MASK.jpg
# P_00743_LEFT_MLO_MASK.jpg
# P_00744_RIGHT_CC_MASK.jpg
# P_00744_RIGHT_MLO_MASK.jpg
# P_00750_LEFT_CC_MASK.jpg
# P_00750_LEFT_MLO_MASK.jpg
# P_00750_RIGHT_CC_MASK.jpg
# P_00750_RIGHT_MLO_MASK.jpg
# P_00751_LEFT_CC_MASK.jpg
# P_00757_LEFT_MLO_MASK.jpg
# P_00759_LEFT_CC_MASK.jpg
# P_00759_LEFT_MLO_MASK.jpg
# P_00761_RIGHT_CC_MASK.jpg
# P_00761_RIGHT_MLO_MASK.jpg
# P_00767_LEFT_CC_MASK.jpg
# P_00767_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00767_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00767_LEFT_CC_FULL.jpg
# P_00767_LEFT_MLO_MASK.jpg
# P_00767_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00767_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00767_LEFT_MLO_FULL.jpg
# P_00767_RIGHT_CC_MASK.jpg
# P_00767_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00767_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00767_RIGHT_CC_FULL.jpg
# P_00767_RIGHT_MLO_MASK.jpg
# P_00767_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00767_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00767_RIGHT_MLO_FULL.jpg
# P_00768_LEFT_CC_MASK.jpg
# P_00768_LEFT_MLO_MASK.jpg
# P_00771_RIGHT_CC_MASK.jpg
# P_00771_RIGHT_MLO_MASK.jpg
# P_00772_RIGHT_CC_MASK.jpg
# P_00772_RIGHT_MLO_MASK.jpg
# P_00778_LEFT_CC_MASK.jpg
# P_00778_LEFT_MLO_MASK.jpg
# P_00780_LEFT_CC_MASK.jpg
# P_00780_LEFT_MLO_MASK.jpg
# P_00780_RIGHT_CC_MASK.jpg
# P_00780_RIGHT_MLO_MASK.jpg
# P_00784_RIGHT_CC_MASK.jpg
# P_00784_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00784_RIGHT_MLO_MASK.jpg
# P_00784_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00787_LEFT_CC_MASK.jpg
# P_00787_LEFT_MLO_MASK.jpg
# P_00792_LEFT_CC_MASK.jpg
# P_00792_LEFT_MLO_MASK.jpg
# P_00793_LEFT_CC_MASK.jpg
# P_00793_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00793_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00793_LEFT_CC_FULL.jpg
# P_00793_LEFT_MLO_MASK.jpg
# P_00793_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00793_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00793_LEFT_MLO_FULL.jpg
# P_00799_LEFT_CC_MASK.jpg
# P_00799_LEFT_MLO_MASK.jpg
# P_00799_RIGHT_CC_MASK.jpg
# P_00799_RIGHT_MLO_MASK.jpg
# P_00806_LEFT_CC_MASK.jpg
# P_00806_LEFT_MLO_MASK.jpg
# P_00808_LEFT_MLO_MASK.jpg
# P_00809_LEFT_CC_MASK.jpg
# P_00809_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00809_LEFT_MLO_MASK.jpg
# P_00809_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00812_LEFT_CC_MASK.jpg
# P_00812_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00812_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00812_LEFT_CC_FULL.jpg
# P_00812_LEFT_MLO_MASK.jpg
# P_00812_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_00812_LEFT_MLO_FULL.jpg
# P_00814_LEFT_CC_MASK.jpg
# P_00814_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_00814_LEFT_CC_FULL.jpg
# P_00814_LEFT_MLO_MASK.jpg
# P_00814_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00814_RIGHT_CC_MASK.jpg
# P_00814_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00814_RIGHT_CC_FULL.jpg
# Slice_3 wrong shape: (1, 1) - image P_00814_RIGHT_CC_FULL.jpg
# P_00814_RIGHT_MLO_MASK.jpg
# P_00814_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00819_RIGHT_CC_MASK.jpg
# P_00819_RIGHT_MLO_MASK.jpg
# P_00824_LEFT_CC_MASK.jpg
# P_00824_LEFT_MLO_MASK.jpg
# P_00825_RIGHT_MLO_MASK.jpg
# P_00832_RIGHT_CC_MASK.jpg
# P_00832_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00832_RIGHT_MLO_MASK.jpg
# P_00832_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00832_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00832_RIGHT_MLO_FULL.jpg
# P_00833_LEFT_CC_MASK.jpg
# P_00833_LEFT_MLO_MASK.jpg
# P_00834_LEFT_CC_MASK.jpg
# P_00834_LEFT_MLO_MASK.jpg
# P_00835_LEFT_CC_MASK.jpg
# P_00835_LEFT_MLO_MASK.jpg
# P_00840_RIGHT_CC_MASK.jpg
# P_00840_RIGHT_MLO_MASK.jpg
# P_00842_LEFT_CC_MASK.jpg
# P_00842_LEFT_MLO_MASK.jpg
# P_00846_LEFT_CC_MASK.jpg
# P_00846_LEFT_MLO_MASK.jpg
# P_00847_LEFT_CC_MASK.jpg
# P_00847_LEFT_MLO_MASK.jpg
# P_00852_LEFT_CC_MASK.jpg
# P_00852_LEFT_MLO_MASK.jpg
# P_00854_RIGHT_CC_MASK.jpg
# P_00854_RIGHT_MLO_MASK.jpg
# P_00855_RIGHT_CC_MASK.jpg
# P_00856_LEFT_MLO_MASK.jpg
# P_00856_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00856_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00856_LEFT_MLO_FULL.jpg
# P_00858_LEFT_CC_MASK.jpg
# P_00858_LEFT_MLO_MASK.jpg
# P_00858_RIGHT_CC_MASK.jpg
# P_00858_RIGHT_MLO_MASK.jpg
# P_00861_RIGHT_CC_MASK.jpg
# P_00861_RIGHT_MLO_MASK.jpg
# P_00862_LEFT_CC_MASK.jpg
# P_00862_LEFT_MLO_MASK.jpg
# P_00864_LEFT_CC_MASK.jpg
# P_00864_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00864_LEFT_MLO_MASK.jpg
# P_00864_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00866_RIGHT_CC_MASK.jpg
# P_00866_RIGHT_MLO_MASK.jpg
# P_00868_RIGHT_CC_MASK.jpg
# P_00868_RIGHT_MLO_MASK.jpg
# P_00877_LEFT_CC_MASK.jpg
# P_00877_LEFT_MLO_MASK.jpg
# P_00878_LEFT_CC_MASK.jpg
# P_00878_LEFT_MLO_MASK.jpg
# P_00880_RIGHT_CC_MASK.jpg
# P_00882_LEFT_CC_MASK.jpg
# P_00882_LEFT_MLO_MASK.jpg
# P_00883_RIGHT_CC_MASK.jpg
# P_00883_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00883_RIGHT_CC_FULL.jpg
# P_00883_RIGHT_MLO_MASK.jpg
# P_00883_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00883_RIGHT_MLO_FULL.jpg
# P_00890_RIGHT_MLO_MASK.jpg
# P_00895_RIGHT_CC_MASK.jpg
# P_00895_RIGHT_MLO_MASK.jpg
# P_00897_LEFT_CC_MASK.jpg
# P_00897_LEFT_MLO_MASK.jpg
# P_00899_RIGHT_CC_MASK.jpg
# P_00899_RIGHT_MLO_MASK.jpg
# P_00909_LEFT_MLO_MASK.jpg
# P_00912_LEFT_CC_MASK.jpg
# P_00912_LEFT_MLO_MASK.jpg
# P_00916_RIGHT_MLO_MASK.jpg
# P_00923_RIGHT_CC_MASK.jpg
# P_00923_RIGHT_MLO_MASK.jpg
# P_00924_LEFT_CC_MASK.jpg
# P_00924_LEFT_MLO_MASK.jpg
# P_00924_RIGHT_CC_MASK.jpg
# P_00924_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00924_RIGHT_MLO_MASK.jpg
# P_00925_RIGHT_CC_MASK.jpg
# P_00925_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00925_RIGHT_MLO_MASK.jpg
# P_00925_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00926_LEFT_CC_MASK.jpg
# P_00926_LEFT_MLO_MASK.jpg
# P_00930_LEFT_CC_MASK.jpg
# P_00930_LEFT_MLO_MASK.jpg
# P_00933_LEFT_CC_MASK.jpg
# P_00933_LEFT_MLO_MASK.jpg
# P_00937_LEFT_CC_MASK.jpg
# P_00937_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00937_LEFT_MLO_MASK.jpg
# P_00937_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00937_RIGHT_CC_MASK.jpg
# P_00937_RIGHT_MLO_MASK.jpg
# P_00944_LEFT_CC_MASK.jpg
# P_00944_LEFT_MLO_MASK.jpg
# P_00945_RIGHT_CC_MASK.jpg
# P_00945_RIGHT_MLO_MASK.jpg
# P_00953_LEFT_CC_MASK.jpg
# P_00953_LEFT_MLO_MASK.jpg
# P_00954_RIGHT_CC_MASK.jpg
# P_00954_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00954_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00954_RIGHT_CC_FULL.jpg
# P_00954_RIGHT_MLO_MASK.jpg
# P_00954_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00955_RIGHT_CC_MASK.jpg
# P_00955_RIGHT_MLO_MASK.jpg
# P_00956_LEFT_MLO_MASK.jpg
# P_00960_LEFT_CC_MASK.jpg
# P_00960_LEFT_MLO_MASK.jpg
# P_00965_LEFT_CC_MASK.jpg
# P_00965_LEFT_MLO_MASK.jpg
# P_00967_RIGHT_CC_MASK.jpg
# P_00967_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00967_RIGHT_MLO_MASK.jpg
# P_00967_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00969_LEFT_CC_MASK.jpg
# P_00969_LEFT_MLO_MASK.jpg
# P_00971_RIGHT_MLO_MASK.jpg
# P_00973_RIGHT_CC_MASK.jpg
# P_00973_RIGHT_MLO_MASK.jpg
# P_00973_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00977_LEFT_MLO_MASK.jpg
# P_00978_LEFT_CC_MASK.jpg
# P_00978_LEFT_MLO_MASK.jpg
# P_00981_LEFT_CC_MASK.jpg
# P_00981_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00981_LEFT_MLO_MASK.jpg
# P_00981_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00983_LEFT_CC_MASK.jpg
# P_00989_RIGHT_CC_MASK.jpg
# P_00989_RIGHT_MLO_MASK.jpg
# P_00991_LEFT_CC_MASK.jpg
# P_00991_LEFT_MLO_MASK.jpg
# P_00992_LEFT_CC_MASK.jpg
# P_00992_LEFT_MLO_MASK.jpg
# P_00992_RIGHT_CC_MASK.jpg
# P_00992_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00992_RIGHT_MLO_MASK.jpg
# P_00992_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00993_RIGHT_CC_MASK.jpg
# P_00993_RIGHT_MLO_MASK.jpg
# P_00998_LEFT_CC_MASK.jpg
# P_01002_LEFT_CC_MASK.jpg
# P_01002_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_01002_LEFT_CC_FULL.jpg
# P_01002_LEFT_MLO_MASK.jpg
# P_01002_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_01002_LEFT_MLO_FULL.jpg
# P_01003_LEFT_CC_MASK.jpg
# P_01003_LEFT_MLO_MASK.jpg
# P_01010_RIGHT_MLO_MASK.jpg
# P_01015_LEFT_CC_MASK.jpg
# P_01015_LEFT_MLO_MASK.jpg
# P_01016_RIGHT_MLO_MASK.jpg
# P_01019_LEFT_CC_MASK.jpg
# P_01019_LEFT_MLO_MASK.jpg
# P_01029_LEFT_CC_MASK.jpg
# P_01029_LEFT_MLO_MASK.jpg
# P_01029_RIGHT_CC_MASK.jpg
# P_01029_RIGHT_MLO_MASK.jpg
# P_01033_LEFT_CC_MASK.jpg
# P_01033_LEFT_MLO_MASK.jpg
# P_01034_LEFT_CC_MASK.jpg
# P_01034_LEFT_MLO_MASK.jpg
# P_01037_LEFT_CC_MASK.jpg
# P_01037_LEFT_MLO_MASK.jpg
# P_01040_RIGHT_CC_MASK.jpg
# P_01040_RIGHT_MLO_MASK.jpg
# P_01041_RIGHT_CC_MASK.jpg
# P_01041_RIGHT_MLO_MASK.jpg
# P_01043_RIGHT_CC_MASK.jpg
# P_01043_RIGHT_MLO_MASK.jpg
# P_01045_RIGHT_CC_MASK.jpg
# P_01045_RIGHT_MLO_MASK.jpg
# P_01046_LEFT_CC_MASK.jpg
# P_01046_LEFT_MLO_MASK.jpg
# P_01049_LEFT_CC_MASK.jpg
# P_01049_LEFT_MLO_MASK.jpg
# P_01053_LEFT_CC_MASK.jpg
# P_01053_LEFT_MLO_MASK.jpg
# P_01056_RIGHT_CC_MASK.jpg
# P_01056_RIGHT_MLO_MASK.jpg
# P_01059_LEFT_CC_MASK.jpg
# P_01059_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01059_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01059_LEFT_CC_FULL.jpg
# P_01059_LEFT_MLO_MASK.jpg
# P_01059_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01059_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01059_LEFT_MLO_FULL.jpg
# P_01060_RIGHT_CC_MASK.jpg
# P_01060_RIGHT_MLO_MASK.jpg
# P_01063_RIGHT_MLO_MASK.jpg
# P_01064_LEFT_MLO_MASK.jpg
# P_01065_LEFT_CC_MASK.jpg
# P_01065_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01065_LEFT_MLO_MASK.jpg
# P_01065_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01066_RIGHT_CC_MASK.jpg
# P_01066_RIGHT_MLO_MASK.jpg
# P_01069_LEFT_CC_MASK.jpg
# P_01069_LEFT_MLO_MASK.jpg
# P_01069_RIGHT_CC_MASK.jpg
# P_01069_RIGHT_MLO_MASK.jpg
# P_01072_LEFT_CC_MASK.jpg
# P_01072_LEFT_MLO_MASK.jpg
# P_01073_RIGHT_CC_MASK.jpg
# P_01073_RIGHT_MLO_MASK.jpg
# P_01084_LEFT_CC_MASK.jpg
# P_01084_LEFT_MLO_MASK.jpg
# P_01087_LEFT_CC_MASK.jpg
# P_01087_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01091_RIGHT_MLO_MASK.jpg
# P_01094_RIGHT_CC_MASK.jpg
# P_01094_RIGHT_MLO_MASK.jpg
# P_01095_LEFT_CC_MASK.jpg
# P_01095_LEFT_MLO_MASK.jpg
# P_01099_LEFT_CC_MASK.jpg
# P_01099_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01099_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01099_LEFT_CC_FULL.jpg
# P_01099_LEFT_MLO_MASK.jpg
# P_01099_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01099_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01099_LEFT_MLO_FULL.jpg
# P_01099_RIGHT_CC_MASK.jpg
# P_01099_RIGHT_MLO_MASK.jpg
# P_01099_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01099_RIGHT_MLO_FULL.jpg
# P_01100_RIGHT_CC_MASK.jpg
# P_01100_RIGHT_MLO_MASK.jpg
# P_01102_LEFT_CC_MASK.jpg
# P_01102_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01102_LEFT_MLO_MASK.jpg
# P_01102_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01107_LEFT_CC_MASK.jpg
# P_01108_LEFT_CC_MASK.jpg
# P_01108_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01108_LEFT_MLO_MASK.jpg
# P_01108_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01111_RIGHT_CC_MASK.jpg
# P_01111_RIGHT_MLO_MASK.jpg
# P_01116_LEFT_CC_MASK.jpg
# P_01116_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01116_LEFT_MLO_MASK.jpg
# P_01116_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01121_RIGHT_CC_MASK.jpg
# P_01122_LEFT_MLO_MASK.jpg
# P_01122_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01126_LEFT_CC_MASK.jpg
# P_01126_LEFT_MLO_MASK.jpg
# P_01127_RIGHT_CC_MASK.jpg
# P_01127_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01127_RIGHT_MLO_MASK.jpg
# P_01127_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01128_RIGHT_CC_MASK.jpg
# P_01128_RIGHT_MLO_MASK.jpg
# P_01129_RIGHT_CC_MASK.jpg
# P_01129_RIGHT_MLO_MASK.jpg
# P_01135_RIGHT_CC_MASK.jpg
# P_01135_RIGHT_MLO_MASK.jpg
# P_01135_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01136_RIGHT_CC_MASK.jpg
# P_01136_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01136_RIGHT_MLO_MASK.jpg
# P_01136_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01137_LEFT_CC_MASK.jpg
# P_01137_LEFT_MLO_MASK.jpg
# P_01139_RIGHT_CC_MASK.jpg
# P_01139_RIGHT_MLO_MASK.jpg
# P_01143_RIGHT_CC_MASK.jpg
# P_01143_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01156_LEFT_CC_MASK.jpg
# P_01156_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01156_LEFT_MLO_MASK.jpg
# P_01156_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01156_RIGHT_CC_MASK.jpg
# P_01156_RIGHT_MLO_MASK.jpg
# P_01159_LEFT_CC_MASK.jpg
# P_01159_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01159_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01159_LEFT_CC_FULL.jpg
# P_01159_LEFT_MLO_MASK.jpg
# P_01160_LEFT_CC_MASK.jpg
# P_01160_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01160_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01160_LEFT_CC_FULL.jpg
# P_01160_LEFT_MLO_MASK.jpg
# P_01160_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01160_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01160_LEFT_MLO_FULL.jpg
# P_01160_RIGHT_CC_MASK.jpg
# P_01160_RIGHT_MLO_MASK.jpg
# P_01160_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01160_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01160_RIGHT_MLO_FULL.jpg
# P_01161_LEFT_CC_MASK.jpg
# P_01161_LEFT_MLO_MASK.jpg
# P_01166_RIGHT_CC_MASK.jpg
# P_01166_RIGHT_MLO_MASK.jpg
# P_01169_LEFT_CC_MASK.jpg
# P_01169_LEFT_MLO_MASK.jpg
# P_01170_RIGHT_CC_MASK.jpg
# P_01170_RIGHT_MLO_MASK.jpg
# P_01172_LEFT_CC_MASK.jpg
# P_01172_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01172_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01172_LEFT_CC_FULL.jpg
# P_01172_LEFT_MLO_MASK.jpg
# P_01180_LEFT_CC_MASK.jpg
# P_01180_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01180_LEFT_MLO_MASK.jpg
# P_01180_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01184_LEFT_CC_MASK.jpg
# P_01184_LEFT_MLO_MASK.jpg
# P_01186_LEFT_CC_MASK.jpg
# P_01186_LEFT_MLO_MASK.jpg
# P_01188_RIGHT_CC_MASK.jpg
# P_01188_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01188_RIGHT_MLO_MASK.jpg
# P_01188_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01193_LEFT_CC_MASK.jpg
# P_01196_LEFT_MLO_MASK.jpg
# P_01196_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01197_LEFT_CC_MASK.jpg
# P_01197_LEFT_MLO_MASK.jpg
# P_01198_RIGHT_CC_MASK.jpg
# P_01198_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01198_RIGHT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01198_RIGHT_CC_FULL.jpg
# P_01198_RIGHT_MLO_MASK.jpg
# P_01198_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01200_LEFT_CC_MASK.jpg
# P_01200_LEFT_MLO_MASK.jpg
# P_01200_RIGHT_MLO_MASK.jpg
# P_01205_RIGHT_CC_MASK.jpg
# P_01205_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01205_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01205_RIGHT_CC_FULL.jpg
# P_01205_RIGHT_MLO_MASK.jpg
# P_01205_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01205_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01205_RIGHT_MLO_FULL.jpg
# P_01219_LEFT_CC_MASK.jpg
# P_01219_LEFT_MLO_MASK.jpg
# P_01220_RIGHT_CC_MASK.jpg
# P_01220_RIGHT_MLO_MASK.jpg
# P_01227_RIGHT_CC_MASK.jpg
# P_01227_RIGHT_MLO_MASK.jpg
# P_01229_RIGHT_CC_MASK.jpg
# P_01229_RIGHT_MLO_MASK.jpg
# P_01234_RIGHT_CC_MASK.jpg
# P_01234_RIGHT_MLO_MASK.jpg
# P_01240_RIGHT_MLO_MASK.jpg
# P_01246_RIGHT_MLO_MASK.jpg
# P_01249_LEFT_CC_MASK.jpg
# P_01249_LEFT_MLO_MASK.jpg
# P_01250_LEFT_CC_MASK.jpg
# P_01250_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_01250_LEFT_CC_FULL.jpg
# P_01250_LEFT_MLO_MASK.jpg
# P_01250_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01252_RIGHT_CC_MASK.jpg
# P_01252_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01252_RIGHT_MLO_MASK.jpg
# P_01252_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01255_RIGHT_CC_MASK.jpg
# P_01255_RIGHT_MLO_MASK.jpg
# P_01256_RIGHT_CC_MASK.jpg
# P_01256_RIGHT_MLO_MASK.jpg
# P_01259_RIGHT_CC_MASK.jpg
# P_01259_RIGHT_MLO_MASK.jpg
# P_01262_RIGHT_CC_MASK.jpg
# P_01262_RIGHT_MLO_MASK.jpg
# P_01264_RIGHT_MLO_MASK.jpg
# P_01274_LEFT_CC_MASK.jpg
# P_01274_LEFT_MLO_MASK.jpg
# P_01274_RIGHT_CC_MASK.jpg
# P_01274_RIGHT_MLO_MASK.jpg
# P_01275_LEFT_CC_MASK.jpg
# P_01275_LEFT_MLO_MASK.jpg
# P_01276_LEFT_CC_MASK.jpg
# P_01276_LEFT_MLO_MASK.jpg
# P_01276_RIGHT_CC_MASK.jpg
# P_01276_RIGHT_MLO_MASK.jpg
# P_01284_RIGHT_MLO_MASK.jpg
# P_01286_LEFT_CC_MASK.jpg
# P_01286_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01286_LEFT_MLO_MASK.jpg
# P_01286_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01288_RIGHT_MLO_MASK.jpg
# P_01291_RIGHT_CC_MASK.jpg
# P_01291_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01291_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01291_RIGHT_CC_FULL.jpg
# P_01291_RIGHT_MLO_MASK.jpg
# P_01291_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01291_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01291_RIGHT_MLO_FULL.jpg
# P_01292_RIGHT_CC_MASK.jpg
# P_01292_RIGHT_MLO_MASK.jpg
# P_01293_RIGHT_CC_MASK.jpg
# P_01293_RIGHT_MLO_MASK.jpg
# P_01296_RIGHT_CC_MASK.jpg
# P_01296_RIGHT_MLO_MASK.jpg
# P_01297_LEFT_CC_MASK.jpg
# P_01297_LEFT_MLO_MASK.jpg
# P_01300_LEFT_CC_MASK.jpg
# P_01300_LEFT_MLO_MASK.jpg
# P_01306_LEFT_CC_MASK.jpg
# P_01306_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01306_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01306_LEFT_CC_FULL.jpg
# P_01306_LEFT_MLO_MASK.jpg
# P_01306_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01306_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01306_LEFT_MLO_FULL.jpg
# P_01306_RIGHT_CC_MASK.jpg
# P_01306_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01306_RIGHT_MLO_MASK.jpg
# P_01307_LEFT_CC_MASK.jpg
# P_01307_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01307_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01307_LEFT_CC_FULL.jpg
# P_01307_LEFT_MLO_MASK.jpg
# P_01309_RIGHT_CC_MASK.jpg
# P_01309_RIGHT_MLO_MASK.jpg
# P_01313_LEFT_CC_MASK.jpg
# P_01313_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01313_LEFT_MLO_MASK.jpg
# P_01313_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01314_LEFT_CC_MASK.jpg
# P_01314_LEFT_MLO_MASK.jpg
# P_01315_LEFT_CC_MASK.jpg
# P_01315_LEFT_MLO_MASK.jpg
# P_01319_RIGHT_CC_MASK.jpg
# P_01319_RIGHT_MLO_MASK.jpg
# P_01321_RIGHT_CC_MASK.jpg
# P_01321_RIGHT_MLO_MASK.jpg
# P_01334_RIGHT_CC_MASK.jpg
# P_01334_RIGHT_MLO_MASK.jpg
# P_01336_LEFT_CC_MASK.jpg
# P_01336_LEFT_MLO_MASK.jpg
# P_01336_RIGHT_CC_MASK.jpg
# P_01336_RIGHT_MLO_MASK.jpg
# P_01337_LEFT_CC_MASK.jpg
# P_01337_LEFT_MLO_MASK.jpg
# P_01338_LEFT_CC_MASK.jpg
# P_01338_LEFT_MLO_MASK.jpg
# P_01339_LEFT_CC_MASK.jpg
# P_01339_LEFT_MLO_MASK.jpg
# P_01342_LEFT_CC_MASK.jpg
# P_01342_LEFT_MLO_MASK.jpg
# P_01345_LEFT_CC_MASK.jpg
# P_01346_LEFT_CC_MASK.jpg
# P_01346_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01346_LEFT_MLO_MASK.jpg
# P_01346_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_01346_LEFT_MLO_FULL.jpg
# P_01358_RIGHT_CC_MASK.jpg
# P_01358_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01358_RIGHT_MLO_MASK.jpg
# P_01358_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01359_LEFT_CC_MASK.jpg
# P_01359_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_01359_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01359_LEFT_CC_FULL.jpg
# P_01359_LEFT_MLO_MASK.jpg
# P_01359_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_01359_LEFT_MLO_FULL.jpg
# P_01361_LEFT_CC_MASK.jpg
# P_01361_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01361_LEFT_MLO_MASK.jpg
# P_01361_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01361_LEFT_MLO_FULL.jpg
# P_01362_RIGHT_CC_MASK.jpg
# P_01362_RIGHT_MLO_MASK.jpg
# P_01365_LEFT_CC_MASK.jpg
# P_01365_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01365_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01365_LEFT_CC_FULL.jpg
# P_01365_LEFT_MLO_MASK.jpg
# P_01365_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01366_LEFT_MLO_MASK.jpg
# P_01369_RIGHT_MLO_MASK.jpg
# P_01370_LEFT_CC_MASK.jpg
# P_01370_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01370_LEFT_MLO_MASK.jpg
# P_01370_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01375_LEFT_CC_MASK.jpg
# P_01375_LEFT_MLO_MASK.jpg
# P_01384_LEFT_MLO_MASK.jpg
# P_01385_RIGHT_CC_MASK.jpg
# P_01385_RIGHT_MLO_MASK.jpg
# P_01387_LEFT_CC_MASK.jpg
# P_01387_LEFT_MLO_MASK.jpg
# P_01392_LEFT_CC_MASK.jpg
# P_01392_LEFT_MLO_MASK.jpg
# P_01397_LEFT_CC_MASK.jpg
# P_01397_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01397_LEFT_MLO_MASK.jpg
# P_01397_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01400_LEFT_CC_MASK.jpg
# P_01400_LEFT_MLO_MASK.jpg
# P_01401_LEFT_CC_MASK.jpg
# P_01401_LEFT_MLO_MASK.jpg
# P_01406_RIGHT_CC_MASK.jpg
# P_01406_RIGHT_MLO_MASK.jpg
# P_01408_LEFT_CC_MASK.jpg
# P_01408_LEFT_MLO_MASK.jpg
# P_01409_LEFT_CC_MASK.jpg
# P_01409_LEFT_MLO_MASK.jpg
# P_01409_RIGHT_CC_MASK.jpg
# P_01409_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01409_RIGHT_MLO_MASK.jpg
# P_01409_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01410_LEFT_CC_MASK.jpg
# P_01410_LEFT_MLO_MASK.jpg
# P_01420_RIGHT_CC_MASK.jpg
# P_01420_RIGHT_MLO_MASK.jpg
# P_01420_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01420_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01420_RIGHT_MLO_FULL.jpg
# P_01422_RIGHT_CC_MASK.jpg
# P_01422_RIGHT_MLO_MASK.jpg
# P_01424_LEFT_CC_MASK.jpg
# P_01424_LEFT_MLO_MASK.jpg
# P_01435_RIGHT_CC_MASK.jpg
# P_01435_RIGHT_MLO_MASK.jpg
# P_01436_RIGHT_CC_MASK.jpg
# P_01436_RIGHT_MLO_MASK.jpg
# P_01437_LEFT_CC_MASK.jpg
# P_01437_LEFT_MLO_MASK.jpg
# P_01437_RIGHT_CC_MASK.jpg
# P_01437_RIGHT_MLO_MASK.jpg
# P_01440_LEFT_CC_MASK.jpg
# P_01440_LEFT_MLO_MASK.jpg
# P_01440_RIGHT_CC_MASK.jpg
# P_01440_RIGHT_MLO_MASK.jpg
# P_01443_RIGHT_CC_MASK.jpg
# P_01443_RIGHT_MLO_MASK.jpg
# P_01446_LEFT_MLO_MASK.jpg
# P_01451_RIGHT_CC_MASK.jpg
# P_01451_RIGHT_MLO_MASK.jpg
# P_01454_LEFT_MLO_MASK.jpg
# P_01455_RIGHT_CC_MASK.jpg
# P_01455_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01455_RIGHT_MLO_MASK.jpg
# P_01455_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01455_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01455_RIGHT_MLO_FULL.jpg
# P_01456_LEFT_CC_MASK.jpg
# P_01456_LEFT_MLO_MASK.jpg
# P_01457_LEFT_CC_MASK.jpg
# P_01457_LEFT_MLO_MASK.jpg
# P_01457_RIGHT_CC_MASK.jpg
# P_01457_RIGHT_MLO_MASK.jpg
# P_01458_LEFT_CC_MASK.jpg
# P_01458_LEFT_MLO_MASK.jpg
# P_01459_LEFT_CC_MASK.jpg
# P_01459_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01459_LEFT_MLO_MASK.jpg
# P_01459_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01459_LEFT_MLO_FULL.jpg
# Slice_3 wrong shape: (1, 1) - image P_01459_LEFT_MLO_FULL.jpg
# P_01462_LEFT_CC_MASK.jpg
# P_01462_LEFT_MLO_MASK.jpg
# P_01467_RIGHT_CC_MASK.jpg
# P_01467_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01467_RIGHT_MLO_MASK.jpg
# P_01467_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01472_RIGHT_MLO_MASK.jpg
# P_01478_RIGHT_CC_MASK.jpg
# P_01478_RIGHT_MLO_MASK.jpg
# P_01487_RIGHT_MLO_MASK.jpg
# P_01488_LEFT_CC_MASK.jpg
# P_01488_LEFT_MLO_MASK.jpg
# P_01488_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01497_LEFT_CC_MASK.jpg
# P_01497_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01497_LEFT_MLO_MASK.jpg
# P_01497_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01497_RIGHT_MLO_MASK.jpg
# P_01497_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01505_RIGHT_CC_MASK.jpg
# ...
# P_01526_RIGHT_CC_MASK.jpg
# P_01526_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01526_RIGHT_CC_FULL.jpg
# P_01526_RIGHT_MLO_MASK.jpg
# P_01526_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01526_RIGHT_MLO_FULL.jpg
# Slice_3 wrong shape: (1, 1) - image P_01526_RIGHT_MLO_FULL.jpg
# P_01537_RIGHT_CC_MASK.jpg
# P_01537_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01545_RIGHT_CC_MASK.jpg
# P_01545_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01545_RIGHT_MLO_MASK.jpg
# P_01545_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01548_LEFT_CC_MASK.jpg
# P_01548_LEFT_MLO_MASK.jpg
# P_01549_LEFT_CC_MASK.jpg
# P_01549_LEFT_MLO_MASK.jpg
# P_01561_LEFT_CC_MASK.jpg
# P_01561_LEFT_MLO_MASK.jpg
# P_01563_LEFT_CC_MASK.jpg
# P_01563_LEFT_MLO_MASK.jpg
# P_01563_RIGHT_CC_MASK.jpg
# P_01563_RIGHT_MLO_MASK.jpg
# P_01566_LEFT_CC_MASK.jpg
# P_01566_LEFT_MLO_MASK.jpg
# P_01567_LEFT_CC_MASK.jpg
# P_01567_LEFT_MLO_MASK.jpg
# P_01569_RIGHT_CC_MASK.jpg
# P_01569_RIGHT_MLO_MASK.jpg
# P_01569_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01570_RIGHT_CC_MASK.jpg
# P_01570_RIGHT_MLO_MASK.jpg
# P_01571_RIGHT_CC_MASK.jpg
# P_01571_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01571_RIGHT_MLO_MASK.jpg
# P_01573_RIGHT_CC_MASK.jpg
# P_01573_RIGHT_MLO_MASK.jpg
# P_01574_RIGHT_CC_MASK.jpg
# P_01574_RIGHT_MLO_MASK.jpg
# P_01575_RIGHT_MLO_MASK.jpg
# P_01576_RIGHT_CC_MASK.jpg
# P_01576_RIGHT_MLO_MASK.jpg
# P_01577_RIGHT_CC_MASK.jpg
# P_01577_RIGHT_MLO_MASK.jpg
# P_01579_RIGHT_CC_MASK.jpg
# P_01579_RIGHT_MLO_MASK.jpg
# P_01582_LEFT_CC_MASK.jpg
# P_01582_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01582_LEFT_MLO_MASK.jpg
# P_01582_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01582_RIGHT_CC_MASK.jpg
# P_01582_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01582_RIGHT_MLO_MASK.jpg
# P_01582_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01585_RIGHT_CC_MASK.jpg
# P_01585_RIGHT_MLO_MASK.jpg
# P_01596_LEFT_CC_MASK.jpg
# P_01596_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01596_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01596_LEFT_CC_FULL.jpg
# P_01596_LEFT_MLO_MASK.jpg
# P_01596_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01605_LEFT_CC_MASK.jpg
# P_01605_LEFT_MLO_MASK.jpg
# P_01609_LEFT_CC_MASK.jpg
# P_01609_LEFT_MLO_MASK.jpg
# P_01610_RIGHT_MLO_MASK.jpg
# P_01616_RIGHT_CC_MASK.jpg
# P_01616_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01616_RIGHT_MLO_MASK.jpg
# P_01616_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01625_RIGHT_CC_MASK.jpg
# P_01625_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01625_RIGHT_MLO_MASK.jpg
# P_01625_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01626_LEFT_CC_MASK.jpg
# P_01626_LEFT_MLO_MASK.jpg
# P_01628_LEFT_CC_MASK.jpg
# P_01628_LEFT_MLO_MASK.jpg
# P_01628_RIGHT_CC_MASK.jpg
# P_01628_RIGHT_MLO_MASK.jpg
# P_01629_LEFT_CC_MASK.jpg
# P_01629_LEFT_MLO_MASK.jpg
# P_01639_RIGHT_CC_MASK.jpg
# P_01639_RIGHT_MLO_MASK.jpg
# P_01647_RIGHT_CC_MASK.jpg
# P_01647_RIGHT_MLO_MASK.jpg
# P_01655_RIGHT_CC_MASK.jpg
# P_01655_RIGHT_MLO_MASK.jpg
# P_01659_LEFT_CC_MASK.jpg
# P_01659_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01659_LEFT_MLO_MASK.jpg
# P_01659_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01659_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01659_LEFT_MLO_FULL.jpg
# P_01660_RIGHT_CC_MASK.jpg
# P_01660_RIGHT_MLO_MASK.jpg
# P_01664_LEFT_CC_MASK.jpg
# P_01664_LEFT_MLO_MASK.jpg
# P_01664_RIGHT_CC_MASK.jpg
# P_01664_RIGHT_MLO_MASK.jpg
# P_01676_RIGHT_MLO_MASK.jpg
# P_01678_RIGHT_CC_MASK.jpg
# P_01678_RIGHT_MLO_MASK.jpg
# P_01679_RIGHT_CC_MASK.jpg
# P_01679_RIGHT_MLO_MASK.jpg
# P_01683_LEFT_CC_MASK.jpg
# P_01683_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01688_RIGHT_MLO_MASK.jpg
# P_01688_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01688_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01688_RIGHT_MLO_FULL.jpg
# P_01691_RIGHT_CC_MASK.jpg
# P_01691_RIGHT_MLO_MASK.jpg
# P_01700_LEFT_CC_MASK.jpg
# P_01700_LEFT_MLO_MASK.jpg
# P_01700_RIGHT_CC_MASK.jpg
# P_01700_RIGHT_MLO_MASK.jpg
# P_01703_RIGHT_MLO_MASK.jpg
# P_01705_LEFT_CC_MASK.jpg
# P_01705_LEFT_MLO_MASK.jpg
# P_01709_RIGHT_CC_MASK.jpg
# P_01709_RIGHT_MLO_MASK.jpg
# P_01718_RIGHT_MLO_MASK.jpg
# P_01721_RIGHT_CC_MASK.jpg
# P_01723_RIGHT_CC_MASK.jpg
# P_01723_RIGHT_MLO_MASK.jpg
# P_01724_LEFT_CC_MASK.jpg
# P_01724_LEFT_MLO_MASK.jpg
# P_01724_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01725_RIGHT_CC_MASK.jpg
# P_01725_RIGHT_MLO_MASK.jpg
# P_01729_LEFT_CC_MASK.jpg
# P_01729_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01729_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01729_LEFT_CC_FULL.jpg
# P_01729_LEFT_MLO_MASK.jpg
# P_01729_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01729_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01729_LEFT_MLO_FULL.jpg
# P_01730_LEFT_CC_MASK.jpg
# P_01730_LEFT_MLO_MASK.jpg
# P_01732_LEFT_CC_MASK.jpg
# P_01732_LEFT_MLO_MASK.jpg
# P_01736_LEFT_CC_MASK.jpg
# P_01736_LEFT_MLO_MASK.jpg
# P_01736_RIGHT_CC_MASK.jpg
# P_01736_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01736_RIGHT_MLO_MASK.jpg
# P_01736_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01740_LEFT_CC_MASK.jpg
# P_01740_LEFT_MLO_MASK.jpg
# P_01740_RIGHT_CC_MASK.jpg
# P_01740_RIGHT_MLO_MASK.jpg
# P_01741_RIGHT_CC_MASK.jpg
# P_01741_RIGHT_MLO_MASK.jpg
# P_01748_RIGHT_CC_MASK.jpg
# P_01748_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01748_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01748_RIGHT_CC_FULL.jpg
# P_01748_RIGHT_MLO_MASK.jpg
# P_01750_LEFT_CC_MASK.jpg
# P_01750_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01750_LEFT_MLO_MASK.jpg
# P_01750_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01756_LEFT_CC_MASK.jpg
# P_01756_LEFT_MLO_MASK.jpg
# P_01759_RIGHT_CC_MASK.jpg
# P_01759_RIGHT_MLO_MASK.jpg
# P_01760_RIGHT_CC_MASK.jpg
# P_01760_RIGHT_MLO_MASK.jpg
# P_01766_LEFT_CC_MASK.jpg
# P_01766_LEFT_MLO_MASK.jpg
# P_01767_LEFT_CC_MASK.jpg
# P_01767_LEFT_MLO_MASK.jpg
# P_01769_LEFT_CC_MASK.jpg
# P_01769_LEFT_MLO_MASK.jpg
# P_01769_RIGHT_CC_MASK.jpg
# P_01769_RIGHT_MLO_MASK.jpg
# P_01770_LEFT_MLO_MASK.jpg
# P_01777_LEFT_CC_MASK.jpg
# P_01777_LEFT_MLO_MASK.jpg
# P_01783_LEFT_MLO_MASK.jpg
# P_01783_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01784_LEFT_CC_MASK.jpg
# P_01784_LEFT_MLO_MASK.jpg
# P_01786_RIGHT_CC_MASK.jpg
# P_01786_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01786_RIGHT_MLO_MASK.jpg
# P_01786_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01791_LEFT_CC_MASK.jpg
# P_01791_LEFT_MLO_MASK.jpg
# P_01792_RIGHT_CC_MASK.jpg
# P_01792_RIGHT_MLO_MASK.jpg
# P_01793_LEFT_CC_MASK.jpg
# P_01793_LEFT_MLO_MASK.jpg
# P_01809_LEFT_MLO_MASK.jpg
# P_01809_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01810_LEFT_CC_MASK.jpg
# P_01810_LEFT_MLO_MASK.jpg
# P_01818_LEFT_CC_MASK.jpg
# P_01818_LEFT_MLO_MASK.jpg
# P_01819_LEFT_CC_MASK.jpg
# P_01819_LEFT_MLO_MASK.jpg
# P_01823_LEFT_CC_MASK.jpg
# P_01823_LEFT_MLO_MASK.jpg
# P_01823_RIGHT_CC_MASK.jpg
# P_01823_RIGHT_MLO_MASK.jpg
# P_01830_LEFT_CC_MASK.jpg
# P_01830_LEFT_MLO_MASK.jpg
# P_01830_RIGHT_CC_MASK.jpg
# P_01830_RIGHT_MLO_MASK.jpg
# P_01832_LEFT_CC_MASK.jpg
# P_01832_LEFT_MLO_MASK.jpg
# P_01838_LEFT_CC_MASK.jpg
# P_01838_LEFT_MLO_MASK.jpg
# P_01838_RIGHT_CC_MASK.jpg
# P_01838_RIGHT_MLO_MASK.jpg
# P_01839_LEFT_CC_MASK.jpg
# P_01839_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01839_LEFT_MLO_MASK.jpg
# P_01839_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01840_RIGHT_MLO_MASK.jpg
# P_01846_RIGHT_CC_MASK.jpg
# P_01846_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01846_RIGHT_MLO_MASK.jpg
# P_01846_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01847_LEFT_CC_MASK.jpg
# P_01847_LEFT_MLO_MASK.jpg
# P_01856_LEFT_CC_MASK.jpg
# P_01856_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01856_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01856_LEFT_CC_FULL.jpg
# P_01856_LEFT_MLO_MASK.jpg
# P_01858_LEFT_CC_MASK.jpg
# P_01858_LEFT_MLO_MASK.jpg
# P_01864_LEFT_CC_MASK.jpg
# P_01864_LEFT_MLO_MASK.jpg
# P_01864_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01864_RIGHT_CC_MASK.jpg
# P_01864_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01864_RIGHT_MLO_MASK.jpg
# P_01864_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01864_RIGHT_MLO_FULL.jpg
# P_01875_LEFT_CC_MASK.jpg
# P_01875_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01875_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01875_LEFT_CC_FULL.jpg
# P_01875_LEFT_MLO_MASK.jpg
# P_01875_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01875_RIGHT_CC_MASK.jpg
# P_01875_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01875_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01875_RIGHT_CC_FULL.jpg
# P_01875_RIGHT_MLO_MASK.jpg
# P_01875_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_01884_RIGHT_CC_MASK.jpg
# P_01884_RIGHT_MLO_MASK.jpg
# P_01885_LEFT_CC_MASK.jpg
# P_01885_LEFT_MLO_MASK.jpg
# P_01885_RIGHT_CC_MASK.jpg
# P_01885_RIGHT_MLO_MASK.jpg
# P_02105_LEFT_CC_MASK.jpg
# P_02105_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02105_LEFT_MLO_MASK.jpg
# P_02105_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_02105_LEFT_MLO_FULL.jpg
# P_02115_LEFT_CC_MASK.jpg
# P_02115_LEFT_MLO_MASK.jpg
# P_02133_LEFT_CC_MASK.jpg
# P_02133_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02133_LEFT_MLO_MASK.jpg
# P_02133_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02154_LEFT_CC_MASK.jpg
# P_02154_LEFT_MLO_MASK.jpg
# P_02190_RIGHT_CC_MASK.jpg
# P_02190_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02190_RIGHT_MLO_MASK.jpg
# P_02190_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02195_RIGHT_CC_MASK.jpg
# P_02195_RIGHT_MLO_MASK.jpg
# P_02195_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_02195_RIGHT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_02195_RIGHT_MLO_FULL.jpg
# P_02218_LEFT_CC_MASK.jpg
# P_02218_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_02218_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_02218_LEFT_CC_FULL.jpg
# P_02218_LEFT_MLO_MASK.jpg
# P_02218_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02220_LEFT_CC_MASK.jpg
# P_02220_LEFT_MLO_MASK.jpg
# P_02226_LEFT_CC_MASK.jpg
# P_02226_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02226_LEFT_MLO_MASK.jpg
# P_02226_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02232_LEFT_CC_MASK.jpg
# P_02232_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02232_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_02232_LEFT_CC_FULL.jpg
# P_02232_LEFT_MLO_MASK.jpg
# P_02232_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02234_LEFT_CC_MASK.jpg
# P_02234_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02234_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_02234_LEFT_CC_FULL.jpg
# P_02234_LEFT_MLO_MASK.jpg
# P_02259_LEFT_CC_MASK.jpg
# P_02259_LEFT_MLO_MASK.jpg
# P_02270_RIGHT_CC_MASK.jpg
# P_02270_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02270_RIGHT_MLO_MASK.jpg
# P_02270_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02285_LEFT_CC_MASK.jpg
# P_02285_LEFT_MLO_MASK.jpg
# P_02285_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02285_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_02285_LEFT_MLO_FULL.jpg
# P_02313_LEFT_CC_MASK.jpg
# P_02313_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02313_LEFT_MLO_MASK.jpg
# P_02313_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02316_RIGHT_CC_MASK.jpg
# P_02316_RIGHT_MLO_MASK.jpg
# P_02318_RIGHT_CC_MASK.jpg
# P_02318_RIGHT_MLO_MASK.jpg
# P_02323_LEFT_CC_MASK.jpg
# P_02323_LEFT_MLO_MASK.jpg
# P_02323_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02323_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_02323_LEFT_MLO_FULL.jpg
# P_02348_RIGHT_CC_MASK.jpg
# P_02348_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02348_RIGHT_MLO_MASK.jpg
# P_02348_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02368_RIGHT_CC_MASK.jpg
# P_02368_RIGHT_MLO_MASK.jpg
# P_02380_LEFT_CC_MASK.jpg
# P_02380_LEFT_MLO_MASK.jpg
# P_02380_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02393_LEFT_CC_MASK.jpg
# P_02393_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_02393_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_02393_LEFT_CC_FULL.jpg
# P_02393_LEFT_MLO_MASK.jpg
# P_02393_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02400_LEFT_CC_MASK.jpg
# P_02400_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02400_LEFT_MLO_MASK.jpg
# P_02400_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02402_RIGHT_CC_MASK.jpg
# P_02402_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02402_RIGHT_MLO_MASK.jpg
# P_02402_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02405_RIGHT_CC_MASK.jpg
# P_02405_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02405_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_02405_RIGHT_CC_FULL.jpg
# P_02405_RIGHT_MLO_MASK.jpg
# P_02405_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02409_RIGHT_CC_MASK.jpg
# P_02409_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02409_RIGHT_MLO_MASK.jpg
# P_02419_LEFT_CC_MASK.jpg
# P_02419_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02419_LEFT_MLO_MASK.jpg
# P_02419_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_02419_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_02419_LEFT_MLO_FULL.jpg
# P_02424_RIGHT_CC_MASK.jpg
# P_02424_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02424_RIGHT_MLO_MASK.jpg
# P_02424_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02434_LEFT_CC_MASK.jpg
# P_02434_LEFT_MLO_MASK.jpg
# P_02437_LEFT_CC_MASK.jpg
# P_02437_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02437_LEFT_MLO_MASK.jpg
# P_02437_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02442_LEFT_CC_MASK.jpg
# P_02442_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02442_LEFT_MLO_MASK.jpg
# P_02442_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02456_LEFT_MLO_MASK.jpg
# P_02456_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02456_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_02456_LEFT_MLO_FULL.jpg
# P_02459_RIGHT_CC_MASK.jpg
# P_02459_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02459_RIGHT_MLO_MASK.jpg
# P_02459_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02460_RIGHT_CC_MASK.jpg
# P_02460_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_02460_RIGHT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_02460_RIGHT_CC_FULL.jpg
# P_02460_RIGHT_MLO_MASK.jpg
# P_02460_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02468_LEFT_CC_MASK.jpg
# P_02468_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02468_LEFT_MLO_MASK.jpg
# P_02468_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02475_LEFT_CC_MASK.jpg
# P_02475_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02475_LEFT_MLO_MASK.jpg
# P_02475_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02489_RIGHT_CC_MASK.jpg
# P_02489_RIGHT_MLO_MASK.jpg
# P_02508_LEFT_CC_MASK.jpg
# P_02508_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02508_LEFT_MLO_MASK.jpg
# P_02508_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02518_RIGHT_CC_MASK.jpg
# P_02518_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02518_RIGHT_MLO_MASK.jpg
# P_02518_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02518_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_02518_RIGHT_MLO_FULL.jpg
# P_02522_RIGHT_CC_MASK.jpg
# P_02522_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_02522_RIGHT_CC_FULL.jpg
# P_02522_RIGHT_MLO_MASK.jpg
# P_02522_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02559_RIGHT_CC_MASK.jpg
# P_02559_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02559_RIGHT_MLO_MASK.jpg
# P_02559_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02559_RIGHT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_02559_RIGHT_MLO_FULL.jpg
# P_02563_RIGHT_CC_MASK.jpg
# P_02563_RIGHT_MLO_MASK.jpg
# P_02566_RIGHT_CC_MASK.jpg
# P_02566_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02566_RIGHT_MLO_MASK.jpg
# P_02566_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02572_LEFT_CC_MASK.jpg
# P_02572_LEFT_MLO_MASK.jpg
# P_02584_LEFT_CC_MASK.jpg
# P_02584_LEFT_MLO_MASK.jpg

# %%
print("Calc Train Slices shape:",calc_train_slices.shape)
print("Calc Train File Name List:", len(calc_train_image_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1d306870aae9> in <module>()
# ----> 1 print("Calc Train Slices shape:",calc_train_slices.shape)
#       2 print("Calc Train File Name List:", len(calc_train_image_names))
#
# NameError: name 'calc_train_slices' is not defined

# %%
calc_train_labels = []
train_labels = pd.read_pickle(os.path.join("data", "train_labels.pkl"))
train_labels['IMAGE_NAME2'] = train_labels.index
train_labels = train_labels.drop_duplicates(['IMAGE_NAME2'])

#calc_train_image_names = np.load("data/calc_train_filenames.npy")

for image in calc_train_image_names:
    calc_train_labels.append(train_labels.loc[image]['CLASS'])
    
print("Calc Train Labels:", len(calc_train_labels))
# Out:
# Calc Train Labels: 2345

# %%
np.save(os.path.join("data", "calc_train_slices.npy"), calc_train_slices)
np.save(os.path.join("data", "calc_train_filenames.npy"), calc_train_image_names)
np.save(os.path.join("data", "calc_train_labels.npy"), np.array(calc_train_labels))

# %%
# check image to make sure it matches the cropped image
plt.imshow(calc_train_slices[1509].reshape(299,299))
plt.title(calc_train_image_names[1509])

# %% [markdown]
# ## Mass Test

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Test ROI JPEGs", "Mass Test All Mask JPEGs", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Test Full JPEGs", "Mass Test All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Test All Mask JPEGs"
image_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Test All Full JPEGs"

mass_test_slices, mass_test_image_names = create_roi_slices(mask_dir, image_dir, output=True)
# Out:
# P_00016_LEFT_CC_MASK.jpg
# P_00016_LEFT_MLO_MASK.jpg
# P_00017_LEFT_CC_MASK.jpg
# P_00017_LEFT_MLO_MASK.jpg
# P_00032_RIGHT_CC_MASK.jpg
# P_00032_RIGHT_MLO_MASK.jpg
# P_00037_RIGHT_CC_MASK.jpg
# P_00037_RIGHT_MLO_MASK.jpg
# P_00056_LEFT_MLO_MASK.jpg
# P_00066_LEFT_CC_MASK.jpg
# P_00066_LEFT_MLO_MASK.jpg
# P_00099_LEFT_MLO_MASK.jpg
# P_00114_LEFT_MLO_MASK.jpg
# P_00116_RIGHT_CC_MASK.jpg
# P_00116_RIGHT_MLO_MASK.jpg
# P_00118_RIGHT_CC_MASK.jpg
# P_00118_RIGHT_MLO_MASK.jpg
# P_00124_RIGHT_CC_MASK.jpg
# P_00126_RIGHT_CC_MASK.jpg
# P_00126_RIGHT_MLO_MASK.jpg
# P_00131_LEFT_CC_MASK.jpg
# P_00131_LEFT_MLO_MASK.jpg
# P_00145_LEFT_CC_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2191, 894)
# Image shape: (2520, 1028)
# P_00145_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2185, 1077)
# Image shape: (2513, 1238)
# P_00147_RIGHT_CC_MASK.jpg
# P_00147_RIGHT_MLO_MASK.jpg
# P_00156_RIGHT_MLO_MASK.jpg
# P_00158_RIGHT_MLO_MASK.jpg
# P_00159_RIGHT_MLO_MASK.jpg
# P_00171_RIGHT_CC_MASK.jpg
# P_00171_RIGHT_MLO_MASK.jpg
# P_00173_LEFT_CC_MASK.jpg
# P_00173_LEFT_MLO_MASK.jpg
# P_00173_RIGHT_CC_MASK.jpg
# P_00173_RIGHT_MLO_MASK.jpg
# P_00177_LEFT_CC_MASK.jpg
# P_00177_LEFT_MLO_MASK.jpg
# P_00192_RIGHT_CC_MASK.jpg
# P_00192_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00194_RIGHT_CC_MASK.jpg
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# P_00194_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00194_RIGHT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00194_RIGHT_CC_FULL.jpg
# P_00194_RIGHT_MLO_MASK.jpg
# P_00194_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_00198_LEFT_CC_MASK.jpg
# P_00198_LEFT_MLO_MASK.jpg
# P_00200_LEFT_CC_MASK.jpg
# P_00200_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00200_LEFT_MLO_MASK.jpg
# P_00200_RIGHT_CC_MASK.jpg
# P_00200_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00200_RIGHT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00200_RIGHT_CC_FULL.jpg
# P_00200_RIGHT_MLO_MASK.jpg
# P_00202_RIGHT_CC_MASK.jpg
# P_00202_RIGHT_MLO_MASK.jpg
# P_00203_LEFT_CC_MASK.jpg
# P_00203_LEFT_MLO_MASK.jpg
# P_00209_LEFT_MLO_MASK.jpg
# P_00212_RIGHT_CC_MASK.jpg
# P_00212_RIGHT_MLO_MASK.jpg
# P_00230_RIGHT_CC_MASK.jpg
# P_00230_RIGHT_MLO_MASK.jpg
# P_00238_RIGHT_CC_MASK.jpg
# P_00238_RIGHT_MLO_MASK.jpg
# P_00278_RIGHT_CC_MASK.jpg
# P_00278_RIGHT_MLO_MASK.jpg
# P_00296_LEFT_CC_MASK.jpg
# P_00296_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00296_LEFT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00296_LEFT_CC_FULL.jpg
# P_00296_LEFT_MLO_MASK.jpg
# P_00296_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00296_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00296_LEFT_MLO_FULL.jpg
# P_00324_RIGHT_CC_MASK.jpg
# P_00324_RIGHT_MLO_MASK.jpg
# P_00340_LEFT_CC_MASK.jpg
# P_00343_LEFT_CC_MASK.jpg
# P_00343_LEFT_MLO_MASK.jpg
# P_00343_RIGHT_CC_MASK.jpg
# P_00343_RIGHT_MLO_MASK.jpg
# P_00347_LEFT_CC_MASK.jpg
# P_00347_LEFT_MLO_MASK.jpg
# P_00358_RIGHT_CC_MASK.jpg
# P_00358_RIGHT_MLO_MASK.jpg
# P_00359_LEFT_MLO_MASK.jpg
# P_00369_LEFT_CC_MASK.jpg
# P_00369_LEFT_MLO_MASK.jpg
# P_00375_RIGHT_CC_MASK.jpg
# P_00375_RIGHT_MLO_MASK.jpg
# P_00379_LEFT_CC_MASK.jpg
# P_00379_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2343, 1410)
# Image shape: (2692, 1620)
# P_00381_LEFT_CC_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2309, 1390)
# Image shape: (2655, 1598)
# P_00381_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2343, 1593)
# Image shape: (2692, 1830)
# P_00387_RIGHT_CC_MASK.jpg
# P_00387_RIGHT_MLO_MASK.jpg
# P_00391_LEFT_CC_MASK.jpg
# P_00391_LEFT_MLO_MASK.jpg
# P_00391_RIGHT_CC_MASK.jpg
# P_00391_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00391_RIGHT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00391_RIGHT_CC_FULL.jpg
# P_00391_RIGHT_MLO_MASK.jpg
# P_00394_RIGHT_MLO_MASK.jpg
# P_00405_LEFT_CC_MASK.jpg
# P_00405_LEFT_MLO_MASK.jpg
# P_00409_RIGHT_CC_MASK.jpg
# P_00409_RIGHT_MLO_MASK.jpg
# P_00429_LEFT_CC_MASK.jpg
# P_00429_LEFT_MLO_MASK.jpg
# P_00433_LEFT_CC_MASK.jpg
# P_00433_LEFT_MLO_MASK.jpg
# P_00457_LEFT_CC_MASK.jpg
# P_00457_LEFT_MLO_MASK.jpg
# P_00464_RIGHT_CC_MASK.jpg
# P_00464_RIGHT_MLO_MASK.jpg
# P_00470_RIGHT_CC_MASK.jpg
# P_00470_RIGHT_MLO_MASK.jpg
# P_00481_RIGHT_CC_MASK.jpg
# P_00481_RIGHT_MLO_MASK.jpg
# P_00482_LEFT_CC_MASK.jpg
# P_00482_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00482_LEFT_MLO_MASK.jpg
# P_00482_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00482_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_00482_LEFT_MLO_FULL.jpg
# P_00490_RIGHT_CC_MASK.jpg
# P_00490_RIGHT_MLO_MASK.jpg
# P_00493_RIGHT_CC_MASK.jpg
# P_00494_RIGHT_CC_MASK.jpg
# P_00494_RIGHT_MLO_MASK.jpg
# P_00498_LEFT_CC_MASK.jpg
# P_00498_LEFT_MLO_MASK.jpg
# P_00500_RIGHT_MLO_MASK.jpg
# P_00510_LEFT_CC_MASK.jpg
# P_00510_LEFT_MLO_MASK.jpg
# P_00514_LEFT_MLO_MASK.jpg
# P_00516_LEFT_CC_MASK.jpg
# P_00516_LEFT_MLO_MASK.jpg
# P_00524_LEFT_CC_MASK.jpg
# P_00524_LEFT_MLO_MASK.jpg
# P_00533_LEFT_CC_MASK.jpg
# P_00533_LEFT_MLO_MASK.jpg
# P_00544_LEFT_CC_MASK.jpg
# P_00544_LEFT_MLO_MASK.jpg
# P_00576_LEFT_CC_MASK.jpg
# P_00576_LEFT_MLO_MASK.jpg
# P_00587_RIGHT_CC_MASK.jpg
# P_00587_RIGHT_MLO_MASK.jpg
# P_00591_RIGHT_MLO_MASK.jpg
# P_00598_LEFT_CC_MASK.jpg
# P_00598_LEFT_MLO_MASK.jpg
# P_00601_LEFT_CC_MASK.jpg
# P_00601_LEFT_MLO_MASK.jpg
# P_00612_RIGHT_MLO_MASK.jpg
# P_00615_RIGHT_CC_MASK.jpg
# P_00615_RIGHT_MLO_MASK.jpg
# P_00623_LEFT_CC_MASK.jpg
# P_00623_LEFT_MLO_MASK.jpg
# P_00629_RIGHT_CC_MASK.jpg
# P_00629_RIGHT_MLO_MASK.jpg
# P_00636_RIGHT_CC_MASK.jpg
# P_00636_RIGHT_MLO_MASK.jpg
# P_00639_LEFT_MLO_MASK.jpg
# P_00639_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00641_RIGHT_CC_MASK.jpg
# P_00641_RIGHT_MLO_MASK.jpg
# P_00652_LEFT_CC_MASK.jpg
# P_00656_RIGHT_MLO_MASK.jpg
# P_00662_LEFT_CC_MASK.jpg
# P_00662_LEFT_MLO_MASK.jpg
# P_00671_LEFT_CC_MASK.jpg
# P_00671_LEFT_MLO_MASK.jpg
# P_00677_RIGHT_CC_MASK.jpg
# P_00677_RIGHT_MLO_MASK.jpg
# P_00699_RIGHT_CC_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2264, 1462)
# Image shape: (2602, 1680)
# P_00699_RIGHT_MLO_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2277, 1638)
# Image shape: (2618, 1883)
# P_00707_RIGHT_CC_MASK.jpg
# P_00707_RIGHT_MLO_MASK.jpg
# P_00718_RIGHT_MLO_MASK.jpg
# P_00738_RIGHT_CC_MASK.jpg
# P_00738_RIGHT_MLO_MASK.jpg
# P_00741_LEFT_CC_MASK.jpg
# P_00741_LEFT_MLO_MASK.jpg
# P_00758_LEFT_CC_MASK.jpg
# P_00758_LEFT_MLO_MASK.jpg
# P_00766_LEFT_CC_MASK.jpg
# P_00766_LEFT_MLO_MASK.jpg
# P_00773_LEFT_CC_MASK.jpg
# P_00773_LEFT_MLO_MASK.jpg
# P_00788_RIGHT_MLO_MASK.jpg
# P_00813_RIGHT_MLO_MASK.jpg
# P_00820_LEFT_CC_MASK.jpg
# P_00820_LEFT_MLO_MASK.jpg
# P_00820_RIGHT_CC_MASK.jpg
# P_00820_RIGHT_MLO_MASK.jpg
# P_00837_RIGHT_CC_MASK.jpg
# P_00837_RIGHT_MLO_MASK.jpg
# P_00875_RIGHT_CC_MASK.jpg
# P_00875_RIGHT_MLO_MASK.jpg
# P_00882_RIGHT_CC_MASK.jpg
# P_00882_RIGHT_MLO_MASK.jpg
# P_00893_LEFT_CC_MASK.jpg
# P_00893_LEFT_MLO_MASK.jpg
# P_00922_RIGHT_CC_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2296, 1077)
# Image shape: (2640, 1238)
# P_00922_RIGHT_MLO_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2289, 1077)
# Image shape: (2633, 1238)
# P_00924_RIGHT_CC_MASK.jpg
# P_00928_RIGHT_CC_MASK.jpg
# P_00928_RIGHT_MLO_MASK.jpg
# P_00932_LEFT_MLO_MASK.jpg
# P_00942_LEFT_CC_MASK.jpg
# P_00947_RIGHT_CC_MASK.jpg
# P_00947_RIGHT_MLO_MASK.jpg
# P_00951_LEFT_CC_MASK.jpg
# P_00951_RIGHT_CC_MASK.jpg
# P_00951_RIGHT_MLO_MASK.jpg
# P_00962_RIGHT_CC_MASK.jpg
# P_00962_RIGHT_MLO_MASK.jpg
# P_00966_RIGHT_MLO_MASK.jpg
# P_00969_LEFT_CC_MASK.jpg
# P_00969_LEFT_MLO_MASK.jpg
# P_00979_LEFT_CC_MASK.jpg
# P_00979_LEFT_MLO_MASK.jpg
# P_00980_LEFT_CC_MASK.jpg
# P_00980_LEFT_MLO_MASK.jpg
# P_00985_RIGHT_CC_MASK.jpg
# P_00985_RIGHT_MLO_MASK.jpg
# P_00986_LEFT_MLO_MASK.jpg
# P_00987_LEFT_CC_MASK.jpg
# P_00987_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00987_LEFT_MLO_MASK.jpg
# P_00987_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00987_LEFT_MLO_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_00987_LEFT_MLO_FULL.jpg
# P_01014_LEFT_CC_MASK.jpg
# P_01014_LEFT_MLO_MASK.jpg
# P_01044_LEFT_MLO_MASK.jpg
# P_01068_RIGHT_MLO_MASK.jpg
# P_01090_LEFT_CC_MASK.jpg
# P_01090_LEFT_MLO_MASK.jpg
# P_01090_RIGHT_MLO_MASK.jpg
# P_01101_LEFT_CC_MASK.jpg
# P_01106_LEFT_MLO_MASK.jpg
# P_01108_RIGHT_CC_MASK.jpg
# P_01108_RIGHT_MLO_MASK.jpg
# P_01110_RIGHT_CC_MASK.jpg
# P_01114_RIGHT_MLO_MASK.jpg
# P_01119_LEFT_CC_MASK.jpg
# P_01119_LEFT_MLO_MASK.jpg
# P_01140_LEFT_CC_MASK.jpg
# P_01140_LEFT_MLO_MASK.jpg
# P_01145_LEFT_MLO_MASK.jpg
# P_01167_LEFT_MLO_MASK.jpg
# P_01183_LEFT_CC_MASK.jpg
# P_01183_LEFT_MLO_MASK.jpg
# P_01187_LEFT_MLO_MASK.jpg
# P_01192_LEFT_CC_MASK.jpg
# P_01192_LEFT_MLO_MASK.jpg
# P_01204_RIGHT_CC_MASK.jpg
# P_01204_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01204_RIGHT_CC_FULL.jpg
# Slice_2 wrong shape: (1, 1) - image P_01204_RIGHT_CC_FULL.jpg
# P_01204_RIGHT_MLO_MASK.jpg
# P_01210_RIGHT_MLO_MASK.jpg
# P_01213_LEFT_CC_MASK.jpg
# P_01213_LEFT_MLO_MASK.jpg
# P_01235_RIGHT_MLO_MASK.jpg
# P_01251_LEFT_CC_MASK.jpg
# P_01251_LEFT_MLO_MASK.jpg
# P_01254_RIGHT_CC_MASK.jpg
# P_01254_RIGHT_MLO_MASK.jpg
# P_01257_RIGHT_CC_MASK.jpg
# P_01257_RIGHT_MLO_MASK.jpg
# P_01277_RIGHT_CC_MASK.jpg
# P_01277_RIGHT_MLO_MASK.jpg
# P_01294_RIGHT_CC_MASK.jpg
# P_01294_RIGHT_MLO_MASK.jpg
# P_01298_LEFT_CC_MASK.jpg
# P_01298_LEFT_MLO_MASK.jpg
# P_01307_RIGHT_CC_MASK.jpg
# P_01307_RIGHT_MLO_MASK.jpg
# P_01316_RIGHT_CC_MASK.jpg
# P_01316_RIGHT_MLO_MASK.jpg
# P_01322_RIGHT_CC_MASK.jpg
# P_01322_RIGHT_MLO_MASK.jpg
# P_01323_LEFT_CC_MASK.jpg
# P_01323_LEFT_MLO_MASK.jpg
# P_01331_LEFT_CC_MASK.jpg
# P_01331_LEFT_MLO_MASK.jpg
# P_01333_LEFT_CC_MASK.jpg
# P_01333_LEFT_MLO_MASK.jpg
# P_01347_RIGHT_CC_MASK.jpg
# P_01347_RIGHT_MLO_MASK.jpg
# P_01348_LEFT_MLO_MASK.jpg
# P_01351_LEFT_CC_MASK.jpg
# P_01365_LEFT_CC_MASK.jpg
# P_01365_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01378_LEFT_CC_MASK.jpg
# P_01378_RIGHT_CC_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2264, 1305)
# Image shape: (2602, 1500)
# P_01378_RIGHT_MLO_MASK.jpg
# P_01381_RIGHT_CC_MASK.jpg
# P_01381_RIGHT_MLO_MASK.jpg
# P_01395_RIGHT_CC_MASK.jpg
# P_01395_RIGHT_MLO_MASK.jpg
# P_01416_RIGHT_CC_MASK.jpg
# P_01416_RIGHT_MLO_MASK.jpg
# P_01467_RIGHT_CC_MASK.jpg
# P_01477_LEFT_CC_MASK.jpg
# P_01489_RIGHT_MLO_MASK.jpg
# P_01502_LEFT_CC_MASK.jpg
# P_01502_LEFT_MLO_MASK.jpg
# P_01510_RIGHT_CC_MASK.jpg
# P_01510_RIGHT_MLO_MASK.jpg
# P_01512_LEFT_CC_MASK.jpg
# P_01512_LEFT_MLO_MASK.jpg
# P_01518_LEFT_CC_MASK.jpg
# P_01518_LEFT_MLO_MASK.jpg
# P_01534_RIGHT_CC_MASK.jpg
# P_01534_RIGHT_MLO_MASK.jpg
# P_01539_RIGHT_CC_MASK.jpg
# P_01539_RIGHT_MLO_MASK.jpg
# P_01546_LEFT_CC_MASK.jpg
# P_01546_LEFT_MLO_MASK.jpg
# P_01551_LEFT_CC_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2343, 1619)
# Image shape: (2692, 1860)
# P_01551_LEFT_MLO_MASK.jpg
# P_01558_RIGHT_CC_MASK.jpg
# P_01558_RIGHT_MLO_MASK.jpg
# P_01566_RIGHT_CC_MASK.jpg
# P_01566_RIGHT_MLO_MASK.jpg
# P_01578_LEFT_MLO_MASK.jpg
# P_01590_LEFT_CC_MASK.jpg
# P_01590_LEFT_MLO_MASK.jpg
# P_01595_LEFT_CC_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2342, 1429)
# Image shape: (2693, 1643)
# P_01595_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image!
# Mask shape: (2343, 1345)
# Image shape: (2692, 1545)
# P_01599_LEFT_CC_MASK.jpg
# P_01599_LEFT_MLO_MASK.jpg
# P_01605_LEFT_CC_MASK.jpg
# P_01614_LEFT_MLO_MASK.jpg
# P_01617_LEFT_CC_MASK.jpg
# P_01617_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01617_LEFT_CC_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01617_LEFT_CC_FULL.jpg
# P_01617_LEFT_MLO_MASK.jpg
# P_01617_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01623_RIGHT_CC_MASK.jpg
# P_01623_RIGHT_MLO_MASK.jpg
# P_01640_LEFT_MLO_MASK.jpg
# P_01640_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01640_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01640_LEFT_MLO_FULL.jpg
# P_01645_RIGHT_CC_MASK.jpg
# P_01651_RIGHT_CC_MASK.jpg
# P_01651_RIGHT_MLO_MASK.jpg
# P_01661_LEFT_CC_MASK.jpg
# P_01661_LEFT_MLO_MASK.jpg
# P_01661_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01661_LEFT_MLO_FULL.jpg
# Slice_4 wrong shape: (1, 1) - image P_01661_LEFT_MLO_FULL.jpg
# P_01666_RIGHT_CC_MASK.jpg
# P_01666_RIGHT_MLO_MASK.jpg
# P_01673_RIGHT_CC_MASK.jpg
# P_01673_RIGHT_MLO_MASK.jpg
# P_01677_RIGHT_MLO_MASK.jpg
# P_01684_LEFT_CC_MASK.jpg
# P_01684_LEFT_MLO_MASK.jpg
# P_01690_LEFT_CC_MASK.jpg
# P_01690_LEFT_MLO_MASK.jpg
# P_01697_LEFT_CC_MASK.jpg
# P_01697_LEFT_MLO_MASK.jpg
# P_01716_RIGHT_CC_MASK.jpg
# P_01716_RIGHT_MLO_MASK.jpg
# P_01719_RIGHT_CC_MASK.jpg
# P_01719_RIGHT_MLO_MASK.jpg
# P_01726_RIGHT_CC_MASK.jpg
# P_01726_RIGHT_MLO_MASK.jpg
# P_01741_LEFT_CC_MASK.jpg
# P_01741_LEFT_MLO_MASK.jpg
# P_01765_RIGHT_CC_MASK.jpg
# P_01765_RIGHT_MLO_MASK.jpg
# P_01778_RIGHT_CC_MASK.jpg
# P_01787_LEFT_CC_MASK.jpg
# P_01787_LEFT_MLO_MASK.jpg
# P_01795_LEFT_CC_MASK.jpg
# P_01795_LEFT_MLO_MASK.jpg
# P_01796_LEFT_CC_MASK.jpg
# P_01796_LEFT_MLO_MASK.jpg
# P_01797_LEFT_CC_MASK.jpg
# P_01797_LEFT_MLO_MASK.jpg
# P_01800_LEFT_CC_MASK.jpg
# P_01800_LEFT_MLO_MASK.jpg
# P_01800_RIGHT_CC_MASK.jpg
# P_01807_RIGHT_MLO_MASK.jpg
# P_01815_RIGHT_CC_MASK.jpg
# P_01815_RIGHT_MLO_MASK.jpg
# P_01825_RIGHT_CC_MASK.jpg
# P_01825_RIGHT_MLO_MASK.jpg
# P_01833_RIGHT_MLO_MASK.jpg
# P_01865_LEFT_MLO_MASK.jpg
# P_01912_RIGHT_CC_MASK.jpg
# P_01912_RIGHT_MLO_MASK.jpg

# %%
print("Mass Test Slices shape:", mass_test_slices.shape)
print("Mass Test File Name List:", len(mass_test_image_names))
# Out:
# Mass Test Slices shape: (402, 299, 299, 1)
# Mass Test File Name List: 402

# %%
# check images to make sure it matches the cropped image
plt.imshow(mass_test_slices[99].reshape(299,299))
plt.title(mass_test_image_names[99])

# %%
# process labels for slices
test_labels = pd.read_pickle(os.path.join("data", "test_labels.pkl"))

test_labels['IMAGE_NAME2'] = test_labels.index
test_labels = test_labels.drop_duplicates(['IMAGE_NAME2'])
mass_test_labels = []

for image in mass_test_image_names:
    label = test_labels.loc[image]['CLASS']
    mass_test_labels.append(test_labels.loc[image]['CLASS'])
    
print("Mass Test Labels:", len(mass_test_labels))
# Out:
# Mass Test Labels: 402

# %%
np.save(os.path.join("data", "mass_test_slices.npy"), mass_test_slices)
np.save(os.path.join("data", "mass_test_filenames.npy"), mass_test_image_names)
np.save(os.path.join("data", "mass_test_labels.npy"), np.array(mass_test_labels))

# %% [markdown]
# ## Calc Test

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Test ROI JPEGs", "Calc Test All Mask JPEGs", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Test Full JPEGs", "Calc Test All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Test All Mask JPEGs"
image_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Test All Full JPEGs"

calc_test_slices, calc_test_image_names = create_roi_slices(mask_dir, image_dir, output=True)
# Out:
# P_00038_LEFT_CC.jpg
# P_00038_LEFT_CC000001.jpg
# P_00038_LEFT_MLO000001.jpg
# P_00038_RIGHT_CC000001.jpg
# P_00038_RIGHT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00038_RIGHT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_00038_RIGHT_CC.jpg
# P_00038_RIGHT_CC000001_1.jpg
# P_00038_RIGHT_CC000001_1.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00038_RIGHT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_00038_RIGHT_CC.jpg
# P_00038_RIGHT_MLO000001.jpg
# P_00038_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_00038_RIGHT_MLO000001_1.jpg
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# P_00038_RIGHT_MLO000001_1.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00038_RIGHT_MLO.jpg
# Slice_4 wrong shape: (1, 1) - image P_00038_RIGHT_MLO.jpg
# P_00041_LEFT_CC000001.jpg
# P_00041_LEFT_MLO000001.jpg
# P_00077_LEFT_CC000001.jpg
# P_00077_LEFT_MLO000001.jpg
# P_00077_RIGHT_CC000001.jpg
# P_00077_RIGHT_MLO000001.jpg
# P_00100_RIGHT_CC000001.jpg
# P_00100_RIGHT_MLO000001.jpg
# P_00127_RIGHT_CC000001.jpg
# P_00127_RIGHT_MLO000001.jpg
# P_00132_LEFT_MLO000001.jpg
# P_00132_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00132_LEFT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_00132_LEFT_MLO.jpg
# P_00140_LEFT_CC000001_1.jpg
# P_00140_LEFT_MLO000001.jpg
# P_00140_RIGHT_CC000001.jpg
# P_00140_RIGHT_MLO000001.jpg
# P_00141_LEFT_CC000001.jpg
# P_00141_LEFT_MLO000001.jpg
# P_00150_RIGHT_MLO000001.jpg
# P_00163_LEFT_CC000001.jpg
# P_00163_LEFT_MLO000001.jpg
# P_00164_RIGHT_CC000001.jpg
# P_00180_LEFT_CC000001.jpg
# P_00180_LEFT_CC000001.jpg Mask too big, reframing...
# P_00180_LEFT_MLO000001.jpg
# P_00180_LEFT_MLO000001.jpg Mask too big, reframing...
# P_00195_LEFT_CC000001.jpg
# P_00195_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00195_LEFT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_00195_LEFT_CC.jpg
# P_00195_LEFT_MLO000001.jpg
# P_00202_RIGHT_CC000001.jpg
# P_00202_RIGHT_CC000001.jpg Mask too big, reframing...
# P_00202_RIGHT_MLO000001.jpg
# P_00202_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_00214_LEFT_CC000001.jpg
# P_00214_LEFT_CC000001_1.jpg
# P_00214_LEFT_MLO000001.jpg
# P_00214_RIGHT_MLO000001.jpg
# P_00223_LEFT_MLO000001.jpg
# P_00244_RIGHT_MLO000001.jpg
# P_00246_RIGHT_MLO000001.jpg
# P_00257_RIGHT_CC000001.jpg
# P_00257_RIGHT_MLO000001.jpg
# P_00299_LEFT_MLO000001.jpg
# P_00299_LEFT_MLO000001.jpg Mask too big, reframing...
# P_00299_RIGHT_CC000001.jpg
# P_00299_RIGHT_CC000001.jpg Mask too big, reframing...
# P_00299_RIGHT_MLO000001.jpg
# P_00299_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_00315_LEFT_MLO_MASK.jpg
# P_00325_RIGHT_MLO000001.jpg
# P_00331_LEFT_CC000001.jpg
# P_00331_LEFT_MLO000001.jpg
# P_00344_LEFT_CC000001.jpg
# P_00344_LEFT_MLO000001.jpg
# P_00352_LEFT_CC000001.jpg
# P_00352_LEFT_MLO000001.jpg
# P_00353_LEFT_CC1000001.jpg
# Error: P_00353_LEFT_CC1_FULL.jpg
# P_00353_LEFT_CC2000001.jpg
# Error: P_00353_LEFT_CC2_FULL.jpg
# P_00353_LEFT_MLO000001.jpg
# Mask shape doesn't match image!
# Mask shape: (2312, 1540)
# Image shape: (2320, 1536)
# P_00353_LEFT_MLO000001_1.jpg
# P_00368_LEFT_CC000001.jpg
# P_00368_LEFT_CC000001.jpg Mask too big, reframing...
# P_00368_LEFT_MLO000001.jpg
# P_00368_LEFT_MLO000001.jpg Mask too big, reframing...
# P_00372_RIGHT_CC000001.jpg
# P_00372_RIGHT_CC000001.jpg Mask too big, reframing...
# P_00372_RIGHT_MLO000001.jpg
# P_00372_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00372_RIGHT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_00372_RIGHT_MLO.jpg
# P_00390_RIGHT_CC000001.jpg
# P_00390_RIGHT_CC000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00390_RIGHT_CC.jpg
# Slice_2 wrong shape: (1, 1) - image P_00390_RIGHT_CC.jpg
# P_00390_RIGHT_MLO000001.jpg
# P_00390_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00390_RIGHT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_00390_RIGHT_MLO.jpg
# P_00397_LEFT_CC000001.jpg
# P_00402_RIGHT_CC000001.jpg
# P_00402_RIGHT_MLO000001.jpg
# P_00403_RIGHT_CC000001.jpg
# P_00403_RIGHT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00403_RIGHT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_00403_RIGHT_CC.jpg
# P_00403_RIGHT_MLO000001.jpg
# P_00403_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_00460_LEFT_CC000001.jpg
# P_00460_LEFT_CC000001.jpg Mask too big, reframing...
# P_00460_LEFT_MLO000001.jpg
# P_00460_LEFT_MLO000001.jpg Mask too big, reframing...
# P_00466_LEFT_MLO000001.jpg
# P_00485_LEFT_CC000001.jpg
# P_00485_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_00485_LEFT_CC.jpg
# P_00485_LEFT_CC000001_1.jpg
# P_00485_LEFT_CC000001_2.jpg
# P_00485_LEFT_CC000001_3.jpg
# P_00485_LEFT_CC_MASK.jpg
# P_00485_LEFT_MLO000001.jpg
# P_00485_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_00485_LEFT_MLO.jpg
# P_00495_RIGHT_CC000001.jpg
# P_00495_RIGHT_CC000001_1.jpg
# P_00495_RIGHT_MLO000001.jpg
# P_00495_RIGHT_MLO000001_1.jpg
# P_00497_LEFT_CC000001.jpg
# P_00497_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00497_LEFT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_00497_LEFT_CC.jpg
# P_00497_LEFT_MLO000001.jpg
# P_00497_LEFT_MLO000001.jpg Mask too big, reframing...
# P_00537_RIGHT_MLO000001.jpg
# P_00537_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_00562_LEFT_CC000001.jpg
# P_00562_LEFT_CC000001_1.jpg
# P_00562_LEFT_MLO000001.jpg
# P_00562_LEFT_MLO000001_1.jpg
# P_00562_RIGHT_CC000001.jpg
# P_00562_RIGHT_MLO000001.jpg
# P_00570_LEFT_MLO000001.jpg
# P_00579_LEFT_MLO000001.jpg
# P_00589_LEFT_CC000001.jpg
# P_00589_LEFT_MLO000001.jpg
# P_00608_LEFT_CC000001.jpg
# P_00608_LEFT_MLO000001.jpg
# P_00620_LEFT_CC000001.jpg
# P_00643_LEFT_CC000001.jpg
# P_00643_LEFT_MLO000001.jpg
# P_00646_LEFT_CC000001.jpg
# P_00646_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00646_LEFT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_00646_LEFT_CC.jpg
# P_00646_LEFT_MLO000001.jpg
# P_00649_LEFT_CC000001.jpg
# P_00649_LEFT_MLO000001.jpg
# P_00649_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00649_LEFT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_00649_LEFT_MLO.jpg
# Slice_3 wrong shape: (1, 1) - image P_00649_LEFT_MLO.jpg
# Slice_4 wrong shape: (1, 1) - image P_00649_LEFT_MLO.jpg
# P_00663_RIGHT_CC000001.jpg
# P_00663_RIGHT_MLO000001.jpg
# P_00663_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00663_RIGHT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_00663_RIGHT_MLO.jpg
# P_00678_LEFT_CC000001.jpg
# P_00678_LEFT_CC000001.jpg Mask too big, reframing...
# P_00679_LEFT_CC000001.jpg
# P_00679_LEFT_MLO000001.jpg
# P_00681_LEFT_CC000001.jpg
# P_00681_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00681_LEFT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_00681_LEFT_CC.jpg
# P_00681_LEFT_MLO000001.jpg
# P_00681_LEFT_MLO000001.jpg Mask too big, reframing...
# P_00686_RIGHT_MLO000001.jpg
# P_00723_LEFT_MLO000001.jpg
# P_00723_LEFT_MLO000001_1.jpg
# P_00723_LEFT_MLO000001_2.jpg
# P_00753_LEFT_CC000001.jpg
# P_00753_LEFT_MLO000001.jpg
# P_00774_RIGHT_CC000001.jpg
# P_00774_RIGHT_MLO000001.jpg
# P_00789_LEFT_MLO000001.jpg
# P_00790_RIGHT_CC000001.jpg
# P_00790_RIGHT_MLO000001.jpg
# P_00795_LEFT_CC000001.jpg
# P_00795_LEFT_MLO000001.jpg
# P_00811_LEFT_CC000001.jpg
# P_00811_LEFT_CC000001.jpg Mask too big, reframing...
# P_00827_RIGHT_CC000001.jpg
# P_00827_RIGHT_MLO000001.jpg
# P_00843_RIGHT_CC000001.jpg
# P_00843_RIGHT_MLO000001.jpg
# P_00857_RIGHT_CC000001.jpg
# P_00857_RIGHT_CC000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00857_RIGHT_CC.jpg
# Slice_2 wrong shape: (1, 1) - image P_00857_RIGHT_CC.jpg
# P_00857_RIGHT_MLO000001.jpg
# P_00857_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_00876_LEFT_CC000001.jpg
# P_00876_LEFT_MLO000001.jpg
# P_00879_RIGHT_CC000001.jpg
# P_00879_RIGHT_MLO000001.jpg
# P_00905_RIGHT_CC000001.jpg
# P_00905_RIGHT_MLO000001.jpg
# P_00906_LEFT_CC000001.jpg
# P_00906_LEFT_MLO000001.jpg
# P_00906_LEFT_MLO000001_1.jpg
# P_00919_RIGHT_CC000001.jpg
# P_00919_RIGHT_MLO000001.jpg
# P_00974_RIGHT_CC000001.jpg
# P_00974_RIGHT_MLO000001.jpg
# P_01004_LEFT_CC000001.jpg
# P_01004_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01004_LEFT_CC.jpg
# Slice_2 wrong shape: (1, 1) - image P_01004_LEFT_CC.jpg
# P_01004_LEFT_CC000001_1.jpg
# P_01004_LEFT_MLO000001.jpg
# P_01004_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01004_LEFT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_01004_LEFT_MLO.jpg
# P_01004_LEFT_MLO000001_1.jpg
# P_01006_LEFT_CC000001.jpg
# P_01006_LEFT_MLO000001.jpg
# P_01022_LEFT_CC000001.jpg
# P_01022_LEFT_MLO000001.jpg
# P_01030_RIGHT_CC000001.jpg
# P_01030_RIGHT_CC000001_1.jpg
# P_01030_RIGHT_MLO000001.jpg
# P_01030_RIGHT_MLO000001_1.jpg
# P_01042_RIGHT_CC000001.jpg
# P_01042_RIGHT_MLO000001.jpg
# P_01050_LEFT_MLO000001.jpg
# P_01058_LEFT_CC000001.jpg
# P_01058_LEFT_MLO000001.jpg
# P_01067_LEFT_CC000001.jpg
# P_01067_LEFT_MLO000001.jpg
# P_01092_LEFT_CC000001.jpg
# P_01092_LEFT_MLO000001.jpg
# P_01132_RIGHT_MLO000001.jpg
# P_01148_RIGHT_MLO000001.jpg
# P_01152_RIGHT_CC_MASK.jpg
# P_01152_RIGHT_MLO000001.jpg
# P_01154_LEFT_CC000001.jpg
# P_01154_LEFT_CC000001.jpg Mask too big, reframing...
# P_01154_LEFT_MLO000001.jpg
# P_01154_LEFT_MLO000001.jpg Mask too big, reframing...
# P_01157_RIGHT_CC000001.jpg
# P_01157_RIGHT_MLO000001.jpg
# P_01179_LEFT_MLO000001.jpg
# P_01211_LEFT_CC000001.jpg
# P_01211_LEFT_MLO000001.jpg
# P_01211_RIGHT_CC000001.jpg
# P_01211_RIGHT_CC000001_1.jpg
# P_01211_RIGHT_MLO000001.jpg
# P_01211_RIGHT_MLO000001_1.jpg
# P_01217_RIGHT_CC000001.jpg
# P_01217_RIGHT_CC000001_1.jpg
# Mask shape doesn't match image!
# Mask shape: (2136, 1552)
# Image shape: (2399, 1185)
# P_01217_RIGHT_MLO000001.jpg
# P_01237_LEFT_CC000001.jpg
# P_01237_LEFT_MLO000001.jpg
# P_01253_RIGHT_CC000001.jpg
# P_01253_RIGHT_MLO000001.jpg
# P_01272_LEFT_CC000001.jpg
# P_01272_LEFT_CC000001_1.jpg
# P_01272_LEFT_MLO000001.jpg
# P_01272_LEFT_MLO_MASK.jpg
# P_01303_LEFT_CC000001.jpg
# P_01303_LEFT_MLO000001.jpg
# P_01308_LEFT_MLO000001.jpg
# P_01318_LEFT_MLO000001.jpg
# P_01320_LEFT_MLO000001.jpg
# P_01320_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01320_LEFT_MLO.jpg
# Slice_4 wrong shape: (1, 1) - image P_01320_LEFT_MLO.jpg
# P_01352_LEFT_CC000001.jpg
# P_01352_LEFT_MLO_MASK.jpg
# P_01353_LEFT_CC000001.jpg
# P_01353_LEFT_MLO000001.jpg
# P_01353_LEFT_MLO000001.jpg Mask too big, reframing...
# P_01390_RIGHT_CC000001.jpg
# P_01390_RIGHT_CC000001_1.jpg
# P_01390_RIGHT_MLO000001.jpg
# P_01390_RIGHT_MLO000001_1.jpg
# P_01399_RIGHT_CC000001.jpg
# P_01399_RIGHT_MLO000001.jpg
# P_01407_LEFT_CC000001.jpg
# P_01407_LEFT_MLO000001.jpg
# P_01407_RIGHT_CC000001.jpg
# P_01407_RIGHT_MLO000001.jpg
# P_01414_RIGHT_CC000001.jpg
# P_01414_RIGHT_MLO000001.jpg
# P_01415_RIGHT_MLO000001.jpg
# P_01419_LEFT_CC000001.jpg
# P_01419_LEFT_MLO000001.jpg
# P_01425_LEFT_CC000001.jpg
# P_01425_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01425_LEFT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_01425_LEFT_CC.jpg
# P_01425_LEFT_MLO000001.jpg
# P_01425_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01425_LEFT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_01425_LEFT_MLO.jpg
# P_01460_LEFT_MLO000001.jpg
# P_01460_LEFT_MLO000001_1.jpg
# P_01460_LEFT_MLO000001_1.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01460_LEFT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_01460_LEFT_MLO.jpg
# P_01460_LEFT_MLO000001_2.jpg
# Mask shape doesn't match image!
# Mask shape: (2232, 1512)
# Image shape: (2240, 1508)
# P_01460_RIGHT_CC000001.jpg
# P_01460_RIGHT_CC000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01460_RIGHT_CC.jpg
# Slice_2 wrong shape: (1, 1) - image P_01460_RIGHT_CC.jpg
# P_01460_RIGHT_MLO000001.jpg
# P_01460_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01460_RIGHT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_01460_RIGHT_MLO.jpg
# P_01460_RIGHT_MLO000001_1.jpg
# P_01465_LEFT_MLO000001.jpg
# P_01471_RIGHT_CC000001.jpg
# P_01471_RIGHT_MLO000001.jpg
# P_01476_RIGHT_CC000001.jpg
# P_01476_RIGHT_MLO000001.jpg
# P_01476_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01476_RIGHT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_01476_RIGHT_MLO.jpg
# P_01483_LEFT_CC000001.jpg
# P_01483_LEFT_CC000001.jpg Mask too big, reframing...
# P_01483_LEFT_MLO000001.jpg
# P_01483_LEFT_MLO000001.jpg Mask too big, reframing...
# P_01490_LEFT_CC000001.jpg
# P_01490_LEFT_MLO000001.jpg
# P_01502_LEFT_CC000001.jpg
# P_01502_LEFT_CC000001.jpg Mask too big, reframing...
# P_01502_LEFT_MLO000001.jpg
# P_01502_LEFT_MLO000001.jpg Mask too big, reframing...
# P_01523_LEFT_MLO000001.jpg
# P_01523_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01523_LEFT_MLO.jpg
# Slice_4 wrong shape: (1, 1) - image P_01523_LEFT_MLO.jpg
# P_01534_LEFT_CC_MASK.jpg
# P_01534_LEFT_MLO000001.jpg
# P_01535_LEFT_CC000001.jpg
# P_01535_LEFT_MLO000001.jpg
# P_01536_RIGHT_CC000001.jpg
# P_01536_RIGHT_MLO000001.jpg
# P_01536_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01536_RIGHT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_01536_RIGHT_MLO.jpg
# P_01538_RIGHT_MLO000001.jpg
# P_01538_RIGHT_MLO000001_1.jpg
# P_01547_LEFT_CC000001.jpg
# P_01547_LEFT_MLO000001.jpg
# P_01562_LEFT_CC000001.jpg
# P_01562_LEFT_MLO000001.jpg
# P_01602_RIGHT_CC000001.jpg
# P_01621_LEFT_CC000001.jpg
# P_01621_LEFT_CC000001.jpg Mask too big, reframing...
# P_01621_LEFT_MLO000001.jpg
# P_01621_LEFT_MLO000001.jpg Mask too big, reframing...
# P_01635_RIGHT_CC000001.jpg
# P_01635_RIGHT_MLO000001.jpg
# P_01643_LEFT_CC000001.jpg
# P_01643_LEFT_MLO000001.jpg
# P_01643_RIGHT_CC000001.jpg
# P_01643_RIGHT_MLO000001.jpg
# P_01670_LEFT_CC000001.jpg
# P_01670_LEFT_MLO000001.jpg
# P_01670_LEFT_MLO000001_1.jpg
# P_01670_LEFT_MLO000001_2.jpg
# P_01711_RIGHT_CC000001.jpg
# P_01711_RIGHT_CC000001.jpg Mask too big, reframing...
# P_01711_RIGHT_MLO000001.jpg
# P_01711_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_01713_RIGHT_MLO000001.jpg
# P_01713_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_01713_RIGHT_MLO.jpg
# Slice_4 wrong shape: (1, 1) - image P_01713_RIGHT_MLO.jpg
# P_01728_LEFT_CC000001.jpg
# P_01743_RIGHT_MLO000001.jpg
# P_01743_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_01752_LEFT_CC000001.jpg
# P_01752_LEFT_MLO000001.jpg
# P_01773_RIGHT_CC000001.jpg
# P_01773_RIGHT_MLO000001.jpg
# P_01803_RIGHT_CC000001.jpg
# P_01803_RIGHT_MLO000001.jpg
# P_01803_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01803_RIGHT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_01803_RIGHT_MLO.jpg
# P_01820_LEFT_MLO000001.jpg
# P_01820_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01820_LEFT_MLO.jpg
# Slice_2 wrong shape: (1, 1) - image P_01820_LEFT_MLO.jpg
# P_01834_LEFT_MLO000001.jpg
# P_01842_LEFT_MLO000001.jpg
# P_01845_RIGHT_CC000001.jpg
# P_01845_RIGHT_CC000001_1.jpg
# P_01845_RIGHT_MLO000001.jpg
# P_01845_RIGHT_MLO000001_1.jpg
# P_01861_LEFT_CC000001.jpg
# P_01861_LEFT_MLO000001.jpg
# P_01867_LEFT_CC000001.jpg
# P_01867_LEFT_CC000001_1.jpg
# P_01867_LEFT_MLO000001.jpg
# P_01867_LEFT_MLO000001_1.jpg
# P_01868_LEFT_CC000001.jpg
# P_01868_LEFT_MLO000001.jpg
# P_01872_LEFT_CC000001.jpg
# P_01872_LEFT_MLO000001.jpg
# P_01882_LEFT_CC000001.jpg
# P_01882_LEFT_MLO000001.jpg
# P_01883_RIGHT_CC000001.jpg
# P_01883_RIGHT_CC000001.jpg Mask too big, reframing...
# P_01883_RIGHT_MLO000001.jpg
# P_01883_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_02102_LEFT_CC000001.jpg
# P_02102_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_02102_LEFT_CC.jpg
# P_02102_LEFT_MLO000001.jpg
# P_02102_LEFT_MLO000001.jpg Mask too big, reframing...
# P_02139_LEFT_CC000001.jpg
# P_02139_LEFT_MLO000001.jpg
# P_02139_LEFT_MLO000001.jpg Mask too big, reframing...
# P_02153_RIGHT_CC000001.jpg
# P_02153_RIGHT_MLO000001.jpg
# P_02159_LEFT_CC000001.jpg
# P_02159_LEFT_MLO000001.jpg
# P_02176_RIGHT_CC000001.jpg
# P_02176_RIGHT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02176_RIGHT_CC.jpg
# P_02176_RIGHT_MLO000001.jpg
# P_02176_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_02198_LEFT_CC000001.jpg
# P_02198_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_02198_LEFT_CC.jpg
# Slice_2 wrong shape: (1, 1) - image P_02198_LEFT_CC.jpg
# P_02198_LEFT_MLO000001.jpg
# P_02198_LEFT_MLO000001.jpg Mask too big, reframing...
# P_02275_LEFT_CC000001.jpg
# P_02275_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_02275_LEFT_CC.jpg
# P_02275_LEFT_MLO000001.jpg
# P_02275_LEFT_MLO000001.jpg Mask too big, reframing...
# P_02418_RIGHT_CC000001.jpg
# P_02418_RIGHT_CC000001.jpg Mask too big, reframing...
# P_02418_RIGHT_MLO000001.jpg
# P_02418_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_02420_RIGHT_CC000001.jpg
# P_02420_RIGHT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02420_RIGHT_CC.jpg
# Slice_4 wrong shape: (1, 1) - image P_02420_RIGHT_CC.jpg
# P_02420_RIGHT_MLO000001.jpg
# P_02420_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_02432_LEFT_CC000001.jpg
# P_02432_LEFT_CC000001.jpg Mask too big, reframing...
# P_02432_LEFT_MLO000001.jpg
# P_02432_LEFT_MLO000001.jpg Mask too big, reframing...
# P_02464_RIGHT_CC000001.jpg
# P_02464_RIGHT_CC000001.jpg Mask too big, reframing...
# P_02464_RIGHT_MLO000001.jpg
# P_02464_RIGHT_MLO000001.jpg Mask too big, reframing...
# P_02498_RIGHT_CC000001.jpg
# P_02498_RIGHT_MLO000001.jpg
# P_02501_RIGHT_CC000001.jpg
# P_02501_RIGHT_MLO000001.jpg
# P_02501_RIGHT_MLO000001.jpg Mask too big, reframing...

# %%
print("Calc Test Slices shape:", calc_test_slices.shape)
print("Calc Test File Name List:", len(calc_test_image_names))
# Out:
# Calc Test Slices shape: (558, 299, 299, 1)
# Calc Test File Name List: 558

# %%
# check image to make sure it matches the cropped image
plt.imshow(calc_test_slices[76].reshape(299,299))
plt.title(calc_test_image_names[76])

# %%
# P_00038_RIGHT_CC
for i in range(len(calc_test_image_names)):
    if calc_test_image_names[i] == "P_00485_LEFT_CC.jpg":
        plt.imshow(calc_test_slices[i].reshape(299,299))
        plt.title("P_00485_LEFT_CC.jpg - idx: " + str(i))
        plt.show()

# %%
test_labels = pd.read_pickle(os.path.join("data", "test_labels.pkl"))
test_labels['IMAGE_NAME2'] = test_labels.index
test_labels = test_labels.drop_duplicates(['IMAGE_NAME2'])

calc_test_labels = []
for image in calc_test_image_names:
    label = test_labels.loc[image]['CLASS']
    calc_test_labels .append(test_labels.loc[image]['CLASS'])
    
print("Calc Test Labels:", len(calc_test_labels))
# Out:
# Calc Test Labels: 558

# %%
np.save(os.path.join("data", "calc_test_slices.npy"), calc_test_slices)
np.save(os.path.join("data", "calc_test_filenames.npy"), calc_test_image_names)
np.save(os.path.join("data", "calc_test_labels.npy"), np.array(calc_test_labels))

# %% [markdown]
# ## Create File with All Slices

# %%
mass_train_labels = np.load(os.path.join("data", "mass_train_labels.npy"))
mass_test_labels = np.load(os.path.join("data", "mass_test_labels.npy"))
calc_train_labels = np.load(os.path.join("data", "calc_train_labels.npy"))
calc_test_labels = np.load(os.path.join("data", "calc_test_labels.npy"))
all_labels = np.concatenate([mass_train_labels, mass_test_labels, calc_train_labels, calc_test_labels], axis=0)

# %%
mass_train_slices = np.load(os.path.join("data", "mass_train_slices.npy"))
mass_test_slices = np.load(os.path.join("data", "mass_test_slices.npy"))
calc_train_slices = np.load(os.path.join("data", "calc_train_slices.npy"))
calc_test_slices = np.load(os.path.join("data", "calc_test_slices.npy"))
all_slices = np.concatenate([mass_train_slices, mass_test_slices, calc_train_slices, calc_test_slices], axis=0)

# %%
print("All labels:", all_labels.shape)
print("All slices:", all_slices.shape)
# Out:
# All labels: (4112,)
# All slices: (4112, 299, 299, 1)

# %%
np.save(os.path.join("data", "all_slices.npy"), all_slices)
np.save(os.path.join("data", "all_labels.npy"), all_labels)

# %% [markdown]
# ## Mask Sizes

# %% [markdown]
# The MIAS scans are sized 1024x1024 so have been scaled down. The DDSM images are full size and the regions of interest have been cut out of them at full size. We know the radius of the MIAS abnormalities, if we can get an average radius of DDSM abnormalities we can scale the MIAS data so that the sizes will match.

# %%
def get_mask_sizes(mask_dir, output=True):
    # loop through mask directory
    mask_files = os.listdir(mask_dir)
    mask_sizes = []
    
    for mask in mask_files:
        if output:
            print(mask)
        
        # get the mask, if the mask is bigger than the slice we will create multiple slices 
        # using the corners of the mask. 
        center_row, center_col, too_big, mask_size = create_mask(mask_dir + "/" + mask, return_size=True)
        mask_sizes.append(mask_size)
        
    return mask_sizes

# %%
## get the sizes of the masks as this will be used to scale the MIAS data properly
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Train All Mask JPEGs Full"

mass_train_mask_sizes = get_mask_sizes(mask_dir, output=False)

# %%
print("Mean ROI Radius Mass Train Data:", np.mean(mass_train_mask_sizes))
print("Median ROI Radius Mass Train Data:", np.median(mass_train_mask_sizes))
print("Min ROI Radius Mass Train Data:", np.min(mass_train_mask_sizes))
print("Max ROI Radius Mass Train Data:", np.max(mass_train_mask_sizes))
# Out:
# Mean ROI Radius Mass Train Data: 176.38161106590724
# Median ROI Radius Mass Train Data: 159.0
# Min ROI Radius Mass Train Data: 56
# Max ROI Radius Mass Train Data: 681

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Train All Mask JPEGs Full"

calc_train_mask_sizes = get_mask_sizes(mask_dir, output=False)

# %%
print("Mean ROI Radius Calc Train Data:", np.mean(calc_train_mask_sizes))
print("Median ROI Radius Calc Train Data:", np.median(calc_train_mask_sizes))
print("Min ROI Radius Calc Train Data:", np.min(calc_train_mask_sizes))
print("Max ROI Radius Calc Train Data:", np.max(calc_train_mask_sizes))
# Out:
# Mean ROI Radius Calc Train Data: 271.4922575387123
# Median ROI Radius Calc Train Data: 184.0
# Min ROI Radius Calc Train Data: 20
# Max ROI Radius Calc Train Data: 1899

# %%
all_mask_sizes = np.concatenate([mass_train_mask_sizes, calc_train_mask_sizes], axis=0)
                                 
print("Mean ROI Radius All Train Data:", np.mean(all_mask_sizes))
print("Median ROI Radius All Train Data:", np.median(all_mask_sizes))
print("Min ROI Radius All Train Data:", np.min(all_mask_sizes))
print("Max ROI Radius All Train Data:", np.max(all_mask_sizes))
# Out:
# Mean ROI Radius All Train Data: 223.89820846905536
# Median ROI Radius All Train Data: 167.0
# Min ROI Radius All Train Data: 20
# Max ROI Radius All Train Data: 1899

# %% [markdown]
# <b>Compare to MIAS Data:</b><br>
# Mean abnormality radius: 50.57657657657658<br>
# Median abnormality radius: 41.0<br>
# Min abnormality radius: 3.0<br>
# Max abnormality radius: 197.0<br>

# %%
plt.hist(all_mask_sizes, bins=range(0, 1750, 100))
plt.title("DDSM Mass Radii")
plt.show()

# %% [markdown]
# <b>Compare to MIAS Radii</b>
# <img align="left" src="data:image/png;base64,...">

# %% [markdown]
# I am going to use an estimate of four to convert from the MIAS to DDSM data, as far as abnormality radii, so the MIAS data slices will be zoomed in by 4x to make them equivalent to the DDSM slices.
