# %%
import PIL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import shutil
import re
from mammo_utils import create_mask, half_image
# %matplotlib inline

# %%
## rename the files to include the patient id so we can match the image up with the labels
## also copy the images to a single directory so we have them all in one place
def rename_and_copy_files(path, sourcedir="JPEG512", destdir="AllJPEGS512", scan_type="FULL"):
    directories = os.listdir(path+sourcedir)
    source_path = path + sourcedir + "/"
    destination_path = path + destdir + "/"
    
    # keep a counter so each file has a unique name
    i = 1
    
    # loop through the directories
    for directory in directories:
        # get the patient number and image type from the directory name
        patient_id = re.findall("_(P_[\d]+)_", directory)
        
        if len(patient_id) > 0:
            patient_id = str(patient_id[0])
        else:
            continue
        
        image_side = re.findall("_(LEFT|RIGHT)_", directory)
        
        if len(image_side) > 0:
            image_side = str(image_side[0])
        else:
            continue
        
        image_type = re.findall("(CC|MLO)", directory)
        if len(image_type) > 0:
            image_type = str(image_type[0])
        else:
            continue
        
        if not patient_id:
            continue
            
        # get the subdirectories
        subdir = os.listdir(source_path+directory)
        flag = False
        
        # get the next level of subdirectories
        if scan_type == 'FULL':
            subdir = subdir[0]
        elif (scan_type == "MASK") and (len(subdir) > 1):
            subdir = subdir[1]
        else:
            subdir = subdir[0]
            flag = True
            
        subsubdir = os.listdir(source_path+directory+'/'+subdir)
        if flag == False:
            files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[0])
            path = source_path+directory+'/'+subdir+'/'+subsubdir[0]
        else:
            try:
                if "mask" in str(subsubdir[0]):
                    files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[0])
                    path = source_path+directory+'/'+subdir+'/'+subsubdir[0]
                else:
                    files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[1])
                    path = source_path+directory+'/'+subdir+'/'+subsubdir[1]
            except:
                continue

        for file in files:
            # rename the file so we know where it came from, if image is not properly labeled skip it
            try:
                new_name = path+'/'+patient_id+'_'+image_side+'_'+image_type+'_'+scan_type+'.jpg'
                os.rename(path+'/'+file, new_name)
            except:
                print("Error:", new_name)
                continue
            
            # make sure the destination directory exists
            try:
                os.stat(destination_path)
            except:
                os.mkdir(destination_path)  
            
            # copy the files so they are all in one directory
            shutil.copy(new_name, destination_path)

        i += 1

## function to create ROI slices from masks and full images
## inputs: mask_dir and image_dir - paths to directories containing respective images
##         output - if True will output each file processed, 
##                  if False will only output errors and warnings, 
##                  if None won't ouput anything
## returns: numpy array of images and list of corresponding file names

def create_roi_slices(mask_dir, image_dir, output=True):
    # loop through mask directory
    mask_files = os.listdir(mask_dir)
    slices_list = []
    image_names_list = []

    for mask in mask_files:
        if output:
            print(mask)
        
        # get the mask, if the mask is bigger than the slice we will create multiple slices 
        # using the corners of the mask. 
        center_row, center_col, too_big = create_mask(mask_dir + "/" + mask)
        
        if too_big and output is not None:
            print("Mask is too big cropping:", mask)
            
        # open the full image
        image_file = mask.replace("MASK", "FULL")
        
        # some files have multiple masks, handle that case
        image_file = re.sub("(00\d+).jpg", ".jpg", image_file)
        base_image_file = image_file
        
        # try to open the image, if it doesn't exist continue
        try:
            full_image = PIL.Image.open(image_dir + "/" + image_file)
        except:
            # strip the image_file down to the bare name and then try some variations
            image_file = image_file.replace("_FULL", "")
            image_file = re.sub("_(\d).jpg", ".jpg", image_file)
            image_file = image_file.replace("000000", "")
            base_image_file = image_file.replace("000001", "")
            image_file = base_image_file.replace(".jpg", "000000.jpg")
            try:
                full_image = PIL.Image.open(image_dir + "/" + image_file)
            except:
                image_file = base_image_file.replace(".jpg", "_FULL.jpg")
                try:
                    full_image = PIL.Image.open(image_dir + "/" + image_file)
                except:
                    print("Error:", image_file)
                    continue

        # scale the full image to half size
        full_image = half_image(full_image)
        image_h, image_w = full_image.size
        
        # turn it into an array
        full_image_arr = np.array(full_image)
        
        # get rid of the extra dimensions with unneccessary info
        full_image_arr = full_image_arr[:,:,0]
        image_h, image_w = full_image_arr.shape
        
        # slice the ROI from the image - if the mask is bigger than the slice the center contains tuples
        # defining the corners of the mask
        if not too_big:
            full_image_slice = full_image_arr[center_row-150:center_row+149,center_col-150:center_col+149]
        else:
            full_image_slice = full_image_arr[center_row[0]:center_row[0]+299,center_col[0]:center_col[0]+299]
            full_image_slice_2 = full_image_arr[center_row[1]-299:center_row[1],center_col[1]-299:center_col[1]]
            
        # if the slice is the wrong shape the mask must be too close to the edges, move it so it fits
        if full_image_slice.shape != (299,299) and not too_big:            
            if (center_row - 150 < 0):
                center_row = 150
            elif center_row + 150 > image_h:
                center_row = image_h - 150
            
            if center_col - 150 < 0:
                center_col = 150
            elif center_col + 150 > image_w:
                center_col = image_w - 150
            
            if not too_big:
                full_image_slice = full_image_arr[center_row-150:center_row+149,center_col-150:center_col+149]
            elif output is not None:
                print("Slice is wrong size:", mask)
        
        # if we have multiple slices we need to reshape it differently
        if too_big and full_image_slice.shape != (299,299):
            # if the slice would go over the sides of the picture make it stop at the edge
            if center_col[0] + 299 > image_w:
                full_image_slice = full_image_arr[center_row[0]:center_row[0]+299,image_w-299:image_w]
            elif center_col[0] - 299 < 0:
                full_image_slice = full_image_arr[center_row[0]:center_row[0]+299,0:299]
        
        if too_big and full_image_slice_2.shape != (299,299):
            if center_col[1] + 299 > image_w:
                full_image_slice_2 = full_image_arr[center_row[1]-299:center_row[1],image_w-299:image_w]
            elif center_col[1] - 299 < 0:
                full_image_slice_2 = full_image_arr[center_row[1]-299:center_row[1],0:299]   
            
            #if center_row[1] + 299 > image_h:
            #    full_image_slice_2 = full_image_arr[image_h-299:image_h,center_col[1]-299:cen]
                
        # if the slice is still the wrong size just skip it
        if full_image_slice.shape == (299,299):
            slices_list.append(full_image_slice.reshape(299,299,1))
            image_names_list.append(base_image_file.replace("_FULL", ""))
        elif output is not None:
            print("Shape Error Slice 1:", mask)
            
        # if we cropped the mask add the extra image as well
        if too_big and full_image_slice_2.shape == (299,299):
            slices_list.append(full_image_slice_2.reshape(299,299,1))
            image_names_list.append(base_image_file.replace("_FULL", ""))
        elif too_big and output is not None:
            print("Shape Error Slice 2:", mask)
            print("Slice Shape:", full_image_slice_2.shape)
            print("Mask Center R:", center_row, "Mask Center C:", center_col)
            print("Full Image Shape:", full_image_arr.shape)
            #continue
        
    return np.array(slices_list), image_names_list

# %% [markdown]
# ## Mass Train

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Train ROI JPEGs", "Mass Train All Mask JPEGs Full", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Train JPEGs Full 2", "Mass Train All JPEGs Full", scan_type="FULL")
# Out:
# Error: Patient-Mass-Training_P_00779_LEFT_CC_1/Study_DDSM_MG[20160720]
# Error: Patient-Mass-Training_P_01849_RIGHT_MLO_1/Study_DDSM_MG[20160720]

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Train All Mask JPEGs Full"
image_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Train All JPEGs Full"

mass_train_slices, mass_train_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# Mask is too big cropping: P_00044_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00051_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00051_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00110_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00110_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00120_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00120_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00128_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00146_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00190_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00206_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00234_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00236_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00265_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00314_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00314_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00319_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00335_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00363_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00413_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00423_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00431_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00462_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00462_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00517_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00517_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00539_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00568_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00568_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00678_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00695_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00695_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00698_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00706_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00732_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00732_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00737_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00737_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00775_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00775_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00798_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00798_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00802_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00802_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00815_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00831_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00903_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00958_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00978_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00984_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00990_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00990_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00997_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01000_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01000_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01031_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01036_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01138_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01138_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01165_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01165_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01185_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01189_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01201_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01221_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01221_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01225_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01231_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01262_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01270_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01270_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01326_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01356_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01364_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01413_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01434_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01494_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01529_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01529_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01573_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01668_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01668_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01682_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01701_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01775_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01780_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01780_LEFT_MLO_MASK.jpg

# %%
print("Mass Train Slices shape:",mass_train_slices.shape)
print("Mass Train File Name List:", len(mass_train_image_names))
# Out:
# Mass Train Slices shape: (1316, 299, 299, 1)
# Mass Train File Name List: 1316

# %%
# process labels for slices
train_labels = pd.read_pickle(os.path.join("data", "train_labels.pkl"))
train_labels['IMAGE_NAME2'] = train_labels.index
train_labels = train_labels.drop_duplicates(['IMAGE_NAME2'])

mass_train_image_names = np.load(os.path.join("data", "mass_train_filenames.npy"))
mass_train_labels = []

for image in mass_train_image_names:
    label = train_labels.loc[image]['CLASS']
    mass_train_labels.append(label)
    
mass_train_labels = np.array(mass_train_labels)
print("Mass Train Labels:", len(mass_train_labels))
# Out:
# Mass Train Labels: 1316

# %%
np.save(os.path.join("data", "mass_train_slices.npy"), mass_train_slices)
np.save(os.path.join("data", "mass_train_filenames.npy"), mass_train_image_names)
np.save(os.path.join("data", "mass_train_labels.npy"), mass_train_labels)

# %%
# check image to make sure it matches the cropped image
plt.imshow(mass_train_slices[437].reshape(299,299))
plt.title(mass_train_image_names[437])

# %% [markdown]
# ## Calc Train

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Train ROI JPEGsl", "Calc Train All Mask JPEGs Full", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Train All JPEGs Full", "Calc Train All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Train All Mask JPEGs Full"
image_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Train All Full JPEGs"

calc_train_slices, calc_train_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# Mask is too big cropping: P_00005_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00005_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00007_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00007_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00012_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00012_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00013_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00019_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00019_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00030_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00030_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00030_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00030_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00043_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00084_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00084_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00085_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00085_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00098_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00098_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00101_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00101_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00151_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00161_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00197_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00197_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00201_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00208_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00220_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00220_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00243_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00243_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00255_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00255_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00266_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00266_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00268_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00268_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00270_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00270_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00271_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00271_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00280_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00280_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00302_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00302_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00311_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00316_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00316_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00322_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00322_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00355_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00355_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00357_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00360_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00360_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00377_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00385_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00385_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00385_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00385_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00393_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00438_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00438_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00443_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00445_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00452_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00452_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00452_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00452_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00473_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00473_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00474_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00474_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00480_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00480_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00480_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00480_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00484_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00484_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00486_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00486_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00508_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00508_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00510_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00510_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00510_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00534_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00534_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00546_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00551_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00551_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00573_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00573_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00574_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00574_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00582_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00584_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00591_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00591_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00601_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00601_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00606_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00609_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00624_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00624_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00627_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00638_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00638_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00647_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00655_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00658_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00658_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00664_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00664_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00673_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00680_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00680_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00680_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00680_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00683_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00683_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00685_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00693_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00693_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00710_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00712_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00712_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00734_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00734_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00767_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00767_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00767_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00767_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00784_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00784_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00793_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00793_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00809_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00809_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00812_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00812_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00814_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00814_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00814_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00814_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00832_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00832_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00856_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00864_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00864_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00883_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00883_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00924_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00925_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00925_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00937_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00937_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00954_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00954_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00967_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00967_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00973_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00981_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00981_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00992_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00992_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01002_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01002_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01059_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01059_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01065_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01065_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01087_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01099_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01099_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01099_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01102_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01102_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01108_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01108_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01116_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01116_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01122_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01127_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01127_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01135_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01136_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01136_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01143_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01156_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01156_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01159_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01160_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01160_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01160_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01172_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01180_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01180_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01188_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01188_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01196_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01198_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01198_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01205_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01205_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01250_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01250_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01252_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01252_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01286_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01286_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01291_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01291_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01306_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01306_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01306_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01307_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01313_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01313_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01346_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01346_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01358_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01358_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01359_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01359_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01361_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01361_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01365_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01365_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01370_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01370_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01397_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01397_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01409_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01409_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01420_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01455_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01455_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01459_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01459_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01467_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01467_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01488_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01497_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01497_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01497_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01505_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01505_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01524_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01524_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01526_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01526_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01537_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01545_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01545_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01569_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01571_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01582_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01582_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01582_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01582_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01596_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01596_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01616_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01616_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01625_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01625_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01659_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01659_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01683_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01688_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01724_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01729_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01729_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01736_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01736_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01748_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01750_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01750_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01783_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01786_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01786_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01809_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01839_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01839_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01846_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01846_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01856_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01864_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01864_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01864_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_01875_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01875_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01875_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01875_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02105_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02105_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02133_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02133_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02190_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02190_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02195_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02218_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02218_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02226_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02226_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02232_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02232_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02234_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02270_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02270_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02285_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02313_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02313_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02323_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02348_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02348_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02380_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02393_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02393_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02400_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02400_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02402_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02402_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02405_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02405_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02409_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02419_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02419_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02424_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02424_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02437_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02437_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02442_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02442_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02456_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02459_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02459_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02460_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02460_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02468_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02468_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02475_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02475_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02508_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_02508_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_02518_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02518_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02522_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02522_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02559_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02559_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_02566_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_02566_RIGHT_MLO_MASK.jpg

# %%
print("Calc Train Slices shape:",calc_train_slices.shape)
print("Calc Train File Name List:", len(calc_train_image_names))
# Out:
# Calc Train Slices shape: (1582, 299, 299, 1)
# Calc Train File Name List: 1582

# %%
calc_train_labels = []
train_labels = pd.read_pickle(os.path.join("data", "train_labels.pkl"))
train_labels['IMAGE_NAME2'] = train_labels.index
train_labels = train_labels.drop_duplicates(['IMAGE_NAME2'])

calc_train_image_names = np.load("data/calc_train_filenames.npy")

for image in calc_train_image_names:
    calc_train_labels.append(train_labels.loc[image]['CLASS'])
    
print("Calc Train Labels:", len(calc_train_labels))
# Out:
# Calc Train Labels: 1582

# %%
np.save(os.path.join("data", "calc_train_slices.npy"), calc_train_slices)
np.save(os.path.join("data", "calc_train_filenames.npy"), calc_train_image_names)
np.save(os.path.join("data", "calc_train_labels.npy"), np.array(calc_train_labels))

# %%
# check image to make sure it matches the cropped image
plt.imshow(calc_train_slices[1509].reshape(299,299))
plt.title(calc_train_image_names[1509])

# %% [markdown]
# ## Mass Test

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Test ROI JPEGs", "Mass Test All Mask JPEGs", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Test Full JPEGs", "Mass Test All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Test All Mask JPEGs"
image_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Test All Full JPEGs"

mass_test_slices, mass_test_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# Mask is too big cropping: P_00192_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00194_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00194_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00200_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00200_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00296_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00296_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00391_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_00482_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00482_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00639_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_00922_RIGHT_MLO_MASK.jpg
# Mask is too big cropping: P_00987_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_00987_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01204_RIGHT_CC_MASK.jpg
# Mask is too big cropping: P_01365_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01617_LEFT_CC_MASK.jpg
# Mask is too big cropping: P_01617_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01640_LEFT_MLO_MASK.jpg
# Mask is too big cropping: P_01661_LEFT_MLO_MASK.jpg

# %%
print("Mass Test Slices shape:", mass_test_slices.shape)
print("Mass Test File Name List:", len(mass_test_image_names))
# Out:
# Mass Test Slices shape: (381, 299, 299, 1)
# Mass Test File Name List: 381

# %%
# process labels for slices
mass_test_image_names = np.load("data/mass_test_filenames.npy")
test_labels = pd.read_pickle(os.path.join("data", "test_labels.pkl"))

test_labels['IMAGE_NAME2'] = test_labels.index
test_labels = test_labels.drop_duplicates(['IMAGE_NAME2'])
mass_test_labels = []

for image in mass_test_image_names:
    label = test_labels.loc[image]['CLASS']
    mass_test_labels.append(test_labels.loc[image]['CLASS'])
    
print("Mass Test Labels:", len(mass_test_labels))
# Out:
# Mass Test Labels: 381

# %%
#np.save(os.path.join("data", "mass_test_slices.npy"), mass_test_slices)
#np.save(os.path.join("data", "mass_test_filenames.npy"), mass_test_image_names)
np.save(os.path.join("data", "mass_test_labels.npy"), np.array(mass_test_labels))

# %%
# check image to make sure it matches the cropped image
plt.imshow(mass_test_slices[99].reshape(299,299))
plt.title(mass_test_image_names[99])

# %% [markdown]
# ## Calc Test

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Test ROI JPEGs", "Calc Test All Mask JPEGs", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Test Full JPEGs", "Calc Test All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Test All Mask JPEGs"
image_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Test All Full JPEGs"

calc_test_slices, calc_test_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# Mask is too big cropping: P_00038_RIGHT_CC000001.jpg
# Mask is too big cropping: P_00132_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00180_LEFT_CC000001.jpg
# Mask is too big cropping: P_00180_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00195_LEFT_CC000001.jpg
# Mask is too big cropping: P_00202_RIGHT_CC000001.jpg
# Mask is too big cropping: P_00202_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_00299_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00299_RIGHT_CC000001.jpg
# Mask is too big cropping: P_00299_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_00368_LEFT_CC000001.jpg
# Mask is too big cropping: P_00368_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00372_RIGHT_CC000001.jpg
# Mask is too big cropping: P_00372_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_00390_RIGHT_CC000001.jpg
# Mask is too big cropping: P_00390_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_00403_RIGHT_CC000001.jpg
# Mask is too big cropping: P_00403_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_00460_LEFT_CC000001.jpg
# Mask is too big cropping: P_00460_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00485_LEFT_CC000001.jpg
# Mask is too big cropping: P_00485_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00497_LEFT_CC000001.jpg
# Mask is too big cropping: P_00497_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00537_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_00646_LEFT_CC000001.jpg
# Mask is too big cropping: P_00649_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00663_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_00678_LEFT_CC000001.jpg
# Mask is too big cropping: P_00681_LEFT_CC000001.jpg
# Mask is too big cropping: P_00681_LEFT_MLO000001.jpg
# Mask is too big cropping: P_00811_LEFT_CC000001.jpg
# Mask is too big cropping: P_00857_RIGHT_CC000001.jpg
# Mask is too big cropping: P_00857_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_01004_LEFT_CC000001.jpg
# Mask is too big cropping: P_01004_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01154_LEFT_CC000001.jpg
# Mask is too big cropping: P_01154_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01320_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01353_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01425_LEFT_CC000001.jpg
# Mask is too big cropping: P_01425_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01460_LEFT_MLO000001_1.jpg
# Mask is too big cropping: P_01460_LEFT_MLO000001_2.jpg
# Mask is too big cropping: P_01460_RIGHT_CC000001.jpg
# Mask is too big cropping: P_01460_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_01476_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_01483_LEFT_CC000001.jpg
# Mask is too big cropping: P_01483_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01502_LEFT_CC000001.jpg
# Mask is too big cropping: P_01502_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01523_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01536_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_01621_LEFT_CC000001.jpg
# Mask is too big cropping: P_01621_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01711_RIGHT_CC000001.jpg
# Mask is too big cropping: P_01711_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_01713_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_01743_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_01803_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_01820_LEFT_MLO000001.jpg
# Mask is too big cropping: P_01883_RIGHT_CC000001.jpg
# Mask is too big cropping: P_01883_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_02102_LEFT_CC000001.jpg
# Mask is too big cropping: P_02102_LEFT_MLO000001.jpg
# Mask is too big cropping: P_02139_LEFT_MLO000001.jpg
# Mask is too big cropping: P_02176_RIGHT_CC000001.jpg
# Mask is too big cropping: P_02176_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_02198_LEFT_CC000001.jpg
# Mask is too big cropping: P_02198_LEFT_MLO000001.jpg
# Mask is too big cropping: P_02275_LEFT_CC000001.jpg
# Mask is too big cropping: P_02275_LEFT_MLO000001.jpg
# Mask is too big cropping: P_02418_RIGHT_CC000001.jpg
# Mask is too big cropping: P_02418_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_02420_RIGHT_CC000001.jpg
# Mask is too big cropping: P_02420_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_02432_LEFT_CC000001.jpg
# Mask is too big cropping: P_02432_LEFT_MLO000001.jpg
# Mask is too big cropping: P_02464_RIGHT_CC000001.jpg
# Mask is too big cropping: P_02464_RIGHT_MLO000001.jpg
# Mask is too big cropping: P_02501_RIGHT_MLO000001.jpg

# %%
print("Calc Test Slices shape:", calc_test_slices.shape)
print("Calc Test File Name List:", len(calc_test_image_names))
# Out:
# Calc Test Slices shape: (397, 299, 299, 1)
# Calc Test File Name List: 397

# %%
test_labels = pd.read_pickle(os.path.join("data", "test_labels.pkl"))
test_labels['IMAGE_NAME2'] = test_labels.index
test_labels = test_labels.drop_duplicates(['IMAGE_NAME2'])

calc_test_image_names = np.load("data/calc_test_filenames.npy")
calc_test_labels = []
for image in calc_test_image_names:
    label = test_labels.loc[image]['CLASS']
    calc_test_labels .append(test_labels.loc[image]['CLASS'])
    
print("Calc Test Labels:", len(calc_test_labels))
# Out:
# Calc Test Labels: 397

# %%
np.save(os.path.join("data", "calc_test_slices.npy"), calc_test_slices)
np.save(os.path.join("data", "calc_test_filenames.npy"), calc_test_image_names)
np.save(os.path.join("data", "calc_test_labels.npy"), np.array(calc_test_labels))

# %%
# check image to make sure it matches the cropped image
plt.imshow(calc_test_slices[59].reshape(299,299))
plt.title(calc_test_image_names[59])

# %% [markdown]
# ## Create File with All Slices

# %%
mass_train_labels = np.load(os.path.join("data", "mass_train_labels.npy"))
mass_test_labels = np.load(os.path.join("data", "mass_test_labels.npy"))
calc_train_labels = np.load(os.path.join("data", "calc_train_labels.npy"))
calc_test_labels = np.load(os.path.join("data", "calc_test_labels.npy"))
all_labels = np.concatenate([mass_train_labels, mass_test_labels, calc_train_labels, calc_test_labels], axis=0)

# %%
all_slices = np.concatenate([mass_train_slices, mass_test_slices, calc_train_slices, calc_test_slices], axis=0)

# %%
np.save(os.path.join("data", "all_slices.npy"), all_slices)
np.save(os.path.join("data", "all_labels.npy"), all_labels)
