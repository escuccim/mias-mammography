# %%
import PIL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import shutil
import re
from scipy.misc import imresize
from mammo_utils import create_mask, half_image
# %matplotlib inline

# %%
## rename the files to include the patient id so we can match the image up with the labels
## also copy the images to a single directory so we have them all in one place
def rename_and_copy_files(path, sourcedir="JPEG512", destdir="AllJPEGS512", scan_type="FULL"):
    directories = os.listdir(path+sourcedir)
    source_path = path + sourcedir + "/"
    destination_path = path + destdir + "/"
    
    # keep a counter so each file has a unique name
    i = 1
    
    # loop through the directories
    for directory in directories:
        # get the patient number and image type from the directory name
        patient_id = re.findall("_(P_[\d]+)_", directory)
        
        if len(patient_id) > 0:
            patient_id = str(patient_id[0])
        else:
            continue
        
        image_side = re.findall("_(LEFT|RIGHT)_", directory)
        
        if len(image_side) > 0:
            image_side = str(image_side[0])
        else:
            continue
        
        image_type = re.findall("(CC|MLO)", directory)
        if len(image_type) > 0:
            image_type = str(image_type[0])
        else:
            continue
        
        if not patient_id:
            continue
            
        # get the subdirectories
        subdir = os.listdir(source_path+directory)
        flag = False
        
        # get the next level of subdirectories
        if scan_type == 'FULL':
            subdir = subdir[0]
        elif (scan_type == "MASK") and (len(subdir) > 1):
            subdir = subdir[1]
        else:
            subdir = subdir[0]
            flag = True
            
        subsubdir = os.listdir(source_path+directory+'/'+subdir)
        if flag == False:
            files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[0])
            path = source_path+directory+'/'+subdir+'/'+subsubdir[0]
        else:
            try:
                if "mask" in str(subsubdir[0]):
                    files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[0])
                    path = source_path+directory+'/'+subdir+'/'+subsubdir[0]
                else:
                    files = os.listdir(source_path+directory+'/'+subdir+'/'+subsubdir[1])
                    path = source_path+directory+'/'+subdir+'/'+subsubdir[1]
            except:
                continue

        for file in files:
            # rename the file so we know where it came from, if image is not properly labeled skip it
            try:
                new_name = path+'/'+patient_id+'_'+image_side+'_'+image_type+'_'+scan_type+'.jpg'
                os.rename(path+'/'+file, new_name)
            except:
                print("Error:", new_name)
                continue
            
            # make sure the destination directory exists
            try:
                os.stat(destination_path)
            except:
                os.mkdir(destination_path)  
            
            # copy the files so they are all in one directory
            shutil.copy(new_name, destination_path)

        i += 1

## for the masks that are too big we are going to attempt to slice it into four slices, one for each corner.
## this function makes sure that the corners don't run off the image
def check_slice_corners(image_slice, full_image_arr, corners):
    h, w = image_slice.shape
    image_h, image_w = full_image_arr.shape
    
    # if the slice is the right shape return it
    if (h == 299) & (w == 299) and (np.mean(image_slice) > 25):
        return image_slice
    
    # else try to reframe it by checking each corner
    else:
        if corners[0] < 0:
            corners[0] = 0
            corners[1] = 299
        elif corners[1] > image_h:
            corners[1] = image_h
            corners[0] = image_h - 299
        
        if corners[2] < 0:
            corners[2] = 0
            corners[3] = 299
        elif corners[3] > image_w:
            corners[3] = image_w
            corners[2] = image_w - 299
            
        image_slice = full_image_arr[corners[0]:corners[1],corners[2]:corners[3]]
        
        # check that the slice contains useable info and doesn't just contain empty space
        if (np.mean(image_slice) > 25):
            return image_slice
    
    # else there is a problem, return an unusable array
    return np.array([0]).reshape((1,1))

## remove extraneous characters from end of file name and return it
def clean_name(name):
    patient_id = re.findall("(P_[\d]+)_", name)
    if len(patient_id) > 0:
        patient_id = patient_id[0]
    else:
        print("Name error")
        return name

    image_side = re.findall("_(LEFT|RIGHT)_", name)

    if len(image_side) > 0:
        image_side = image_side[0]
    else:
        print("Side error")
        return name

    image_type = re.findall("(CC|MLO)", name)
    if len(image_type) > 0:
        image_type = image_type[0]
    else:
        return name
    
    return patient_id + "_" + image_side + "_" + image_type

## function to create ROI slices from masks and full images
## inputs: mask_dir and image_dir - paths to directories containing respective images
##         slice_size - size of slices to create
##         output - if True will output each file processed, 
##                  if False will only output errors and warnings, 
##                  if None won't ouput anything
## returns: numpy array of images and list of corresponding file names
def create_roi_slices(mask_dir, image_dir, slice_size=299, output=True):
    # loop through mask directory
    mask_files = os.listdir(mask_dir)
    slices_list = []
    image_names_list = []

    for mask in mask_files:
        if output:
            print(mask)
        
        # get the base file name from the mask name
        base_image_file = clean_name(mask)
        image_file = base_image_file + "_FULL.jpg"
        
        # try to open the image, if it doesn't exist continue
        try:
            full_image = PIL.Image.open(image_dir + "/" + image_file)
        except:
            try:
                full_image = PIL.Image.open(image_dir + "/" + base_image_file + "000000.jpg")
            except:
                try:
                    full_image = PIL.Image.open(image_dir + "/" + base_image_file + "000001.jpg")
                except:
                    print("Error FileNotFound:", base_image_file)
                    continue       
        
        # scale the full image to half size
        full_image = half_image(full_image)
        image_h, image_w = full_image.size
        
        # turn it into an array
        full_image_arr = np.array(full_image)
        
        # get rid of the extra dimensions with unneccessary info
        full_image_arr = full_image_arr[:,:,0]
        image_h, image_w = full_image_arr.shape
        
        # get the mask, if the mask is bigger than the slice we will create multiple slices using the corners of the mask. 
        center_row, center_col, too_big, full_image_arr, mask_size = create_mask(mask_dir + "/" + mask, full_image_arr)
        
        # if there is a problem then skip this one
        if (center_row == 0) and (center_col == 0):
            print("Error, skipping", mask)
            continue
        
        # if the mask (with 20 pixel margin) will fit in one slice do that
        if not too_big:
            full_image_slice = full_image_arr[center_row-150:center_row+149,center_col-150:center_col+149]
            
        # otherwise if the mask is too big we are going to cut the ROI into multiple slices so each contains an edge
        else:
            if output is not None:
                print(mask, "Mask too big, reframing...")
                
            # get the height and width of the mask
            mask_height = center_row[1] - center_row[0]
            mask_width = center_col[1] - center_col[0]
            
            mask_too_high = mask_height > (slice_size + 10)
            mask_too_wide = mask_width > (slice_size + 10)
            
            # first let's size the abnormality down so it fits in one slice and use that as well
            mask_size = np.max([mask_height, mask_width])
            
            use_full_slice = False
            full_image_slice = full_image_arr[center_row[0] - 10:center_row[0] + mask_size,center_col[0] - 10:center_col[0] + mask_size]
            
            # if the slice isn't shaped right just ignore it, this isn't important enough to try to reshape it
            if full_image_slice.shape[0] == full_image_slice.shape[1]:
                try:
                    full_image_slice = imresize(full_image_slice, (slice_size,slice_size))
                    use_full_slice = True
                except:
                    use_full_slice = False
            
            # let's create the set of corners for each slice
            slice_1_corners = [center_row[0], center_row[0] + slice_size, center_col[0], center_col[0]+slice_size]
            slice_2_corners = [center_row[0], center_row[0] + slice_size, center_col[1] - slice_size, center_col[1]]
            slice_3_corners = [center_row[1] - slice_size, center_row[1], center_col[0], center_col[0] + slice_size]
            slice_4_corners = [center_row[1] - slice_size, center_row[1], center_col[1] - slice_size, center_col[1]]
            
            # now let's cut the ROI into up to four slices so that each contains an edge
            if mask_too_wide:
                full_image_slice_1 = full_image_arr[center_row[0]:center_row[0]+slice_size,center_col[0]:center_col[0]+slice_size]
                full_image_slice_2 = full_image_arr[center_row[0]:center_row[0]+slice_size,center_col[1]-slice_size:center_col[1]]
                
                # check the shape of the slices
                full_image_slice_1 = check_slice_corners(full_image_slice_1, full_image_arr, slice_1_corners)
                full_image_slice_2 = check_slice_corners(full_image_slice_2, full_image_arr, slice_2_corners)
            
            # if the mask is not too wide create slices that will fail the test and not be used
            else:
                full_image_slice_1 = np.array([0]).reshape(1,1)
                full_image_slice_2 = np.array([0]).reshape(1,1)
                
            if mask_too_high:
                full_image_slice_3 = full_image_arr[center_row[1]-slice_size:center_row[1],center_col[0]:center_col[0]+slice_size]
                full_image_slice_4 = full_image_arr[center_row[1]-slice_size:center_row[1],center_col[1]-slice_size:center_col[1]]            
                
                # check the shapes
                full_image_slice_3 = check_slice_corners(full_image_slice_3, full_image_arr, slice_3_corners)
                full_image_slice_4 = check_slice_corners(full_image_slice_4, full_image_arr, slice_4_corners)
            
            # if the mask is not too high create slices that will fail the test and not be used    
            else:
                full_image_slice_3 = np.array([0]).reshape(1,1)
                full_image_slice_4 = np.array([0]).reshape(1,1)
                
        # if the slice is the wrong shape the mask must be too close to the edges of the scan, move it so it fits
        margin = math.ceil(slice_size / 2)
        margin_2 = slice_size - margin
        if full_image_slice.shape != (slice_size,slice_size) and not too_big:
            if (center_row - margin < 0):
                center_row = margin
            elif center_row + margin > image_h:
                center_row = image_h - margin
            
            if center_col - margin < 0:
                center_col = margin
            elif center_col + margin > image_w:
                center_col = image_w - margin
            
            if not too_big:
                full_image_slice = full_image_arr[center_row-margin:center_row+margin_2,center_col-margin:center_col+margin_2]
            elif output is not None:
                print(mask, "Slice is wrong size:")
        
        # if the main slice is the right shape add it to the list
        if full_image_slice.shape == (slice_size,slice_size):
            # half the image
            full_image_slice = imresize(full_image_slice, (slice_size,slice_size))
            slices_list.append(full_image_slice.reshape(slice_size,slice_size,1))
            image_names_list.append(base_image_file + ".jpg")
       
        threshold_1 = 50
        threshold_2 = 100
        # if the slice is very small, let's create a larger zoomed versions of it as well
        if mask_size <= threshold_1:
            if output is not None:
                print("Zooming slice (1)", mask, "mask size is", mask_size)
            try:
                # leave 25 pixel margin on either side of ROI
                zoom_size = mask_size + 100
                
                # add some randomness to the images for more variety, instead of having them perfectly centered
                # flip a coin for the sign of the offset
                fuzz_sign_h = np.random.binomial(1,0.5)
                fuzz_sign_w = np.random.binomial(1,0.5)
                
                # offset by a random number that will keep the ROI in frame
                fuzz_factor_h = np.random.randint(low=0, high=45)
                if fuzz_sign_h == 0:
                    fuzz_factor_h = 0 - fuzz_factor_h
                    
                fuzz_factor_w = np.random.randint(low=0, high=45)
                if fuzz_sign_w == 0:
                    fuzz_factor_w = 0 - fuzz_factor_w
                
                top = center_row - (mask_size // 2) - 50 + fuzz_factor_h
                left = center_col - (mask_size // 2) - 50 + fuzz_factor_w
                
                # crop the slice down and then zoom in
                #full_image_slice_zoom = full_image_arr[center_row-margin_h_1:center_row+margin_h_2,center_col-margin_w_1:center_col+margin_w_2]
                full_image_slice_zoom = full_image_arr[top:top+zoom_size,left:left+zoom_size]
                full_image_slice_zoom = imresize(full_image_slice_zoom, (slice_size,slice_size))

                # make sure the size is correct and then add it to the list
                if full_image_slice_zoom.shape == (slice_size,slice_size):
                    slices_list.append(full_image_slice_zoom.reshape(slice_size,slice_size,1))
                    image_names_list.append(base_image_file + ".jpg")
                else:
                    if output is not None:
                        prrint(mask, "Zoomed to wrong shape!")
            except:
                pass    
            
        if mask_size <= threshold_2:
            if output is not None:
                print("Zooming slice (2)", mask, "mask size is", mask_size)
            try:
                zoom_size = mask_size + 50
                
                # add some randomness to the images for more variety, instead of having them perfectly centered
                # flip a coin for the sign of the offset
                fuzz_sign_h = np.random.binomial(1,0.5)
                fuzz_sign_w = np.random.binomial(1,0.5)
                
                # offset by a random number that will keep the ROI in frame
                fuzz_factor_h = np.random.randint(low=0, high=30)
                if fuzz_sign_h == 0:
                    fuzz_factor_h = 0 - fuzz_factor_h
                    
                fuzz_factor_w = np.random.randint(low=0, high=30)
                if fuzz_sign_w == 0:
                    fuzz_factor_w = 0 - fuzz_factor_w
                    
                top = center_row - (mask_size // 2) - 25 + fuzz_factor_h
                left = center_col - (mask_size // 2) - 25 + fuzz_factor_w
                
                # crop the slice down and then zoom in
                #full_image_slice_zoom = full_image_arr[center_row-margin_h_1:center_row+margin_h_2,center_col-margin_w_1:center_col+margin_w_2]
                full_image_slice_zoom = full_image_arr[top:top+zoom_size,left:left+zoom_size]
                full_image_slice_zoom = imresize(full_image_slice_zoom, (slice_size,slice_size))

                # make sure the size is correct and then add it to the list
                if full_image_slice_zoom.shape == (slice_size,slice_size):
                    slices_list.append(full_image_slice_zoom.reshape(slice_size,slice_size,1))
                    image_names_list.append(base_image_file + ".jpg")
                else:
                    print("Zoomed slice is wrong size", mask, "size", full_image_slice_zoom.shape)
            except:
                print("Error creating zoom...", mask)
            
        # if we have multiple slices check them
        if too_big:
            if full_image_slice_1.shape == (slice_size,slice_size):
                slices_list.append(full_image_slice_1.reshape(slice_size,slice_size,1))
                image_names_list.append(base_image_file + ".jpg")
            elif output is not None:
                print("Slice_1 wrong shape:", full_image_slice_1.shape, "- image", base_image_file)
                
            if full_image_slice_2.shape == (slice_size,slice_size):
                slices_list.append(full_image_slice_2.reshape(slice_size,slice_size,1))
                image_names_list.append(base_image_file + ".jpg")
            elif output is not None:
                print("Slice_2 wrong shape:", full_image_slice_2.shape, "- image", base_image_file)
                
            if full_image_slice_3.shape == (slice_size,slice_size):
                slices_list.append(full_image_slice_3.reshape(slice_size,slice_size,1))
                image_names_list.append(base_image_file + ".jpg")
            elif output is not None:
                print("Slice_3 wrong shape:", full_image_slice_3.shape, "- image", base_image_file)
                
            if full_image_slice_4.shape == (slice_size,slice_size):
                slices_list.append(full_image_slice_4.reshape(slice_size,slice_size,1))
                image_names_list.append(base_image_file + ".jpg")
            elif output is not None:
                print("Slice_4 wrong shape:", full_image_slice_4.shape, "- image", base_image_file)
        
    return np.array(slices_list), image_names_list

# %% [markdown]
# ## Mass Train

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Train ROI JPEGs", "Mass Train All Mask JPEGs Full", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Train JPEGs Full 2", "Mass Train All JPEGs Full", scan_type="FULL")
# Out:
# Error: Patient-Mass-Training_P_00779_LEFT_CC_1/Study_DDSM_MG[20160720]
# Error: Patient-Mass-Training_P_01849_RIGHT_MLO_1/Study_DDSM_MG[20160720]

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "E:\\Documents\\Mammography\\CBIS-DDSM\\Mass Train All Mask JPEGs Full"
image_dir = "E:\\Documents\\Mammography\\CBIS-DDSM\\Mass Train All JPEGs Full"

mass_train_slices, mass_train_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00004_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00004_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00004_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00009_RIGHT_CC_MASK.jpg mask size is 98
# Zooming slice (2) P_00021_RIGHT_CC_MASK.jpg mask size is 75
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00026_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00026_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00034_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00034_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00041_LEFT_CC_MASK.jpg mask size is 88
# Zooming slice (2) P_00041_LEFT_MLO_MASK.jpg mask size is 85
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00045_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00045_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00055_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00058_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00059_LEFT_CC000000.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00059_LEFT_CC000000.jpg
# Mask shape: (2302, 1526)
# Image shape: (2652, 1760)
# Error, skipping P_00059_LEFT_CC000000.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00059_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00059_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1468)
# Image shape: (2653, 1693)
# Error, skipping P_00059_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00065_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00065_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00068_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00074_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00074_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00074_RIGHT_CC_MASK.jpg mask size is 97
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00074_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00074_RIGHT_MLO_MASK.jpg mask size is 93
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00076_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00076_LEFT_CC_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00076_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00092_RIGHT_CC_MASK.jpg mask size is 56
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00096_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00106_LEFT_CC_MASK.jpg mask size is 75
# Zooming slice (2) P_00106_LEFT_MLO_MASK.jpg mask size is 97
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00106_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00106_RIGHT_CC_MASK.jpg mask size is 61
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00106_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00106_RIGHT_MLO_MASK.jpg mask size is 74
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00108_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00108_LEFT_CC_MASK.jpg
# Mask shape: (2302, 1435)
# Image shape: (2652, 1655)
# Error, skipping P_00108_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00108_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00108_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1455)
# Image shape: (2653, 1678)
# Error, skipping P_00108_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00110_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00110_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00117_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00119_LEFT_MLO_MASK.jpg mask size is 68
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00134_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00137_LEFT_MLO_MASK.jpg mask size is 74
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00149_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00166_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00166_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00190_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00207_LEFT_CC_MASK.jpg mask size is 90
# Zooming slice (2) P_00207_LEFT_MLO_MASK.jpg mask size is 95
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00218_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00218_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00218_LEFT_MLO_MASK.jpg mask size is 85
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00221_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00221_RIGHT_MLO_MASK.jpg mask size is 97
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00225_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00234_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00248_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00273_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00279_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00279_LEFT_CC_MASK.jpg
# Mask shape: (2303, 1566)
# Image shape: (2652, 1805)
# Error, skipping P_00279_LEFT_CC_MASK.jpg
# Error FileNotFound: P_00279_LEFT_MLO
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00281_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00283_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00289_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00289_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00303_LEFT_CC_MASK.jpg mask size is 86
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00304_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00304_LEFT_MLO_MASK.jpg
# Mask shape: (2230, 1435)
# Image shape: (2569, 1655)
# Error, skipping P_00304_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00309_LEFT_CC_MASK.jpg mask size is 94
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00317_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00319_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00319_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00330_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00330_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00332_LEFT_CC_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00335_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00342_RIGHT_CC_MASK.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00348_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00348_LEFT_CC_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00348_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00354_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00366_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00366_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00370_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00370_RIGHT_CC_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00370_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00383_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00384_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00384_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00389_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00396_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00396_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00401_LEFT_CC_MASK.jpg mask size is 86
# Zooming slice (2) P_00401_LEFT_MLO_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00406_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00406_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00414_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00414_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00415_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00415_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00420_RIGHT_CC_MASK.jpg mask size is 87
# Zooming slice (2) P_00421_LEFT_MLO_MASK.jpg mask size is 84
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00423_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00427_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00427_RIGHT_MLO_MASK.jpg mask size is 96
# Zooming slice (2) P_00428_LEFT_CC_MASK.jpg mask size is 93
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00435_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00436_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00436_LEFT_CC_MASK.jpg
# Mask shape: (2120, 1292)
# Image shape: (2442, 1490)
# Error, skipping P_00436_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00436_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00436_LEFT_MLO_MASK.jpg
# Mask shape: (2276, 1448)
# Image shape: (2622, 1670)
# Error, skipping P_00436_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00437_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00437_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00440_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00441_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00444_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00444_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00453_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00453_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00453_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1292)
# Image shape: (2652, 1490)
# Error, skipping P_00453_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00468_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00468_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00484_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00488_LEFT_CC_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00492_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00495_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00496_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00496_LEFT_CC_MASK.jpg mask size is 68
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00496_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00504_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00512_RIGHT_CC_MASK.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00526_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00528_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00532_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00535_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00543_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00549_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00549_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00550_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00554_LEFT_CC_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00559_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00564_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00566_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00566_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00572_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00572_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00577_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00592_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00592_LEFT_CC_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00592_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00605_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00607_RIGHT_CC_MASK.jpg mask size is 86
# Zooming slice (2) P_00617_RIGHT_MLO_MASK.jpg mask size is 67
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00622_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00626_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00626_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00630_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00630_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00637_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00644_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00644_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00648_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00648_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00651_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00653_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00653_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00659_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00661_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00661_LEFT_CC_MASK.jpg mask size is 91
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00661_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00661_LEFT_MLO_MASK.jpg mask size is 81
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00665_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00673_RIGHT_MLO_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00675_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00675_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00678_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00678_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00687_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00687_LEFT_CC_MASK.jpg
# Mask shape: (2262, 1076)
# Image shape: (2608, 1243)
# Error, skipping P_00687_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00687_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00687_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1194)
# Image shape: (2653, 1378)
# Error, skipping P_00687_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00692_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00694_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00694_RIGHT_MLO_MASK.jpg
# P_00695_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00695_RIGHT_MLO_MASK.jpg
# P_00695_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00703_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00703_LEFT_CC_MASK.jpg
# Mask shape: (2231, 1318)
# Image shape: (2569, 1520)
# Error, skipping P_00703_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00703_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00703_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1455)
# Image shape: (2653, 1678)
# Error, skipping P_00703_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00710_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00711_RIGHT_CC_MASK.jpg mask size is 92
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00715_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00715_RIGHT_CC_MASK.jpg mask size is 96
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00715_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00715_RIGHT_MLO_MASK.jpg mask size is 97
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00717_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00717_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00720_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00730_RIGHT_CC_MASK.jpg mask size is 67
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00733_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00733_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00739_LEFT_CC_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00754_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00754_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00764_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00764_RIGHT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00765_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00765_RIGHT_CC_MASK.jpg mask size is 79
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00765_RIGHT_MLO_MASK.jpg
# Mask shape: (2341, 1155)
# Image shape: (2693, 1328)
# Error, skipping P_00765_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00770_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00778_RIGHT_MLO_MASK.jpg mask size is 64
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00782_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00794_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00794_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00801_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00801_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00803_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00810_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00810_RIGHT_MLO_MASK.jpg mask size is 82
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00816_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00816_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00823_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00823_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00823_RIGHT_MLO_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00826_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00826_LEFT_CC_MASK.jpg
# Mask shape: (2270, 1507)
# Image shape: (2615, 1738)
# Error, skipping P_00826_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00826_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00826_LEFT_MLO_MASK.jpg
# Mask shape: (2282, 1585)
# Image shape: (2630, 1828)
# Error, skipping P_00826_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00829_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00829_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00831_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00845_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00845_RIGHT_CC_MASK.jpg mask size is 83
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00851_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00851_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00853_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00859_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00859_LEFT_CC_MASK.jpg
# Mask shape: (2276, 1265)
# Image shape: (2622, 1460)
# Error, skipping P_00859_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00859_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00859_LEFT_MLO_MASK.jpg
# Mask shape: (2302, 1363)
# Image shape: (2653, 1573)
# Error, skipping P_00859_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00865_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00871_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00881_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00881_LEFT_CC_MASK.jpg mask size is 73
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00881_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00881_LEFT_MLO_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00894_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00896_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00898_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00901_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00903_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00913_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00913_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00915_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00915_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00920_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00927_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00927_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00927_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1618)
# Image shape: (2652, 1865)
# Error, skipping P_00927_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00935_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00939_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00939_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00939_RIGHT_MLO_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00941_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00949_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00949_LEFT_CC_MASK.jpg
# Mask shape: (2164, 965)
# Image shape: (2494, 1115)
# Error, skipping P_00949_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00949_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00949_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1057)
# Image shape: (2651, 1220)
# Error, skipping P_00949_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00970_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00970_LEFT_MLO_MASK.jpg mask size is 89
# Zooming slice (2) P_00972_LEFT_CC_MASK.jpg mask size is 73
# Zooming slice (2) P_00972_LEFT_MLO_MASK.jpg mask size is 95
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00976_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00976_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00988_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00988_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00990_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00990_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00995_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00995_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_00996_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01031_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01034_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01034_RIGHT_MLO_MASK.jpg mask size is 86
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01036_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01047_LEFT_MLO_MASK.jpg mask size is 62
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01048_RIGHT_CC_MASK.jpg
# Mask shape: (2302, 1116)
# Image shape: (2648, 1283)
# Error, skipping P_01048_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01048_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01054_RIGHT_MLO_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01070_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01070_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01077_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01086_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01104_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01109_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01115_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01115_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01118_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01118_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01120_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01120_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01131_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01131_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01146_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01153_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01158_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01165_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01165_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01165_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01171_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01171_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01182_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01182_LEFT_CC_MASK.jpg
# Mask shape: (2303, 1331)
# Image shape: (2652, 1535)
# Error, skipping P_01182_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01182_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01182_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1370)
# Image shape: (2652, 1580)
# Error, skipping P_01182_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01185_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01194_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01212_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01212_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01215_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01215_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01226_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01226_LEFT_MLO_MASK.jpg mask size is 90
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01230_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01233_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01233_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01237_RIGHT_MLO_MASK.jpg mask size is 69
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01239_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01243_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01243_LEFT_CC_MASK.jpg
# Mask shape: (2302, 1402)
# Image shape: (2653, 1618)
# Error, skipping P_01243_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01243_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01243_LEFT_MLO_MASK.jpg
# Mask shape: (2302, 1585)
# Image shape: (2653, 1828)
# Error, skipping P_01243_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01258_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01262_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01264_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01267_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01267_RIGHT_MLO_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01271_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01271_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01273_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01274_RIGHT_MLO_MASK.jpg mask size is 81
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01279_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01280_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01281_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01283_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01299_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01301_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01301_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01305_LEFT_CC_MASK.jpg mask size is 95
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01327_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01332_RIGHT_CC_MASK.jpg mask size is 83
# Zooming slice (2) P_01332_RIGHT_MLO_MASK.jpg mask size is 93
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01340_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01343_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01354_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01355_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01360_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01362_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01363_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01363_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01367_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01371_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01371_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01379_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01379_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01388_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01402_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01406_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01413_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01413_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01417_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01418_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01423_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01423_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01427_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01431_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01431_LEFT_MLO_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01433_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01433_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01439_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01439_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01441_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01442_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01442_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01447_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01452_RIGHT_CC_MASK.jpg mask size is 83
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01475_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01475_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01484_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01485_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01485_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01486_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01486_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01493_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01495_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01501_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01501_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01503_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01503_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01504_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01504_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01506_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01508_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01509_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01509_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01517_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01529_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01532_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01532_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01553_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01557_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01557_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01557_RIGHT_MLO_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01559_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01560_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01560_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01565_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01565_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01572_RIGHT_MLO_MASK.jpg mask size is 94
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01581_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01581_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01581_LEFT_MLO_MASK.jpg mask size is 98
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01583_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01583_RIGHT_MLO_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01596_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01608_RIGHT_MLO_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01611_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01611_RIGHT_CC_MASK.jpg mask size is 90
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01611_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01611_RIGHT_MLO_MASK.jpg mask size is 94
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01612_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01612_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01619_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01619_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01630_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01632_LEFT_CC_MASK.jpg mask size is 89
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01632_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01633_RIGHT_MLO_MASK.jpg mask size is 89
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01635_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01637_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01638_RIGHT_CC_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01641_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01641_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01642_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01644_LEFT_CC_MASK.jpg mask size is 86
# Zooming slice (2) P_01644_LEFT_MLO_MASK.jpg mask size is 91
# Zooming slice (2) P_01652_RIGHT_MLO_MASK.jpg mask size is 97
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01669_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01680_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01686_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01686_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01687_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01687_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01689_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01694_RIGHT_MLO_MASK.jpg mask size is 85
# Zooming slice (2) P_01698_RIGHT_CC_MASK.jpg mask size is 94
# Zooming slice (2) P_01698_RIGHT_MLO_MASK.jpg mask size is 98
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01702_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01702_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01710_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01710_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01712_RIGHT_CC_MASK.jpg mask size is 94
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01714_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01714_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01717_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01733_RIGHT_MLO_MASK.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01735_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01739_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01739_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01744_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01744_LEFT_MLO_MASK.jpg mask size is 91
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01745_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01749_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01749_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01754_RIGHT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01757_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01757_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01785_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01785_RIGHT_CC_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01785_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01799_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01799_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01801_RIGHT_CC_MASK.jpg mask size is 87
# Zooming slice (2) P_01801_RIGHT_MLO_MASK.jpg mask size is 97
# Zooming slice (2) P_01802_LEFT_MLO_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01805_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01805_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01816_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01816_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01824_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01826_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01826_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01829_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01831_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01831_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01840_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01849_RIGHT_CC_MASK.jpg mask size is 98
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01850_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01850_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01853_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01860_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01876_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01876_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01877_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01877_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01886_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01887_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01887_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01908_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01908_LEFT_CC_MASK.jpg
# Mask shape: (2146, 1194)
# Image shape: (2473, 1378)
# Error, skipping P_01908_LEFT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01946_RIGHT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01981_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01981_RIGHT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_01983_LEFT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02033_RIGHT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02033_RIGHT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02079_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02079_RIGHT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02079_RIGHT_MLO_MASK.jpg
# Mask shape: (2230, 1461)
# Image shape: (2569, 1685)
# Error, skipping P_02079_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02092_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02092_LEFT_CC_MASK.jpg
# Mask shape: (2237, 1252)
# Image shape: (2577, 1445)
# Error, skipping P_02092_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02092_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Train All Mask JPEGs Full/P_02092_LEFT_MLO_MASK.jpg
# Mask shape: (2283, 1481)
# Image shape: (2630, 1708)
# Error, skipping P_02092_LEFT_MLO_MASK.jpg

# %%
print("Mass Train Slices shape:",mass_train_slices.shape)
print("Mass Train File Name List:", len(mass_train_image_names))
# Out:
# Mass Train Slices shape: (1278, 299, 299, 1)
# Mass Train File Name List: 1278

# %%
# check image to make sure it matches the cropped image
plt.imshow(mass_train_slices[437].reshape(299,299))
plt.title(mass_train_image_names[437])

# %%
# look at some other images that have been transformed to make sure everything looks good
names_to_check = ["P_00559_LEFT_MLO.jpg", "P_00009_RIGHT_CC.jpg", "P_00059_LEFT_CC.jpg", "P_00496_LEFT_CC.jpg", "P_00778_RIGHT_MLO.jpg", "P_00903_LEFT_MLO.jpg", "P_01185_RIGHT_MLO.jpg"]
for name in names_to_check:
    for i in range(len(mass_train_image_names)):
        if mass_train_image_names[i] == name:
            plt.imshow(mass_train_slices[i].reshape(299,299))
            plt.title(name + " - idx: " + str(i))
            plt.show()

# %%
# process labels for slices
train_labels = pd.read_pickle(os.path.join("data", "train_labels.pkl"))
train_labels['IMAGE_NAME2'] = train_labels.index
train_labels = train_labels.drop_duplicates(['IMAGE_NAME2'])

#mass_train_image_names = np.load(os.path.join("data", "mass_train_filenames.npy"))
mass_train_labels = []

for image in mass_train_image_names:
    label = train_labels.loc[image]['CLASS']
    mass_train_labels.append(label)
    
mass_train_labels = np.array(mass_train_labels)
print("Mass Train Labels:", len(mass_train_labels))
# Out:
# Mass Train Labels: 1278

# %%
np.save(os.path.join("data", "mass_train_slices.npy"), mass_train_slices)
np.save(os.path.join("data", "mass_train_filenames.npy"), mass_train_image_names)
np.save(os.path.join("data", "mass_train_labels.npy"), mass_train_labels)

# %% [markdown]
# ## Calc Train

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Train ROI JPEGsl", "Calc Train All Mask JPEGs Full", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Train All JPEGs Full", "Calc Train All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "E:\\Documents\\Mammography\\CBIS-DDSM\\Calc Train All Mask JPEGs Full"
image_dir = "E:\\Documents\\Mammography\\CBIS-DDSM\\Calc Train All Full JPEGs"

calc_train_slices, calc_train_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00007_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00007_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00008_LEFT_CC_MASK.jpg mask size is 51
# Zooming slice (2) P_00008_LEFT_MLO_MASK.jpg mask size is 52
# Zooming slice (2) P_00008_RIGHT_CC_MASK.jpg mask size is 60
# Zooming slice (1) P_00010_LEFT_CC_MASK.jpg mask size is 44
# Zooming slice (2) P_00010_LEFT_CC_MASK.jpg mask size is 44
# Zooming slice (1) P_00010_LEFT_MLO_MASK.jpg mask size is 47
# Zooming slice (2) P_00010_LEFT_MLO_MASK.jpg mask size is 47
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00011_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00011_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00013_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00014_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00016_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00019_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00019_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00022_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00024_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00024_LEFT_CC_MASK.jpg mask size is 91
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00024_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00024_LEFT_MLO_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00028_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00028_LEFT_MLO_MASK.jpg mask size is 59
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00029_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00030_RIGHT_MLO_MASK.jpg
# P_00030_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00031_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00031_LEFT_CC_MASK.jpg mask size is 75
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00034_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00034_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00043_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00047_LEFT_CC_MASK.jpg mask size is 52
# Zooming slice (2) P_00047_LEFT_MLO_MASK.jpg mask size is 52
# Zooming slice (2) P_00048_RIGHT_CC_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00049_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00049_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00063_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00078_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00083_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00084_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00084_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00088_LEFT_CC_MASK.jpg mask size is 72
# Zooming slice (2) P_00088_LEFT_MLO_MASK.jpg mask size is 76
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00098_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00105_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00105_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00106_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00106_RIGHT_CC_MASK.jpg mask size is 51
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00106_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00106_RIGHT_MLO_MASK.jpg mask size is 64
# Zooming slice (2) P_00112_LEFT_CC_MASK.jpg mask size is 72
# Zooming slice (2) P_00112_LEFT_MLO_MASK.jpg mask size is 88
# Zooming slice (2) P_00112_RIGHT_CC_MASK.jpg mask size is 100
# Zooming slice (2) P_00112_RIGHT_MLO_MASK.jpg mask size is 56
# Zooming slice (2) P_00121_LEFT_MLO_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00151_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00157_LEFT_CC_MASK.jpg mask size is 100
# Zooming slice (2) P_00157_LEFT_MLO_MASK.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00159_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00161_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00162_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00162_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00179_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00179_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00181_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00181_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00182_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00185_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00185_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00189_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00189_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00196_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00196_RIGHT_CC_MASK.jpg mask size is 51
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00196_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00196_RIGHT_MLO_MASK.jpg mask size is 51
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00197_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00197_RIGHT_MLO_MASK.jpg
# P_00201_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00220_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00220_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00232_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00232_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00243_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00243_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00245_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00250_LEFT_MLO_MASK.jpg
# Zooming slice (1) P_00250_LEFT_MLO_MASK.jpg mask size is 47
# Zooming slice (2) P_00250_LEFT_MLO_MASK.jpg mask size is 47
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00251_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00251_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00255_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00255_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00256_LEFT_CC_MASK.jpg mask size is 76
# Zooming slice (2) P_00256_LEFT_MLO_MASK.jpg mask size is 96
# P_00266_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_00266_LEFT_CC
# P_00266_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_00266_LEFT_MLO
# Slice_3 wrong shape: (1, 1) - image P_00266_LEFT_MLO
# Slice_4 wrong shape: (1, 1) - image P_00266_LEFT_MLO
# P_00268_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00268_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00269_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00269_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00270_LEFT_MLO_MASK.jpg
# P_00271_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00271_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00274_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00274_RIGHT_MLO_MASK.jpg mask size is 71
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00276_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00276_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00282_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00288_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00293_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00293_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00297_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00297_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00302_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00311_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00312_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00312_RIGHT_MLO_MASK.jpg mask size is 91
# P_00316_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00318_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00326_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00336_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00336_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00336_LEFT_MLO_MASK.jpg mask size is 99
# Zooming slice (1) P_00337_LEFT_CC_MASK.jpg mask size is 47
# Zooming slice (2) P_00337_LEFT_CC_MASK.jpg mask size is 47
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00337_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00337_LEFT_MLO_MASK.jpg mask size is 71
# Zooming slice (2) P_00346_RIGHT_CC_MASK.jpg mask size is 88
# Zooming slice (2) P_00346_RIGHT_MLO_MASK.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00355_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00357_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00360_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00360_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00364_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00378_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00378_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00378_LEFT_MLO_MASK.jpg mask size is 84
# P_00385_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00385_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00385_RIGHT_CC
# Slice_4 wrong shape: (1, 1) - image P_00385_RIGHT_CC
# P_00385_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00392_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00392_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00398_LEFT_CC_MASK.jpg mask size is 60
# Zooming slice (2) P_00398_LEFT_MLO_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00400_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00400_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00404_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00410_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00418_RIGHT_CC_MASK.jpg mask size is 96
# Zooming slice (2) P_00418_RIGHT_MLO_MASK.jpg mask size is 72
# Zooming slice (2) P_00422_LEFT_CC_MASK.jpg mask size is 100
# Zooming slice (2) P_00422_LEFT_MLO_MASK.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00425_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00425_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00432_RIGHT_MLO_MASK.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00443_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00445_LEFT_MLO_MASK.jpg
# P_00445_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00448_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00448_LEFT_MLO_MASK.jpg
# P_00452_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00452_RIGHT_MLO_MASK.jpg
# P_00452_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Zooming slice (1) P_00455_LEFT_CC_MASK.jpg mask size is 40
# Zooming slice (2) P_00455_LEFT_CC_MASK.jpg mask size is 40
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00455_LEFT_MLO_MASK.jpg
# Zooming slice (1) P_00455_LEFT_MLO_MASK.jpg mask size is 43
# Zooming slice (2) P_00455_LEFT_MLO_MASK.jpg mask size is 43
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00458_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00458_LEFT_CC_MASK.jpg mask size is 91
# Zooming slice (2) P_00467_LEFT_CC_MASK.jpg mask size is 92
# Zooming slice (2) P_00467_LEFT_MLO_MASK.jpg mask size is 100
# Zooming slice (2) P_00467_RIGHT_CC_MASK.jpg mask size is 88
# Zooming slice (2) P_00467_RIGHT_MLO_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00469_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00469_LEFT_CC_MASK.jpg mask size is 82
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00469_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00469_LEFT_MLO_MASK.jpg mask size is 79
# Zooming slice (2) P_00471_LEFT_CC_MASK.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00471_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00471_LEFT_MLO_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00473_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00474_LEFT_CC_MASK.jpg
# P_00474_LEFT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00474_LEFT_MLO_MASK.jpg
# Zooming slice (1) P_00476_LEFT_CC_MASK.jpg mask size is 31
# Zooming slice (2) P_00476_LEFT_CC_MASK.jpg mask size is 31
# Zooming slice (1) P_00476_LEFT_MLO_MASK.jpg mask size is 48
# Zooming slice (2) P_00476_LEFT_MLO_MASK.jpg mask size is 48
# Zooming slice (1) P_00476_RIGHT_CC_MASK.jpg mask size is 23
# Zooming slice (2) P_00476_RIGHT_CC_MASK.jpg mask size is 23
# Zooming slice (1) P_00476_RIGHT_MLO_MASK.jpg mask size is 28
# Zooming slice (2) P_00476_RIGHT_MLO_MASK.jpg mask size is 28
# P_00480_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00480_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00480_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00480_RIGHT_CC
# P_00480_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00480_RIGHT_MLO
# Slice_4 wrong shape: (1, 1) - image P_00480_RIGHT_MLO
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00484_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00484_LEFT_MLO_MASK.jpg
# P_00486_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00486_RIGHT_CC
# P_00486_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00491_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00502_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00502_LEFT_MLO_MASK.jpg mask size is 87
# Zooming slice (1) P_00505_LEFT_CC_MASK.jpg mask size is 36
# Zooming slice (2) P_00505_LEFT_CC_MASK.jpg mask size is 36
# Zooming slice (2) P_00505_LEFT_MLO_MASK.jpg mask size is 56
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00505_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00505_RIGHT_CC_MASK.jpg mask size is 72
# Zooming slice (1) P_00505_RIGHT_MLO_MASK.jpg mask size is 46
# Zooming slice (2) P_00505_RIGHT_MLO_MASK.jpg mask size is 46
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00506_RIGHT_CC_MASK.jpg
# Zooming slice (1) P_00506_RIGHT_CC_MASK.jpg mask size is 32
# Zooming slice (2) P_00506_RIGHT_CC_MASK.jpg mask size is 32
# Zooming slice (1) P_00506_RIGHT_MLO_MASK.jpg mask size is 47
# Zooming slice (2) P_00506_RIGHT_MLO_MASK.jpg mask size is 47
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00508_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00508_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00510_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00510_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00519_LEFT_CC_MASK.jpg mask size is 96
# Zooming slice (1) P_00529_LEFT_MLO_MASK.jpg mask size is 35
# Zooming slice (2) P_00529_LEFT_MLO_MASK.jpg mask size is 35
# Zooming slice (1) P_00529_RIGHT_CC_MASK.jpg mask size is 28
# Zooming slice (2) P_00529_RIGHT_CC_MASK.jpg mask size is 28
# Zooming slice (1) P_00529_RIGHT_MLO_MASK.jpg mask size is 38
# Zooming slice (2) P_00529_RIGHT_MLO_MASK.jpg mask size is 38
# Zooming slice (2) P_00530_LEFT_CC_MASK.jpg mask size is 69
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00530_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00530_LEFT_MLO_MASK.jpg mask size is 62
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00531_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00531_RIGHT_CC_MASK.jpg mask size is 59
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00531_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00531_RIGHT_MLO_MASK.jpg mask size is 68
# Zooming slice (1) P_00538_RIGHT_CC_MASK.jpg mask size is 44
# Zooming slice (2) P_00538_RIGHT_CC_MASK.jpg mask size is 44
# Zooming slice (2) P_00538_RIGHT_MLO_MASK.jpg mask size is 63
# Zooming slice (1) P_00539_RIGHT_CC_MASK.jpg mask size is 43
# Zooming slice (2) P_00539_RIGHT_CC_MASK.jpg mask size is 43
# Zooming slice (1) P_00539_RIGHT_MLO_MASK.jpg mask size is 24
# Zooming slice (2) P_00539_RIGHT_MLO_MASK.jpg mask size is 24
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00551_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00551_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00552_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00555_RIGHT_CC_MASK.jpg mask size is 56
# Zooming slice (1) P_00555_RIGHT_MLO_MASK.jpg mask size is 39
# Zooming slice (2) P_00555_RIGHT_MLO_MASK.jpg mask size is 39
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00556_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00556_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00557_LEFT_MLO_MASK.jpg mask size is 88
# Zooming slice (2) P_00559_RIGHT_CC_MASK.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00559_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00559_RIGHT_MLO_MASK.jpg mask size is 92
# P_00573_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00573_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00574_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00574_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00578_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00578_LEFT_CC_MASK.jpg mask size is 71
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00578_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00578_LEFT_MLO_MASK.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00583_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00583_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00585_LEFT_CC_MASK.jpg mask size is 76
# P_00591_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00591_RIGHT_CC
# P_00591_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00591_RIGHT_MLO
# Zooming slice (2) P_00593_RIGHT_CC_MASK.jpg mask size is 76
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00606_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00606_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00609_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00609_RIGHT_MLO_MASK.jpg
# Zooming slice (1) P_00613_RIGHT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_00613_RIGHT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_00613_RIGHT_MLO_MASK.jpg mask size is 51
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00624_LEFT_CC_MASK.jpg
# P_00624_LEFT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00624_LEFT_MLO_MASK.jpg
# P_00624_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00625_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00627_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00635_LEFT_CC_MASK.jpg mask size is 56
# Zooming slice (2) P_00635_LEFT_MLO_MASK.jpg mask size is 80
# Zooming slice (2) P_00635_RIGHT_CC_MASK.jpg mask size is 76
# Zooming slice (2) P_00635_RIGHT_MLO_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00638_LEFT_CC_MASK.jpg
# P_00638_LEFT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00638_LEFT_MLO_MASK.jpg
# P_00638_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00642_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00645_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00647_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00647_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00658_LEFT_CC_MASK.jpg
# P_00658_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00658_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00658_LEFT_MLO
# Zooming slice (2) P_00673_RIGHT_MLO_MASK.jpg mask size is 88
# Zooming slice (2) P_00674_RIGHT_MLO_MASK.jpg mask size is 91
# P_00680_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_00680_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00680_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00680_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Zooming slice (2) P_00682_RIGHT_CC_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00683_RIGHT_CC_MASK.jpg
# P_00683_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00683_RIGHT_MLO_MASK.jpg
# P_00693_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_00693_LEFT_CC
# P_00693_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00693_LEFT_MLO
# Zooming slice (2) P_00704_LEFT_CC_MASK.jpg mask size is 64
# Zooming slice (2) P_00704_LEFT_MLO_MASK.jpg mask size is 79
# Zooming slice (1) P_00705_LEFT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_00705_LEFT_CC_MASK.jpg mask size is 48
# Zooming slice (1) P_00705_LEFT_MLO_MASK.jpg mask size is 48
# Zooming slice (2) P_00705_LEFT_MLO_MASK.jpg mask size is 48
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00709_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00709_RIGHT_MLO_MASK.jpg
# P_00712_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00712_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00713_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00725_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00725_LEFT_CC_MASK.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00725_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00725_LEFT_MLO_MASK.jpg mask size is 59
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00735_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00735_LEFT_CC_MASK.jpg mask size is 79
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00735_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00735_LEFT_MLO_MASK.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00736_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00736_LEFT_MLO_MASK.jpg
# Zooming slice (1) P_00744_RIGHT_CC_MASK.jpg mask size is 32
# Zooming slice (2) P_00744_RIGHT_CC_MASK.jpg mask size is 32
# Zooming slice (1) P_00744_RIGHT_MLO_MASK.jpg mask size is 39
# Zooming slice (2) P_00744_RIGHT_MLO_MASK.jpg mask size is 39
# Zooming slice (1) P_00750_LEFT_CC_MASK.jpg mask size is 24
# Zooming slice (2) P_00750_LEFT_CC_MASK.jpg mask size is 24
# Zooming slice (1) P_00750_LEFT_MLO_MASK.jpg mask size is 23
# Zooming slice (2) P_00750_LEFT_MLO_MASK.jpg mask size is 23
# Zooming slice (1) P_00750_RIGHT_CC_MASK.jpg mask size is 28
# Zooming slice (2) P_00750_RIGHT_CC_MASK.jpg mask size is 28
# Zooming slice (1) P_00750_RIGHT_MLO_MASK.jpg mask size is 36
# Zooming slice (2) P_00750_RIGHT_MLO_MASK.jpg mask size is 36
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00751_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00757_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00759_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00759_LEFT_CC_MASK.jpg mask size is 78
# Zooming slice (2) P_00759_LEFT_MLO_MASK.jpg mask size is 87
# P_00767_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00767_LEFT_CC
# Slice_4 wrong shape: (1, 1) - image P_00767_LEFT_CC
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00767_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00767_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00772_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00778_LEFT_MLO_MASK.jpg mask size is 96
# Zooming slice (2) P_00780_RIGHT_CC_MASK.jpg mask size is 56
# Zooming slice (2) P_00780_RIGHT_MLO_MASK.jpg mask size is 72
# P_00784_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_00784_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Zooming slice (2) P_00787_LEFT_MLO_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00806_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00806_LEFT_CC_MASK.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00806_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00808_LEFT_MLO_MASK.jpg
# P_00812_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_00812_LEFT_CC
# Slice_4 wrong shape: (1, 1) - image P_00812_LEFT_CC
# P_00812_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_00812_LEFT_MLO
# P_00814_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_00814_LEFT_CC
# P_00814_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_00814_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00814_RIGHT_CC
# Slice_3 wrong shape: (1, 1) - image P_00814_RIGHT_CC
# P_00814_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00825_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00832_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00832_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00834_LEFT_MLO_MASK.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00835_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00835_LEFT_CC_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00835_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00835_LEFT_MLO_MASK.jpg mask size is 87
# Zooming slice (1) P_00840_RIGHT_CC_MASK.jpg mask size is 32
# Zooming slice (2) P_00840_RIGHT_CC_MASK.jpg mask size is 32
# Zooming slice (1) P_00840_RIGHT_MLO_MASK.jpg mask size is 28
# Zooming slice (2) P_00840_RIGHT_MLO_MASK.jpg mask size is 28
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00846_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00846_LEFT_CC_MASK.jpg mask size is 94
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00846_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00846_LEFT_MLO_MASK.jpg mask size is 87
# Zooming slice (2) P_00847_LEFT_CC_MASK.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00854_RIGHT_CC_MASK.jpg
# Zooming slice (1) P_00854_RIGHT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_00854_RIGHT_CC_MASK.jpg mask size is 48
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00854_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00854_RIGHT_MLO_MASK.jpg mask size is 63
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00855_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00862_LEFT_CC_MASK.jpg mask size is 57
# Zooming slice (2) P_00862_LEFT_MLO_MASK.jpg mask size is 71
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00864_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00864_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00866_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00866_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00868_RIGHT_CC_MASK.jpg mask size is 83
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00868_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00868_RIGHT_MLO_MASK.jpg mask size is 55
# Zooming slice (2) P_00877_LEFT_CC_MASK.jpg mask size is 92
# Zooming slice (2) P_00878_LEFT_CC_MASK.jpg mask size is 80
# Zooming slice (2) P_00878_LEFT_MLO_MASK.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00880_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00880_RIGHT_CC_MASK.jpg mask size is 75
# P_00883_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00883_RIGHT_CC
# P_00883_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_00883_RIGHT_MLO
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00890_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00890_RIGHT_MLO_MASK.jpg mask size is 79
# Zooming slice (1) P_00895_RIGHT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_00895_RIGHT_CC_MASK.jpg mask size is 48
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00895_RIGHT_MLO_MASK.jpg
# Zooming slice (1) P_00895_RIGHT_MLO_MASK.jpg mask size is 40
# Zooming slice (2) P_00895_RIGHT_MLO_MASK.jpg mask size is 40
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00897_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00897_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00899_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00899_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00909_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00909_LEFT_MLO_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00912_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00912_LEFT_CC_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00912_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00912_LEFT_MLO_MASK.jpg mask size is 95
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00916_RIGHT_MLO_MASK.jpg
# Zooming slice (1) P_00916_RIGHT_MLO_MASK.jpg mask size is 48
# Zooming slice (2) P_00916_RIGHT_MLO_MASK.jpg mask size is 48
# Zooming slice (1) P_00924_LEFT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_00924_LEFT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_00924_LEFT_MLO_MASK.jpg mask size is 51
# Zooming slice (2) P_00924_RIGHT_MLO_MASK.jpg mask size is 78
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00926_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00930_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00933_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00945_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00945_RIGHT_CC_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00945_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00954_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00954_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00955_RIGHT_MLO_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00956_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00956_LEFT_MLO_MASK.jpg mask size is 75
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00960_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00960_LEFT_CC_MASK.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00960_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00960_LEFT_MLO_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00965_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00965_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00967_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00971_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00973_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00973_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00977_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00978_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00978_LEFT_MLO_MASK.jpg mask size is 96
# P_00981_LEFT_CC_MASK.jpg Mask too big, reframing...
# Zooming slice (2) P_00989_RIGHT_CC_MASK.jpg mask size is 52
# Zooming slice (1) P_00991_LEFT_CC_MASK.jpg mask size is 44
# Zooming slice (2) P_00991_LEFT_CC_MASK.jpg mask size is 44
# Zooming slice (1) P_00991_LEFT_MLO_MASK.jpg mask size is 44
# Zooming slice (2) P_00991_LEFT_MLO_MASK.jpg mask size is 44
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_00998_LEFT_CC_MASK.jpg
# P_01002_LEFT_CC_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_01002_LEFT_CC
# P_01002_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_01002_LEFT_MLO
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01010_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01016_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01019_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01019_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01029_LEFT_CC_MASK.jpg mask size is 76
# Zooming slice (2) P_01029_RIGHT_CC_MASK.jpg mask size is 72
# Zooming slice (1) P_01029_RIGHT_MLO_MASK.jpg mask size is 48
# Zooming slice (2) P_01029_RIGHT_MLO_MASK.jpg mask size is 48
# Zooming slice (2) P_01034_LEFT_CC_MASK.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01034_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01034_LEFT_MLO_MASK.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01037_LEFT_CC_MASK.jpg
# Zooming slice (2) P_01037_LEFT_CC_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01037_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01040_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01040_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01045_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01045_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01046_LEFT_CC_MASK.jpg
# Zooming slice (2) P_01046_LEFT_CC_MASK.jpg mask size is 79
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01046_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01046_LEFT_MLO_MASK.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01049_LEFT_CC_MASK.jpg
# Zooming slice (2) P_01049_LEFT_CC_MASK.jpg mask size is 59
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01049_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01049_LEFT_MLO_MASK.jpg mask size is 55
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01056_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01056_RIGHT_CC_MASK.jpg mask size is 76
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01056_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01056_RIGHT_MLO_MASK.jpg mask size is 95
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01059_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01059_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01060_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01060_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01063_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01063_RIGHT_MLO_MASK.jpg mask size is 59
# P_01065_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_01065_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01066_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01066_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01066_RIGHT_MLO_MASK.jpg mask size is 84
# Zooming slice (2) P_01069_LEFT_CC_MASK.jpg mask size is 60
# Zooming slice (2) P_01069_LEFT_MLO_MASK.jpg mask size is 60
# Zooming slice (1) P_01069_RIGHT_CC_MASK.jpg mask size is 40
# Zooming slice (2) P_01069_RIGHT_CC_MASK.jpg mask size is 40
# Zooming slice (1) P_01069_RIGHT_MLO_MASK.jpg mask size is 48
# Zooming slice (2) P_01069_RIGHT_MLO_MASK.jpg mask size is 48
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01072_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01072_LEFT_MLO_MASK.jpg
# Zooming slice (1) P_01084_LEFT_CC_MASK.jpg mask size is 44
# Zooming slice (2) P_01084_LEFT_CC_MASK.jpg mask size is 44
# Zooming slice (1) P_01084_LEFT_MLO_MASK.jpg mask size is 28
# Zooming slice (2) P_01084_LEFT_MLO_MASK.jpg mask size is 28
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01087_LEFT_CC_MASK.jpg
# P_01087_LEFT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01094_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01095_LEFT_MLO_MASK.jpg mask size is 88
# P_01099_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01099_LEFT_MLO
# Slice_2 wrong shape: (1, 1) - image P_01099_LEFT_MLO
# P_01099_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01099_RIGHT_MLO
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01100_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01100_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01102_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01102_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01107_LEFT_CC_MASK.jpg
# Zooming slice (2) P_01107_LEFT_CC_MASK.jpg mask size is 72
# Zooming slice (2) P_01111_RIGHT_CC_MASK.jpg mask size is 95
# Zooming slice (2) P_01111_RIGHT_MLO_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01121_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01121_RIGHT_CC_MASK.jpg mask size is 52
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01126_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01126_LEFT_MLO_MASK.jpg mask size is 76
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01127_RIGHT_CC_MASK.jpg
# P_01127_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01127_RIGHT_MLO_MASK.jpg
# P_01127_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Zooming slice (2) P_01128_RIGHT_CC_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01137_LEFT_CC_MASK.jpg
# Zooming slice (2) P_01137_LEFT_CC_MASK.jpg mask size is 60
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01137_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01137_LEFT_MLO_MASK.jpg mask size is 67
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01143_RIGHT_CC_MASK.jpg
# P_01143_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01156_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01161_LEFT_CC_MASK.jpg mask size is 75
# Zooming slice (2) P_01161_LEFT_MLO_MASK.jpg mask size is 90
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01166_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01166_RIGHT_CC_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01166_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01166_RIGHT_MLO_MASK.jpg mask size is 79
# Zooming slice (2) P_01169_LEFT_CC_MASK.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01169_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01169_LEFT_MLO_MASK.jpg mask size is 68
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01172_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01172_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01188_RIGHT_CC_MASK.jpg
# P_01188_RIGHT_CC_MASK.jpg Mask too big, reframing...
# ...
# P_01625_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Zooming slice (2) P_01628_LEFT_CC_MASK.jpg mask size is 88
# Zooming slice (2) P_01628_LEFT_MLO_MASK.jpg mask size is 76
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01628_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01628_RIGHT_CC_MASK.jpg mask size is 67
# Zooming slice (2) P_01628_RIGHT_MLO_MASK.jpg mask size is 96
# Zooming slice (2) P_01629_LEFT_CC_MASK.jpg mask size is 98
# Zooming slice (2) P_01639_RIGHT_CC_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01647_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01647_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01655_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01655_RIGHT_CC_MASK.jpg mask size is 63
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01655_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01655_RIGHT_MLO_MASK.jpg mask size is 55
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01659_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01660_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01660_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01664_RIGHT_CC_MASK.jpg mask size is 96
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01676_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01683_LEFT_CC_MASK.jpg
# Zooming slice (1) P_01691_RIGHT_CC_MASK.jpg mask size is 44
# Zooming slice (2) P_01691_RIGHT_CC_MASK.jpg mask size is 44
# Zooming slice (1) P_01691_RIGHT_MLO_MASK.jpg mask size is 36
# Zooming slice (2) P_01691_RIGHT_MLO_MASK.jpg mask size is 36
# Zooming slice (2) P_01700_LEFT_CC_MASK.jpg mask size is 91
# Zooming slice (2) P_01700_LEFT_MLO_MASK.jpg mask size is 75
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01700_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01700_RIGHT_CC_MASK.jpg mask size is 56
# Zooming slice (1) P_01700_RIGHT_MLO_MASK.jpg mask size is 48
# Zooming slice (2) P_01700_RIGHT_MLO_MASK.jpg mask size is 48
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01703_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01705_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01705_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01709_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01709_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01718_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01718_RIGHT_MLO_MASK.jpg mask size is 89
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01721_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01721_RIGHT_CC_MASK.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01723_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01723_RIGHT_CC_MASK.jpg mask size is 91
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01723_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01723_RIGHT_MLO_MASK.jpg mask size is 94
# Zooming slice (2) P_01725_RIGHT_CC_MASK.jpg mask size is 96
# Zooming slice (2) P_01725_RIGHT_MLO_MASK.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01729_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01729_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01730_LEFT_CC_MASK.jpg
# Zooming slice (2) P_01730_LEFT_CC_MASK.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01730_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01730_LEFT_MLO_MASK.jpg mask size is 83
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01732_LEFT_CC_MASK.jpg
# Zooming slice (2) P_01732_LEFT_CC_MASK.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01732_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01732_LEFT_MLO_MASK.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01736_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01736_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01736_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01736_RIGHT_MLO_MASK.jpg
# Zooming slice (1) P_01740_LEFT_CC_MASK.jpg mask size is 32
# Zooming slice (2) P_01740_LEFT_CC_MASK.jpg mask size is 32
# Zooming slice (1) P_01740_LEFT_MLO_MASK.jpg mask size is 28
# Zooming slice (2) P_01740_LEFT_MLO_MASK.jpg mask size is 28
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01740_RIGHT_CC_MASK.jpg
# Zooming slice (1) P_01740_RIGHT_CC_MASK.jpg mask size is 27
# Zooming slice (2) P_01740_RIGHT_CC_MASK.jpg mask size is 27
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01740_RIGHT_MLO_MASK.jpg
# Zooming slice (1) P_01740_RIGHT_MLO_MASK.jpg mask size is 32
# Zooming slice (2) P_01740_RIGHT_MLO_MASK.jpg mask size is 32
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01741_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01750_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01750_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01756_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01756_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01759_RIGHT_CC_MASK.jpg mask size is 84
# Zooming slice (2) P_01759_RIGHT_MLO_MASK.jpg mask size is 71
# Zooming slice (1) P_01760_RIGHT_CC_MASK.jpg mask size is 35
# Zooming slice (2) P_01760_RIGHT_CC_MASK.jpg mask size is 35
# Zooming slice (1) P_01760_RIGHT_MLO_MASK.jpg mask size is 39
# Zooming slice (2) P_01760_RIGHT_MLO_MASK.jpg mask size is 39
# Zooming slice (2) P_01767_LEFT_CC_MASK.jpg mask size is 76
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01767_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01767_LEFT_MLO_MASK.jpg mask size is 75
# Zooming slice (1) P_01769_LEFT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_01769_LEFT_CC_MASK.jpg mask size is 48
# Zooming slice (2) P_01769_LEFT_MLO_MASK.jpg mask size is 56
# Zooming slice (1) P_01769_RIGHT_CC_MASK.jpg mask size is 32
# Zooming slice (2) P_01769_RIGHT_CC_MASK.jpg mask size is 32
# Zooming slice (2) P_01769_RIGHT_MLO_MASK.jpg mask size is 75
# Zooming slice (2) P_01777_LEFT_MLO_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01783_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01784_LEFT_CC_MASK.jpg mask size is 68
# Zooming slice (2) P_01784_LEFT_MLO_MASK.jpg mask size is 83
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01793_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01809_LEFT_MLO_MASK.jpg
# P_01809_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Zooming slice (1) P_01823_LEFT_CC_MASK.jpg mask size is 32
# Zooming slice (2) P_01823_LEFT_CC_MASK.jpg mask size is 32
# Zooming slice (2) P_01823_LEFT_MLO_MASK.jpg mask size is 60
# Zooming slice (1) P_01823_RIGHT_CC_MASK.jpg mask size is 44
# Zooming slice (2) P_01823_RIGHT_CC_MASK.jpg mask size is 44
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01823_RIGHT_MLO_MASK.jpg
# Zooming slice (1) P_01823_RIGHT_MLO_MASK.jpg mask size is 35
# Zooming slice (2) P_01823_RIGHT_MLO_MASK.jpg mask size is 35
# Zooming slice (2) P_01830_LEFT_CC_MASK.jpg mask size is 67
# Zooming slice (2) P_01830_LEFT_MLO_MASK.jpg mask size is 72
# Zooming slice (2) P_01830_RIGHT_MLO_MASK.jpg mask size is 80
# Zooming slice (2) P_01838_LEFT_CC_MASK.jpg mask size is 79
# Zooming slice (2) P_01838_LEFT_MLO_MASK.jpg mask size is 56
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01838_RIGHT_CC_MASK.jpg
# Zooming slice (1) P_01838_RIGHT_CC_MASK.jpg mask size is 44
# Zooming slice (2) P_01838_RIGHT_CC_MASK.jpg mask size is 44
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01838_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01838_RIGHT_MLO_MASK.jpg mask size is 55
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01839_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01840_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01864_LEFT_CC_MASK.jpg mask size is 51
# P_01864_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01864_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_01864_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01864_RIGHT_MLO
# P_01875_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_01875_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01884_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_01884_RIGHT_CC_MASK.jpg mask size is 84
# Zooming slice (2) P_01884_RIGHT_MLO_MASK.jpg mask size is 88
# Zooming slice (2) P_01885_LEFT_CC_MASK.jpg mask size is 52
# Zooming slice (1) P_01885_LEFT_MLO_MASK.jpg mask size is 47
# Zooming slice (2) P_01885_LEFT_MLO_MASK.jpg mask size is 47
# Zooming slice (1) P_01885_RIGHT_CC_MASK.jpg mask size is 47
# Zooming slice (2) P_01885_RIGHT_CC_MASK.jpg mask size is 47
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_01885_RIGHT_MLO_MASK.jpg
# Zooming slice (1) P_01885_RIGHT_MLO_MASK.jpg mask size is 39
# Zooming slice (2) P_01885_RIGHT_MLO_MASK.jpg mask size is 39
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02105_LEFT_CC_MASK.jpg
# P_02105_LEFT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02105_LEFT_MLO_MASK.jpg
# P_02105_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Slice_2 wrong shape: (1, 1) - image P_02105_LEFT_MLO
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02115_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02115_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02133_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02133_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02154_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02154_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02190_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02218_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02218_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02220_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02220_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02226_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02226_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02234_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02234_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02259_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02259_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02285_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02313_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02316_RIGHT_MLO_MASK.jpg
# P_02348_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02348_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02380_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02380_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02393_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02393_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02400_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02400_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02419_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02419_LEFT_MLO_MASK.jpg
# P_02424_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02434_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02434_LEFT_MLO_MASK.jpg
# P_02437_LEFT_CC_MASK.jpg Mask too big, reframing...
# P_02437_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02442_LEFT_CC_MASK.jpg
# P_02442_LEFT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02442_LEFT_MLO_MASK.jpg
# P_02442_LEFT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02459_RIGHT_MLO_MASK.jpg
# P_02460_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02468_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02468_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02475_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02475_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02508_LEFT_CC_MASK.jpg
# P_02508_LEFT_CC_MASK.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Train All Mask JPEGs Full/P_02508_LEFT_MLO_MASK.jpg
# P_02508_LEFT_MLO_MASK.jpg Mask too big, reframing...
# P_02518_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02518_RIGHT_MLO
# Slice_4 wrong shape: (1, 1) - image P_02518_RIGHT_MLO
# P_02522_RIGHT_CC_MASK.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_02522_RIGHT_CC
# P_02522_RIGHT_MLO_MASK.jpg Mask too big, reframing...
# P_02566_RIGHT_CC_MASK.jpg Mask too big, reframing...
# P_02566_RIGHT_MLO_MASK.jpg Mask too big, reframing...

# %%
print("Calc Train Slices shape:",calc_train_slices.shape)
print("Calc Train File Name List:", len(calc_train_image_names))
# Out:
# Calc Train Slices shape: (1973, 299, 299, 1)
# Calc Train File Name List: 1973

# %%
# check image to make sure it matches the cropped image
plt.imshow(calc_train_slices[1508].reshape(299,299))
plt.title(calc_train_image_names[1508])

# %%
images_to_check = ["P_02393_LEFT_CC.jpg","P_02566_RIGHT_MLO.jpg","P_00088_LEFT_CC.jpg","P_00280_LEFT_MLO.jpg","P_00418_RIGHT_CC.jpg"]

for name in images_to_check:
    for i in range(len(calc_train_image_names)):
        if calc_train_image_names[i] == name:
            plt.imshow(calc_train_slices[i].reshape(299,299))
            plt.title(name + " - idx: " + str(i))
            plt.show()

# %%
calc_train_labels = []
train_labels = pd.read_pickle(os.path.join("data", "train_labels.pkl"))
train_labels['IMAGE_NAME2'] = train_labels.index
train_labels = train_labels.drop_duplicates(['IMAGE_NAME2'])

#calc_train_image_names = np.load("data/calc_train_filenames.npy")

for image in calc_train_image_names:
    calc_train_labels.append(train_labels.loc[image]['CLASS'])
    
print("Calc Train Labels:", len(calc_train_labels))
# Out:
# Calc Train Labels: 1973

# %%
np.save(os.path.join("data", "calc_train_slices.npy"), calc_train_slices)
np.save(os.path.join("data", "calc_train_filenames.npy"), calc_train_image_names)
np.save(os.path.join("data", "calc_train_labels.npy"), np.array(calc_train_labels))

# %% [markdown]
# ## Mass Test

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Test ROI JPEGs", "Mass Test All Mask JPEGs", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Mass Test Full JPEGs", "Mass Test All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "E:\\Documents\\Mammography\\CBIS-DDSM\\Mass Test All Mask JPEGs"
image_dir = "E:\\Documents\\Mammography\\CBIS-DDSM\\Mass Test All Full JPEGs"

mass_test_slices, mass_test_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00016_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00017_LEFT_CC_MASK.jpg mask size is 86
# Zooming slice (2) P_00017_LEFT_MLO_MASK.jpg mask size is 92
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00099_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00099_LEFT_MLO_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00118_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00118_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00124_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00124_RIGHT_CC_MASK.jpg mask size is 73
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00126_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00126_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00145_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00145_LEFT_CC_MASK.jpg
# Mask shape: (2151, 854)
# Image shape: (2480, 988)
# Error, skipping P_00145_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00145_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00145_LEFT_MLO_MASK.jpg
# Mask shape: (2145, 1037)
# Image shape: (2473, 1198)
# Error, skipping P_00145_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00158_RIGHT_MLO_MASK.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00171_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00171_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00177_LEFT_CC_MASK.jpg mask size is 70
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00203_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00203_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00209_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00209_LEFT_MLO_MASK.jpg mask size is 91
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00230_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00230_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00238_RIGHT_CC_MASK.jpg
# Zooming slice (2) P_00238_RIGHT_CC_MASK.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00238_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00238_RIGHT_MLO_MASK.jpg mask size is 89
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00278_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00278_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00340_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00358_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00359_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00369_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00369_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00379_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00379_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00379_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1370)
# Image shape: (2652, 1580)
# Error, skipping P_00379_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00381_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00381_LEFT_CC_MASK.jpg
# Mask shape: (2269, 1350)
# Image shape: (2615, 1558)
# Error, skipping P_00381_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00381_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00381_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1553)
# Image shape: (2652, 1790)
# Error, skipping P_00381_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00387_RIGHT_CC_MASK.jpg mask size is 91
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00391_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00391_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00391_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00391_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00405_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00405_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00433_LEFT_CC_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00457_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00457_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00464_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00464_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00470_RIGHT_MLO_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00481_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00482_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00482_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00493_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00494_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00494_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00498_LEFT_CC_MASK.jpg
# Zooming slice (2) P_00498_LEFT_CC_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00498_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00500_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00510_LEFT_CC_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00510_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00510_LEFT_MLO_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00514_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00524_LEFT_MLO_MASK.jpg mask size is 85
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00544_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00544_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00576_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00576_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_00576_LEFT_MLO_MASK.jpg mask size is 90
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00587_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00587_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00615_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00615_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00656_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00699_RIGHT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00699_RIGHT_CC_MASK.jpg
# Mask shape: (2224, 1422)
# Image shape: (2562, 1640)
# Error, skipping P_00699_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00699_RIGHT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00699_RIGHT_MLO_MASK.jpg
# Mask shape: (2237, 1598)
# Image shape: (2578, 1843)
# Error, skipping P_00699_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00738_RIGHT_MLO_MASK.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00741_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00758_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00773_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00773_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00788_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00813_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00813_RIGHT_MLO_MASK.jpg mask size is 88
# Zooming slice (2) P_00820_LEFT_CC_MASK.jpg mask size is 73
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00837_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00837_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00875_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00875_RIGHT_MLO_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00922_RIGHT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00922_RIGHT_MLO_MASK.jpg
# Mask shape: (2289, 1077)
# Image shape: (2633, 1238)
# Error, skipping P_00922_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_00924_RIGHT_CC_MASK.jpg mask size is 81
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00932_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00962_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00979_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00980_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00980_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_00986_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01068_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01090_RIGHT_MLO_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01101_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01106_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01110_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01114_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01119_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01167_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01187_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01192_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01192_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01210_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01213_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01213_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01235_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01251_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01251_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01257_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01257_RIGHT_MLO_MASK.jpg
# Zooming slice (2) P_01277_RIGHT_MLO_MASK.jpg mask size is 94
# Zooming slice (2) P_01316_RIGHT_CC_MASK.jpg mask size is 93
# Zooming slice (2) P_01316_RIGHT_MLO_MASK.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01322_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01322_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01323_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01323_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01333_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01347_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01347_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01348_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01351_LEFT_CC_MASK.jpg
# Mishaped mask, resizing mask E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01378_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01381_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01489_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01510_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01510_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01512_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01518_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01518_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01534_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01534_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01539_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01539_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01551_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01551_LEFT_CC_MASK.jpg
# Mask shape: (2303, 1579)
# Image shape: (2652, 1820)
# Error, skipping P_01551_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01551_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01558_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01558_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01578_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01590_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01590_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01595_LEFT_CC_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01595_LEFT_CC_MASK.jpg
# Mask shape: (2302, 1389)
# Image shape: (2653, 1603)
# Error, skipping P_01595_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01595_LEFT_MLO_MASK.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01595_LEFT_MLO_MASK.jpg
# Mask shape: (2303, 1305)
# Image shape: (2652, 1505)
# Error, skipping P_01595_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01599_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01599_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01605_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01614_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01623_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01623_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01677_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01690_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01690_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01726_RIGHT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01778_RIGHT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01795_LEFT_CC_MASK.jpg
# Zooming slice (2) P_01795_LEFT_CC_MASK.jpg mask size is 89
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01795_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01795_LEFT_MLO_MASK.jpg mask size is 95
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01796_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01797_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01797_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01800_RIGHT_CC_MASK.jpg mask size is 99
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Mass Test All Mask JPEGs/P_01865_LEFT_MLO_MASK.jpg

# %%
print("Mass Test Slices shape:", mass_test_slices.shape)
print("Mass Test File Name List:", len(mass_test_image_names))
# Out:
# Mass Test Slices shape: (372, 299, 299, 1)
# Mass Test File Name List: 372

# %%
# check images to make sure it matches the cropped image
plt.imshow(mass_test_slices[99].reshape(299,299))
plt.title(mass_test_image_names[99])

# %%
images_to_check = ["P_01800_RIGHT_CC.jpg", "P_00699_RIGHT_CC.jpg", "P_01316_RIGHT_CC.jpg", "P_00924_RIGHT_CC.jpg"]

for name in images_to_check:
    for i in range(len(mass_test_image_names)):
        if mass_test_image_names[i] == name:
            plt.imshow(mass_test_slices[i].reshape(299,299))
            plt.title(name + " - idx: " + str(i))
            plt.show()

# %%
# process labels for slices
test_labels = pd.read_pickle(os.path.join("data", "test_labels.pkl"))

test_labels['IMAGE_NAME2'] = test_labels.index
test_labels = test_labels.drop_duplicates(['IMAGE_NAME2'])
mass_test_labels = []

for image in mass_test_image_names:
    label = test_labels.loc[image]['CLASS']
    mass_test_labels.append(test_labels.loc[image]['CLASS'])
    
print("Mass Test Labels:", len(mass_test_labels))
# Out:
# Mass Test Labels: 372

# %%
np.save(os.path.join("data", "mass_test_slices.npy"), mass_test_slices)
np.save(os.path.join("data", "mass_test_filenames.npy"), mass_test_image_names)
np.save(os.path.join("data", "mass_test_labels.npy"), np.array(mass_test_labels))

# %% [markdown]
# ## Calc Test

# %%
# copy all of the masks into one directory, renaming them appropriately
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Test ROI JPEGs", "Calc Test All Mask JPEGs", scan_type="MASK")
rename_and_copy_files("D:\\Documents\\Mammography\\CBIS-DDSM\\", "Calc Test Full JPEGs", "Calc Test All Full JPEGs", scan_type="FULL")

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "E:\\Documents\\Mammography\\CBIS-DDSM\\Calc Test All Mask JPEGs"
image_dir = "E:\\Documents\\Mammography\\CBIS-DDSM\\Calc Test All Full JPEGs"

calc_test_slices, calc_test_image_names = create_roi_slices(mask_dir, image_dir, output=False)
# Out:
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Zooming slice (1) P_00041_LEFT_CC000001.jpg mask size is 48
# Zooming slice (2) P_00041_LEFT_CC000001.jpg mask size is 48
# Zooming slice (2) P_00041_LEFT_MLO000001.jpg mask size is 52
# Zooming slice (1) P_00077_LEFT_CC000001.jpg mask size is 36
# Zooming slice (2) P_00077_LEFT_CC000001.jpg mask size is 36
# Zooming slice (2) P_00077_LEFT_MLO000001.jpg mask size is 51
# Zooming slice (2) P_00077_RIGHT_CC000001.jpg mask size is 63
# Zooming slice (2) P_00077_RIGHT_MLO000001.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00100_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00100_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00127_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00127_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00132_LEFT_MLO000001.jpg
# Zooming slice (2) P_00140_LEFT_MLO000001.jpg mask size is 96
# Zooming slice (2) P_00140_RIGHT_CC000001.jpg mask size is 76
# Zooming slice (2) P_00140_RIGHT_MLO000001.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00141_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00141_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00150_RIGHT_MLO000001.jpg
# Zooming slice (2) P_00150_RIGHT_MLO000001.jpg mask size is 84
# Zooming slice (2) P_00163_LEFT_CC000001.jpg mask size is 100
# Zooming slice (2) P_00164_RIGHT_CC000001.jpg mask size is 79
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00195_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00195_LEFT_MLO000001.jpg
# P_00202_RIGHT_CC000001.jpg Mask too big, reframing...
# Zooming slice (1) P_00214_LEFT_CC000001.jpg mask size is 36
# Zooming slice (2) P_00214_LEFT_CC000001.jpg mask size is 36
# Zooming slice (2) P_00214_LEFT_MLO000001.jpg mask size is 51
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00223_LEFT_MLO000001.jpg
# Zooming slice (2) P_00244_RIGHT_MLO000001.jpg mask size is 83
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00246_RIGHT_MLO000001.jpg
# Zooming slice (2) P_00246_RIGHT_MLO000001.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00299_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00299_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00325_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00331_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00331_LEFT_MLO000001.jpg
# Zooming slice (2) P_00331_LEFT_MLO000001.jpg mask size is 84
# Zooming slice (2) P_00353_LEFT_CC1000001.jpg mask size is 96
# Zooming slice (2) P_00353_LEFT_CC_1000001.jpg mask size is 96
# Zooming slice (2) P_00402_RIGHT_CC000001.jpg mask size is 76
# Zooming slice (2) P_00402_RIGHT_MLO000001.jpg mask size is 60
# P_00485_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_00485_LEFT_CC
# P_00485_LEFT_MLO000001.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_00485_LEFT_MLO
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00495_RIGHT_CC000001.jpg
# Zooming slice (1) P_00495_RIGHT_CC000001.jpg mask size is 32
# Zooming slice (2) P_00495_RIGHT_CC000001.jpg mask size is 32
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00495_RIGHT_CC000001_1.jpg
# Zooming slice (1) P_00495_RIGHT_MLO000001.jpg mask size is 44
# Zooming slice (2) P_00495_RIGHT_MLO000001.jpg mask size is 44
# Zooming slice (1) P_00495_RIGHT_MLO000001_1.jpg mask size is 32
# Zooming slice (2) P_00495_RIGHT_MLO000001_1.jpg mask size is 32
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00497_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00497_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00537_RIGHT_MLO000001.jpg
# Zooming slice (1) P_00562_LEFT_CC000001.jpg mask size is 28
# Zooming slice (2) P_00562_LEFT_CC000001.jpg mask size is 28
# Zooming slice (1) P_00562_LEFT_CC000001_1.jpg mask size is 44
# Zooming slice (2) P_00562_LEFT_CC000001_1.jpg mask size is 44
# Zooming slice (1) P_00562_LEFT_MLO000001.jpg mask size is 43
# Zooming slice (2) P_00562_LEFT_MLO000001.jpg mask size is 43
# Zooming slice (1) P_00562_LEFT_MLO000001_1.jpg mask size is 28
# Zooming slice (2) P_00562_LEFT_MLO000001_1.jpg mask size is 28
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00562_RIGHT_CC000001.jpg
# Zooming slice (1) P_00562_RIGHT_CC000001.jpg mask size is 27
# Zooming slice (2) P_00562_RIGHT_CC000001.jpg mask size is 27
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00562_RIGHT_MLO000001.jpg
# Zooming slice (1) P_00562_RIGHT_MLO000001.jpg mask size is 36
# Zooming slice (2) P_00562_RIGHT_MLO000001.jpg mask size is 36
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00570_LEFT_MLO000001.jpg
# Zooming slice (2) P_00570_LEFT_MLO000001.jpg mask size is 80
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00579_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00608_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00620_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00649_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00649_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00678_LEFT_CC000001.jpg
# P_00678_LEFT_CC000001.jpg Mask too big, reframing...
# Zooming slice (2) P_00679_LEFT_CC000001.jpg mask size is 88
# Zooming slice (2) P_00679_LEFT_MLO000001.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00686_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00774_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00774_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00789_LEFT_MLO000001.jpg
# Zooming slice (1) P_00795_LEFT_CC000001.jpg mask size is 39
# Zooming slice (2) P_00795_LEFT_CC000001.jpg mask size is 39
# Zooming slice (1) P_00795_LEFT_MLO000001.jpg mask size is 44
# Zooming slice (2) P_00795_LEFT_MLO000001.jpg mask size is 44
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00811_LEFT_CC000001.jpg
# P_00811_LEFT_CC000001.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00827_RIGHT_CC000001.jpg
# Zooming slice (2) P_00827_RIGHT_CC000001.jpg mask size is 87
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00827_RIGHT_MLO000001.jpg
# Zooming slice (2) P_00827_RIGHT_MLO000001.jpg mask size is 83
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00876_LEFT_CC000001.jpg
# Zooming slice (2) P_00876_LEFT_CC000001.jpg mask size is 84
# Zooming slice (2) P_00876_LEFT_MLO000001.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00879_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00879_RIGHT_MLO000001.jpg
# Zooming slice (1) P_00905_RIGHT_CC000001.jpg mask size is 48
# Zooming slice (2) P_00905_RIGHT_CC000001.jpg mask size is 48
# Zooming slice (2) P_00905_RIGHT_MLO000001.jpg mask size is 52
# Zooming slice (2) P_00906_LEFT_CC000001.jpg mask size is 96
# Zooming slice (2) P_00906_LEFT_MLO000001.jpg mask size is 80
# Zooming slice (2) P_00906_LEFT_MLO000001_1.jpg mask size is 84
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00919_RIGHT_CC000001.jpg
# Zooming slice (2) P_00919_RIGHT_CC000001.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00919_RIGHT_MLO000001.jpg
# Zooming slice (2) P_00919_RIGHT_MLO000001.jpg mask size is 75
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00974_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_00974_RIGHT_MLO000001.jpg
# Zooming slice (2) P_00974_RIGHT_MLO000001.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01006_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01006_LEFT_MLO000001.jpg
# Zooming slice (2) P_01022_LEFT_CC000001.jpg mask size is 76
# Zooming slice (2) P_01022_LEFT_MLO000001.jpg mask size is 76
# Zooming slice (1) P_01030_RIGHT_CC000001.jpg mask size is 31
# Zooming slice (2) P_01030_RIGHT_CC000001.jpg mask size is 31
# Zooming slice (1) P_01030_RIGHT_CC000001_1.jpg mask size is 44
# Zooming slice (2) P_01030_RIGHT_CC000001_1.jpg mask size is 44
# Zooming slice (1) P_01030_RIGHT_MLO000001.jpg mask size is 20
# Zooming slice (2) P_01030_RIGHT_MLO000001.jpg mask size is 20
# Zooming slice (1) P_01030_RIGHT_MLO000001_1.jpg mask size is 32
# Zooming slice (2) P_01030_RIGHT_MLO000001_1.jpg mask size is 32
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01050_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01092_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01092_LEFT_MLO000001.jpg
# Zooming slice (2) P_01092_LEFT_MLO000001.jpg mask size is 89
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01132_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01148_RIGHT_MLO000001.jpg
# Zooming slice (2) P_01152_RIGHT_MLO000001.jpg mask size is 100
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01154_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01154_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01157_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01157_RIGHT_MLO000001.jpg
# Zooming slice (1) P_01211_LEFT_CC000001.jpg mask size is 28
# Zooming slice (2) P_01211_LEFT_CC000001.jpg mask size is 28
# Zooming slice (2) P_01211_LEFT_MLO000001.jpg mask size is 51
# Zooming slice (1) P_01211_RIGHT_CC000001.jpg mask size is 28
# Zooming slice (2) P_01211_RIGHT_CC000001.jpg mask size is 28
# Zooming slice (1) P_01211_RIGHT_CC000001_1.jpg mask size is 32
# Zooming slice (2) P_01211_RIGHT_CC000001_1.jpg mask size is 32
# Zooming slice (1) P_01211_RIGHT_MLO000001.jpg mask size is 40
# Zooming slice (2) P_01211_RIGHT_MLO000001.jpg mask size is 40
# Zooming slice (1) P_01211_RIGHT_MLO000001_1.jpg mask size is 48
# Zooming slice (2) P_01211_RIGHT_MLO000001_1.jpg mask size is 48
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01217_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01217_RIGHT_CC000001_1.jpg
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01217_RIGHT_CC000001_1.jpg
# Mask shape: (2096, 1512)
# Image shape: (2359, 1145)
# Error, skipping P_01217_RIGHT_CC000001_1.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01217_RIGHT_CC000001_2.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01217_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01272_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01272_LEFT_MLO_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01303_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01303_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01308_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01318_LEFT_MLO000001.jpg
# Zooming slice (2) P_01318_LEFT_MLO000001.jpg mask size is 91
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01320_LEFT_MLO000001.jpg
# Zooming slice (2) P_01352_LEFT_CC000001.jpg mask size is 71
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01352_LEFT_MLO_MASK.jpg
# Zooming slice (2) P_01352_LEFT_MLO_MASK.jpg mask size is 64
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01353_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01353_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01414_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01414_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01415_RIGHT_MLO000001.jpg
# Zooming slice (2) P_01415_RIGHT_MLO000001.jpg mask size is 91
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01419_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01419_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01425_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01425_LEFT_MLO000001.jpg
# Zooming slice (2) P_01460_LEFT_MLO000001.jpg mask size is 60
# Mask shape doesn't match image! E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01460_LEFT_MLO000001_2.jpg
# Mask shape: (2232, 1512)
# Image shape: (2240, 1508)
# Error, skipping P_01460_LEFT_MLO000001_2.jpg
# P_01460_RIGHT_MLO000001.jpg Mask too big, reframing...
# Slice_1 wrong shape: (1, 1) - image P_01460_RIGHT_MLO
# Slice_2 wrong shape: (1, 1) - image P_01460_RIGHT_MLO
# Zooming slice (2) P_01460_RIGHT_MLO000001_1.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01465_LEFT_MLO000001.jpg
# Zooming slice (2) P_01471_RIGHT_CC000001.jpg mask size is 94
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01476_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01476_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01483_LEFT_MLO000001.jpg
# Zooming slice (2) P_01490_LEFT_CC000001.jpg mask size is 60
# Zooming slice (2) P_01490_LEFT_MLO000001.jpg mask size is 68
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01523_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01534_LEFT_CC_MASK.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01534_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01535_LEFT_CC000001.jpg
# Zooming slice (2) P_01535_LEFT_CC000001.jpg mask size is 76
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01535_LEFT_MLO000001.jpg
# Zooming slice (2) P_01535_LEFT_MLO000001.jpg mask size is 72
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01538_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01538_RIGHT_MLO000001_1.jpg
# Zooming slice (2) P_01538_RIGHT_MLO000001_1.jpg mask size is 100
# Zooming slice (2) P_01562_LEFT_CC000001.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01602_RIGHT_CC000001.jpg
# Zooming slice (2) P_01670_LEFT_MLO000001.jpg mask size is 92
# Zooming slice (2) P_01670_LEFT_MLO000001_2.jpg mask size is 95
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01711_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01711_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01713_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01743_RIGHT_MLO000001.jpg
# P_01743_RIGHT_MLO000001.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01752_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01752_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01820_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01834_LEFT_MLO000001.jpg
# Zooming slice (2) P_01834_LEFT_MLO000001.jpg mask size is 86
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01842_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01845_RIGHT_CC000001.jpg
# Zooming slice (2) P_01845_RIGHT_CC000001.jpg mask size is 88
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01845_RIGHT_CC000001_1.jpg
# Zooming slice (2) P_01845_RIGHT_CC000001_1.jpg mask size is 60
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01845_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01845_RIGHT_MLO000001_1.jpg
# Zooming slice (2) P_01845_RIGHT_MLO000001_1.jpg mask size is 55
# Zooming slice (2) P_01861_LEFT_CC000001.jpg mask size is 59
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01861_LEFT_MLO000001.jpg
# Zooming slice (2) P_01861_LEFT_MLO000001.jpg mask size is 56
# Zooming slice (1) P_01867_LEFT_CC000001.jpg mask size is 34
# Zooming slice (2) P_01867_LEFT_CC000001.jpg mask size is 34
# Zooming slice (1) P_01867_LEFT_CC000001_1.jpg mask size is 36
# Zooming slice (2) P_01867_LEFT_CC000001_1.jpg mask size is 36
# Zooming slice (1) P_01867_LEFT_MLO000001.jpg mask size is 47
# Zooming slice (2) P_01867_LEFT_MLO000001.jpg mask size is 47
# Zooming slice (1) P_01867_LEFT_MLO000001_1.jpg mask size is 24
# Zooming slice (2) P_01867_LEFT_MLO000001_1.jpg mask size is 24
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01872_LEFT_CC000001.jpg
# Zooming slice (2) P_01872_LEFT_CC000001.jpg mask size is 89
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_01872_LEFT_MLO000001.jpg
# Zooming slice (2) P_01872_LEFT_MLO000001.jpg mask size is 74
# P_01883_RIGHT_CC000001.jpg Mask too big, reframing...
# P_01883_RIGHT_MLO000001.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02102_LEFT_CC000001.jpg
# P_02102_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_02102_LEFT_CC
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02102_LEFT_MLO000001.jpg
# P_02102_LEFT_MLO000001.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02139_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02139_LEFT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02159_LEFT_MLO000001.jpg
# P_02176_RIGHT_CC000001.jpg Mask too big, reframing...
# Slice_3 wrong shape: (1, 1) - image P_02176_RIGHT_CC
# P_02176_RIGHT_MLO000001.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02198_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02198_LEFT_MLO000001.jpg
# P_02275_LEFT_CC000001.jpg Mask too big, reframing...
# Slice_4 wrong shape: (1, 1) - image P_02275_LEFT_CC
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02275_LEFT_MLO000001.jpg
# P_02275_LEFT_MLO000001.jpg Mask too big, reframing...
# P_02418_RIGHT_CC000001.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02420_RIGHT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02420_RIGHT_MLO000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02432_LEFT_CC000001.jpg
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02432_LEFT_MLO000001.jpg
# P_02464_RIGHT_CC000001.jpg Mask too big, reframing...
# Trimming borders E:\Documents\Mammography\CBIS-DDSM\Calc Test All Mask JPEGs/P_02464_RIGHT_MLO000001.jpg
# P_02464_RIGHT_MLO000001.jpg Mask too big, reframing...

# %%
print("Calc Test Slices shape:", calc_test_slices.shape)
print("Calc Test File Name List:", len(calc_test_image_names))
# Out:
# Calc Test Slices shape: (486, 299, 299, 1)
# Calc Test File Name List: 486

# %%
# check image to make sure it matches the cropped image
plt.imshow(calc_test_slices[276].reshape(299,299))
plt.title(calc_test_image_names[276])

# %%
images_to_check = ["P_00041_LEFT_CC.jpg", "P_00038_RIGHT_CC.jpg", "P_00214_LEFT_CC.jpg", "P_00795_LEFT_MLO.jpg", "P_01006_LEFT_MLO.jpg", "P_01352_LEFT_MLO.jpg"]

for name in images_to_check:
    for i in range(len(calc_test_image_names)):
        if calc_test_image_names[i] == name:
            plt.imshow(calc_test_slices[i].reshape(299,299))
            plt.title(name + " - idx: " + str(i))
            plt.show()

# %%
test_labels = pd.read_pickle(os.path.join("data", "test_labels.pkl"))
test_labels['IMAGE_NAME2'] = test_labels.index
test_labels = test_labels.drop_duplicates(['IMAGE_NAME2'])

calc_test_labels = []
for image in calc_test_image_names:
    label = test_labels.loc[image]['CLASS']
    calc_test_labels .append(test_labels.loc[image]['CLASS'])
    
print("Calc Test Labels:", len(calc_test_labels))
# Out:
# Calc Test Labels: 486

# %%
np.save(os.path.join("data", "calc_test_slices.npy"), calc_test_slices)
np.save(os.path.join("data", "calc_test_filenames.npy"), calc_test_image_names)
np.save(os.path.join("data", "calc_test_labels.npy"), np.array(calc_test_labels))

# %% [markdown]
# ## Create File with All Slices

# %%
mass_train_labels = np.load(os.path.join("data", "mass_train_labels.npy"))
mass_test_labels = np.load(os.path.join("data", "mass_test_labels.npy"))
calc_train_labels = np.load(os.path.join("data", "calc_train_labels.npy"))
calc_test_labels = np.load(os.path.join("data", "calc_test_labels.npy"))
all_labels = np.concatenate([mass_train_labels, mass_test_labels, calc_train_labels, calc_test_labels], axis=0)

# %%
mass_train_slices = np.load(os.path.join("data", "mass_train_slices.npy"))
mass_test_slices = np.load(os.path.join("data", "mass_test_slices.npy"))
calc_train_slices = np.load(os.path.join("data", "calc_train_slices.npy"))
calc_test_slices = np.load(os.path.join("data", "calc_test_slices.npy"))
all_slices = np.concatenate([mass_train_slices, mass_test_slices, calc_train_slices, calc_test_slices], axis=0)

# %%
mass_train_names = np.load(os.path.join("data", "mass_train_filenames.npy"))
mass_test_names = np.load(os.path.join("data", "mass_test_filenames.npy"))
calc_train_names = np.load(os.path.join("data", "calc_train_filenames.npy"))
calc_test_names = np.load(os.path.join("data", "calc_test_filenames.npy"))
all_names = np.concatenate([mass_train_names, mass_test_names, calc_train_names, calc_test_names], axis=0)

# %%
print("All labels:", all_labels.shape)
print("All slices:", all_slices.shape)
print("All filenames:", all_names.shape)
# Out:
# All labels: (4109,)
# All slices: (4109, 299, 299, 1)
# All filenames: (4109,)

# %%
np.save(os.path.join("data", "all_slices.npy"), all_slices)
np.save(os.path.join("data", "all_labels.npy"), all_labels)
np.save(os.path.join("data", "all_names.npy"), all_names)

# %% [markdown]
# ## Mask Sizes

# %% [markdown]
# The MIAS scans are sized 1024x1024 so have been scaled down. The DDSM images are full size and the regions of interest have been cut out of them at full size. We know the radius of the MIAS abnormalities, if we can get an average radius of DDSM abnormalities we can scale the MIAS data so that the sizes will match.

# %%
def get_mask_sizes(mask_dir, output=True):
    # loop through mask directory
    mask_files = os.listdir(mask_dir)
    mask_sizes = []
    
    for mask in mask_files:
        if output:
            print(mask)
        
        # get the mask, if the mask is bigger than the slice we will create multiple slices 
        # using the corners of the mask. 
        center_row, center_col, too_big, _, mask_size = create_mask(mask_dir + "/" + mask, np.array([0]).reshape(1,1))
        mask_sizes.append(mask_size)
        
    return mask_sizes

# %%
## get the sizes of the masks as this will be used to scale the MIAS data properly
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Mass Train All Mask JPEGs Full"

mass_train_mask_sizes = get_mask_sizes(mask_dir, output=False)

# %%
print("Mean ROI Radius Mass Train Data:", np.mean(mass_train_mask_sizes))
print("Median ROI Radius Mass Train Data:", np.median(mass_train_mask_sizes))
print("Min ROI Radius Mass Train Data:", np.min(mass_train_mask_sizes))
print("Max ROI Radius Mass Train Data:", np.max(mass_train_mask_sizes))
# Out:
# Mean ROI Radius Mass Train Data: 176.38161106590724
# Median ROI Radius Mass Train Data: 159.0
# Min ROI Radius Mass Train Data: 56
# Max ROI Radius Mass Train Data: 681

# %%
## go through the directories and crop out the ROI from the full image using the mask
mask_dir = "D:\\Documents\\Mammography\\CBIS-DDSM\\Calc Train All Mask JPEGs Full"

calc_train_mask_sizes = get_mask_sizes(mask_dir, output=False)

# %%
print("Mean ROI Radius Calc Train Data:", np.mean(calc_train_mask_sizes))
print("Median ROI Radius Calc Train Data:", np.median(calc_train_mask_sizes))
print("Min ROI Radius Calc Train Data:", np.min(calc_train_mask_sizes))
print("Max ROI Radius Calc Train Data:", np.max(calc_train_mask_sizes))
# Out:
# Mean ROI Radius Calc Train Data: 271.4922575387123
# Median ROI Radius Calc Train Data: 184.0
# Min ROI Radius Calc Train Data: 20
# Max ROI Radius Calc Train Data: 1899

# %%
all_mask_sizes = np.concatenate([mass_train_mask_sizes, calc_train_mask_sizes], axis=0)
                                 
print("Mean ROI Radius All Train Data:", np.mean(all_mask_sizes))
print("Median ROI Radius All Train Data:", np.median(all_mask_sizes))
print("Min ROI Radius All Train Data:", np.min(all_mask_sizes))
print("Max ROI Radius All Train Data:", np.max(all_mask_sizes))
# Out:
# Mean ROI Radius All Train Data: 223.89820846905536
# Median ROI Radius All Train Data: 167.0
# Min ROI Radius All Train Data: 20
# Max ROI Radius All Train Data: 1899

# %% [markdown]
# <b>Compare to MIAS Data:</b><br>
# Mean abnormality radius: 50.57657657657658<br>
# Median abnormality radius: 41.0<br>
# Min abnormality radius: 3.0<br>
# Max abnormality radius: 197.0<br>

# %%
plt.hist(all_mask_sizes, bins=range(0, 1750, 100))
plt.title("DDSM Mass Radii")
plt.show()

# %% [markdown]
# <b>Compare to MIAS Radii</b>
# <img align="left" src="data:image/png;base64,...">

# %% [markdown]
# I am going to use an estimate of four to convert from the MIAS to DDSM data, as far as abnormality radii, so the MIAS data slices will be zoomed in by 4x to make them equivalent to the DDSM slices.
