# %%
import PIL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import chain
import math
import random
import os
from scipy.misc import imresize
from mammo_utils import remove_white_from_image, slice_normal_image, create_slices, read_pgm, get_roi_edges, get_fuzzy_offset, get_roi_edges, random_flip_image, progress, extract_slice
# %matplotlib inline

# %% [markdown]
# This notebook attempts to slice the MIAS images in the same way as the DDSM and CBIS-DDSM images were sliced, so that the models can be evaluated on the MIAS data. The code that could not be directly reused was cut-and-pasted with as little modfication as possible to maintain consistency.

# %%
def get_image_class(df, idx):
     # get the name of the image from the data
    img_name = df.loc[idx]['path']
    severity = df.loc[idx]['SEVERITY']
    img_class = df.loc[idx]['CLASS']
    
    if severity == "M":
        img_label = "MALIGNANT_"
        if img_class == "NORM":
            img_label = "NORMAL"
        elif img_class == "CALC":
            img_label = img_label + "calcification"
        else:
            img_label = img_label + "mass"
    elif severity == "B":
        img_label = "BENIGN_"
        if img_class == "CALC":
            img_label = img_label + "calcification"
        elif img_class == "NORM":
            img_label = "NORMAL"
        else:
            img_label = img_label + "mass"
    else:
        img_label = "NORMAL"
    
    return img_label

def trim_image_margins(img):
    img_h = img.shape[0]
    img_w = img.shape[1]
    
    # get which columns are all black
    black_pixels = np.sum(img == 0, axis=0)
    
    blank_cols = (black_pixels >= (img_h - 10))
    
    # first trim from the left
    first_col = np.argmax(~blank_cols)
    
    # now trim from the right
    last_col = img_w - np.argmax(~np.flip(blank_cols, axis=0))
    #last_col = 0
    
    img = img[:,first_col:last_col]
    
    return img, first_col, last_col
    
def get_random_scale(scale_by):
    # get the random factor
    random_scale_by = np.random.normal(loc=scale_by, scale=(scale_by * 0.4), size=None)
    
    # if the scale by is within a range return it, else keep trying until it is within the range
    if (random_scale_by > 1.5) and (random_scale_by < 2.75):
        return random_scale_by
    else:
        return get_random_scale(scale_by)
    
## Copy of function used to crop cbis images, but altered to deal with MIAS images
## returns: numpy array of images and list of corresponding file names
def create_mias_slices(df, pgm_dir="E:\\Documents\\Mammography\\MIAS\\pgms\\", scale_by=2.2, slice_size=299, var_upper_threshold=2000, var_lower_threshold=20, mean_threshold=38, debug=None):
    # loop through rows in the data frame
    slices_list = []
    image_names_list = []
    labels_list = []
    full_slice_size = slice_size
    
    counter = 0
    if debug is None:
        progress(counter, len(df), 'WORKING')
    
    for index, row in all_cases_df.iterrows():
        
        # get the base file name from the mask name
        image_name = row['path']
        
        # create a progress bar
        counter += 1
        if debug is None:
            progress(counter,  len(df), image_name)
            
        # try to open the image, if it doesn't exist continue
        try:
            full_image_arr = read_pgm(pgm_dir + image_name)
        except:
            print(image_name, "file not found!")
            continue       
        
        # get rid of the extra dimensions with unneccessary info
        image_h, image_w = full_image_arr.shape
        
        ## let's try extracting the ROI at size and then scaling it after it's been extracted
        # scale the image up by scale_by so it's on the same scale as the CBIS images
#         new_size = int(image_h * random_scale_by)
#         full_image_arr = imresize(full_image_arr, (new_size, new_size))

        # get the new shape of the image
        image_h, image_w = full_image_arr.shape
            
        # get the class of the image
        image_class = get_image_class(df, index)
        if debug is True:
            print(image_name, image_class)
        
        # if the image is abnormal
        if image_class != "NORMAL":            
            if debug is True:
                print(image_name, "abnormal")
            
            # if the image doesn't have ROI data skip it
            if np.isnan(row['X']):
                continue
            
            # get the size and shape of the ROI, NOT offset by the number of columns trimmed off
            center_col = int(row['X'])# * scale_by)
            center_row = image_h - int(row['Y'])# * scale_by)

            # the ROI is square so we don't need to get the sizes individually
            roi_size = mask_height = mask_width = mask_size = row['RADIUS'] * scale_by

            #####################################################################################
            ## extract the ROI with context size equal to double ROI size and random augmentation
            if debug:
                print("Adding ROI at size", image_name)

            img_slice = extract_slice(full_image_arr, center_col, center_row, roi_size, padding=1.2, context_scale=2, return_slice_size=299, distort=False)

            if img_slice.shape == (299,299, 1):
                slices_list.append(img_slice)
                image_names_list.append(image_name)
                labels_list.append(image_class)

            ####################################################################################
            ## Extract the ROI with a smaller margins
            img_slice = extract_slice(full_image_arr, center_col, center_row, roi_size, padding=1.3, context_scale=1.5, return_slice_size=299, distort=False)

            if img_slice.shape == (299,299, 1):
                slices_list.append(img_slice)
                image_names_list.append(image_name)
                labels_list.append(image_class)

            # if the slice is the right shape add it to the list
            if img_slice.shape == (slice_size,slice_size):
                slices_list.append(random_flip_image(img_slice.reshape(slice_size,slice_size,1)))
                image_names_list.append(image_name)
                labels_list.append(image_class)
            elif debug is not None:
                print("Actual size slice is wrong shape", image_name)
                
        ## ELse if the image is normal
        else:
            if debug is not None:
                print(image_name, " creating tiles")
            
            ## now we have to resize the image so the normal tiles are on the same scale
            new_size = int(image_h * scale_by)
            full_image_arr = imresize(full_image_arr, (new_size, new_size))
            
            # remove the margins
            full_image_arr, _, _ = trim_image_margins(full_image_arr)
            
            # slice the image into 299x299 tiles
            size = 299
            stride = 200
            tiles = [full_image_arr[x:x+size,y:y+size] for x in range(0,full_image_arr.shape[0],stride) for y in range(0,full_image_arr.shape[1],stride)]
            usable_tiles = []

            # for each tile:
            for i in range(len(tiles)):
                # make sure tile has correct shape
                if tiles[i].shape == (size,size):
                    # make sure the tile doesn't have too many white or black pixels, that indicates it is not useful
                    if (np.sum(np.sum(tiles[i] >= 225)) < 100) and (np.sum(np.sum(tiles[i] <= 20)) <= 50000):
                        # make sure tile has stuff in it
                        if np.mean(tiles[i]) >= mean_threshold:
                            # make sure the tile contains image and not mostly empty space
                            if np.var(tiles[i]) <= var_upper_threshold:
                                if np.var(tiles[i]) >= var_lower_threshold:
                                    # flip a coin to decide whether to include the tile
                                    coin = np.random.binomial(1, 0.3)
                                    if coin:
                                        # reshape the tile so they will work with the convnet
                                        slices_list.append(random_flip_image(tiles[i].reshape(299,299,1)))
                                        image_names_list.append(image_name)
                                        labels_list.append(image_class)

    return np.array(slices_list), np.array(labels_list), image_names_list

# %%
# import and clean the annotation data, this time leave the duplicates
all_cases_df = pd.read_table('data/Info.txt', delimiter=' ')
all_cases_df = all_cases_df[all_cases_df.columns[:-1]] # drop last column
all_cases_df['path'] = all_cases_df['REFNUM'].map(lambda x: '%s.pgm' % x)

# %%
slices, labels, filenames = create_mias_slices(all_cases_df, debug=True)
# Out:
# mdb001.pgm BENIGN_mass
# mdb001.pgm abnormal
# Adding ROI at size mdb001.pgm
# Actual size slice is wrong shape mdb001.pgm
# mdb002.pgm BENIGN_mass
# mdb002.pgm abnormal
# Adding ROI at size mdb002.pgm
# Actual size slice is wrong shape mdb002.pgm
# mdb003.pgm NORMAL
# mdb003.pgm  creating tiles
# mdb004.pgm NORMAL
# mdb004.pgm  creating tiles
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# mdb005.pgm BENIGN_mass
# mdb005.pgm abnormal
# Adding ROI at size mdb005.pgm
# Actual size slice is wrong shape mdb005.pgm
# mdb005.pgm BENIGN_mass
# mdb005.pgm abnormal
# Adding ROI at size mdb005.pgm
# Actual size slice is wrong shape mdb005.pgm
# mdb006.pgm NORMAL
# mdb006.pgm  creating tiles
# mdb007.pgm NORMAL
# mdb007.pgm  creating tiles
# mdb008.pgm NORMAL
# mdb008.pgm  creating tiles
# mdb009.pgm NORMAL
# mdb009.pgm  creating tiles
# mdb010.pgm BENIGN_mass
# mdb010.pgm abnormal
# Adding ROI at size mdb010.pgm
# Actual size slice is wrong shape mdb010.pgm
# mdb011.pgm NORMAL
# mdb011.pgm  creating tiles
# mdb012.pgm BENIGN_mass
# mdb012.pgm abnormal
# Adding ROI at size mdb012.pgm
# Actual size slice is wrong shape mdb012.pgm
# mdb013.pgm BENIGN_mass
# mdb013.pgm abnormal
# Adding ROI at size mdb013.pgm
# Actual size slice is wrong shape mdb013.pgm
# mdb014.pgm NORMAL
# mdb014.pgm  creating tiles
# mdb015.pgm BENIGN_mass
# mdb015.pgm abnormal
# Adding ROI at size mdb015.pgm
# Actual size slice is wrong shape mdb015.pgm
# mdb016.pgm NORMAL
# mdb016.pgm  creating tiles
# mdb017.pgm BENIGN_mass
# mdb017.pgm abnormal
# Adding ROI at size mdb017.pgm
# Actual size slice is wrong shape mdb017.pgm
# mdb018.pgm NORMAL
# mdb018.pgm  creating tiles
# mdb019.pgm BENIGN_mass
# mdb019.pgm abnormal
# Adding ROI at size mdb019.pgm
# Actual size slice is wrong shape mdb019.pgm
# mdb020.pgm NORMAL
# mdb020.pgm  creating tiles
# mdb021.pgm BENIGN_mass
# mdb021.pgm abnormal
# Adding ROI at size mdb021.pgm
# Actual size slice is wrong shape mdb021.pgm
# mdb022.pgm NORMAL
# mdb022.pgm  creating tiles
# mdb023.pgm MALIGNANT_mass
# mdb023.pgm abnormal
# Adding ROI at size mdb023.pgm
# Actual size slice is wrong shape mdb023.pgm
# mdb024.pgm NORMAL
# mdb024.pgm  creating tiles
# mdb025.pgm BENIGN_mass
# mdb025.pgm abnormal
# Adding ROI at size mdb025.pgm
# Actual size slice is wrong shape mdb025.pgm
# mdb026.pgm NORMAL
# mdb026.pgm  creating tiles
# mdb027.pgm NORMAL
# mdb027.pgm  creating tiles
# mdb028.pgm MALIGNANT_mass
# mdb028.pgm abnormal
# Adding ROI at size mdb028.pgm
# Actual size slice is wrong shape mdb028.pgm
# mdb029.pgm NORMAL
# mdb029.pgm  creating tiles
# mdb030.pgm BENIGN_mass
# mdb030.pgm abnormal
# Adding ROI at size mdb030.pgm
# Actual size slice is wrong shape mdb030.pgm
# mdb031.pgm NORMAL
# mdb031.pgm  creating tiles
# mdb032.pgm BENIGN_mass
# mdb032.pgm abnormal
# Adding ROI at size mdb032.pgm
# Actual size slice is wrong shape mdb032.pgm
# mdb033.pgm NORMAL
# mdb033.pgm  creating tiles
# mdb034.pgm NORMAL
# mdb034.pgm  creating tiles
# mdb035.pgm NORMAL
# mdb035.pgm  creating tiles
# mdb036.pgm NORMAL
# mdb036.pgm  creating tiles
# mdb037.pgm NORMAL
# mdb037.pgm  creating tiles
# mdb038.pgm NORMAL
# mdb038.pgm  creating tiles
# mdb039.pgm NORMAL
# mdb039.pgm  creating tiles
# mdb040.pgm NORMAL
# mdb040.pgm  creating tiles
# mdb041.pgm NORMAL
# mdb041.pgm  creating tiles
# mdb042.pgm NORMAL
# mdb042.pgm  creating tiles
# mdb043.pgm NORMAL
# mdb043.pgm  creating tiles
# mdb044.pgm NORMAL
# mdb044.pgm  creating tiles
# mdb045.pgm NORMAL
# mdb045.pgm  creating tiles
# mdb046.pgm NORMAL
# mdb046.pgm  creating tiles
# mdb047.pgm NORMAL
# mdb047.pgm  creating tiles
# mdb048.pgm NORMAL
# mdb048.pgm  creating tiles
# mdb049.pgm NORMAL
# mdb049.pgm  creating tiles
# mdb050.pgm NORMAL
# mdb050.pgm  creating tiles
# mdb051.pgm NORMAL
# mdb051.pgm  creating tiles
# mdb052.pgm NORMAL
# mdb052.pgm  creating tiles
# mdb053.pgm NORMAL
# mdb053.pgm  creating tiles
# mdb054.pgm NORMAL
# mdb054.pgm  creating tiles
# mdb055.pgm NORMAL
# mdb055.pgm  creating tiles
# mdb056.pgm NORMAL
# mdb056.pgm  creating tiles
# mdb057.pgm NORMAL
# mdb057.pgm  creating tiles
# mdb058.pgm MALIGNANT_mass
# mdb058.pgm abnormal
# Adding ROI at size mdb058.pgm
# Actual size slice is wrong shape mdb058.pgm
# mdb059.pgm BENIGN_mass
# mdb059.pgm abnormal
# mdb060.pgm NORMAL
# mdb060.pgm  creating tiles
# mdb061.pgm NORMAL
# mdb061.pgm  creating tiles
# mdb062.pgm NORMAL
# mdb062.pgm  creating tiles
# mdb063.pgm BENIGN_mass
# mdb063.pgm abnormal
# Adding ROI at size mdb063.pgm
# Actual size slice is wrong shape mdb063.pgm
# mdb064.pgm NORMAL
# mdb064.pgm  creating tiles
# mdb065.pgm NORMAL
# mdb065.pgm  creating tiles
# mdb066.pgm NORMAL
# mdb066.pgm  creating tiles
# mdb067.pgm NORMAL
# mdb067.pgm  creating tiles
# mdb068.pgm NORMAL
# mdb068.pgm  creating tiles
# mdb069.pgm BENIGN_mass
# mdb069.pgm abnormal
# Adding ROI at size mdb069.pgm
# Actual size slice is wrong shape mdb069.pgm
# mdb070.pgm NORMAL
# mdb070.pgm  creating tiles
# mdb071.pgm NORMAL
# mdb071.pgm  creating tiles
# mdb072.pgm MALIGNANT_mass
# mdb072.pgm abnormal
# Adding ROI at size mdb072.pgm
# Actual size slice is wrong shape mdb072.pgm
# mdb073.pgm NORMAL
# mdb073.pgm  creating tiles
# mdb074.pgm NORMAL
# mdb074.pgm  creating tiles
# mdb075.pgm MALIGNANT_mass
# mdb075.pgm abnormal
# Adding ROI at size mdb075.pgm
# Actual size slice is wrong shape mdb075.pgm
# mdb076.pgm NORMAL
# mdb076.pgm  creating tiles
# mdb077.pgm NORMAL
# mdb077.pgm  creating tiles
# mdb078.pgm NORMAL
# mdb078.pgm  creating tiles
# mdb079.pgm NORMAL
# mdb079.pgm  creating tiles
# mdb080.pgm BENIGN_mass
# mdb080.pgm abnormal
# Adding ROI at size mdb080.pgm
# Actual size slice is wrong shape mdb080.pgm
# mdb081.pgm BENIGN_mass
# mdb081.pgm abnormal
# Adding ROI at size mdb081.pgm
# Actual size slice is wrong shape mdb081.pgm
# mdb082.pgm NORMAL
# mdb082.pgm  creating tiles
# mdb083.pgm BENIGN_mass
# mdb083.pgm abnormal
# Adding ROI at size mdb083.pgm
# Actual size slice is wrong shape mdb083.pgm
# mdb084.pgm NORMAL
# mdb084.pgm  creating tiles
# mdb085.pgm NORMAL
# mdb085.pgm  creating tiles
# mdb086.pgm NORMAL
# mdb086.pgm  creating tiles
# mdb087.pgm NORMAL
# mdb087.pgm  creating tiles
# mdb088.pgm NORMAL
# mdb088.pgm  creating tiles
# mdb089.pgm NORMAL
# mdb089.pgm  creating tiles
# mdb090.pgm MALIGNANT_mass
# mdb090.pgm abnormal
# Adding ROI at size mdb090.pgm
# Actual size slice is wrong shape mdb090.pgm
# mdb091.pgm BENIGN_mass
# mdb091.pgm abnormal
# Adding ROI at size mdb091.pgm
# Actual size slice is wrong shape mdb091.pgm
# mdb092.pgm MALIGNANT_mass
# mdb092.pgm abnormal
# Adding ROI at size mdb092.pgm
# Actual size slice is wrong shape mdb092.pgm
# mdb093.pgm NORMAL
# mdb093.pgm  creating tiles
# mdb094.pgm NORMAL
# mdb094.pgm  creating tiles
# mdb095.pgm MALIGNANT_mass
# mdb095.pgm abnormal
# Adding ROI at size mdb095.pgm
# Actual size slice is wrong shape mdb095.pgm
# mdb096.pgm NORMAL
# mdb096.pgm  creating tiles
# mdb097.pgm BENIGN_mass
# mdb097.pgm abnormal
# Adding ROI at size mdb097.pgm
# Actual size slice is wrong shape mdb097.pgm
# mdb098.pgm NORMAL
# mdb098.pgm  creating tiles
# mdb099.pgm BENIGN_mass
# mdb099.pgm abnormal
# Adding ROI at size mdb099.pgm
# Actual size slice is wrong shape mdb099.pgm
# mdb100.pgm NORMAL
# mdb100.pgm  creating tiles
# mdb101.pgm NORMAL
# mdb101.pgm  creating tiles
# mdb102.pgm MALIGNANT_mass
# mdb102.pgm abnormal
# Adding ROI at size mdb102.pgm
# Actual size slice is wrong shape mdb102.pgm
# mdb103.pgm NORMAL
# mdb103.pgm  creating tiles
# mdb104.pgm BENIGN_mass
# mdb104.pgm abnormal
# Adding ROI at size mdb104.pgm
# Actual size slice is wrong shape mdb104.pgm
# mdb105.pgm MALIGNANT_mass
# mdb105.pgm abnormal
# Adding ROI at size mdb105.pgm
# Actual size slice is wrong shape mdb105.pgm
# mdb106.pgm NORMAL
# mdb106.pgm  creating tiles
# mdb107.pgm BENIGN_mass
# mdb107.pgm abnormal
# Adding ROI at size mdb107.pgm
# Actual size slice is wrong shape mdb107.pgm
# mdb108.pgm NORMAL
# mdb108.pgm  creating tiles
# mdb109.pgm NORMAL
# mdb109.pgm  creating tiles
# mdb110.pgm MALIGNANT_mass
# mdb110.pgm abnormal
# Adding ROI at size mdb110.pgm
# Actual size slice is wrong shape mdb110.pgm
# mdb111.pgm MALIGNANT_mass
# mdb111.pgm abnormal
# Adding ROI at size mdb111.pgm
# Actual size slice is wrong shape mdb111.pgm
# mdb112.pgm NORMAL
# mdb112.pgm  creating tiles
# mdb113.pgm NORMAL
# mdb113.pgm  creating tiles
# mdb114.pgm NORMAL
# mdb114.pgm  creating tiles
# mdb115.pgm MALIGNANT_mass
# mdb115.pgm abnormal
# Adding ROI at size mdb115.pgm
# Actual size slice is wrong shape mdb115.pgm
# mdb116.pgm NORMAL
# mdb116.pgm  creating tiles
# mdb117.pgm MALIGNANT_mass
# mdb117.pgm abnormal
# Adding ROI at size mdb117.pgm
# Actual size slice is wrong shape mdb117.pgm
# mdb118.pgm NORMAL
# mdb118.pgm  creating tiles
# mdb119.pgm NORMAL
# mdb119.pgm  creating tiles
# mdb120.pgm MALIGNANT_mass
# mdb120.pgm abnormal
# Adding ROI at size mdb120.pgm
# Actual size slice is wrong shape mdb120.pgm
# mdb121.pgm BENIGN_mass
# mdb121.pgm abnormal
# Adding ROI at size mdb121.pgm
# Actual size slice is wrong shape mdb121.pgm
# mdb122.pgm NORMAL
# mdb122.pgm  creating tiles
# mdb123.pgm NORMAL
# mdb123.pgm  creating tiles
# mdb124.pgm MALIGNANT_mass
# mdb124.pgm abnormal
# Adding ROI at size mdb124.pgm
# Actual size slice is wrong shape mdb124.pgm
# mdb125.pgm MALIGNANT_mass
# mdb125.pgm abnormal
# Adding ROI at size mdb125.pgm
# Actual size slice is wrong shape mdb125.pgm
# mdb126.pgm BENIGN_mass
# mdb126.pgm abnormal
# Adding ROI at size mdb126.pgm
# Actual size slice is wrong shape mdb126.pgm
# mdb127.pgm BENIGN_mass
# mdb127.pgm abnormal
# Adding ROI at size mdb127.pgm
# Actual size slice is wrong shape mdb127.pgm
# mdb128.pgm NORMAL
# mdb128.pgm  creating tiles
# mdb129.pgm NORMAL
# mdb129.pgm  creating tiles
# mdb130.pgm MALIGNANT_mass
# mdb130.pgm abnormal
# Adding ROI at size mdb130.pgm
# Actual size slice is wrong shape mdb130.pgm
# mdb131.pgm NORMAL
# mdb131.pgm  creating tiles
# mdb132.pgm BENIGN_mass
# mdb132.pgm abnormal
# Adding ROI at size mdb132.pgm
# Actual size slice is wrong shape mdb132.pgm
# mdb132.pgm BENIGN_mass
# mdb132.pgm abnormal
# Adding ROI at size mdb132.pgm
# Actual size slice is wrong shape mdb132.pgm
# mdb133.pgm NORMAL
# mdb133.pgm  creating tiles
# mdb134.pgm MALIGNANT_mass
# mdb134.pgm abnormal
# Adding ROI at size mdb134.pgm
# Actual size slice is wrong shape mdb134.pgm
# mdb135.pgm NORMAL
# mdb135.pgm  creating tiles
# mdb136.pgm NORMAL
# mdb136.pgm  creating tiles
# mdb137.pgm NORMAL
# mdb137.pgm  creating tiles
# mdb138.pgm NORMAL
# mdb138.pgm  creating tiles
# mdb139.pgm NORMAL
# mdb139.pgm  creating tiles
# mdb140.pgm NORMAL
# mdb140.pgm  creating tiles
# mdb141.pgm MALIGNANT_mass
# mdb141.pgm abnormal
# Adding ROI at size mdb141.pgm
# Actual size slice is wrong shape mdb141.pgm
# mdb142.pgm BENIGN_mass
# mdb142.pgm abnormal
# Adding ROI at size mdb142.pgm
# Actual size slice is wrong shape mdb142.pgm
# mdb143.pgm NORMAL
# mdb143.pgm  creating tiles
# mdb144.pgm BENIGN_mass
# mdb144.pgm abnormal
# Adding ROI at size mdb144.pgm
# Actual size slice is wrong shape mdb144.pgm
# mdb144.pgm MALIGNANT_mass
# mdb144.pgm abnormal
# Adding ROI at size mdb144.pgm
# Actual size slice is wrong shape mdb144.pgm
# mdb145.pgm BENIGN_mass
# mdb145.pgm abnormal
# Adding ROI at size mdb145.pgm
# Actual size slice is wrong shape mdb145.pgm
# mdb146.pgm NORMAL
# mdb146.pgm  creating tiles
# mdb147.pgm NORMAL
# mdb147.pgm  creating tiles
# mdb148.pgm MALIGNANT_mass
# mdb148.pgm abnormal
# Adding ROI at size mdb148.pgm
# Actual size slice is wrong shape mdb148.pgm
# mdb149.pgm NORMAL
# mdb149.pgm  creating tiles
# mdb150.pgm BENIGN_mass
# mdb150.pgm abnormal
# Adding ROI at size mdb150.pgm
# Actual size slice is wrong shape mdb150.pgm
# mdb151.pgm NORMAL
# mdb151.pgm  creating tiles
# mdb152.pgm BENIGN_mass
# mdb152.pgm abnormal
# Adding ROI at size mdb152.pgm
# Actual size slice is wrong shape mdb152.pgm
# mdb153.pgm NORMAL
# mdb153.pgm  creating tiles
# mdb154.pgm NORMAL
# mdb154.pgm  creating tiles
# mdb155.pgm MALIGNANT_mass
# mdb155.pgm abnormal
# Adding ROI at size mdb155.pgm
# Actual size slice is wrong shape mdb155.pgm
# mdb156.pgm NORMAL
# mdb156.pgm  creating tiles
# mdb157.pgm NORMAL
# mdb157.pgm  creating tiles
# mdb158.pgm MALIGNANT_mass
# mdb158.pgm abnormal
# Adding ROI at size mdb158.pgm
# Actual size slice is wrong shape mdb158.pgm
# mdb159.pgm NORMAL
# mdb159.pgm  creating tiles
# mdb160.pgm BENIGN_mass
# mdb160.pgm abnormal
# Adding ROI at size mdb160.pgm
# Actual size slice is wrong shape mdb160.pgm
# mdb161.pgm NORMAL
# mdb161.pgm  creating tiles
# mdb162.pgm NORMAL
# mdb162.pgm  creating tiles
# mdb163.pgm BENIGN_mass
# mdb163.pgm abnormal
# Adding ROI at size mdb163.pgm
# Actual size slice is wrong shape mdb163.pgm
# mdb164.pgm NORMAL
# mdb164.pgm  creating tiles
# mdb165.pgm BENIGN_mass
# mdb165.pgm abnormal
# Adding ROI at size mdb165.pgm
# Actual size slice is wrong shape mdb165.pgm
# mdb166.pgm NORMAL
# mdb166.pgm  creating tiles
# mdb167.pgm BENIGN_mass
# mdb167.pgm abnormal
# Adding ROI at size mdb167.pgm
# Actual size slice is wrong shape mdb167.pgm
# mdb168.pgm NORMAL
# mdb168.pgm  creating tiles
# mdb169.pgm NORMAL
# mdb169.pgm  creating tiles
# mdb170.pgm MALIGNANT_mass
# mdb170.pgm abnormal
# Adding ROI at size mdb170.pgm
# Actual size slice is wrong shape mdb170.pgm
# mdb171.pgm MALIGNANT_mass
# mdb171.pgm abnormal
# Adding ROI at size mdb171.pgm
# Actual size slice is wrong shape mdb171.pgm
# mdb172.pgm NORMAL
# mdb172.pgm  creating tiles
# mdb173.pgm NORMAL
# mdb173.pgm  creating tiles
# mdb174.pgm NORMAL
# mdb174.pgm  creating tiles
# mdb175.pgm BENIGN_mass
# mdb175.pgm abnormal
# Adding ROI at size mdb175.pgm
# Actual size slice is wrong shape mdb175.pgm
# mdb176.pgm NORMAL
# mdb176.pgm  creating tiles
# mdb177.pgm NORMAL
# mdb177.pgm  creating tiles
# mdb178.pgm MALIGNANT_mass
# mdb178.pgm abnormal
# Adding ROI at size mdb178.pgm
# Actual size slice is wrong shape mdb178.pgm
# mdb179.pgm MALIGNANT_mass
# mdb179.pgm abnormal
# Adding ROI at size mdb179.pgm
# Actual size slice is wrong shape mdb179.pgm
# mdb180.pgm NORMAL
# mdb180.pgm  creating tiles
# mdb181.pgm MALIGNANT_mass
# mdb181.pgm abnormal
# Adding ROI at size mdb181.pgm
# Actual size slice is wrong shape mdb181.pgm
# mdb182.pgm NORMAL
# mdb182.pgm  creating tiles
# mdb183.pgm NORMAL
# mdb183.pgm  creating tiles
# mdb184.pgm MALIGNANT_mass
# mdb184.pgm abnormal
# Adding ROI at size mdb184.pgm
# Actual size slice is wrong shape mdb184.pgm
# mdb185.pgm NORMAL
# mdb185.pgm  creating tiles
# mdb186.pgm MALIGNANT_mass
# mdb186.pgm abnormal
# Adding ROI at size mdb186.pgm
# Actual size slice is wrong shape mdb186.pgm
# mdb187.pgm NORMAL
# mdb187.pgm  creating tiles
# mdb188.pgm BENIGN_mass
# mdb188.pgm abnormal
# Adding ROI at size mdb188.pgm
# Actual size slice is wrong shape mdb188.pgm
# mdb189.pgm NORMAL
# mdb189.pgm  creating tiles
# mdb190.pgm BENIGN_mass
# mdb190.pgm abnormal
# Adding ROI at size mdb190.pgm
# Actual size slice is wrong shape mdb190.pgm
# mdb191.pgm BENIGN_mass
# mdb191.pgm abnormal
# Adding ROI at size mdb191.pgm
# Actual size slice is wrong shape mdb191.pgm
# mdb192.pgm NORMAL
# mdb192.pgm  creating tiles
# mdb193.pgm BENIGN_mass
# mdb193.pgm abnormal
# Adding ROI at size mdb193.pgm
# Actual size slice is wrong shape mdb193.pgm
# mdb194.pgm NORMAL
# mdb194.pgm  creating tiles
# mdb195.pgm BENIGN_mass
# mdb195.pgm abnormal
# Adding ROI at size mdb195.pgm
# Actual size slice is wrong shape mdb195.pgm
# mdb196.pgm NORMAL
# mdb196.pgm  creating tiles
# mdb197.pgm NORMAL
# mdb197.pgm  creating tiles
# mdb198.pgm BENIGN_mass
# mdb198.pgm abnormal
# Adding ROI at size mdb198.pgm
# Actual size slice is wrong shape mdb198.pgm
# mdb199.pgm BENIGN_mass
# mdb199.pgm abnormal
# Adding ROI at size mdb199.pgm
# Actual size slice is wrong shape mdb199.pgm
# mdb200.pgm NORMAL
# mdb200.pgm  creating tiles
# mdb201.pgm NORMAL
# mdb201.pgm  creating tiles
# mdb202.pgm MALIGNANT_mass
# mdb202.pgm abnormal
# Adding ROI at size mdb202.pgm
# Actual size slice is wrong shape mdb202.pgm
# mdb203.pgm NORMAL
# mdb203.pgm  creating tiles
# mdb204.pgm BENIGN_mass
# mdb204.pgm abnormal
# Adding ROI at size mdb204.pgm
# Actual size slice is wrong shape mdb204.pgm
# mdb205.pgm NORMAL
# mdb205.pgm  creating tiles
# mdb206.pgm MALIGNANT_mass
# mdb206.pgm abnormal
# Adding ROI at size mdb206.pgm
# Actual size slice is wrong shape mdb206.pgm
# mdb207.pgm BENIGN_mass
# mdb207.pgm abnormal
# Adding ROI at size mdb207.pgm
# Actual size slice is wrong shape mdb207.pgm
# mdb208.pgm NORMAL
# mdb208.pgm  creating tiles
# mdb209.pgm MALIGNANT_calcification
# mdb209.pgm abnormal
# Adding ROI at size mdb209.pgm
# Actual size slice is wrong shape mdb209.pgm
# mdb210.pgm NORMAL
# mdb210.pgm  creating tiles
# mdb211.pgm MALIGNANT_calcification
# mdb211.pgm abnormal
# Adding ROI at size mdb211.pgm
# Actual size slice is wrong shape mdb211.pgm
# mdb212.pgm BENIGN_calcification
# mdb212.pgm abnormal
# Adding ROI at size mdb212.pgm
# Actual size slice is wrong shape mdb212.pgm
# mdb213.pgm MALIGNANT_calcification
# mdb213.pgm abnormal
# Adding ROI at size mdb213.pgm
# Actual size slice is wrong shape mdb213.pgm
# mdb214.pgm BENIGN_calcification
# mdb214.pgm abnormal
# Adding ROI at size mdb214.pgm
# Actual size slice is wrong shape mdb214.pgm
# mdb215.pgm NORMAL
# mdb215.pgm  creating tiles
# mdb216.pgm MALIGNANT_calcification
# mdb216.pgm abnormal
# mdb217.pgm NORMAL
# mdb217.pgm  creating tiles
# mdb218.pgm BENIGN_calcification
# mdb218.pgm abnormal
# Adding ROI at size mdb218.pgm
# Actual size slice is wrong shape mdb218.pgm
# mdb219.pgm BENIGN_calcification
# mdb219.pgm abnormal
# Adding ROI at size mdb219.pgm
# Actual size slice is wrong shape mdb219.pgm
# mdb220.pgm NORMAL
# mdb220.pgm  creating tiles
# mdb221.pgm NORMAL
# mdb221.pgm  creating tiles
# mdb222.pgm BENIGN_calcification
# mdb222.pgm abnormal
# Adding ROI at size mdb222.pgm
# Actual size slice is wrong shape mdb222.pgm
# mdb223.pgm BENIGN_calcification
# mdb223.pgm abnormal
# Adding ROI at size mdb223.pgm
# Actual size slice is wrong shape mdb223.pgm
# mdb223.pgm BENIGN_calcification
# mdb223.pgm abnormal
# Adding ROI at size mdb223.pgm
# Actual size slice is wrong shape mdb223.pgm
# mdb224.pgm NORMAL
# mdb224.pgm  creating tiles
# mdb225.pgm NORMAL
# mdb225.pgm  creating tiles
# mdb226.pgm BENIGN_calcification
# mdb226.pgm abnormal
# Adding ROI at size mdb226.pgm
# Actual size slice is wrong shape mdb226.pgm
# mdb226.pgm BENIGN_calcification
# mdb226.pgm abnormal
# Adding ROI at size mdb226.pgm
# Actual size slice is wrong shape mdb226.pgm
# mdb226.pgm BENIGN_calcification
# mdb226.pgm abnormal
# Adding ROI at size mdb226.pgm
# Actual size slice is wrong shape mdb226.pgm
# mdb227.pgm BENIGN_calcification
# mdb227.pgm abnormal
# Adding ROI at size mdb227.pgm
# Actual size slice is wrong shape mdb227.pgm
# mdb228.pgm NORMAL
# mdb228.pgm  creating tiles
# mdb229.pgm NORMAL
# mdb229.pgm  creating tiles
# mdb230.pgm NORMAL
# mdb230.pgm  creating tiles
# mdb231.pgm MALIGNANT_calcification
# mdb231.pgm abnormal
# Adding ROI at size mdb231.pgm
# Actual size slice is wrong shape mdb231.pgm
# mdb232.pgm NORMAL
# mdb232.pgm  creating tiles
# mdb233.pgm MALIGNANT_calcification
# mdb233.pgm abnormal
# mdb234.pgm NORMAL
# mdb234.pgm  creating tiles
# mdb235.pgm NORMAL
# mdb235.pgm  creating tiles
# mdb236.pgm BENIGN_calcification
# mdb236.pgm abnormal
# Adding ROI at size mdb236.pgm
# Actual size slice is wrong shape mdb236.pgm
# mdb237.pgm NORMAL
# mdb237.pgm  creating tiles
# mdb238.pgm MALIGNANT_calcification
# mdb238.pgm abnormal
# Adding ROI at size mdb238.pgm
# Actual size slice is wrong shape mdb238.pgm
# mdb239.pgm MALIGNANT_calcification
# mdb239.pgm abnormal
# Adding ROI at size mdb239.pgm
# Actual size slice is wrong shape mdb239.pgm
# mdb239.pgm MALIGNANT_calcification
# mdb239.pgm abnormal
# Adding ROI at size mdb239.pgm
# Actual size slice is wrong shape mdb239.pgm
# mdb240.pgm BENIGN_calcification
# mdb240.pgm abnormal
# Adding ROI at size mdb240.pgm
# Actual size slice is wrong shape mdb240.pgm
# mdb241.pgm MALIGNANT_calcification
# mdb241.pgm abnormal
# Adding ROI at size mdb241.pgm
# Actual size slice is wrong shape mdb241.pgm
# mdb242.pgm NORMAL
# mdb242.pgm  creating tiles
# mdb243.pgm NORMAL
# mdb243.pgm  creating tiles
# mdb244.pgm BENIGN_mass
# mdb244.pgm abnormal
# Adding ROI at size mdb244.pgm
# Actual size slice is wrong shape mdb244.pgm
# mdb245.pgm MALIGNANT_calcification
# mdb245.pgm abnormal
# mdb246.pgm NORMAL
# mdb246.pgm  creating tiles
# mdb247.pgm NORMAL
# mdb247.pgm  creating tiles
# mdb248.pgm BENIGN_calcification
# mdb248.pgm abnormal
# Adding ROI at size mdb248.pgm
# Actual size slice is wrong shape mdb248.pgm
# mdb249.pgm MALIGNANT_calcification
# mdb249.pgm abnormal
# Adding ROI at size mdb249.pgm
# Actual size slice is wrong shape mdb249.pgm
# mdb249.pgm MALIGNANT_calcification
# mdb249.pgm abnormal
# Adding ROI at size mdb249.pgm
# Actual size slice is wrong shape mdb249.pgm
# mdb250.pgm NORMAL
# mdb250.pgm  creating tiles
# mdb251.pgm NORMAL
# mdb251.pgm  creating tiles
# mdb252.pgm BENIGN_calcification
# mdb252.pgm abnormal
# Adding ROI at size mdb252.pgm
# Actual size slice is wrong shape mdb252.pgm
# mdb253.pgm MALIGNANT_calcification
# mdb253.pgm abnormal
# Adding ROI at size mdb253.pgm
# Actual size slice is wrong shape mdb253.pgm
# mdb254.pgm NORMAL
# mdb254.pgm  creating tiles
# mdb255.pgm NORMAL
# mdb255.pgm  creating tiles
# mdb256.pgm MALIGNANT_calcification
# mdb256.pgm abnormal
# Adding ROI at size mdb256.pgm
# Actual size slice is wrong shape mdb256.pgm
# mdb257.pgm NORMAL
# mdb257.pgm  creating tiles
# mdb258.pgm NORMAL
# mdb258.pgm  creating tiles
# mdb259.pgm NORMAL
# mdb259.pgm  creating tiles
# mdb260.pgm NORMAL
# mdb260.pgm  creating tiles
# mdb261.pgm NORMAL
# mdb261.pgm  creating tiles
# mdb262.pgm NORMAL
# mdb262.pgm  creating tiles
# mdb263.pgm NORMAL
# mdb263.pgm  creating tiles
# mdb264.pgm MALIGNANT_mass
# mdb264.pgm abnormal
# Adding ROI at size mdb264.pgm
# Actual size slice is wrong shape mdb264.pgm
# mdb265.pgm MALIGNANT_mass
# mdb265.pgm abnormal
# Adding ROI at size mdb265.pgm
# Actual size slice is wrong shape mdb265.pgm
# mdb266.pgm NORMAL
# mdb266.pgm  creating tiles
# mdb267.pgm MALIGNANT_mass
# mdb267.pgm abnormal
# Adding ROI at size mdb267.pgm
# Actual size slice is wrong shape mdb267.pgm
# mdb268.pgm NORMAL
# mdb268.pgm  creating tiles
# mdb269.pgm NORMAL
# mdb269.pgm  creating tiles
# mdb270.pgm MALIGNANT_mass
# mdb270.pgm abnormal
# Adding ROI at size mdb270.pgm
# Actual size slice is wrong shape mdb270.pgm
# mdb271.pgm MALIGNANT_mass
# mdb271.pgm abnormal
# Adding ROI at size mdb271.pgm
# Actual size slice is wrong shape mdb271.pgm
# mdb272.pgm NORMAL
# mdb272.pgm  creating tiles
# mdb273.pgm NORMAL
# mdb273.pgm  creating tiles
# mdb274.pgm MALIGNANT_mass
# mdb274.pgm abnormal
# Adding ROI at size mdb274.pgm
# Actual size slice is wrong shape mdb274.pgm
# mdb275.pgm NORMAL
# mdb275.pgm  creating tiles
# mdb276.pgm NORMAL
# mdb276.pgm  creating tiles
# mdb277.pgm NORMAL
# mdb277.pgm  creating tiles
# mdb278.pgm NORMAL
# mdb278.pgm  creating tiles
# mdb279.pgm NORMAL
# mdb279.pgm  creating tiles
# mdb280.pgm NORMAL
# mdb280.pgm  creating tiles
# mdb281.pgm NORMAL
# mdb281.pgm  creating tiles
# mdb282.pgm NORMAL
# mdb282.pgm  creating tiles
# mdb283.pgm NORMAL
# mdb283.pgm  creating tiles
# mdb284.pgm NORMAL
# mdb284.pgm  creating tiles
# mdb285.pgm NORMAL
# mdb285.pgm  creating tiles
# mdb286.pgm NORMAL
# mdb286.pgm  creating tiles
# mdb287.pgm NORMAL
# mdb287.pgm  creating tiles
# mdb288.pgm NORMAL
# mdb288.pgm  creating tiles
# mdb289.pgm NORMAL
# mdb289.pgm  creating tiles
# mdb290.pgm BENIGN_mass
# mdb290.pgm abnormal
# Adding ROI at size mdb290.pgm
# Actual size slice is wrong shape mdb290.pgm
# mdb291.pgm NORMAL
# mdb291.pgm  creating tiles
# mdb292.pgm NORMAL
# mdb292.pgm  creating tiles
# mdb293.pgm NORMAL
# mdb293.pgm  creating tiles
# mdb294.pgm NORMAL
# mdb294.pgm  creating tiles
# mdb295.pgm NORMAL
# mdb295.pgm  creating tiles
# mdb296.pgm NORMAL
# mdb296.pgm  creating tiles
# mdb297.pgm NORMAL
# mdb297.pgm  creating tiles
# mdb298.pgm NORMAL
# mdb298.pgm  creating tiles
# mdb299.pgm NORMAL
# mdb299.pgm  creating tiles
# mdb300.pgm NORMAL
# mdb300.pgm  creating tiles
# mdb301.pgm NORMAL
# mdb301.pgm  creating tiles
# mdb302.pgm NORMAL
# mdb302.pgm  creating tiles
# mdb303.pgm NORMAL
# mdb303.pgm  creating tiles
# mdb304.pgm NORMAL
# mdb304.pgm  creating tiles
# mdb305.pgm NORMAL
# mdb305.pgm  creating tiles
# mdb306.pgm NORMAL
# mdb306.pgm  creating tiles
# mdb307.pgm NORMAL
# mdb307.pgm  creating tiles
# mdb308.pgm NORMAL
# mdb308.pgm  creating tiles
# mdb309.pgm NORMAL
# mdb309.pgm  creating tiles
# mdb310.pgm NORMAL
# mdb310.pgm  creating tiles
# mdb311.pgm NORMAL
# mdb311.pgm  creating tiles
# mdb312.pgm BENIGN_mass
# mdb312.pgm abnormal
# Adding ROI at size mdb312.pgm
# Actual size slice is wrong shape mdb312.pgm
# mdb313.pgm NORMAL
# mdb313.pgm  creating tiles
# mdb314.pgm BENIGN_mass
# mdb314.pgm abnormal
# Adding ROI at size mdb314.pgm
# Actual size slice is wrong shape mdb314.pgm
# mdb315.pgm BENIGN_mass
# mdb315.pgm abnormal
# Adding ROI at size mdb315.pgm
# Actual size slice is wrong shape mdb315.pgm
# mdb316.pgm NORMAL
# mdb316.pgm  creating tiles
# mdb317.pgm NORMAL
# mdb317.pgm  creating tiles
# mdb318.pgm NORMAL
# mdb318.pgm  creating tiles
# mdb319.pgm NORMAL
# mdb319.pgm  creating tiles
# mdb320.pgm NORMAL
# mdb320.pgm  creating tiles
# mdb321.pgm NORMAL
# mdb321.pgm  creating tiles
# mdb322.pgm NORMAL
# mdb322.pgm  creating tiles

# %%
print("Slices:", slices.shape)
print("Labels:", labels.shape)
print("Filenames:", len(filenames))
# Out:
# Slices: (8635, 299, 299, 1)
# Labels: (8635,)
# Filenames: 8635

# %%
# look at some random images
N = 20
idxs = random.sample(range(len(slices)), k=N)

for idx in idxs:
    plt.imshow(slices[idx].reshape(299,299))
    plt.title(filenames[idx] + " - " + labels[idx] + " - idx: " + str(idx))
    plt.show()

# %%
pd.value_counts(labels, normalize=True)
# Out:
# NORMAL                     0.972438
# BENIGN_mass                0.012276
# MALIGNANT_mass             0.009033
# BENIGN_calcification       0.003474
# MALIGNANT_calcification    0.002779
# dtype: float64

# %%
# encode the labels
from sklearn import preprocessing

# load the classes used to encode the other data
classes = np.load(os.path.join("data", "all_classes.npy"))

# create the encoder
le = preprocessing.LabelEncoder()
le.fit(labels)

# we want normal to be 0, so we'll do some transformations here
labels_enc = le.transform(labels) + 1
labels_enc[labels_enc == 5] = 0

# make sure the classes match how the other labels were encoded
mias_classes = le.classes_
mias_classes = np.insert(mias_classes, 0, 'NORMAL', axis=0)
mias_classes = mias_classes[0:5]

print("MIAS Classes", mias_classes)
print("Training Classes", classes)
# Out:
# MIAS Classes ['NORMAL' 'BENIGN_calcification' 'BENIGN_mass' 'MALIGNANT_calcification'
#  'MALIGNANT_mass']
# Training Classes ['NORMAL' 'BENIGN_calcification' 'BENIGN_mass' 'MALIGNANT_calcification'
#  'MALIGNANT_mass']

# %%
## save the data
np.save(os.path.join("data", "all_mias_slices.npy"), slices)
np.save(os.path.join("data", "all_mias_labels.npy"), labels_enc)
np.save(os.path.join("data", "all_mias_filenames.npy"), filenames)
