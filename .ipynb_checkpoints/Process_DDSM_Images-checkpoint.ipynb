# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import mammo_utils
import os

# %%
## for a given path, convert all the images in the directory to an array, change all white pixels to black,
## and create an array of "NORMAL" labels, then save the images and the labels and return them
def create_normal_image_file(path, name):
    # turn images into an array
    images_array = mammo_utils.convert_images_to_array(path)[0]
    
    # remove white pixels
    images_array[images_array == 255] = 0
    
    # create the labels
    labels = np.repeat("NORMAL", images_array.shape[0])
    
    # make sure they are the same size
    assert(images_array.shape[0] == labels.shape[0])
    
    # save the data
    np.save(os.path.join("data", name + "_images.npy"), images_array)
    np.save(os.path.join("data", name + "_labels.npy"), labels)
    
    return images_array, labels

# %%
lumisys_images, lumisys_labels = create_normal_image_file("C:\\Users\\eric\\Documents\\Courses\\Applied ML 2\\mammography\\data\\new\\DDSM\\Lumisys JPEG299", name="lumisys")

# %%
print("Lumisys Images:", lumisys_images.shape)
print("Lumisys Labels:", lumisys_labels.shape)
# Out:
# Lumisys Images: (328, 299, 299)
# Lumisys Labels: (328,)

# %%
howtek_images, howtek_labels = create_normal_image_file("C:\\Users\\eric\\Documents\\Courses\\Applied ML 2\\mammography\\data\\new\\DDSM\\Howtek JPEG299", name="howtek")

# %%
print("Howtek Images:", howtek_images.shape)
print("Howtek Labels:", howtek_labels.shape)
# Out:
# Howtek Images: (551, 299, 299)
# Howtek Labels: (551,)

# %%
plt.imshow(howtek_images[400])

# %%
dba_images, dba_labels = create_normal_image_file("C:\\Users\\eric\\Documents\\Courses\\Applied ML 2\\mammography\\data\\new\\DDSM\\DBA JPEG299", name="dba")

# %%
print("DBA Images:", dba_images.shape)
print("DBA Labels:", dba_labels.shape)
# Out:
# DBA Images: (1620, 299, 299)
# DBA Labels: (1620,)

# %%
plt.imshow(dba_images[100])

# %%
dba_images[dba_images > 225] = 0
plt.imshow(dba_images[100])

# %%
# combine the images and labels together into big arrays
normal_images = np.concatenate([howtek_images, lumisys_images, dba_images], axis=0)
normal_labels = np.concatenate([howtek_labels, lumisys_labels, dba_labels], axis=0)

normal_images = normal_images.reshape([-1,299,299,1])

# %%
print("Normal Images:", normal_images.shape)
print("Normal Labels:", normal_labels.shape)
# Out:
# Normal Images: (2499, 299, 299, 1)
# Normal Labels: (2499,)

# %%
# save them
np.save(os.path.join("data","normal_images299.npy"), normal_images)
np.save(os.path.join("data","normal_labels.npy"), normal_labels)

# %%
## get all the images and combine them
train_images = np.load(os.path.join("data", "train_images299.npy"))
test_images = np.load(os.path.join("data", "test_images299.npy"))

train_labels = np.load(os.path.join("data", "train_labels.npy"))
test_labels = np.load(os.path.join("data", "test_labels.npy"))

normal_images = np.load(os.path.join("data", "normal_images299.npy"))
normal_labels = np.load(os.path.join("data", "normal_labels.npy"))

# %%
all_images = np.concatenate([train_images, test_images, normal_images], axis=0)
all_labels = np.concatenate([train_labels, test_labels, normal_labels], axis=0)

# scale the images
#all_images = (all_images - 128) / 255.0

print("All images:", all_images.shape)
print("All labels:", all_labels.shape)
# Out:
# All images: (5600, 299, 299, 1)
# All labels: (5600,)

# %%
# shuffle the data
from sklearn.utils import shuffle
all_images, all_labels = shuffle(all_images, all_labels, random_state=0)

image_batches = []
label_batches = []

# split the data into 5 batches of 1120 each
for i in range(5):
    start = i * 1120
    end = start + 1120
    image_batch = all_images[start:end]
    label_batch = all_labels[start:end]
    
    assert(image_batch.shape[0] == label_batch.shape[0])
    
    np.save(os.path.join("data", "images_" + str(i) + ".npy"), image_batch)
    np.save(os.path.join("data", "labels_" + str(i) + ".npy"), label_batch)

# %%
import tensorflow as tf
import os

def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

# %%
# convert to TF records files
train_filename = os.path.join('data','train.tfrecords')

# open the TFRecords file
writer = tf.python_io.TFRecordWriter(train_filename)

# encode the labels
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

le.fit(all_labels)
classes = le.classes_

# write training data
for i in range(4):
    # load the data and label files
    images = np.load(os.path.join("data", "images_" + str(i) + ".npy"))
    labels = np.load(os.path.join("data", "labels_" + str(i) + ".npy"))
    labels = le.transform(labels)
    
    for j in range(images.shape[0]):
        # create different labels we can choose from
        label_main = labels[j]
        
        # label as normal or abnormal
        label_normal = 1
        if label_main == 4:
            label_normal = 0
        
        # label as benign, malignant or normal
        label_pathology = 0
        if (label_main == 0) or (label_main == 1):
            label_pathology = 1
        elif (label_main == 2) or (label_main == 3):
            label_pathology = 2
            
        # label as normal, calcification or mass
        label_type = 0
        if (label_main == 0) or (label_main == 2):
            label_type = 1
        elif (label_main == 1) or (label_main == 3):
            label_type = 2
            
        img = images[j]
       
        img_raw = img.tostring()
        
        feature = {'label_class': _int64_feature(label_main),
                   'label_normal': _int64_feature(label_normal),
                   'label_pathology': _int64_feature(label_pathology),
                   'label_type': _int64_feature(label_type),
                   'image': _bytes_feature(img_raw)}
        
        # Create an example protocol buffer
        example = tf.train.Example(features=tf.train.Features(feature=feature))
    
        # Serialize to string and write on the file
        writer.write(example.SerializeToString())

writer.close()

# %%
classes
# Out:
# array(['BENIGN_calcification', 'BENIGN_mass', 'MALIGNANT_calcification',
#        'MALIGNANT_mass', 'NORMAL'], dtype='<U23')

# %%
# convert to TF records files
test_filename = os.path.join('data','test.tfrecords')

# open the TFRecords file
writer = tf.python_io.TFRecordWriter(test_filename)

# encode the labels
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

le.fit(all_labels)
classes = le.classes_

# write training data
i = 4
# load the data and label files
images = np.load(os.path.join("data", "images_" + str(i) + ".npy"))
labels = np.load(os.path.join("data", "labels_" + str(i) + ".npy"))
labels = le.transform(labels)

for j in range(images.shape[0]):
    label_main = labels[j]
    
    # label as normal or abnormal
    label_normal = 1
    if label_main == 4:
        label_normal = 0

    # label as benign, malignant or normal
    label_pathology = 0
    if (label_main == 0) or (label_main == 1):
        label_pathology = 1
    elif (label_main == 2) or (label_main == 3):
        label_pathology = 2

    # label as normal, calcification or mass
    label_type = 0
    if (label_main == 0) or (label_main == 2):
        label_type = 1
    elif (label_main == 1) or (label_main == 3):
        label_type = 2
    
    img = images[j]

    img_raw = img.tostring()

    feature = {'label_class': _int64_feature(label_main),
                   'label_normal': _int64_feature(label_normal),
                   'label_pathology': _int64_feature(label_pathology),
                   'label_type': _int64_feature(label_type),
                   'image': _bytes_feature(img_raw)}

    # Create an example protocol buffer
    example = tf.train.Example(features=tf.train.Features(feature=feature))

    # Serialize to string and write on the file
    writer.write(example.SerializeToString())

writer.close()

# %%
# save the classes
np.save(os.path.join("data", "classes.npy"), classes)

# %%
record_iterator = tf.python_io.tf_record_iterator(path=train_filename)

for string_record in record_iterator:
    example = tf.train.Example()
    example.ParseFromString(string_record)
    
    img_string = (example.features.feature['image']
                                  .bytes_list
                                  .value[0])
    
    img_1d = np.fromstring(img_string, dtype=np.uint8)
    
    reconstructed_img = (img_1d * 255) + 128
    reconstructed_img = img_1d.reshape((-1, 299, 299, 1))
    
    
    plt.imshow(reconstructed_img[0])
    plt.show()
    break
# Out:
# (715208,)
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-3997ee3d8bb1> in <module>()
#      14     reconstructed_img = (reconstructed_img * 255) + 128
#      15
# ---> 16     plt.imshow(reconstructed_img[0])
#      17     plt.show()
#      18     break
#
# ~\Anaconda2\envs\exts-aml2\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3155                         filternorm=filternorm, filterrad=filterrad,
# ...

# %%
record_iterator
# Out:
# <generator object tf_record_iterator at 0x000002E100FD1990>
