# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import re
from glob import glob
import pandas as pd
# Out:
# C:\Users\eric\Anaconda2\envs\exts-aml2\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Read in PGM Data

# %%
def read_pgm(filename, byteorder='>'):
    """Return image data from a raw PGM file as numpy array.
    Format specification: http://netpbm.sourceforge.net/doc/pgm.html
    """
    with open(filename, 'rb') as f:
        buffer = f.read()
    try:
        header, width, height, maxval = re.search(
            b"(^P5\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n]\s)*)", buffer).groups()
    except AttributeError:
        raise ValueError("Not a raw PGM file: '%s'" % filename)
    return np.frombuffer(buffer,
                            dtype='u1' if int(maxval) < 256 else byteorder+'u2',
                            count=int(width)*int(height),
                            offset=len(header)
                            ).reshape((int(height), int(width)))

# %%
# read all pgms in
files = glob('data/pgms/*.pgm')
data = []

for file in files:
    data.append(read_pgm(file) * 1.0)

images = np.array(data)

# %%
# save the images to an npy file for ease of future use
np.save('./images.npy', images)

# %% [markdown]
# ## Look at some images

# %%
# this should be the right hand image for patient 1
plt.imshow(read_pgm(glob('data/pgms/*.pgm')[0]))

# %%
# this should be the left hand image for patient 1
plt.imshow(read_pgm(glob('data/pgms/*.pgm')[1]))

# %% [markdown]
# ## Annotation Data

# %%
# code from existing kaggle kernel
all_cases_df = pd.read_table('data/Info.txt', delimiter=' ')
all_cases_df = all_cases_df[all_cases_df.columns[:-1]] # drop last column
all_cases_df['path'] = all_cases_df['REFNUM'].map(lambda x: '%s.pgm' % x)
all_cases_df.head(10)
# Out:
#    REFNUM BG CLASS SEVERITY      X      Y  RADIUS        path
# 0  mdb001  G  CIRC        B  535.0  425.0   197.0  mdb001.pgm
# 1  mdb002  G  CIRC        B  522.0  280.0    69.0  mdb002.pgm
# 2  mdb003  D  NORM      NaN    NaN    NaN     NaN  mdb003.pgm
# 3  mdb004  D  NORM      NaN    NaN    NaN     NaN  mdb004.pgm
# 4  mdb005  F  CIRC        B  477.0  133.0    30.0  mdb005.pgm
# 5  mdb005  F  CIRC        B  500.0  168.0    26.0  mdb005.pgm
# 6  mdb006  F  NORM      NaN    NaN    NaN     NaN  mdb006.pgm
# 7  mdb007  G  NORM      NaN    NaN    NaN     NaN  mdb007.pgm
# 8  mdb008  G  NORM      NaN    NaN    NaN     NaN  mdb008.pgm
# 9  mdb009  F  NORM      NaN    NaN    NaN     NaN  mdb009.pgm

# %%
## Clean up the data.
# Some images have multiple abnormalities, this makes the sizes of the label and images not match. There are 322 images but 330 
# labels. To solve this we will need to use the refnum to collapse the labels, hopefully we won't have any images which are 
# classified as both normal and abnormal.

# Let's drop the duplicate rows
all_cases_df.drop_duplicates(subset=['REFNUM'], keep='first', inplace=True)

# reindex it
all_cases_df.reset_index(inplace=True)
all_cases_df.shape
# Out:
# (322, 9)

# %%
# the data is the right shape now, save it to an npy
annotations = all_cases_df
np.save('./annotations.npy', annotations)

# %%
# percentages by class
all_cases_df['CLASS'].value_counts(normalize=True)
# Out:
# NORM    0.642857
# CALC    0.077640
# CIRC    0.071429
# ARCH    0.059006
# SPIC    0.059006
# ASYM    0.046584
# MISC    0.043478
# Name: CLASS, dtype: float64

# %%
# percentages by type
all_cases_df['SEVERITY'].value_counts(normalize=True)
# Out:
# B    0.556522
# M    0.443478
# Name: SEVERITY, dtype: float64

# %%
# info on the size of the abnormalities
print("Mean abnormality radius:",np.mean(all_cases_df.RADIUS))
print("Min abnormality radius:",np.min(all_cases_df.RADIUS))
print("Max abnormality radius:",np.max(all_cases_df.RADIUS))
# Out:
# Mean abnormality radius: 50.57657657657658
# Min abnormality radius: 3.0
# Max abnormality radius: 197.0

# %% [markdown]
# ## Look at scans of various classes

# %%
sample_count = 3
fig, m_axs = plt.subplots(len(all_cases_df['CLASS'].value_counts()), 3, figsize = (12, 20))
for c_axs, (c_cat, c_df) in zip(m_axs, all_cases_df.groupby('CLASS')):
    for c_ax, (_, c_row) in zip(c_axs, c_df.sample(sample_count).iterrows()):
        c_ax.imshow(read_pgm('data/pgms/' + c_row['path']), cmap = 'bone')
        c_ax.axis('off')
        c_ax.set_title('{CLASS}-{SEVERITY}'.format(**c_row))

# %% [markdown]
# ## Scans

# %%
# import the data
with h5py.File('data/all_mias_scans.h5') as scan_h5:
    bg_info = scan_h5['BG'][:]
    class_info = scan_h5['CLASS'][:]
    # low res scans
    scan_lr = scan_h5['scan'][:][:, ::16, ::16]
# Out:
# KeysView(<HDF5 file "all_mias_scans.h5" (mode r)>)

# %%
# flatten vectors
scan_lr_flat = scan_lr.reshape((scan_lr.shape[0], -1))

# %%
# process the labels into usable labels
from sklearn.preprocessing import LabelEncoder
class_le = LabelEncoder()
class_le.fit(class_info)
class_vec = class_le.transform(class_info)

# %%
class_le.classes_
# Out:
# array([b'ARCH', b'ASYM', b'CALC', b'CIRC', b'MISC', b'NORM', b'SPIC'],
#       dtype='|S4')

# %%
# look at a low res scan
plt.imshow(scan_lr[0], cmap = 'bone')

# %%
class_vec.shape
# Out:
# (330,)
